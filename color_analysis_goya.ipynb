# %%
import cv2
import os
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from pprint import pprint
import pandas as pd
from sklearn.mixture import GaussianMixture
from sklearn.mixture import BayesianGaussianMixture
# from sklearn.cluster import DBSCAN
from sklearn.cluster import KMeans
from collections import Counter
from skimage import color as scolor
from PIL import Image
from datetime import datetime
from dotenv import load_dotenv

# %%
load_dotenv()
folder_path = os.getenv('path_goya_pics')
df_lines_circles = os.getenv('path_lines_dataset_goya')
# folder_path = './data/paintings'
# folder_path

# %%
files = os.listdir(folder_path)
target_files = []
for f in files:
    if ('.jpg' in f) or ('.jpeg' in f):
        target_files.append(os.path.join(folder_path, f))

print('Количество картин в датасете:', len(target_files))
# Out:
# Количество картин в датасете: 243

# %% [markdown]
# ### Смотрим, сколько картин художник написал за каждый год жизни

# %%
dates = []
for i in target_files:
    date = i.split('/')[-1].split('_')[0]
    dates.append(date)

# %%
from collections import Counter

year_counts = dict(Counter(dates))
del year_counts['yyyy']

# %%
df = pd.DataFrame(dates, columns=['year'])
df.shape
# Out:
# (243, 1)

# %%
df['unknown'] = df.year.apply(lambda x: True if x == 'yyyy' else False)
df.unknown.value_counts()
# Out:
# unknown
# False    240
# True       3
# Name: count, dtype: int64

# %%
result = df.groupby('year', as_index=False).agg({'unknown': 'count'}).rename(columns={'unknown': 'count'})

# %%
mask = df[df.unknown == False].year.to_list()
mask.sort()
# mask

# %%
mask.extend(['yyyy' for _ in range(4)])
len(mask)
# Out:
# 244

# %%
sns.set_theme(style="white")

# %%
plt.rcParams['font.family'] = 'serif'
plt.rcParams['font.serif'] = ['Times New Roman']

plt.figure(figsize=(15, 8))

color_hex = '#{:02x}{:02x}{:02x}'.format(102, 118, 146)
bar_plot = sns.barplot(data=result, x='year', y='count', color=color_hex, order=mask)

plt.title('Распределение картин по годам', fontdict={'fontsize': 16, 'fontweight': 'bold'})
plt.xlabel('Год', fontdict={'fontsize': 12})
plt.ylabel('Количество картин', fontdict={'fontsize': 12})
plt.xticks(rotation=45)


for p in bar_plot.patches:
    bar_plot.annotate(format(int(p.get_height())), 
                        (p.get_x() + p.get_width() / 2., p.get_height()), 
                        ha='center', va='bottom', fontsize=10, color='black', 
                        xytext=(0, 5), textcoords='offset points')

plt.show()

# %%
df_counts = pd.DataFrame(year_counts.items(), columns=['year', 'count'])
df_counts.head()
# Out:
#    year  count
# 0  1799      5
# 1  1775      4
# 2  1812     13
# 3  1787      6
# 4  1814     11

# %% [markdown]
# ### Смотрим 7 самых часто встречающихся диапазонов цветов на всех картинках

# %%
def rgb_to_lab(rgb_array):

    rgb_array = rgb_array / 255.0  # normalizing RGB
    lab_array = scolor.rgb2lab(rgb_array)
    
    return lab_array

# %%
def get_pixels_from_folder(folder_path, rgb_lab):

    all_pixels = []

    for filename in os.listdir(folder_path):
        if filename.lower().endswith(('.png', '.jpg', '.jpeg')):
            image_path = os.path.join(folder_path, filename)
            try:
                img = Image.open(image_path).convert('RGB')
                img = img.resize((128, 128))
                pixels = np.array(img)
                all_pixels.append(pixels.reshape(-1, 3))

            except Exception as e:
                print(f"Can't open {filename}: {e}")

    # combine all pixels into one vector
    if all_pixels:
        rgb_vector = np.vstack(all_pixels) 
        if rgb_lab == 'RGB':
            return rgb_vector
        elif rgb_lab == 'LAB':
            lab_vector = rgb_to_lab(rgb_vector)
            return lab_vector
    else:
        return np.array([])

# %%
# finding the n most common color ranges in the !RGB vector! and sort them by frequency
def find_most_common_colors(vector, rgb_lab, classifier_type, n_colors=7):
    
    if vector.size == 0:
        print("Vector is empty")
        return []

    if classifier_type == 'KMeans':
        results_cluster = KMeans(n_clusters=n_colors)
        results_cluster.fit(vector)
        colors = results_cluster.cluster_centers_
    elif classifier_type == 'GM':
        results_cluster = GaussianMixture(n_components=n_colors, random_state=42)
        results_cluster.fit(vector)
        colors = results_cluster.means_
        labels = results_cluster.predict(vector) # 'GaussianMixture' object has no attribute 'labels_'
    elif classifier_type == 'GMM':
        gmm = BayesianGaussianMixture(n_components=n_colors, random_state=42)
        gmm.fit(vector)
        colors = gmm.means_
        labels = gmm.predict(vector)
        
        
    # colors = results_cluster.cluster_centers_
    
    if rgb_lab == 'LAB':
        rgb_colors = scolor.lab2rgb(colors.reshape(1, -1, 3)).reshape(-1, 3) * 255 # LAB to RGB
    elif rgb_lab == 'RGB':
        rgb_colors = colors        
    rgb_colors = np.clip(rgb_colors, 0, 255).astype(int)

    # counting pixels of each cluster by color
    if classifier_type == 'KMeans':
        labels = results_cluster.labels_
        label_counts = Counter(labels)
    elif classifier_type == 'GM':
        label_counts = Counter(labels)
    elif classifier_type == 'GMM':
        # labels = gmm.predict(lab_vector)
        label_counts = Counter(labels)

    sorted_colors = sorted(label_counts.items(), key=lambda x: x[1], reverse=True)
    sorted_rgb_colors = rgb_colors[[color[0] for color in sorted_colors]]

    return sorted_rgb_colors

# %%
def plot_colors(colors):
    plt.figure(figsize=(15, 6))
    plt.imshow([colors], aspect='auto')
    
    for i, color in enumerate(colors):
        plt.text(i, 0, str(i+1), ha='center', va='center', fontsize=20, color='white')
    
    plt.axis('off')
    plt.show()

# %% [markdown]
# ##### Без перевода из RGB в Lab с помощью KMeans:

# %%
pixels_vector = get_pixels_from_folder(folder_path, rgb_lab='RGB')

# %%
most_common_colors_nolab = find_most_common_colors(pixels_vector, rgb_lab='RGB', classifier_type='KMeans', n_colors=7)

# %%
most_common_colors_nolab
# Out:
# array([[ 52,  43,  35],
#        [ 19,  16,  15],
#        [ 91,  75,  58],
#        [172, 163, 140],
#        [146, 109,  70],
#        [118, 124, 117],
#        [213, 208, 191]])

# %%
print("Семь самых распространенных цветов (RGB):")
c = 1
for i in most_common_colors_nolab:
    print(f'Цвет {c}: {i}')
    c += 1

plot_colors(most_common_colors_nolab)
# Out:
# Семь самых распространенных цветов (RGB):
# Цвет 1: [52 43 35]
# Цвет 2: [19 16 15]
# Цвет 3: [91 75 58]
# Цвет 4: [172 163 140]
# Цвет 5: [146 109  70]
# Цвет 6: [118 124 117]
# Цвет 7: [213 208 191]

# %% [markdown]
# ##### С переводом из RGB в LAB с помощью KMeans:

# %%
pixels_vector = get_pixels_from_folder(folder_path, rgb_lab='LAB')

# %%
most_common_colors = find_most_common_colors(pixels_vector, rgb_lab='LAB', classifier_type='KMeans', n_colors=7)

# %%
print("Семь самых распространенных цветов (RGB -> LAB -> RGB):")
c = 1
for i in most_common_colors:
    print(f'Цвет {c}: {i}')
    c += 1

plot_colors(most_common_colors)
# Out:
# Семь самых распространенных цветов (RGB -> LAB -> RGB):
# Цвет 1: [24 21 20]
# Цвет 2: [58 49 40]
# Цвет 3: [98 86 65]
# Цвет 4: [127 135 134]
# Цвет 5: [164 137  91]
# Цвет 6: [201 194 176]
# Цвет 7: [130  69  42]

# %% [markdown]
# ##### С переводом из RGB в LAB с помощью GaussianMixture:

# %%
most_common_colors_gauss = find_most_common_colors(pixels_vector, rgb_lab='LAB', classifier_type='GM', n_colors=7)

# %%
print("Семь самых распространенных цветов (RGB):")
c = 1
for i in most_common_colors_gauss:
    print(f'Цвет {c}: {i}')
    c += 1

plot_colors(most_common_colors_gauss)
# Out:
# Семь самых распространенных цветов (RGB):
# Цвет 1: [43 37 31]
# Цвет 2: [91 79 63]
# Цвет 3: [16 15 14]
# Цвет 4: [187 177 158]
# Цвет 5: [135 139 133]
# Цвет 6: [144 121  84]
# Цвет 7: [97 54 38]

# %% [markdown]
# ##### С переводом из RGB в LAB с помощью BayesianGaussianMixture:

# %%
most_common_colors_gaussbayes = find_most_common_colors(pixels_vector, rgb_lab='LAB', classifier_type='GMM', n_colors=7)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/mixture/_base.py:269: ConvergenceWarning: Best performing initialization did not converge. Try different init parameters, or increase max_iter, tol, or check for degenerate data.
#   warnings.warn(

# %%
print("Семь самых распространенных цветов (RGB):")
c = 1
for i in most_common_colors_gaussbayes:
    print(f'Цвет {c}: {i}')
    c += 1

plot_colors(most_common_colors_gaussbayes)
# Out:
# Семь самых распространенных цветов (RGB):
# Цвет 1: [57 47 38]
# Цвет 2: [29 27 24]
# Цвет 3: [144 139 127]
# Цвет 4: [119  97  71]
# Цвет 5: [8 8 7]
# Цвет 6: [159 155 133]
# Цвет 7: [103  56  37]

# %% [markdown]
# ### Смотрим, как часто эти цвета встречаются по годам

# %%
def sum_pixels_by_year(results, years):

    summed_results = {color: [] for color in results.keys()}
    unique_years = sorted(list(set(years)))

    for year in unique_years:
        indices = [i for i, y in enumerate(years) if y == year]
        for color in results.keys():
            summed_value = np.sum([results[color][i] for i in indices])
            summed_results[color].append(summed_value)

    return summed_results, unique_years

def min_max_normalization(data):
    min_val = min(data)
    max_val = max(data)
    return [(x - min_val) / (max_val - min_val) for x in data]

def count_pixels_in_range(image_path, color, tolerance=20):
    img = Image.open(image_path).convert('RGB')
    img = img.resize((128, 128))
    img_array = np.array(img)

    # defining the boundaries for each channel
    lower_bound = np.array(color) - tolerance
    upper_bound = np.array(color) + tolerance

    # mask for pixels falling within the range
    mask = np.all((img_array >= lower_bound) & (img_array <= upper_bound), axis=-1)

    return np.sum(mask)  # number of pixels corresponding to color

def extract_date_from_filename(filename):
    try:
        year, month, day = map(int, filename.split('_')[:3])
        return datetime(year, month, day)
    except (IndexError, ValueError):
        return None
    
def extract_year_from_filename(filename):
    try:
        year = int(filename.split('_')[0])
        return year
    except (IndexError, ValueError):
        return None 
    
def analyze_most_popular_ever_colors(folder_path, colors):

    results = {tuple(color): [] for color in colors}
    years = []
    files = []

    for filename in sorted(os.listdir(folder_path)):
        if filename.lower().endswith(('.png', '.jpg', '.jpeg', '.bmp', '.gif')):
            # files.append(filename)
            image_path = os.path.join(folder_path, filename)
            
            year = extract_year_from_filename(filename)
            if year is None:
                continue
            years.append(year)
            files.append(filename)

            pixel_counts = []
            for color in colors:
                count = count_pixels_in_range(image_path, color, tolerance=20)
                pixel_counts.append(count)

            for i, color in enumerate(colors):
                results[tuple(color)].append(pixel_counts[i])

    # converting the results into a numpy array for sorting
    years = np.array(years)
    for color in results:
        results[color] = np.array(results[color])

    # sorting by year
    sorted_indices = np.argsort(years)
    years = years[sorted_indices]
    for color in results:
        results[color] = results[color][sorted_indices]

    return results, years, files

# %%
def plot_bar_distribution(results, years, model_name):
    
    results, years = sum_pixels_by_year(results, years)

    colors = list(results.keys())
    counts = np.array(list(results.values()))

    year_pixel_counts = {year: np.zeros(len(colors)) for year in years}

    # sum pixels by year
    for i, year in enumerate(years):
        for j, color in enumerate(colors):
            year_pixel_counts[year][j] += counts[j][i]

    # converting the data into an array to build a graph
    summed_counts = np.array(list(year_pixel_counts.values()))
    summed_counts = summed_counts / summed_counts.sum(axis=1, keepdims=True)

    # convert colors to format for matplotlib (from 0 to 1)
    color_palette = [(r/255, g/255, b/255) for r, g, b in colors]

    sns.set_theme(style="white")
    
    plt.rcParams['font.family'] = 'serif'
    plt.rcParams['font.serif'] = ['Times New Roman']
    
    plt.figure(figsize=(15, 10))

    bottom = np.zeros(len(years))
    for i, color in enumerate(colors):
        plt.bar(range(len(years)), summed_counts[:, i], bottom=bottom, color=color_palette[i], label=f'Color {color}')
        bottom += summed_counts[:, i]  # update the lower limit for accumulation

    plt.title(f'Распределение 7 самых часто встречающихся цветов по годам ({model_name})', fontdict={'fontsize': 16, 'fontweight': 'bold'})
    plt.xlabel('Год', fontdict={'fontsize': 12})
    plt.ylabel('Количество пикселей (нормализованное)', fontdict={'fontsize': 12})
    plt.xticks(ticks=range(len(years)), labels=years, rotation=45)
    plt.show()

# %% [markdown]
# #### KMeans:

# %%
results, years, files = analyze_most_popular_ever_colors(folder_path, np.array(most_common_colors))

# %%
plot_bar_distribution(results, years, model_name='KMeans')

# %%
from pprint import pprint

pprint(results)
# Out:
# {(36, 35, 39): array([4176, 5327,  252, 6388, 5862, 2627, 1317, 1811, 1190,  520, 4914,
#         983, 1291, 2738, 3411, 3474,  961, 5304, 1058,   23, 1357,  175,
#        1063, 1191, 6181, 6676,  200, 1295, 4430, 4405, 2730, 3231,   52,
#        1114, 6089, 5393,    9, 5296, 2052, 1742, 2104, 1645, 2789, 2263,
#         769, 3340,  340, 3438,    5, 2154, 2344, 4371, 1434, 1266,  300,
#         218, 5565, 5422, 2357, 6088, 1142, 2779, 2884, 2751,  590, 8034,
#        4015, 2967, 3934,  964, 1792,  309,   12,  633,  904, 4790,  877,
#        5103, 2574,  991, 5499, 1300, 1126, 3075,  557, 4041, 6543, 8137,
#        4510, 6195, 4586, 1088, 5990, 1092, 4730,  695, 3304, 4185, 3707,
#        7420, 2045, 3307, 4149, 6222, 6997,  102, 3534,  326, 2605, 5572,
#         283, 2512, 1723, 1373, 2138,  330, 8528,  820, 2769, 1991, 2531,
#        1695, 1242, 2190, 1226, 1639, 1322, 3739, 1315, 1187,  455,  215,
#        3188, 4959, 4921, 3022, 5127, 4329, 4286, 2600,  940,  441,  657,
#        3934, 3322, 1678, 4534, 1910, 1082, 1853, 5756, 2160, 1065, 1124,
#          34, 1095, 1481, 2081, 1624, 3365,    7, 2731,  801, 4323,  723,
#         605, 2221, 1038, 1622, 3193,  203,  505, 2498, 4321, 1716,   59,
#        2668,  748, 3176,  446,  421,  250,  348, 4803,  805,  847, 2433,
#        2848,  814, 4186,  838, 1729, 3128,  905, 4124,  173, 2758, 1267,
#        3973,  349, 3465, 2520,   72, 2313, 1294, 3840, 2937,  765, 1427,
#        3380, 1578,  549,    6, 2093, 2938,  658, 1282]),
#  (76, 70, 60): array([2518, 1460,  884, 3420, 1731, 2598, 1269, 2166,  902,  587,  853,
#        1305,   87, 2283, 2094, 2271,  611, 3567,  395, 3094,  842,  209,
#        1708, 1393, 2964, 1689, 6740, 2000, 4645,  734, 2609,  448,  496,
#        5782, 1896, 2105, 7474, 2129,  764,  511, 1448,  154, 1416,  223,
#         230, 5968, 2314, 4300, 1334, 3644, 4868,  188, 1353, 1505,  664,
#        1542, 1707, 5834,  200, 1041, 2368, 6111, 3007,  742,  596, 2949,
#         100,  644, 1971,  421, 1113,  262,  556,   68, 3146, 2011,  554,
#        1943, 1272,  731, 1475,  606, 1305, 1613, 1082,  977,  525, 1560,
#         738,  814,  285,  748,  912,  656,   64,  312, 1992, 1089,  743,
#        1528, 3374, 1778,  670, 2190, 1750,  804, 1374, 2825,  751, 1105,
#        1513, 1619, 1694,  836, 1619,  696,  894,  352,  834, 1377,  897,
#        1476, 2792, 1614, 1846, 1091, 1031, 1532,  909, 1296,  781, 1213,
#         983,  943,  989, 1295,  300, 1938, 1219, 1089,  302,  218, 1832,
#         567,   92, 2303, 1466,  530,  215, 1703, 1644,  905,  884,  319,
#         106,  222, 1132, 2589,  676, 1312,  848, 1161, 1580, 1435, 2396,
#        1238, 1031,  190, 2298, 1212,  241, 1052,  891, 4278, 1268,  849,
#        2409,  654,  411,  244,   55, 1550,  814, 3857,  599, 1077,  812,
#         581,  601,  668,  472, 1204,  717,  477, 4396, 1882,  737, 1356,
#        1024, 1110,  512, 2686,   54, 1426,  835, 1162, 2013,  338,  377,
#         887,  912,  353, 2338, 1781, 1773, 1856,  732]),
#  (100, 117, 145): array([   0,    0,    0,   22,   10,    1,   42,    3,  362,  154,  535,
#        1444,    0,  163,  783,    0,  953,    0,   11,    3,  100,  231,
#          12,   24,    0,    0,    3,    0,    7,    2,    0,  330, 1997,
#           2,    0,  131,    0,  135,  115,    0, 1333, 2269,  204, 2378,
#          55,    7,  102,    1,    0,    0,    4,    5,    0, 1106,    0,
#         299,    0,    0,  360,    0,   96,   34,    3,   40,    0,    2,
#           0,   19,    5,   94,   24,   11,  209, 1064,    0,    0,   44,
#         329,  798,    0,  279,  158,    7,  802, 1497,   89,  128,   59,
#          68,  166, 1478,  318,   41,  384,  644,  165,  224,   56, 1674,
#         228,   65,    6,    0,  137,    5, 1209,    2,  128,   70,  181,
#         169,  133,  154,   67,    0,  119,    0,    0,  142,  528,    4,
#         129,    8,  216,   86,   22,    8,   17,   85,   43,  962,  117,
#         256,    0,    0,  179,  344,   92,  263,   14,    0,  689, 1733,
#         824,   30, 3756,  766,   17,  748,  179,    0,    0,   15,  274,
#         972,   85,  175,  755,  114,  150,    3,    2,    0,  226,  482,
#         626,  195,  470,   20,  267,   73,  602,  936,    0,   80,  686,
#         540,   37,  415,  353,    1,  153,  132,   53,   38,   86,   24,
#         253,   39,    0,  468,  265,  943, 1022,  179,   15,  453,  192,
#         424,   60,  662,    0,  765,  526,   97,  104,    0,   79,  240,
#         321,   13,  255,   10,  112,  133,  122,   29]),
#  (135, 123, 95): array([ 379,  423, 2527,  407,  948,  990, 1126, 2026,  603,  750,  138,
#        1221,  115,  772,  446,   53, 1734, 2305,  226, 3057,  633,  132,
#         921,  673,  612,  233,  971,  158,  912,  557,  279,   54,  693,
#         277,   14,  128, 2427,  123,  301,  382,  118,  137,  608,   30,
#          49,  279, 3062, 1406,  963,  238,  485,  133, 2477,  757,  111,
#         824,  416,   31,  157,    6, 1331,   94,  704,  164, 1430,  129,
#          47,  124,  310,  188,  820,  164,  352,   25,  898,  135,  535,
#         475,  267,  265,  623,  510,  531,  277,  284,  155,  188,  104,
#         195,   60,    3,  515,  501,  851,    6,  489, 1735, 1991, 2017,
#         134,  556, 1503,   86,  427,  147, 1301,  152,  749,  243,  122,
#         501,  160,  859,  535,   53,  714,  321,  405,  261,  587,  124,
#         432, 1380, 1043, 2608,  208, 1063, 1248,  510, 1147,  379, 2780,
#         306,   36,   40,  696,   26,  916,  354,  277,  174,  193,  517,
#         119,  111,  636,   50,  271,  194,  259,  590,  153, 1399,  329,
#         665,   22,  458,  425,  354,  369, 5490,  398,  696,  843,  951,
#         212,  371,  573, 1165,  218,  923,  891,  376,  436,  254,  940,
#        1032,  471,  119,  970,   62,  460, 1648,  136,  332,  814,  565,
#         309,  334,  351,  581,  406,  108,  239,  462, 1330,  429,  200,
#         230,  977,   85, 1127,  116,  486, 1067,  455,  643,  262,  368,
#         451,  819,  253, 3254,  589,  711,  921,  473]),
#  (153, 80, 50): array([   0,    5,  189,   49,  126,  502,    1,  120,    1,   62,   16,
#           4,  155,    1,  566, 2298,   13,   15,  406, 1599,   63,   21,
#        1009,  634,    6,  486,  262,  892,   60,  250,  878,   87,    9,
#         973,  294,    0,    0,    0,  366,    0,   59,  104,  402,    0,
#         301,    9,  164,  180, 1622,  297,   54,  635,  604,   11, 2759,
#         839,  223,  182,   66,  744,  195,    0,   29,  310,  162,  293,
#         306,  542,  208,  560,  389,  420,  388,  290,  622,  224,    7,
#           8,  342,  153,    0,  288,  240,  934,  126,   14,  123,    9,
#           0,   35,    0,    1,   54,  249,    0,   13,    0,   89,   84,
#           0,  253,  460,   59,   34,  344,  164,  271,  479,  358,   40,
#         370,  680,  547,   64, 1583,  108,    1, 1512,  162,  226,  454,
#         256,  452,   71,  163,  239,  174,   88,  136,  109,  433,  257,
#          96, 1696, 1761,   23,    1,  306,  111,  682,   30,  307,   97,
#        2268,   45,   10,   30,  207,  202,  197,  577,  302,  331,  101,
#          10,  223,  499,   48,   82,  228,  630,  290,   15,  139,   41,
#         110,  121,  128, 1068,   63,  179, 1298,    1,    0,  734,   23,
#          31,  152,   49,  126,   32,   91,   81,  377,  318,  373,  366,
#         195,  324,  292,  295,  652,    4,   50,   99, 1163,   21,   80,
#         102,  144,   77,  449,   37,  162,  715,  489,  575,  661,  188,
#         294,  175,  419,  192,  139,  273,  211,  367]),
#  (197, 189, 178): array([  95,  174,  463,  602,  254,   22,  430,  933,    4, 1939,  115,
#         195,    2,  481,   17,   85,  163,  274, 1563,    0, 1062, 1193,
#          88,  114,    6,    0,  509,    8,  224,  370,  656,  102,   57,
#        1937,    6,   61,  389,   63,  139,  385,  367,  106,  548,   14,
#           6,  222,    0,  146,  139,    2,  316,    9,    0, 1301,    0,
#          15,    0,    0,   32,    0,    0,  399,    2, 1173,   46,    0,
#           1,   32,  532,  593, 2270,  628,  152,  108,    3,    1, 2754,
#         494,  444,    6, 1248,  438,  994,  269,  106, 2368,   83,   64,
#        1125,  317,    0, 6204, 1232,  461,  124, 1874,  211,  365,  326,
#        1191,  298,   26,    0,    2,   40,  734,  468,  191, 1531,   96,
#        1160,  138,  247, 2777,    2,  777,  116,  421, 2341,  854,    0,
#         628,  524,  651,   75,    9, 3588,  255, 1782, 1333,   10, 1372,
#         529,    0,    0, 1467,  866,   94,  741,  134,    1,  190,  794,
#         402,   37,   91,  297,  164, 3887, 2763,  236,   83,  126,  422,
#         140,    5, 1239,  758,  645,  282,   28,  350,    0,  443,  728,
#        1696,  688, 2519,    0, 1898,  276,  197, 1138,  226,  707, 1060,
#         930, 4945,  836,  610,  677, 3445, 1981,    0,  303,  975,  258,
#        1089,  302, 1800,  386,  557,  142, 1166,   64, 1254,  658, 1416,
#         306,  441,  885,    1,  402, 1261,  988, 1239,  327,  585, 1673,
#         239,  885,  236,  413,  574, 1092,   23,  674]),
#  (198, 159, 84): array([   5,    2,   68,   29,   30, 1049,  143,   42,    9,  214,  141,
#         156,    5,  117,  106,  154,    3,   83,   10,    8,    0,    0,
#         957,   64,  245,  742,  378,  429,    6,    2,  132,   38,  523,
#           0,    0,    1,    0,    1,   20,    0,   23,   44,  184,    5,
#          28,    2,    0,   14, 2510,    0,   79,   51,    0,    0,  340,
#         278, 1126,    0,  352,  244,  747,    0,   47,   52,  442,    4,
#         117,  139,    5,  316,    8,  831, 1800,   64,  820,  329,    3,
#          18,  102,  481,   28,  299,   34,    0,    2,  163,   91,    1,
#           0,   10,    0,    0,   12,  142,    0,  309,    0,   47,   13,
#           0,   15,  495,  338,    0,   96,  847,  269,   53,  262,   12,
#          79,  623,  248,  265,   20,  429,  391,  320,   81,  101,  746,
#         337,  144,  395,  120,    2,  203,  201,  556,  287,  683,   35,
#         377,  412,  426,   59,    0,   22,   19,   39,   24,  165,  217,
#          22,    4,    8,    4,   16,   40,    4,    3,  171,  689,  229,
#         107,    2,  330,   13,   46,  851,  331,  846, 1811,   18,   16,
#         177,  430,   54, 1367,   40,  107,  537,    9,    0,   22,  264,
#          19,  121,   13,  594,  125,   82,  255,  728,  135,  170, 1411,
#         218,  135,   29,  638,  568,   18,   29,  240,   33,   93,  361,
#         298,  410,   23,  307,   50,   31,  252,  272,  275,   40,  261,
#         425,   42,  378,  234,  366,  238,  102,  425])}

# %%
df_KMeans = pd.DataFrame.from_dict(results, orient='index', columns=years)
df_KMeans = df_KMeans.T
df_KMeans = df_KMeans.reset_index().rename(columns={'index': 'year'})

# %%
df_KMeans = df_KMeans.groupby('year', as_index=False).sum()

# %%
df_KMeans.head()
# Out:
#    year  (36, 35, 39)  (76, 70, 60)  (197, 189, 178)  (135, 123, 95)  \
# 0  1882          9503          3978              269             802
# 1  1883           252           884              463            2527
# 2  1885          6388          3420              602             407
# 3  1886          5862          1731              254             948
# 4  1888          2627          2598               22             990
#
#    (100, 117, 145)  (153, 80, 50)  (198, 159, 84)
# 0                0              5               7
# 1                0            189              68
# 2               22             49              29
# 3               10            126              30
# 4                1            502            1049

# %% [markdown]
# #### GaussianMixture:

# %%
results_GM, years, files = analyze_most_popular_ever_colors(folder_path, np.array(most_common_colors_gauss))

# %%
plot_bar_distribution(results_GM, years, model_name='GaussianMixture')

# %%
df_GM = pd.DataFrame.from_dict(results_GM, orient='index', columns=years)
df_GM = df_GM.T
df_GM = df_GM.reset_index().rename(columns={'index': 'year'})
df_GM = df_GM.groupby('year', as_index=False).sum()
df_GM.head()
# Out:
#    year  (43, 37, 31)  (91, 79, 63)  (16, 15, 14)  (187, 177, 158)  \
# 0  1771         27001          5613         24229              678
# 1  1772         11089          2464          4784                0
# 2  1774          3994           798           586              451
# 3  1775          9032          5565          2260             2369
# 4  1776          1140          1657             0             1734
#
#    (135, 139, 133)  (144, 121, 84)  (97, 54, 38)
# 0              884            1347          5954
# 1               38             184          4501
# 2               19             799          6692
# 3             1441            4847          3373
# 4             1460             681          1526

# %%
len(df_GM)
# Out:
# 51

# %%
len(files)
# Out:
# 245

# %%
len(results_GM)
# Out:
# 7

# %%
num = 1
sl = {}
for i in results_GM:
    print(results_GM[i][num])
    print(i)
# Out:
# 9265
# (43, 37, 31)
# 767
# (91, 79, 63)
# 4769
# (16, 15, 14)
# 94
# (187, 177, 158)
# 2
# (135, 139, 133)
# 243
# (144, 121, 84)
# 607
# (97, 54, 38)

# %%
for j in results_GM:
    print(results_GM[j][77])
# Out:
# 1869
# 5020
# 353
# 1441
# 1139
# 489
# 471

# %%
len(files)
# Out:
# 245

# %%
len(results_GM)
# Out:
# 7

# %%
n = 0

for j in results_GM:
    print(results_GM[j][n])
    n+=1
# Out:
# 5026
# 767
# 8957
# 0
# 878
# 5
# 1527

# %%
info_dict = {}

num = 0
for i in files:
    if (i.split('_')[0] != 'yyyy') and i != '.DS_Store':
        col = {}
        for j in results_GM:
            col[str(j)] = results_GM[j][num]
        info_dict[i] = {
            'path': i,
            'name_of_painting': ' '.join((i.split('_')[4:])).replace('.jpeg', ''),
            'year': i.split('_')[0],
            'most_common_colors_ever': col
        }
        num += 1

# %%
info_dict
# Out:
# {'1799_mm_dd_i_Тирана.jpeg': {'path': '1799_mm_dd_i_Тирана.jpeg',
#   'name_of_painting': 'Тирана',
#   'year': '1799',
#   'most_common_colors_ever': {'(43, 37, 31)': 5026,
#    '(91, 79, 63)': 0,
#    '(16, 15, 14)': 9495,
#    '(187, 177, 158)': 0,
#    '(135, 139, 133)': 0,
#    '(144, 121, 84)': 1,
#    '(97, 54, 38)': 683}},
#  '1775_mm_dd_i_Охота.jpeg': {'path': '1775_mm_dd_i_Охота.jpeg',
#   'name_of_painting': 'Охота',
#   'year': '1775',
#   'most_common_colors_ever': {'(43, 37, 31)': 9265,
#    '(91, 79, 63)': 767,
#    '(16, 15, 14)': 4769,
#    '(187, 177, 158)': 94,
#    '(135, 139, 133)': 2,
#    '(144, 121, 84)': 243,
#    '(97, 54, 38)': 607}},
#  '1812_mm_dd_i_Деревенская_коррида.jpeg': {'path': '1812_mm_dd_i_Деревенская_коррида.jpeg',
#   'name_of_painting': 'Деревенская коррида',
#   'year': '1812',
#   'most_common_colors_ever': {'(43, 37, 31)': 5111,
#    '(91, 79, 63)': 775,
#    '(16, 15, 14)': 8957,
#    '(187, 177, 158)': 0,
#    '(135, 139, 133)': 0,
#    '(144, 121, 84)': 147,
#    '(97, 54, 38)': 1180}},
#  '1787_mm_dd_i_Портрет_испанского_короля_Карла_III.jpeg': {'path': '1787_mm_dd_i_Портрет_испанского_короля_Карла_III.jpeg',
#   'name_of_painting': 'Портрет испанского короля Карла III',
#   'year': '1787',
#   'most_common_colors_ever': {'(43, 37, 31)': 5304,
#    '(91, 79, 63)': 1031,
#    '(16, 15, 14)': 791,
#    '(187, 177, 158)': 0,
#    '(135, 139, 133)': 4,
#    '(144, 121, 84)': 204,
#    '(97, 54, 38)': 2458}},
#  '1814_mm_dd_i_Махи_на_балконе.jpeg': {'path': '1814_mm_dd_i_Махи_на_балконе.jpeg',
#   'name_of_painting': 'Махи на балконе',
#   'year': '1814',
#   'most_common_colors_ever': {'(43, 37, 31)': 2295,
#    '(91, 79, 63)': 3040,
#    '(16, 15, 14)': 217,
#    '(187, 177, 158)': 584,
#    '(135, 139, 133)': 878,
#    '(144, 121, 84)': 752,
#    '(97, 54, 38)': 1026}},
#  '1795_mm_dd_i_Герцогиня_Альба_и_дуэнья_"Ла_Беата".jpeg': {'path': '1795_mm_dd_i_Герцогиня_Альба_и_дуэнья_"Ла_Беата".jpeg',
#   'name_of_painting': 'Герцогиня Альба и дуэнья "Ла Беата"',
#   'year': '1795',
#   'most_common_colors_ever': {'(43, 37, 31)': 1724,
#    '(91, 79, 63)': 11,
#    '(16, 15, 14)': 3603,
#    '(187, 177, 158)': 0,
#    '(135, 139, 133)': 0,
#    '(144, 121, 84)': 5,
#    '(97, 54, 38)': 2974}},
#  '1820_mm_dd_i_Портрет_Тибурсио_Переса-и-Куэрво.jpeg': {'path': '1820_mm_dd_i_Портрет_Тибурсио_Переса-и-Куэрво.jpeg',
#   'name_of_painting': 'Портрет Тибурсио Переса-и-Куэрво',
#   'year': '1820',
#   'most_common_colors_ever': {'(43, 37, 31)': 9365,
#    '(91, 79, 63)': 2453,
#    '(16, 15, 14)': 1181,
#    '(187, 177, 158)': 0,
#    '(135, 139, 133)': 38,
#    '(144, 121, 84)': 179,
#    '(97, 54, 38)': 1527}},
#  '1814_mm_dd_i_Жозефа_Байе_или_Леокадия_Вейс.jpeg': {'path': '1814_mm_dd_i_Жозефа_Байе_или_Леокадия_Вейс.jpeg',
#   'name_of_painting': 'Жозефа Байе или Леокадия Вейс',
#   'year': '1814',
#   'most_common_colors_ever': {'(43, 37, 31)': 754,
#    '(91, 79, 63)': 646,
#    '(16, 15, 14)': 51,
#    '(187, 177, 158)': 163,
#    '(135, 139, 133)': 18,
#    '(144, 121, 84)': 448,
#    '(97, 54, 38)': 2768}},
#  '1783_mm_dd_i_Хосе_Монино_Редондо,_граф_Флоридабланка.jpeg': {'path': '1783_mm_dd_i_Хосе_Монино_Редондо,_граф_Флоридабланка.jpeg',
#   'name_of_painting': 'Хосе Монино Редондо, граф Флоридабланка',
#   'year': '1783',
#   'most_common_colors_ever': {'(43, 37, 31)': 3240,
#    '(91, 79, 63)': 152,
#    '(16, 15, 14)': 535,
#    '(187, 177, 158)': 288,
#    '(135, 139, 133)': 1,
#    '(144, 121, 84)': 351,
#    '(97, 54, 38)': 3924}},
#  '1783_mm_dd_a_Автопортрет.jpeg': {'path': '1783_mm_dd_a_Автопортрет.jpeg',
#   'name_of_painting': 'Автопортрет',
#   'year': '1783',
#   'most_common_colors_ever': {'(43, 37, 31)': 2308,
#    '(91, 79, 63)': 2282,
#    '(16, 15, 14)': 3,
#    '(187, 177, 158)': 861,
#    '(135, 139, 133)': 93,
#    '(144, 121, 84)': 1530,
#    '(97, 54, 38)': 1455}},
#  '1806_mm_dd_i_Портрет_доньи_Антонии_Сарате.jpeg': {'path': '1806_mm_dd_i_Портрет_доньи_Антонии_Сарате.jpeg',
#   'name_of_painting': 'Портрет доньи Антонии Сарате',
#   'year': '1806',
#   'most_common_colors_ever': {'(43, 37, 31)': 2023,
#    '(91, 79, 63)': 360,
#    '(16, 15, 14)': 1085,
#    '(187, 177, 158)': 1052,
#    '(135, 139, 133)': 935,
#    '(144, 121, 84)': 1353,
#    '(97, 54, 38)': 885}},
#  '1815_mm_dd_i_Портрет_Фердинанда_VII_де_Бурбона,_короля_Испании.jpeg': {'path': '1815_mm_dd_i_Портрет_Фердинанда_VII_де_Бурбона,_короля_Испании.jpeg',
#   'name_of_painting': 'Портрет Фердинанда VII де Бурбона, короля Испании',
#   'year': '1815',
#   'most_common_colors_ever': {'(43, 37, 31)': 2337,
#    '(91, 79, 63)': 1240,
#    '(16, 15, 14)': 191,
#    '(187, 177, 158)': 295,
#    '(135, 139, 133)': 246,
#    '(144, 121, 84)': 1116,
#    '(97, 54, 38)': 751}},
#  '1814_mm_dd_i_Расстрел_повстанцев_3_мая_1808_года_в_Мадриде.jpeg': {'path': '1814_mm_dd_i_Расстрел_повстанцев_3_мая_1808_года_в_Мадриде.jpeg',
#   'name_of_painting': 'Расстрел повстанцев 3 мая 1808 года в Мадриде',
#   'year': '1814',
#   'most_common_colors_ever': {'(43, 37, 31)': 2364,
#    '(91, 79, 63)': 1683,
#    '(16, 15, 14)': 981,
#    '(187, 177, 158)': 161,
#    '(135, 139, 133)': 167,
#    '(144, 121, 84)': 848,
#    '(97, 54, 38)': 282}},
#  '1789_mm_dd_i_Карл_IV.jpeg': {'path': '1789_mm_dd_i_Карл_IV.jpeg',
#   'name_of_painting': 'Карл IV',
#   'year': '1789',
#   'most_common_colors_ever': {'(43, 37, 31)': 1140,
#    '(91, 79, 63)': 1657,
#    '(16, 15, 14)': 0,
#    '(187, 177, 158)': 1734,
#    '(135, 139, 133)': 1460,
#    '(144, 121, 84)': 681,
#    '(97, 54, 38)': 1526}},
#  '1798_mm_dd_i_Фреска_часовни_Св._Антония_Флоридского,_деталь_4.jpeg': {'path': '1798_mm_dd_i_Фреска_часовни_Св._Антония_Флоридского,_деталь_4.jpeg',
#   'name_of_painting': 'Фреска часовни Св. Антония Флоридского, деталь 4',
#   'year': '1798',
#   'most_common_colors_ever': {'(43, 37, 31)': 922,
#    '(91, 79, 63)': 2806,
#    '(16, 15, 14)': 0,
#    '(187, 177, 158)': 1369,
#    '(135, 139, 133)': 400,
#    '(144, 121, 84)': 1128,
#    '(97, 54, 38)': 1587}},
#  '1819_mm_dd_i_Кузница.jpeg': {'path': '1819_mm_dd_i_Кузница.jpeg',
#   'name_of_painting': 'Кузница',
#   'year': '1819',
#   'most_common_colors_ever': {'(43, 37, 31)': 1291,
#    '(91, 79, 63)': 3207,
#    '(16, 15, 14)': 5,
#    '(187, 177, 158)': 1148,
#    '(135, 139, 133)': 320,
#    '(144, 121, 84)': 1881,
#    '(97, 54, 38)': 1358}},
#  '1800_mm_dd_i_Граф_Тахо.jpeg': {'path': '1800_mm_dd_i_Граф_Тахо.jpeg',
#   'name_of_painting': 'Граф Тахо',
#   'year': '1800',
#   'most_common_colors_ever': {'(43, 37, 31)': 1907,
#    '(91, 79, 63)': 1617,
#    '(16, 15, 14)': 398,
#    '(187, 177, 158)': 1278,
#    '(135, 139, 133)': 827,
#    '(144, 121, 84)': 1251,
#    '(97, 54, 38)': 2350}},
#  '1812_mm_dd_i_Точильщик.jpeg': {'path': '1812_mm_dd_i_Точильщик.jpeg',
#   'name_of_painting': 'Точильщик',
#   'year': '1812',
#   'most_common_colors_ever': {'(43, 37, 31)': 3907,
#    '(91, 79, 63)': 1393,
#    '(16, 15, 14)': 1437,
#    '(187, 177, 158)': 1113,
#    '(135, 139, 133)': 822,
#    '(144, 121, 84)': 563,
#    '(97, 54, 38)': 712}},
#  '1777_mm_dd_i_Прогулка_в_Андалусии.jpeg': {'path': '1777_mm_dd_i_Прогулка_в_Андалусии.jpeg',
#   'name_of_painting': 'Прогулка в Андалусии',
#   'year': '1777',
#   'most_common_colors_ever': {'(43, 37, 31)': 7680,
#    '(91, 79, 63)': 1974,
#    '(16, 15, 14)': 99,
#    '(187, 177, 158)': 266,
#    '(135, 139, 133)': 374,
#    '(144, 121, 84)': 571,
#    '(97, 54, 38)': 1201}},
#  '1812_mm_dd_i_Мёртвая_индейка.jpeg': {'path': '1812_mm_dd_i_Мёртвая_индейка.jpeg',
#   'name_of_painting': 'Мёртвая индейка',
#   'year': '1812',
#   'most_common_colors_ever': {'(43, 37, 31)': 2302,
#    '(91, 79, 63)': 910,
#    '(16, 15, 14)': 1643,
#    '(187, 177, 158)': 830,
#    '(135, 139, 133)': 2172,
#    '(144, 121, 84)': 288,
#    '(97, 54, 38)': 271}},
#  '1798_mm_dd_i_Портрет_матадора_Педро_Ромеро.jpeg': {'path': '1798_mm_dd_i_Портрет_матадора_Педро_Ромеро.jpeg',
#   'name_of_painting': 'Портрет матадора Педро Ромеро',
#   'year': '1798',
#   'most_common_colors_ever': {'(43, 37, 31)': 1622,
#    '(91, 79, 63)': 2251,
#    '(16, 15, 14)': 0,
#    '(187, 177, 158)': 1280,
#    '(135, 139, 133)': 1509,
#    '(144, 121, 84)': 1333,
#    '(97, 54, 38)': 402}},
#  '1804_mm_dd_i_Портрет_Бартоломе_Суреда-и-Мизероль.jpeg': {'path': '1804_mm_dd_i_Портрет_Бартоломе_Суреда-и-Мизероль.jpeg',
#   'name_of_painting': 'Портрет Бартоломе Суреда-и-Мизероль',
#   'year': '1804',
#   'most_common_colors_ever': {'(43, 37, 31)': 2583,
#    '(91, 79, 63)': 1381,
#    '(16, 15, 14)': 796,
#    '(187, 177, 158)': 1292,
#    '(135, 139, 133)': 273,
#    '(144, 121, 84)': 372,
#    '(97, 54, 38)': 1032}},
#  '1787_mm_dd_i_Женщина_с_двумя_мальчиками_у_фонтана.jpeg': {'path': '1787_mm_dd_i_Женщина_с_двумя_мальчиками_у_фонтана.jpeg',
#   'name_of_painting': 'Женщина с двумя мальчиками у фонтана',
#   'year': '1787',
#   'most_common_colors_ever': {'(43, 37, 31)': 4306,
#    '(91, 79, 63)': 942,
#    '(16, 15, 14)': 440,
#    '(187, 177, 158)': 198,
#    '(135, 139, 133)': 129,
#    '(144, 121, 84)': 504,
#    '(97, 54, 38)': 643}},
#  '1775_mm_dd_i_Охота_на_приманку.jpeg': {'path': '1775_mm_dd_i_Охота_на_приманку.jpeg',
#   'name_of_painting': 'Охота на приманку',
#   'year': '1775',
#   'most_common_colors_ever': {'(43, 37, 31)': 3927,
#    '(91, 79, 63)': 1863,
#    '(16, 15, 14)': 673,
#    '(187, 177, 158)': 1334,
#    '(135, 139, 133)': 444,
#    '(144, 121, 84)': 759,
#    '(97, 54, 38)': 2004}},
#  '1793_mm_dd_i_Бродячие_комедианты.jpeg': {'path': '1793_mm_dd_i_Бродячие_комедианты.jpeg',
#   'name_of_painting': 'Бродячие комедианты',
#   'year': '1793',
#   'most_common_colors_ever': {'(43, 37, 31)': 2193,
#    '(91, 79, 63)': 673,
#    '(16, 15, 14)': 3550,
#    '(187, 177, 158)': 31,
#    '(135, 139, 133)': 226,
#    '(144, 121, 84)': 237,
#    '(97, 54, 38)': 272}},
#  '1771_mm_dd_i_Победоносный_Ганнибал_впервые_видит_Италию_с_вершин_Альп.jpeg': {'path': '1771_mm_dd_i_Победоносный_Ганнибал_впервые_видит_Италию_с_вершин_Альп.jpeg',
#   'name_of_painting': 'Победоносный Ганнибал впервые видит Италию с вершин Альп',
#   'year': '1771',
#   'most_common_colors_ever': {'(43, 37, 31)': 4824,
#    '(91, 79, 63)': 1296,
#    '(16, 15, 14)': 42,
#    '(187, 177, 158)': 1083,
#    '(135, 139, 133)': 27,
#    '(144, 121, 84)': 216,
#    '(97, 54, 38)': 2396}},
#  '1786_mm_dd_s_Пьяный_каменщик_(эскиз).jpeg': {'path': '1786_mm_dd_s_Пьяный_каменщик_(эскиз).jpeg',
#   'name_of_painting': 'Пьяный каменщик (эскиз)',
#   'year': '1786',
#   'most_common_colors_ever': {'(43, 37, 31)': 5351,
#    '(91, 79, 63)': 1595,
#    '(16, 15, 14)': 1071,
#    '(187, 177, 158)': 709,
#    '(135, 139, 133)': 2554,
#    '(144, 121, 84)': 588,
#    '(97, 54, 38)': 705}},
#  '1814_mm_dd_i_Процессия_флагеллантов_(бичующихся).jpeg': {'path': '1814_mm_dd_i_Процессия_флагеллантов_(бичующихся).jpeg',
#   'name_of_painting': 'Процессия флагеллантов (бичующихся)',
#   'year': '1814',
#   'most_common_colors_ever': {'(43, 37, 31)': 1943,
#    '(91, 79, 63)': 730,
#    '(16, 15, 14)': 2239,
#    '(187, 177, 158)': 645,
#    '(135, 139, 133)': 533,
#    '(144, 121, 84)': 350,
#    '(97, 54, 38)': 369}},
#  '1822_mm_dd_i_Портрет_дона_Себастьяна_Габриеля_де_Борбона-и-Браганца.jpeg': {'path': '1822_mm_dd_i_Портрет_дона_Себастьяна_Габриеля_де_Борбона-и-Браганца.jpeg',
#   'name_of_painting': 'Портрет дона Себастьяна Габриеля де Борбона-и-Браганца',
#   'year': '1822',
#   'most_common_colors_ever': {'(43, 37, 31)': 3604,
#    '(91, 79, 63)': 2281,
#    '(16, 15, 14)': 5,
#    '(187, 177, 158)': 0,
#    '(135, 139, 133)': 1,
#    '(144, 121, 84)': 1279,
#    '(97, 54, 38)': 3364}},
#  '1771_mm_dd_i_Венера_и_Адонис.jpeg': {'path': '1771_mm_dd_i_Венера_и_Адонис.jpeg',
#   'name_of_painting': 'Венера и Адонис',
#   'year': '1771',
#   'most_common_colors_ever': {'(43, 37, 31)': 2453,
#    '(91, 79, 63)': 1719,
#    '(16, 15, 14)': 3,
#    '(187, 177, 158)': 186,
#    '(135, 139, 133)': 1461,
#    '(144, 121, 84)': 452,
#    '(97, 54, 38)': 1503}},
#  '1786_mm_dd_i_Мальчики_с_мастифом.jpeg': {'path': '1786_mm_dd_i_Мальчики_с_мастифом.jpeg',
#   'name_of_painting': 'Мальчики с мастифом',
#   'year': '1786',
#   'most_common_colors_ever': {'(43, 37, 31)': 4246,
#    '(91, 79, 63)': 1918,
#    '(16, 15, 14)': 929,
#    '(187, 177, 158)': 332,
#    '(135, 139, 133)': 1279,
#    '(144, 121, 84)': 346,
#    '(97, 54, 38)': 901}},
#  '1792_mm_dd_i_Ходули.jpeg': {'path': '1792_mm_dd_i_Ходули.jpeg',
#   'name_of_painting': 'Ходули',
#   'year': '1792',
#   'most_common_colors_ever': {'(43, 37, 31)': 3169,
#    '(91, 79, 63)': 1967,
#    '(16, 15, 14)': 224,
#    '(187, 177, 158)': 451,
#    '(135, 139, 133)': 1187,
#    '(144, 121, 84)': 992,
#    '(97, 54, 38)': 1780}},
#  '1798_mm_dd_i_Портрет_доктора_Андреса_дель_Пераля.jpeg': {'path': '1798_mm_dd_i_Портрет_доктора_Андреса_дель_Пераля.jpeg',
#   'name_of_painting': 'Портрет доктора Андреса дель Пераля',
#   'year': '1798',
#   'most_common_colors_ever': {'(43, 37, 31)': 14184,
#    '(91, 79, 63)': 190,
#    '(16, 15, 14)': 12661,
#    '(187, 177, 158)': 0,
#    '(135, 139, 133)': 0,
#    '(144, 121, 84)': 113,
#    '(97, 54, 38)': 283}},
#  '1778_mm_dd_i_Мальчики_собирают_фрукты.jpeg': {'path': '1778_mm_dd_i_Мальчики_собирают_фрукты.jpeg',
#   'name_of_painting': 'Мальчики собирают фрукты',
#   'year': '1778',
#   'most_common_colors_ever': {'(43, 37, 31)': 2914,
#    '(91, 79, 63)': 3192,
#    '(16, 15, 14)': 129,
#    '(187, 177, 158)': 879,
#    '(135, 139, 133)': 1095,
#    '(144, 121, 84)': 517,
#    '(97, 54, 38)': 1526}},
#  '1792_mm_dd_i_Свадьба.jpeg': {'path': '1792_mm_dd_i_Свадьба.jpeg',
#   'name_of_painting': 'Свадьба',
#   'year': '1792',
#   'most_common_colors_ever': {'(43, 37, 31)': 5405,
#    '(91, 79, 63)': 480,
#    '(16, 15, 14)': 124,
#    '(187, 177, 158)': 2,
#    '(135, 139, 133)': 850,
#    '(144, 121, 84)': 198,
#    '(97, 54, 38)': 1617}},
#  '1823_mm_dd_i_Две_женщины_и_мужчина.jpeg': {'path': '1823_mm_dd_i_Две_женщины_и_мужчина.jpeg',
#   'name_of_painting': 'Две женщины и мужчина',
#   'year': '1823',
#   'most_common_colors_ever': {'(43, 37, 31)': 3047,
#    '(91, 79, 63)': 2841,
#    '(16, 15, 14)': 96,
#    '(187, 177, 158)': 1203,
#    '(135, 139, 133)': 1314,
#    '(144, 121, 84)': 440,
#    '(97, 54, 38)': 2225}},
#  '1823_mm_dd_i_Серия_мрачных_картин._Два_монаха.jpeg': {'path': '1823_mm_dd_i_Серия_мрачных_картин._Два_монаха.jpeg',
#   'name_of_painting': 'Серия мрачных картин. Два монаха',
#   'year': '1823',
#   'most_common_colors_ever': {'(43, 37, 31)': 959,
#    '(91, 79, 63)': 2197,
#    '(16, 15, 14)': 0,
#    '(187, 177, 158)': 320,
#    '(135, 139, 133)': 307,
#    '(144, 121, 84)': 539,
#    '(97, 54, 38)': 990}},
#  '1786_mm_dd_i_Падение.jpeg': {'path': '1786_mm_dd_i_Падение.jpeg',
#   'name_of_painting': 'Падение',
#   'year': '1786',
#   'most_common_colors_ever': {'(43, 37, 31)': 6505,
#    '(91, 79, 63)': 2017,
#    '(16, 15, 14)': 3571,
#    '(187, 177, 158)': 67,
#    '(135, 139, 133)': 168,
#    '(144, 121, 84)': 295,
#    '(97, 54, 38)': 823}},
#  '1823_mm_dd_i_Серия_мрачных_картин-_Паломники.jpeg': {'path': '1823_mm_dd_i_Серия_мрачных_картин-_Паломники.jpeg',
#   'name_of_painting': 'Серия мрачных картин- Паломники',
#   'year': '1823',
#   'most_common_colors_ever': {'(43, 37, 31)': 6456,
#    '(91, 79, 63)': 356,
#    '(16, 15, 14)': 10433,
#    '(187, 177, 158)': 117,
#    '(135, 139, 133)': 0,
#    '(144, 121, 84)': 583,
#    '(97, 54, 38)': 246}},
#  '1799_mm_dd_i_Св._Григорий_Магно.jpeg': {'path': '1799_mm_dd_i_Св._Григорий_Магно.jpeg',
#   'name_of_painting': 'Св. Григорий Магно',
#   'year': '1799',
#   'most_common_colors_ever': {'(43, 37, 31)': 11110,
#    '(91, 79, 63)': 1068,
#    '(16, 15, 14)': 2422,
#    '(187, 177, 158)': 121,
#    '(135, 139, 133)': 15,
#    '(144, 121, 84)': 349,
#    '(97, 54, 38)': 573}},
#  '1793_mm_dd_i_Графиня_Карпио,_маркиза_де_ла_Солана.jpeg': {'path': '1793_mm_dd_i_Графиня_Карпио,_маркиза_де_ла_Солана.jpeg',
#   'name_of_painting': 'Графиня Карпио, маркиза де ла Солана',
#   'year': '1793',
#   'most_common_colors_ever': {'(43, 37, 31)': 921,
#    '(91, 79, 63)': 312,
#    '(16, 15, 14)': 43,
#    '(187, 177, 158)': 11,
#    '(135, 139, 133)': 21,
#    '(144, 121, 84)': 425,
#    '(97, 54, 38)': 3037}},
#  '1798_mm_dd_i_Дон_Педро_де_Алькантара_из_рода_Тельес-Хиронов,_9-й_герцог_Осуна.jpeg': {'path': '1798_mm_dd_i_Дон_Педро_де_Алькантара_из_рода_Тельес-Хиронов,_9-й_герцог_Осуна.jpeg',
#   'name_of_painting': 'Дон Педро де Алькантара из рода Тельес-Хиронов, 9-й герцог Осуна',
#   'year': '1798',
#   'most_common_colors_ever': {'(43, 37, 31)': 6193,
#    '(91, 79, 63)': 1063,
#    '(16, 15, 14)': 2365,
#    '(187, 177, 158)': 177,
#    '(135, 139, 133)': 116,
#    '(144, 121, 84)': 1560,
#    '(97, 54, 38)': 1069}},
#  '1800_mm_dd_i_Сон.jpeg': {'path': '1800_mm_dd_i_Сон.jpeg',
#   'name_of_painting': 'Сон',
#   'year': '1800',
#   'most_common_colors_ever': {'(43, 37, 31)': 2965,
#    '(91, 79, 63)': 290,
#    '(16, 15, 14)': 11764,
#    '(187, 177, 158)': 92,
#    '(135, 139, 133)': 96,
#    '(144, 121, 84)': 83,
#    '(97, 54, 38)': 326}},
#  '1805_mm_dd_i_Молодая_дама_в_мантилье_и_баскине.jpeg': {'path': '1805_mm_dd_i_Молодая_дама_в_мантилье_и_баскине.jpeg',
#   'name_of_painting': 'Молодая дама в мантилье и баскине',
#   'year': '1805',
#   'most_common_colors_ever': {'(43, 37, 31)': 5193,
#    '(91, 79, 63)': 2191,
#    '(16, 15, 14)': 4069,
#    '(187, 177, 158)': 313,
#    '(135, 139, 133)': 423,
#    '(144, 121, 84)': 722,
#    '(97, 54, 38)': 530}},
#  '1783_mm_dd_i_Мария_Тереза_де_Виллабрига1.jpeg': {'path': '1783_mm_dd_i_Мария_Тереза_де_Виллабрига1.jpeg',
#   'name_of_painting': 'Мария Тереза де Виллабрига1',
#   'year': '1783',
#   'most_common_colors_ever': {'(43, 37, 31)': 3905,
#    '(91, 79, 63)': 2112,
#    '(16, 15, 14)': 1599,
#    '(187, 177, 158)': 614,
#    '(135, 139, 133)': 2604,
#    '(144, 121, 84)': 1004,
#    '(97, 54, 38)': 268}},
#  '1787_mm_dd_i_Метель.jpeg': {'path': '1787_mm_dd_i_Метель.jpeg',
#   'name_of_painting': 'Метель',
#   'year': '1787',
#   'most_common_colors_ever': {'(43, 37, 31)': 1984,
#    '(91, 79, 63)': 647,
#    '(16, 15, 14)': 10331,
#    '(187, 177, 158)': 1149,
#    '(135, 139, 133)': 897,
#    '(144, 121, 84)': 88,
#    '(97, 54, 38)': 120}},
#  '1798_mm_dd_i_Фреска_часовни_Св._Антония_Флоридского,_деталь_5.jpeg': {'path': '1798_mm_dd_i_Фреска_часовни_Св._Антония_Флоридского,_деталь_5.jpeg',
#   'name_of_painting': 'Фреска часовни Св. Антония Флоридского, деталь 5',
#   'year': '1798',
#   'most_common_colors_ever': {'(43, 37, 31)': 8180,
#    '(91, 79, 63)': 92,
#    '(16, 15, 14)': 11126,
#    '(187, 177, 158)': 7,
#    '(135, 139, 133)': 0,
#    '(144, 121, 84)': 57,
#    '(97, 54, 38)': 401}},
#  '1814_mm_dd_i_Восстание_2_мая_1808_года_в_Мадриде.jpeg': {'path': '1814_mm_dd_i_Восстание_2_мая_1808_года_в_Мадриде.jpeg',
#   'name_of_painting': 'Восстание 2 мая 1808 года в Мадриде',
#   'year': '1814',
#   'most_common_colors_ever': {'(43, 37, 31)': 1082,
#    '(91, 79, 63)': 336,
#    '(16, 15, 14)': 9925,
#    '(187, 177, 158)': 94,
#    '(135, 139, 133)': 74,
#    '(144, 121, 84)': 48,
#    '(97, 54, 38)': 37}},
#  '1819_mm_dd_i_Молодая_женщина_с_письмом.jpeg': {'path': '1819_mm_dd_i_Молодая_женщина_с_письмом.jpeg',
#   'name_of_painting': 'Молодая женщина с письмом',
#   'year': '1819',
#   'most_common_colors_ever': {'(43, 37, 31)': 5424,
#    '(91, 79, 63)': 723,
#    '(16, 15, 14)': 2018,
#    '(187, 177, 158)': 149,
#    '(135, 139, 133)': 75,
#    '(144, 121, 84)': 476,
#    '(97, 54, 38)': 1679}},
#  '1779_mm_dd_i_Портрет_Леандро_Фернандеса_Моратина.jpeg': {'path': '1779_mm_dd_i_Портрет_Леандро_Фернандеса_Моратина.jpeg',
#   'name_of_painting': 'Портрет Леандро Фернандеса Моратина',
#   'year': '1779',
#   'most_common_colors_ever': {'(43, 37, 31)': 685,
#    '(91, 79, 63)': 1354,
#    '(16, 15, 14)': 508,
#    '(187, 177, 158)': 2474,
#    '(135, 139, 133)': 1084,
#    '(144, 121, 84)': 954,
#    '(97, 54, 38)': 165}},
#  '1811_mm_dd_i_Портрет_актрисы_Антонии_Сарате.jpeg': {'path': '1811_mm_dd_i_Портрет_актрисы_Антонии_Сарате.jpeg',
#   'name_of_painting': 'Портрет актрисы Антонии Сарате',
#   'year': '1811',
#   'most_common_colors_ever': {'(43, 37, 31)': 5290,
#    '(91, 79, 63)': 1155,
#    '(16, 15, 14)': 7231,
#    '(187, 177, 158)': 323,
#    '(135, 139, 133)': 226,
#    '(144, 121, 84)': 397,
#    '(97, 54, 38)': 91}},
#  '1794_mm_dd_i_Двор_сумасшедшего_дома.jpeg': {'path': '1794_mm_dd_i_Двор_сумасшедшего_дома.jpeg',
#   'name_of_painting': 'Двор сумасшедшего дома',
#   'year': '1794',
#   'most_common_colors_ever': {'(43, 37, 31)': 838,
#    '(91, 79, 63)': 2510,
#    '(16, 15, 14)': 23,
#    '(187, 177, 158)': 1000,
#    '(135, 139, 133)': 1589,
#    '(144, 121, 84)': 2460,
#    '(97, 54, 38)': 1307}},
#  '1797_mm_dd_i_Портрет_Мартина_Сапатера.jpeg': {'path': '1797_mm_dd_i_Портрет_Мартина_Сапатера.jpeg',
#   'name_of_painting': 'Портрет Мартина Сапатера',
#   'year': '1797',
#   'most_common_colors_ever': {'(43, 37, 31)': 1388,
#    '(91, 79, 63)': 1728,
#    '(16, 15, 14)': 146,
#    '(187, 177, 158)': 281,
#    '(135, 139, 133)': 240,
#    '(144, 121, 84)': 1949,
#    '(97, 54, 38)': 1142}},
#  '1804_mm_dd_i_Маркиза_фон_Виллафранка.jpeg': {'path': '1804_mm_dd_i_Маркиза_фон_Виллафранка.jpeg',
#   'name_of_painting': 'Маркиза фон Виллафранка',
#   'year': '1804',
#   'most_common_colors_ever': {'(43, 37, 31)': 2020,
#    '(91, 79, 63)': 1779,
#    '(16, 15, 14)': 1618,
#    '(187, 177, 158)': 821,
#    '(135, 139, 133)': 586,
#    '(144, 121, 84)': 652,
#    '(97, 54, 38)': 154}},
#  '1813_mm_dd_i_Портрет_художницы_Лолы_Хименес.jpeg': {'path': '1813_mm_dd_i_Портрет_художницы_Лолы_Хименес.jpeg',
#   'name_of_painting': 'Портрет художницы Лолы Хименес',
#   'year': '1813',
#   'most_common_colors_ever': {'(43, 37, 31)': 561,
#    '(91, 79, 63)': 1378,
#    '(16, 15, 14)': 1794,
#    '(187, 177, 158)': 1108,
#    '(135, 139, 133)': 2001,
#    '(144, 121, 84)': 2109,
#    '(97, 54, 38)': 1419}},
#  '1814_mm_dd_i_Трибунал_инквизиции.jpeg': {'path': '1814_mm_dd_i_Трибунал_инквизиции.jpeg',
#   'name_of_painting': 'Трибунал инквизиции',
#   'year': '1814',
#   'most_common_colors_ever': {'(43, 37, 31)': 1301,
#    '(91, 79, 63)': 1429,
#    '(16, 15, 14)': 1304,
#    '(187, 177, 158)': 790,
#    '(135, 139, 133)': 1020,
#    '(144, 121, 84)': 723,
#    '(97, 54, 38)': 544}},
#  '1777_mm_dd_i_Танец_на_берегу_реки_Мансанарес.jpeg': {'path': '1777_mm_dd_i_Танец_на_берегу_реки_Мансанарес.jpeg',
#   'name_of_painting': 'Танец на берегу реки Мансанарес',
#   'year': '1777',
#   'most_common_colors_ever': {'(43, 37, 31)': 1319,
#    '(91, 79, 63)': 593,
#    '(16, 15, 14)': 1353,
#    '(187, 177, 158)': 867,
#    '(135, 139, 133)': 851,
#    '(144, 121, 84)': 782,
#    '(97, 54, 38)': 341}},
#  '1791_mm_dd_i_Портрет_Луиса_Марии_де_Кистуэ-и-Мартинеса.jpeg': {'path': '1791_mm_dd_i_Портрет_Луиса_Марии_де_Кистуэ-и-Мартинеса.jpeg',
#   'name_of_painting': 'Портрет Луиса Марии де Кистуэ-и-Мартинеса',
#   'year': '1791',
#   'most_common_colors_ever': {'(43, 37, 31)': 1218,
#    '(91, 79, 63)': 1405,
#    '(16, 15, 14)': 371,
#    '(187, 177, 158)': 1967,
#    '(135, 139, 133)': 2658,
#    '(144, 121, 84)': 329,
#    '(97, 54, 38)': 239}},
#  '1801_mm_dd_i_Мануэль_Годой,_герцог_Алькудии,_"принц_мира".jpeg': {'path': '1801_mm_dd_i_Мануэль_Годой,_герцог_Алькудии,_"принц_мира".jpeg',
#   'name_of_painting': 'Мануэль Годой, герцог Алькудии, "принц мира"',
#   'year': '1801',
#   'most_common_colors_ever': {'(43, 37, 31)': 784,
#    '(91, 79, 63)': 1618,
#    '(16, 15, 14)': 910,
#    '(187, 177, 158)': 182,
#    '(135, 139, 133)': 126,
#    '(144, 121, 84)': 887,
#    '(97, 54, 38)': 134}},
#  '1789_mm_dd_i_Портрет_Карлоса_IV.jpeg': {'path': '1789_mm_dd_i_Портрет_Карлоса_IV.jpeg',
#   'name_of_painting': 'Портрет Карлоса IV',
#   'year': '1789',
#   'most_common_colors_ever': {'(43, 37, 31)': 893,
#    '(91, 79, 63)': 1436,
#    '(16, 15, 14)': 2057,
#    '(187, 177, 158)': 2831,
#    '(135, 139, 133)': 1014,
#    '(144, 121, 84)': 415,
#    '(97, 54, 38)': 1085}},
#  '1780_mm_dd_i_Прачки.jpeg': {'path': '1780_mm_dd_i_Прачки.jpeg',
#   'name_of_painting': 'Прачки',
#   'year': '1780',
#   'most_common_colors_ever': {'(43, 37, 31)': 3006,
#    '(91, 79, 63)': 2130,
#    '(16, 15, 14)': 2054,
#    '(187, 177, 158)': 58,
#    '(135, 139, 133)': 13,
#    '(144, 121, 84)': 392,
#    '(97, 54, 38)': 511}},
#  '1806_mm_dd_i_Портрет_Педро_Мокарте,_певца_собора_Толедо.jpeg': {'path': '1806_mm_dd_i_Портрет_Педро_Мокарте,_певца_собора_Толедо.jpeg',
#   'name_of_painting': 'Портрет Педро Мокарте, певца собора Толедо',
#   'year': '1806',
#   'most_common_colors_ever': {'(43, 37, 31)': 829,
#    '(91, 79, 63)': 794,
#    '(16, 15, 14)': 784,
#    '(187, 177, 158)': 2006,
#    '(135, 139, 133)': 1260,
#    '(144, 121, 84)': 893,
#    '(97, 54, 38)': 596}},
#  '1793_mm_dd_i_Пикадор,_оказавшись_на_быке.jpeg': {'path': '1793_mm_dd_i_Пикадор,_оказавшись_на_быке.jpeg',
#   'name_of_painting': 'Пикадор, оказавшись на быке',
#   'year': '1793',
#   'most_common_colors_ever': {'(43, 37, 31)': 448,
#    '(91, 79, 63)': 732,
#    '(16, 15, 14)': 184,
#    '(187, 177, 158)': 1541,
#    '(135, 139, 133)': 4038,
#    '(144, 121, 84)': 1143,
#    '(97, 54, 38)': 630}},
#  '1785_mm_dd_i_Портрет_графини-герцогини_Бенавенте.jpeg': {'path': '1785_mm_dd_i_Портрет_графини-герцогини_Бенавенте.jpeg',
#   'name_of_painting': 'Портрет графини-герцогини Бенавенте',
#   'year': '1785',
#   'most_common_colors_ever': {'(43, 37, 31)': 5243,
#    '(91, 79, 63)': 2169,
#    '(16, 15, 14)': 1608,
#    '(187, 177, 158)': 169,
#    '(135, 139, 133)': 91,
#    '(144, 121, 84)': 413,
#    '(97, 54, 38)': 859}},
#  '1807_mm_dd_i_Портрет_дамы.jpeg': {'path': '1807_mm_dd_i_Портрет_дамы.jpeg',
#   'name_of_painting': 'Портрет дамы',
#   'year': '1807',
#   'most_common_colors_ever': {'(43, 37, 31)': 74,
#    '(91, 79, 63)': 646,
#    '(16, 15, 14)': 0,
#    '(187, 177, 158)': 451,
#    '(135, 139, 133)': 2177,
#    '(144, 121, 84)': 131,
#    '(97, 54, 38)': 36}},
#  '1816_mm_dd_i_Коррида_на_разделенной_арене.jpeg': {'path': '1816_mm_dd_i_Коррида_на_разделенной_арене.jpeg',
#   'name_of_painting': 'Коррида на разделенной арене',
#   'year': '1816',
#   'most_common_colors_ever': {'(43, 37, 31)': 5089,
#    '(91, 79, 63)': 4654,
#    '(16, 15, 14)': 1997,
#    '(187, 177, 158)': 152,
#    '(135, 139, 133)': 1222,
#    '(144, 121, 84)': 65,
#    '(97, 54, 38)': 715}},
#  '1802_mm_dd_i_Портрет_Дон_Хосе_Керальто.jpeg': {'path': '1802_mm_dd_i_Портрет_Дон_Хосе_Керальто.jpeg',
#   'name_of_painting': 'Портрет Дон Хосе Керальто',
#   'year': '1802',
#   'most_common_colors_ever': {'(43, 37, 31)': 2669,
#    '(91, 79, 63)': 1260,
#    '(16, 15, 14)': 928,
#    '(187, 177, 158)': 3585,
#    '(135, 139, 133)': 2266,
#    '(144, 121, 84)': 1362,
#    '(97, 54, 38)': 257}},
#  '1774_mm_dd_i_Обрезание.jpeg': {'path': '1774_mm_dd_i_Обрезание.jpeg',
#   'name_of_painting': 'Обрезание',
#   'year': '1774',
#   'most_common_colors_ever': {'(43, 37, 31)': 262,
#    '(91, 79, 63)': 1937,
#    '(16, 15, 14)': 5,
#    '(187, 177, 158)': 3932,
#    '(135, 139, 133)': 234,
#    '(144, 121, 84)': 1194,
#    '(97, 54, 38)': 161}},
#  '1798_mm_dd_i_Чудо_святого_Антония_Падуанского_(фрагмент).jpeg': {'path': '1798_mm_dd_i_Чудо_святого_Антония_Падуанского_(фрагмент).jpeg',
#   'name_of_painting': 'Чудо святого Антония Падуанского (фрагмент)',
#   'year': '1798',
#   'most_common_colors_ever': {'(43, 37, 31)': 1461,
#    '(91, 79, 63)': 788,
#    '(16, 15, 14)': 5738,
#    '(187, 177, 158)': 98,
#    '(135, 139, 133)': 3,
#    '(144, 121, 84)': 1404,
#    '(97, 54, 38)': 680}},
#  '1798_mm_dd_i_Фреска_часовни_Св._Антония_Флоридского,_деталь_2.jpeg': {'path': '1798_mm_dd_i_Фреска_часовни_Св._Антония_Флоридского,_деталь_2.jpeg',
#   'name_of_painting': 'Фреска часовни Св. Антония Флоридского, деталь 2',
#   'year': '1798',
#   'most_common_colors_ever': {'(43, 37, 31)': 1865,
#    '(91, 79, 63)': 4884,
#    '(16, 15, 14)': 1251,
#    '(187, 177, 158)': 1262,
#    '(135, 139, 133)': 433,
#    '(144, 121, 84)': 1049,
#    '(97, 54, 38)': 941}},
#  '1810_mm_dd_i_Портрет_доньи_Нарсисы_Бараньяна_де_Гойкоечеа.jpeg': {'path': '1810_mm_dd_i_Портрет_доньи_Нарсисы_Бараньяна_де_Гойкоечеа.jpeg',
#   'name_of_painting': 'Портрет доньи Нарсисы Бараньяна де Гойкоечеа',
#   'year': '1810',
#   'most_common_colors_ever': {'(43, 37, 31)': 2580,
#    '(91, 79, 63)': 3519,
#    '(16, 15, 14)': 3034,
#    '(187, 177, 158)': 494,
#    '(135, 139, 133)': 659,
#    '(144, 121, 84)': 1215,
#    '(97, 54, 38)': 75}},
#  '1792_mm_dd_i_Себастьян_Мартинес_и_Перес.jpeg': {'path': '1792_mm_dd_i_Себастьян_Мартинес_и_Перес.jpeg',
#   'name_of_painting': 'Себастьян Мартинес и Перес',
#   'year': '1792',
#   'most_common_colors_ever': {'(43, 37, 31)': 1692,
#    '(91, 79, 63)': 193,
#    '(16, 15, 14)': 4305,
#    '(187, 177, 158)': 0,
#    '(135, 139, 133)': 0,
#    '(144, 121, 84)': 29,
#    '(97, 54, 38)': 270}},
#  '1798_mm_dd_i_Портрет_художника_Хулио_Асенсио.jpeg': {'path': '1798_mm_dd_i_Портрет_художника_Хулио_Асенсио.jpeg',
#   'name_of_painting': 'Портрет художника Хулио Асенсио',
#   'year': '1798',
#   'most_common_colors_ever': {'(43, 37, 31)': 876,
#    '(91, 79, 63)': 1441,
#    '(16, 15, 14)': 82,
#    '(187, 177, 158)': 5227,
#    '(135, 139, 133)': 518,
#    '(144, 121, 84)': 628,
#    '(97, 54, 38)': 313}},
#  '1814_mm_dd_i_Фернандо_III_Наварры_и_VII_Кастилии.jpeg': {'path': '1814_mm_dd_i_Фернандо_III_Наварры_и_VII_Кастилии.jpeg',
#   'name_of_painting': 'Фернандо III Наварры и VII Кастилии',
#   'year': '1814',
#   'most_common_colors_ever': {'(43, 37, 31)': 3449,
#    '(91, 79, 63)': 1431,
#    '(16, 15, 14)': 5698,
#    '(187, 177, 158)': 716,
#    '(135, 139, 133)': 795,
#    '(144, 121, 84)': 177,
#    '(97, 54, 38)': 597}},
#  '1781_mm_dd_i_Богородица,_как_королева_мучеников_(фрагмент).jpeg': {'path': '1781_mm_dd_i_Богородица,_как_королева_мучеников_(фрагмент).jpeg',
#   'name_of_painting': 'Богородица, как королева мучеников (фрагмент)',
#   'year': '1781',
#   'most_common_colors_ever': {'(43, 37, 31)': 5283,
#    '(91, 79, 63)': 813,
#    '(16, 15, 14)': 7246,
#    '(187, 177, 158)': 664,
#    '(135, 139, 133)': 185,
#    '(144, 121, 84)': 876,
#    '(97, 54, 38)': 780}},
#  '1783_mm_dd_i_Портрет_Марии_Терезы_де_Валлабриг_на_коне.jpeg': {'path': '1783_mm_dd_i_Портрет_Марии_Терезы_де_Валлабриг_на_коне.jpeg',
#   'name_of_painting': 'Портрет Марии Терезы де Валлабриг на коне',
#   'year': '1783',
#   'most_common_colors_ever': {'(43, 37, 31)': 4403,
#    '(91, 79, 63)': 2860,
#    '(16, 15, 14)': 305,
#    '(187, 177, 158)': 26,
#    '(135, 139, 133)': 4,
#    '(144, 121, 84)': 1001,
#    '(97, 54, 38)': 2443}},
#  '1777_mm_dd_i_Зонтик.jpeg': {'path': '1777_mm_dd_i_Зонтик.jpeg',
#   'name_of_painting': 'Зонтик',
#   'year': '1777',
#   'most_common_colors_ever': {'(43, 37, 31)': 5984,
#    '(91, 79, 63)': 407,
#    '(16, 15, 14)': 6699,
#    '(187, 177, 158)': 12,
#    '(135, 139, 133)': 35,
#    '(144, 121, 84)': 65,
#    '(97, 54, 38)': 1174}},
#  '1812_mm_dd_i_Маха_на_балконе.jpeg': {'path': '1812_mm_dd_i_Маха_на_балконе.jpeg',
#   'name_of_painting': 'Маха на балконе',
#   'year': '1812',
#   'most_common_colors_ever': {'(43, 37, 31)': 1869,
#    '(91, 79, 63)': 5020,
#    '(16, 15, 14)': 353,
#    '(187, 177, 158)': 1441,
#    '(135, 139, 133)': 1139,
#    '(144, 121, 84)': 489,
#    '(97, 54, 38)': 471}},
#  '1780_mm_dd_i_Любительская_коррида.jpeg': {'path': '1780_mm_dd_i_Любительская_коррида.jpeg',
#   'name_of_painting': 'Любительская коррида',
#   'year': '1780',
#   'most_common_colors_ever': {'(43, 37, 31)': 2062,
#    '(91, 79, 63)': 1602,
#    '(16, 15, 14)': 483,
#    '(187, 177, 158)': 4735,
#    '(135, 139, 133)': 1843,
#    '(144, 121, 84)': 933,
#    '(97, 54, 38)': 293}},
#  '1823_mm_dd_i_Ковен,_или_великий_козел.jpeg': {'path': '1823_mm_dd_i_Ковен,_или_великий_козел.jpeg',
#   'name_of_painting': 'Ковен, или великий козел',
#   'year': '1823',
#   'most_common_colors_ever': {'(43, 37, 31)': 3470,
#    '(91, 79, 63)': 1434,
#    '(16, 15, 14)': 5714,
#    '(187, 177, 158)': 707,
#    '(135, 139, 133)': 789,
#    '(144, 121, 84)': 179,
#    '(97, 54, 38)': 597}},
#  '1798_mm_dd_i_Ведьмы_в_воздухе.jpeg': {'path': '1798_mm_dd_i_Ведьмы_в_воздухе.jpeg',
#   'name_of_painting': 'Ведьмы в воздухе',
#   'year': '1798',
#   'most_common_colors_ever': {'(43, 37, 31)': 5913,
#    '(91, 79, 63)': 2939,
#    '(16, 15, 14)': 3769,
#    '(187, 177, 158)': 142,
#    '(135, 139, 133)': 97,
#    '(144, 121, 84)': 414,
#    '(97, 54, 38)': 782}},
#  '1788_mm_dd_i_Мануэль_Осорио_де_Зунига_(фрагмент).jpeg': {'path': '1788_mm_dd_i_Мануэль_Осорио_де_Зунига_(фрагмент).jpeg',
#   'name_of_painting': 'Мануэль Осорио де Зунига (фрагмент)',
#   'year': '1788',
#   'most_common_colors_ever': {'(43, 37, 31)': 1659,
#    '(91, 79, 63)': 2461,
#    '(16, 15, 14)': 1528,
#    '(187, 177, 158)': 458,
#    '(135, 139, 133)': 642,
#    '(144, 121, 84)': 849,
#    '(97, 54, 38)': 673}},
#  '1820_mm_dd_a_Автопортрет с доктором Арриетой.jpeg': {'path': '1820_mm_dd_a_Автопортрет с доктором Арриетой.jpeg',
#   'name_of_painting': 'Автопортрет с доктором Арриетой',
#   'year': '1820',
#   'most_common_colors_ever': {'(43, 37, 31)': 1051,
#    '(91, 79, 63)': 2180,
#    '(16, 15, 14)': 26,
#    '(187, 177, 158)': 1443,
#    '(135, 139, 133)': 1178,
#    '(144, 121, 84)': 2172,
#    '(97, 54, 38)': 723}},
#  '1792_mm_dd_i_Игра_"Конь_и_всадник".jpeg': {'path': '1792_mm_dd_i_Игра_"Конь_и_всадник".jpeg',
#   'name_of_painting': 'Игра "Конь и всадник"',
#   'year': '1792',
#   'most_common_colors_ever': {'(43, 37, 31)': 1281,
#    '(91, 79, 63)': 1230,
#    '(16, 15, 14)': 109,
#    '(187, 177, 158)': 892,
#    '(135, 139, 133)': 1077,
#    '(144, 121, 84)': 1994,
#    '(97, 54, 38)': 631}},
#  '1779_mm_dd_i_Ярмарка_в_Мадриде.jpeg': {'path': '1779_mm_dd_i_Ярмарка_в_Мадриде.jpeg',
#   'name_of_painting': 'Ярмарка в Мадриде',
#   'year': '1779',
#   'most_common_colors_ever': {'(43, 37, 31)': 2250,
#    '(91, 79, 63)': 4975,
#    '(16, 15, 14)': 765,
#    '(187, 177, 158)': 129,
#    '(135, 139, 133)': 604,
#    '(144, 121, 84)': 2069,
#    '(97, 54, 38)': 1244}},
#  '1812_mm_dd_i_Маха_и_Селестина_на_балконе.jpeg': {'path': '1812_mm_dd_i_Маха_и_Селестина_на_балконе.jpeg',
#   'name_of_painting': 'Маха и Селестина на балконе',
#   'year': '1812',
#   'most_common_colors_ever': {'(43, 37, 31)': 7812,
#    '(91, 79, 63)': 1419,
#    '(16, 15, 14)': 3496,
#    '(187, 177, 158)': 33,
#    '(135, 139, 133)': 142,
#    '(144, 121, 84)': 305,
#    '(97, 54, 38)': 1152}},
#  '1800_mm_dd_a_Автопортрет_в_очках.jpeg': {'path': '1800_mm_dd_a_Автопортрет_в_очках.jpeg',
#   'name_of_painting': 'Автопортрет в очках',
#   'year': '1800',
#   'most_common_colors_ever': {'(43, 37, 31)': 1673,
#    '(91, 79, 63)': 744,
#    '(16, 15, 14)': 1838,
#    '(187, 177, 158)': 764,
#    '(135, 139, 133)': 2549,
#    '(144, 121, 84)': 753,
#    '(97, 54, 38)': 1284}},
#  '1779_mm_dd_i_Качели.jpeg': {'path': '1779_mm_dd_i_Качели.jpeg',
#   'name_of_painting': 'Качели',
#   'year': '1779',
#   'most_common_colors_ever': {'(43, 37, 31)': 1443,
#    '(91, 79, 63)': 2569,
#    '(16, 15, 14)': 258,
#    '(187, 177, 158)': 2246,
#    '(135, 139, 133)': 619,
#    '(144, 121, 84)': 1067,
#    '(97, 54, 38)': 1054}},
#  '1798_mm_dd_i_Кардинал_Луис_Мария_де_Борон.jpeg': {'path': '1798_mm_dd_i_Кардинал_Луис_Мария_де_Борон.jpeg',
#   'name_of_painting': 'Кардинал Луис Мария де Борон',
#   'year': '1798',
#   'most_common_colors_ever': {'(43, 37, 31)': 1996,
#    '(91, 79, 63)': 1711,
#    '(16, 15, 14)': 1450,
#    '(187, 177, 158)': 1551,
#    '(135, 139, 133)': 519,
#    '(144, 121, 84)': 781,
#    '(97, 54, 38)': 587}},
#  '1823_mm_dd_i_Асмодей,_или_Фантастическое_видение.jpeg': {'path': '1823_mm_dd_i_Асмодей,_или_Фантастическое_видение.jpeg',
#   'name_of_painting': 'Асмодей, или Фантастическое видение',
#   'year': '1823',
#   'most_common_colors_ever': {'(43, 37, 31)': 6206,
#    '(91, 79, 63)': 1416,
#    '(16, 15, 14)': 8023,
#    '(187, 177, 158)': 275,
#    '(135, 139, 133)': 161,
#    '(144, 121, 84)': 594,
#    '(97, 54, 38)': 478}},
#  '1813_mm_dd_i_Последователи._Штурм_крепости_на_скале.jpeg': {'path': '1813_mm_dd_i_Последователи._Штурм_крепости_на_скале.jpeg',
#   'name_of_painting': 'Последователи. Штурм крепости на скале',
#   'year': '1813',
#   'most_common_colors_ever': {'(43, 37, 31)': 728,
#    '(91, 79, 63)': 1107,
#    '(16, 15, 14)': 4146,
#    '(187, 177, 158)': 100,
#    '(135, 139, 133)': 264,
#    '(144, 121, 84)': 32,
#    '(97, 54, 38)': 6}},
#  '1789_mm_dd_i_Жмурки.jpeg': {'path': '1789_mm_dd_i_Жмурки.jpeg',
#   'name_of_painting': 'Жмурки',
#   'year': '1789',
#   'most_common_colors_ever': {'(43, 37, 31)': 1986,
#    '(91, 79, 63)': 3209,
#    '(16, 15, 14)': 463,
#    '(187, 177, 158)': 1789,
#    '(135, 139, 133)': 1399,
#    '(144, 121, 84)': 573,
#    '(97, 54, 38)': 737}},
#  '1774_mm_dd_i_Рождение_Богородицы.jpeg': {'path': '1774_mm_dd_i_Рождение_Богородицы.jpeg',
#   'name_of_painting': 'Рождение Богородицы',
#   'year': '1774',
#   'most_common_colors_ever': {'(43, 37, 31)': 4093,
#    '(91, 79, 63)': 1057,
#    '(16, 15, 14)': 9101,
#    '(187, 177, 158)': 241,
#    '(135, 139, 133)': 189,
#    '(144, 121, 84)': 269,
#    '(97, 54, 38)': 333}},
#  '1811_mm_dd_i_Портрет_Хуана_Антонио_Льоренте.jpeg': {'path': '1811_mm_dd_i_Портрет_Хуана_Антонио_Льоренте.jpeg',
#   'name_of_painting': 'Портрет Хуана Антонио Льоренте',
#   'year': '1811',
#   'most_common_colors_ever': {'(43, 37, 31)': 5973,
#    '(91, 79, 63)': 2259,
#    '(16, 15, 14)': 5128,
#    '(187, 177, 158)': 93,
#    '(135, 139, 133)': 50,
#    '(144, 121, 84)': 424,
#    '(97, 54, 38)': 577}},
#  '1795_mm_dd_i_Пикадор.jpeg': {'path': '1795_mm_dd_i_Пикадор.jpeg',
#   'name_of_painting': 'Пикадор',
#   'year': '1795',
#   'most_common_colors_ever': {'(43, 37, 31)': 3243,
#    '(91, 79, 63)': 1497,
#    '(16, 15, 14)': 3129,
#    '(187, 177, 158)': 21,
#    '(135, 139, 133)': 1932,
#    '(144, 121, 84)': 51,
#    '(97, 54, 38)': 598}},
#  '1787_mm_dd_i_Эскизы_гобеленов_для_королевских_дворцов_Прадо_и_Эскориал._Мальчики_с_мастифом.jpeg': {'path': '1787_mm_dd_i_Эскизы_гобеленов_для_королевских_дворцов_Прадо_и_Эскориал._Мальчики_с_мастифом.jpeg',
#   'name_of_painting': 'Эскизы гобеленов для королевских дворцов Прадо и Эскориал. Мальчики с мастифом',
#   'year': '1787',
#   'most_common_colors_ever': {'(43, 37, 31)': 4450,
#    '(91, 79, 63)': 2634,
#    '(16, 15, 14)': 2964,
#    '(187, 177, 158)': 762,
#    '(135, 139, 133)': 482,
#    '(144, 121, 84)': 812,
#    '(97, 54, 38)': 439}},
#  '1814_mm_dd_i_Стычка_с_мамелюками_2_мая_1808_года_в_Мадриде.jpeg': {'path': '1814_mm_dd_i_Стычка_с_мамелюками_2_мая_1808_года_в_Мадриде.jpeg',
#   'name_of_painting': 'Стычка с мамелюками 2 мая 1808 года в Мадриде',
#   'year': '1814',
#   'most_common_colors_ever': {'(43, 37, 31)': 6028,
#    '(91, 79, 63)': 878,
#    '(16, 15, 14)': 7838,
#    '(187, 177, 158)': 574,
#    '(135, 139, 133)': 88,
#    '(144, 121, 84)': 310,
#    '(97, 54, 38)': 649}},
#  '1798_mm_dd_i_Фердинанд_Гиймарде_—_французский_посол_в_Испании.jpeg': {'path': '1798_mm_dd_i_Фердинанд_Гиймарде_—_французский_посол_в_Испании.jpeg',
#   'name_of_painting': 'Фердинанд Гиймарде — французский посол в Испании',
#   'year': '1798',
#   'most_common_colors_ever': {'(43, 37, 31)': 9769,
#    '(91, 79, 63)': 2330,
#    '(16, 15, 14)': 2499,
#    '(187, 177, 158)': 116,
#    '(135, 139, 133)': 417,
#    '(144, 121, 84)': 201,
#    '(97, 54, 38)': 641}},
#  '1786_mm_dd_i_Лето.jpeg': {'path': '1786_mm_dd_i_Лето.jpeg',
#   'name_of_painting': 'Лето',
#   'year': '1786',
#   'most_common_colors_ever': {'(43, 37, 31)': 2664,
#    '(91, 79, 63)': 1051,
#    '(16, 15, 14)': 8055,
#    '(187, 177, 158)': 405,
#    '(135, 139, 133)': 176,
#    '(144, 121, 84)': 672,
#    '(97, 54, 38)': 408}},
#  '1823_mm_dd_i_Два_старика_за_едой.jpeg': {'path': '1823_mm_dd_i_Два_старика_за_едой.jpeg',
#   'name_of_painting': 'Два старика за едой',
#   'year': '1823',
#   'most_common_colors_ever': {'(43, 37, 31)': 530,
#    '(91, 79, 63)': 836,
#    '(16, 15, 14)': 245,
#    '(187, 177, 158)': 1996,
#    '(135, 139, 133)': 7048,
#    '(144, 121, 84)': 722,
#    '(97, 54, 38)': 112}},
#  '1798_mm_dd_i_Шабаш_ведьм.jpeg': {'path': '1798_mm_dd_i_Шабаш_ведьм.jpeg',
#   'name_of_painting': 'Шабаш ведьм',
#   'year': '1798',
#   'most_common_colors_ever': {'(43, 37, 31)': 3804,
#    '(91, 79, 63)': 1002,
#    '(16, 15, 14)': 1104,
#    '(187, 177, 158)': 346,
#    '(135, 139, 133)': 3146,
#    '(144, 121, 84)': 445,
#    '(97, 54, 38)': 826}},
#  '1800_mm_dd_i_Король_Испании_Карл_IV_и_его_семья.jpeg': {'path': '1800_mm_dd_i_Король_Испании_Карл_IV_и_его_семья.jpeg',
#   'name_of_painting': 'Король Испании Карл IV и его семья',
#   'year': '1800',
#   'most_common_colors_ever': {'(43, 37, 31)': 7900,
#    '(91, 79, 63)': 1547,
#    '(16, 15, 14)': 3294,
#    '(187, 177, 158)': 114,
#    '(135, 139, 133)': 1479,
#    '(144, 121, 84)': 140,
#    '(97, 54, 38)': 120}},
#  '1779_mm_dd_i_С_гитарой.jpeg': {'path': '1779_mm_dd_i_С_гитарой.jpeg',
#   'name_of_painting': 'С гитарой',
#   'year': '1779',
#   'most_common_colors_ever': {'(43, 37, 31)': 8548,
#    '(91, 79, 63)': 1692,
#    '(16, 15, 14)': 4350,
#    '(187, 177, 158)': 23,
#    '(135, 139, 133)': 0,
#    '(144, 121, 84)': 2224,
#    '(97, 54, 38)': 475}},
#  '1798_mm_dd_i_Чудо_Св._Антония.jpeg': {'path': '1798_mm_dd_i_Чудо_Св._Антония.jpeg',
#   'name_of_painting': 'Чудо Св. Антония',
#   'year': '1798',
#   'most_common_colors_ever': {'(43, 37, 31)': 1643,
#    '(91, 79, 63)': 872,
#    '(16, 15, 14)': 6640,
#    '(187, 177, 158)': 35,
#    '(135, 139, 133)': 31,
#    '(144, 121, 84)': 832,
#    '(97, 54, 38)': 452}},
#  '1810_mm_dd_i_Похороны_сардинки.jpeg': {'path': '1810_mm_dd_i_Похороны_сардинки.jpeg',
#   'name_of_painting': 'Похороны сардинки',
#   'year': '1810',
#   'most_common_colors_ever': {'(43, 37, 31)': 5032,
#    '(91, 79, 63)': 3169,
#    '(16, 15, 14)': 4955,
#    '(187, 177, 158)': 123,
#    '(135, 139, 133)': 81,
#    '(144, 121, 84)': 355,
#    '(97, 54, 38)': 763}},
#  '1798_mm_dd_i_Портрет_французского_посла_в_Испании_Фердинанда_Гиймардета.jpeg': {'path': '1798_mm_dd_i_Портрет_французского_посла_в_Испании_Фердинанда_Гиймардета.jpeg',
#   'name_of_painting': 'Портрет французского посла в Испании Фердинанда Гиймардета',
#   'year': '1798',
#   'most_common_colors_ever': {'(43, 37, 31)': 4303,
#    '(91, 79, 63)': 5291,
#    '(16, 15, 14)': 1203,
#    '(187, 177, 158)': 227,
#    '(135, 139, 133)': 223,
#    '(144, 121, 84)': 847,
#    '(97, 54, 38)': 394}},
#  '1804_mm_dd_i_Портрет_маркизы_Сантьяго.jpeg': {'path': '1804_mm_dd_i_Портрет_маркизы_Сантьяго.jpeg',
#   'name_of_painting': 'Портрет маркизы Сантьяго',
#   'year': '1804',
#   'most_common_colors_ever': {'(43, 37, 31)': 2463,
#    '(91, 79, 63)': 3127,
#    '(16, 15, 14)': 3969,
#    '(187, 177, 158)': 2413,
#    '(135, 139, 133)': 347,
#    '(144, 121, 84)': 219,
#    '(97, 54, 38)': 247}},
#  '1824_mm_dd_i_Бой_быков._Суэрте_де_варас.jpeg': {'path': '1824_mm_dd_i_Бой_быков._Суэрте_де_варас.jpeg',
#   'name_of_painting': 'Бой быков. Суэрте де варас',
#   'year': '1824',
#   'most_common_colors_ever': {'(43, 37, 31)': 2877,
#    '(91, 79, 63)': 2280,
#    '(16, 15, 14)': 1914,
#    '(187, 177, 158)': 43,
#    '(135, 139, 133)': 5565,
#    '(144, 121, 84)': 1977,
#    '(97, 54, 38)': 615}},
#  '1798_mm_dd_i_Заклинание.jpeg': {'path': '1798_mm_dd_i_Заклинание.jpeg',
#   'name_of_painting': 'Заклинание',
#   'year': '1798',
#   'most_common_colors_ever': {'(43, 37, 31)': 4095,
#    '(91, 79, 63)': 2455,
#    '(16, 15, 14)': 1387,
#    '(187, 177, 158)': 525,
#    '(135, 139, 133)': 2254,
#    '(144, 121, 84)': 359,
#    '(97, 54, 38)': 577}},
#  '1807_mm_dd_i_Портрет_актера_Исидро_Маркеса.jpeg': {'path': '1807_mm_dd_i_Портрет_актера_Исидро_Маркеса.jpeg',
#   'name_of_painting': 'Портрет актера Исидро Маркеса',
#   'year': '1807',
#   'most_common_colors_ever': {'(43, 37, 31)': 1020,
#    '(91, 79, 63)': 819,
#    '(16, 15, 14)': 3098,
#    '(187, 177, 158)': 378,
#    '(135, 139, 133)': 351,
#    '(144, 121, 84)': 727,
#    '(97, 54, 38)': 300}},
#  '1828_mm_dd_i_Хосе_Пио_де_Молина.jpeg': {'path': '1828_mm_dd_i_Хосе_Пио_де_Молина.jpeg',
#   'name_of_painting': 'Хосе Пио де Молина',
#   'year': '1828',
#   'most_common_colors_ever': {'(43, 37, 31)': 3802,
#    '(91, 79, 63)': 1788,
#    '(16, 15, 14)': 3742,
#    '(187, 177, 158)': 1817,
#    '(135, 139, 133)': 1342,
#    '(144, 121, 84)': 667,
#    '(97, 54, 38)': 353}},
#  '1801_mm_dd_i_Портрет_Марии_Луизы_де_Бурбон.jpeg': {'path': '1801_mm_dd_i_Портрет_Марии_Луизы_де_Бурбон.jpeg',
#   'name_of_painting': 'Портрет Марии Луизы де Бурбон',
#   'year': '1801',
#   'most_common_colors_ever': {'(43, 37, 31)': 18,
#    '(91, 79, 63)': 1215,
#    '(16, 15, 14)': 0,
#    '(187, 177, 158)': 2778,
#    '(135, 139, 133)': 2088,
#    '(144, 121, 84)': 1482,
#    '(97, 54, 38)': 45}},
#  '1795_mm_dd_i_Портрет_сеньоры_Кеан_Бермудес,_жены_Хуана_Агостино_Бермудеса.jpeg': {'path': '1795_mm_dd_i_Портрет_сеньоры_Кеан_Бермудес,_жены_Хуана_Агостино_Бермудеса.jpeg',
#   'name_of_painting': 'Портрет сеньоры Кеан Бермудес, жены Хуана Агостино Бермудеса',
#   'year': '1795',
#   'most_common_colors_ever': {'(43, 37, 31)': 221,
#    '(91, 79, 63)': 443,
#    '(16, 15, 14)': 82,
#    '(187, 177, 158)': 579,
#    '(135, 139, 133)': 230,
#    '(144, 121, 84)': 1261,
#    '(97, 54, 38)': 1030}},
#  '1792_mm_dd_i_Соломенное_чучело_(Марионетка).jpeg': {'path': '1792_mm_dd_i_Соломенное_чучело_(Марионетка).jpeg',
#   'name_of_painting': 'Соломенное чучело (Марионетка)',
#   'year': '1792',
#   'most_common_colors_ever': {'(43, 37, 31)': 1330,
#    '(91, 79, 63)': 1231,
#    '(16, 15, 14)': 2238,
#    '(187, 177, 158)': 809,
#    '(135, 139, 133)': 1625,
#    '(144, 121, 84)': 466,
#    '(97, 54, 38)': 614}},
#  '1783_mm_dd_i_Хосе_Моньино,_1-й_граф_Флоридабланка.jpeg': {'path': '1783_mm_dd_i_Хосе_Моньино,_1-й_граф_Флоридабланка.jpeg',
#   'name_of_painting': 'Хосе Моньино, 1-й граф Флоридабланка',
#   'year': '1783',
#   'most_common_colors_ever': {'(43, 37, 31)': 3900,
#    '(91, 79, 63)': 2553,
#    '(16, 15, 14)': 2873,
#    '(187, 177, 158)': 620,
#    '(135, 139, 133)': 1976,
#    '(144, 121, 84)': 479,
#    '(97, 54, 38)': 625}},
#  '1783_mm_dd_i_Мария_Тереза_де_Виллабрига.jpeg': {'path': '1783_mm_dd_i_Мария_Тереза_де_Виллабрига.jpeg',
#   'name_of_painting': 'Мария Тереза де Виллабрига',
#   'year': '1783',
#   'most_common_colors_ever': {'(43, 37, 31)': 2089,
#    '(91, 79, 63)': 2329,
#    '(16, 15, 14)': 135,
#    '(187, 177, 158)': 583,
#    '(135, 139, 133)': 2050,
#    '(144, 121, 84)': 339,
#    '(97, 54, 38)': 240}},
#  '1798_mm_dd_i_Фреска_часовни_Св._Антония_Флоридского,_деталь_3.jpeg': {'path': '1798_mm_dd_i_Фреска_часовни_Св._Антония_Флоридского,_деталь_3.jpeg',
#   'name_of_painting': 'Фреска часовни Св. Антония Флоридского, деталь 3',
#   'year': '1798',
#   'most_common_colors_ever': {'(43, 37, 31)': 3159,
#    '(91, 79, 63)': 2915,
#    '(16, 15, 14)': 3099,
#    '(187, 177, 158)': 158,
#    '(135, 139, 133)': 167,
#    '(144, 121, 84)': 639,
#    '(97, 54, 38)': 1067}},
#  '1813_mm_dd_i_Портрет_Хосе_Коста-и-Бонелиса_по_прозвищу_Пепито.jpeg': {'path': '1813_mm_dd_i_Портрет_Хосе_Коста-и-Бонелиса_по_прозвищу_Пепито.jpeg',
#   'name_of_painting': 'Портрет Хосе Коста-и-Бонелиса по прозвищу Пепито',
#   'year': '1813',
#   'most_common_colors_ever': {'(43, 37, 31)': 3061,
#    '(91, 79, 63)': 2474,
#    '(16, 15, 14)': 5503,
#    '(187, 177, 158)': 34,
#    '(135, 139, 133)': 604,
#    '(144, 121, 84)': 393,
#    '(97, 54, 38)': 153}},
#  '1792_mm_dd_i_Мальчики_взбирались_на_дерево_(картон_для_гобелена).jpeg': {'path': '1792_mm_dd_i_Мальчики_взбирались_на_дерево_(картон_для_гобелена).jpeg',
#   'name_of_painting': 'Мальчики взбирались на дерево (картон для гобелена)',
#   'year': '1792',
#   'most_common_colors_ever': {'(43, 37, 31)': 773,
#    '(91, 79, 63)': 1354,
#    '(16, 15, 14)': 1064,
#    '(187, 177, 158)': 1396,
#    '(135, 139, 133)': 1092,
#    '(144, 121, 84)': 1248,
#    '(97, 54, 38)': 1169}},
#  '1823_mm_dd_i_Тонущая_собака.jpeg': {'path': '1823_mm_dd_i_Тонущая_собака.jpeg',
#   'name_of_painting': 'Тонущая собака',
#   'year': '1823',
#   'most_common_colors_ever': {'(43, 37, 31)': 3085,
#    '(91, 79, 63)': 2502,
#    '(16, 15, 14)': 5491,
#    '(187, 177, 158)': 37,
#    '(135, 139, 133)': 600,
#    '(144, 121, 84)': 396,
#    '(97, 54, 38)': 152}},
#  '1792_mm_dd_i_Девушки_с_кувшинами.jpeg': {'path': '1792_mm_dd_i_Девушки_с_кувшинами.jpeg',
#   'name_of_painting': 'Девушки с кувшинами',
#   'year': '1792',
#   'most_common_colors_ever': {'(43, 37, 31)': 2068,
#    '(91, 79, 63)': 378,
#    '(16, 15, 14)': 11478,
#    '(187, 177, 158)': 109,
#    '(135, 139, 133)': 72,
#    '(144, 121, 84)': 879,
#    '(97, 54, 38)': 425}},
#  '1800_mm_dd_i_Обнаженная_Маха.jpeg': {'path': '1800_mm_dd_i_Обнаженная_Маха.jpeg',
#   'name_of_painting': 'Обнаженная Маха',
#   'year': '1800',
#   'most_common_colors_ever': {'(43, 37, 31)': 5151,
#    '(91, 79, 63)': 1318,
#    '(16, 15, 14)': 5737,
#    '(187, 177, 158)': 232,
#    '(135, 139, 133)': 499,
#    '(144, 121, 84)': 1246,
#    '(97, 54, 38)': 413}},
#  '1788_mm_dd_i_Дон_Мануэль_Осорио_Манрике_де_Суньига,_ребёнок.jpeg': {'path': '1788_mm_dd_i_Дон_Мануэль_Осорио_Манрике_де_Суньига,_ребёнок.jpeg',
#   'name_of_painting': 'Дон Мануэль Осорио Манрике де Суньига, ребёнок',
#   'year': '1788',
#   'most_common_colors_ever': {'(43, 37, 31)': 2336,
#    '(91, 79, 63)': 482,
#    '(16, 15, 14)': 12348,
#    '(187, 177, 158)': 127,
#    '(135, 139, 133)': 42,
#    '(144, 121, 84)': 249,
#    '(97, 54, 38)': 174}},
#  '1803_mm_dd_i_Портрет_графини_Чинчон.jpeg': {'path': '1803_mm_dd_i_Портрет_графини_Чинчон.jpeg',
#   'name_of_painting': 'Портрет графини Чинчон',
#   'year': '1803',
#   'most_common_colors_ever': {'(43, 37, 31)': 6444,
#    '(91, 79, 63)': 2307,
#    '(16, 15, 14)': 4936,
#    '(187, 177, 158)': 75,
#    '(135, 139, 133)': 83,
#    '(144, 121, 84)': 2304,
# ...
#   'name_of_painting': 'Мальчики играют в солдатиков',
#   'year': '1779',
#   'most_common_colors_ever': {'(43, 37, 31)': 1851,
#    '(91, 79, 63)': 3802,
#    '(16, 15, 14)': 261,
#    '(187, 177, 158)': 511,
#    '(135, 139, 133)': 1806,
#    '(144, 121, 84)': 1308,
#    '(97, 54, 38)': 2124}},
#  '1809_mm_dd_i_Аллегория_города_Мадрида.jpeg': {'path': '1809_mm_dd_i_Аллегория_города_Мадрида.jpeg',
#   'name_of_painting': 'Аллегория города Мадрида',
#   'year': '1809',
#   'most_common_colors_ever': {'(43, 37, 31)': 11744,
#    '(91, 79, 63)': 528,
#    '(16, 15, 14)': 2884,
#    '(187, 177, 158)': 25,
#    '(135, 139, 133)': 52,
#    '(144, 121, 84)': 128,
#    '(97, 54, 38)': 367}},
#  '1798_mm_dd_i_Полет_ведьм.jpeg': {'path': '1798_mm_dd_i_Полет_ведьм.jpeg',
#   'name_of_painting': 'Полет ведьм',
#   'year': '1798',
#   'most_common_colors_ever': {'(43, 37, 31)': 10141,
#    '(91, 79, 63)': 1368,
#    '(16, 15, 14)': 1924,
#    '(187, 177, 158)': 410,
#    '(135, 139, 133)': 138,
#    '(144, 121, 84)': 367,
#    '(97, 54, 38)': 531}},
#  '1806_mm_dd_i_Портрет_доньи_Исабель_Кобос_де_Порсель.jpeg': {'path': '1806_mm_dd_i_Портрет_доньи_Исабель_Кобос_де_Порсель.jpeg',
#   'name_of_painting': 'Портрет доньи Исабель Кобос де Порсель',
#   'year': '1806',
#   'most_common_colors_ever': {'(43, 37, 31)': 3887,
#    '(91, 79, 63)': 936,
#    '(16, 15, 14)': 3081,
#    '(187, 177, 158)': 128,
#    '(135, 139, 133)': 189,
#    '(144, 121, 84)': 231,
#    '(97, 54, 38)': 910}},
#  '1778_mm_dd_i_Воздушный_змей.jpeg': {'path': '1778_mm_dd_i_Воздушный_змей.jpeg',
#   'name_of_painting': 'Воздушный змей',
#   'year': '1778',
#   'most_common_colors_ever': {'(43, 37, 31)': 2281,
#    '(91, 79, 63)': 4159,
#    '(16, 15, 14)': 1463,
#    '(187, 177, 158)': 110,
#    '(135, 139, 133)': 2194,
#    '(144, 121, 84)': 765,
#    '(97, 54, 38)': 806}},
#  '1808_mm_dd_i_Тюремная_сцена.jpeg': {'path': '1808_mm_dd_i_Тюремная_сцена.jpeg',
#   'name_of_painting': 'Тюремная сцена',
#   'year': '1808',
#   'most_common_colors_ever': {'(43, 37, 31)': 9729,
#    '(91, 79, 63)': 19,
#    '(16, 15, 14)': 2260,
#    '(187, 177, 158)': 0,
#    '(135, 139, 133)': 0,
#    '(144, 121, 84)': 1,
#    '(97, 54, 38)': 580}},
#  '1788_mm_dd_s_Эскизы_гобеленов_для_королевских_дворцов_Прадо_и_Эскориал._Полдник_на_лоне_природы.jpeg': {'path': '1788_mm_dd_s_Эскизы_гобеленов_для_королевских_дворцов_Прадо_и_Эскориал._Полдник_на_лоне_природы.jpeg',
#   'name_of_painting': 'Эскизы гобеленов для королевских дворцов Прадо и Эскориал. Полдник на лоне природы',
#   'year': '1788',
#   'most_common_colors_ever': {'(43, 37, 31)': 2402,
#    '(91, 79, 63)': 1116,
#    '(16, 15, 14)': 1587,
#    '(187, 177, 158)': 83,
#    '(135, 139, 133)': 3116,
#    '(144, 121, 84)': 607,
#    '(97, 54, 38)': 1418}},
#  '1780_mm_dd_i_Дровосеки.jpeg': {'path': '1780_mm_dd_i_Дровосеки.jpeg',
#   'name_of_painting': 'Дровосеки',
#   'year': '1780',
#   'most_common_colors_ever': {'(43, 37, 31)': 555,
#    '(91, 79, 63)': 1194,
#    '(16, 15, 14)': 71,
#    '(187, 177, 158)': 394,
#    '(135, 139, 133)': 599,
#    '(144, 121, 84)': 1277,
#    '(97, 54, 38)': 1703}},
#  '1823_mm_dd_i_Паломничество_в_Сан-Исидро.jpeg': {'path': '1823_mm_dd_i_Паломничество_в_Сан-Исидро.jpeg',
#   'name_of_painting': 'Паломничество в Сан-Исидро',
#   'year': '1823',
#   'most_common_colors_ever': {'(43, 37, 31)': 10188,
#    '(91, 79, 63)': 998,
#    '(16, 15, 14)': 12032,
#    '(187, 177, 158)': 0,
#    '(135, 139, 133)': 2,
#    '(144, 121, 84)': 44,
#    '(97, 54, 38)': 274}},
#  '1810_mm_dd_i_Цикл_картин_"Ужасы_войны"._Чумной_барак.jpeg': {'path': '1810_mm_dd_i_Цикл_картин_"Ужасы_войны"._Чумной_барак.jpeg',
#   'name_of_painting': 'Цикл картин "Ужасы войны". Чумной барак',
#   'year': '1810',
#   'most_common_colors_ever': {'(43, 37, 31)': 2252,
#    '(91, 79, 63)': 1168,
#    '(16, 15, 14)': 10984,
#    '(187, 177, 158)': 209,
#    '(135, 139, 133)': 290,
#    '(144, 121, 84)': 133,
#    '(97, 54, 38)': 195}},
#  '1794_mm_dd_i_Разбой.jpeg': {'path': '1794_mm_dd_i_Разбой.jpeg',
#   'name_of_painting': 'Разбой',
#   'year': '1794',
#   'most_common_colors_ever': {'(43, 37, 31)': 4512,
#    '(91, 79, 63)': 3772,
#    '(16, 15, 14)': 3602,
#    '(187, 177, 158)': 49,
#    '(135, 139, 133)': 123,
#    '(144, 121, 84)': 189,
#    '(97, 54, 38)': 49}},
#  '1820_mm_dd_i_Архитектор_Дон_Тибурсио.jpeg': {'path': '1820_mm_dd_i_Архитектор_Дон_Тибурсио.jpeg',
#   'name_of_painting': 'Архитектор Дон Тибурсио',
#   'year': '1820',
#   'most_common_colors_ever': {'(43, 37, 31)': 1395,
#    '(91, 79, 63)': 1539,
#    '(16, 15, 14)': 4600,
#    '(187, 177, 158)': 479,
#    '(135, 139, 133)': 1559,
#    '(144, 121, 84)': 1055,
#    '(97, 54, 38)': 210}},
#  '1798_mm_dd_i_Фреска_часовни_Св._Антония_Флоридского,_деталь_6.jpeg': {'path': '1798_mm_dd_i_Фреска_часовни_Св._Антония_Флоридского,_деталь_6.jpeg',
#   'name_of_painting': 'Фреска часовни Св. Антония Флоридского, деталь 6',
#   'year': '1798',
#   'most_common_colors_ever': {'(43, 37, 31)': 2224,
#    '(91, 79, 63)': 1447,
#    '(16, 15, 14)': 9014,
#    '(187, 177, 158)': 386,
#    '(135, 139, 133)': 356,
#    '(144, 121, 84)': 922,
#    '(97, 54, 38)': 434}},
#  '1816_mm_dd_i_Майское_дерево.jpeg': {'path': '1816_mm_dd_i_Майское_дерево.jpeg',
#   'name_of_painting': 'Майское дерево',
#   'year': '1816',
#   'most_common_colors_ever': {'(43, 37, 31)': 364,
#    '(91, 79, 63)': 225,
#    '(16, 15, 14)': 15063,
#    '(187, 177, 158)': 5,
#    '(135, 139, 133)': 228,
#    '(144, 121, 84)': 70,
#    '(97, 54, 38)': 87}},
#  '1827_mm_dd_i_Портрет_Мариано_Гойи,_внука_художника.jpeg': {'path': '1827_mm_dd_i_Портрет_Мариано_Гойи,_внука_художника.jpeg',
#   'name_of_painting': 'Портрет Мариано Гойи, внука художника',
#   'year': '1827',
#   'most_common_colors_ever': {'(43, 37, 31)': 7889,
#    '(91, 79, 63)': 2369,
#    '(16, 15, 14)': 1775,
#    '(187, 177, 158)': 0,
#    '(135, 139, 133)': 1,
#    '(144, 121, 84)': 687,
#    '(97, 54, 38)': 684}},
#  '1803_mm_dd_i_Портрет_графа_Фернанда_Нуньеса_VII.jpeg': {'path': '1803_mm_dd_i_Портрет_графа_Фернанда_Нуньеса_VII.jpeg',
#   'name_of_painting': 'Портрет графа Фернанда Нуньеса VII',
#   'year': '1803',
#   'most_common_colors_ever': {'(43, 37, 31)': 373,
#    '(91, 79, 63)': 228,
#    '(16, 15, 14)': 15052,
#    '(187, 177, 158)': 10,
#    '(135, 139, 133)': 226,
#    '(144, 121, 84)': 74,
#    '(97, 54, 38)': 88}},
#  '1784_mm_dd_i_Семья_инфанта_Дона_Луиса_де_Бурбона.jpeg': {'path': '1784_mm_dd_i_Семья_инфанта_Дона_Луиса_де_Бурбона.jpeg',
#   'name_of_painting': 'Семья инфанта Дона Луиса де Бурбона',
#   'year': '1784',
#   'most_common_colors_ever': {'(43, 37, 31)': 774,
#    '(91, 79, 63)': 1841,
#    '(16, 15, 14)': 0,
#    '(187, 177, 158)': 1858,
#    '(135, 139, 133)': 414,
#    '(144, 121, 84)': 1474,
#    '(97, 54, 38)': 1393}},
#  '1779_mm_dd_i_Продавщицы_посуды.jpeg': {'path': '1779_mm_dd_i_Продавщицы_посуды.jpeg',
#   'name_of_painting': 'Продавщицы посуды',
#   'year': '1779',
#   'most_common_colors_ever': {'(43, 37, 31)': 9987,
#    '(91, 79, 63)': 1555,
#    '(16, 15, 14)': 8593,
#    '(187, 177, 158)': 79,
#    '(135, 139, 133)': 7,
#    '(144, 121, 84)': 367,
#    '(97, 54, 38)': 374}},
#  '1771_mm_dd_a_Автопортрет.jpeg': {'path': '1771_mm_dd_a_Автопортрет.jpeg',
#   'name_of_painting': 'Автопортрет',
#   'year': '1771',
#   'most_common_colors_ever': {'(43, 37, 31)': 5065,
#    '(91, 79, 63)': 640,
#    '(16, 15, 14)': 9031,
#    '(187, 177, 158)': 21,
#    '(135, 139, 133)': 169,
#    '(144, 121, 84)': 256,
#    '(97, 54, 38)': 243}},
#  '1812_mm_dd_i_Святой_Иоанн_Креститель_в_пустыне.jpeg': {'path': '1812_mm_dd_i_Святой_Иоанн_Креститель_в_пустыне.jpeg',
#   'name_of_painting': 'Святой Иоанн Креститель в пустыне',
#   'year': '1812',
#   'most_common_colors_ever': {'(43, 37, 31)': 12060,
#    '(91, 79, 63)': 1418,
#    '(16, 15, 14)': 6490,
#    '(187, 177, 158)': 51,
#    '(135, 139, 133)': 15,
#    '(144, 121, 84)': 356,
#    '(97, 54, 38)': 215}},
#  '1808_mm_dd_i_Госпожа_Франсиска_Сабас_Гарсия.jpeg': {'path': '1808_mm_dd_i_Госпожа_Франсиска_Сабас_Гарсия.jpeg',
#   'name_of_painting': 'Госпожа Франсиска Сабас Гарсия',
#   'year': '1808',
#   'most_common_colors_ever': {'(43, 37, 31)': 448,
#    '(91, 79, 63)': 464,
#    '(16, 15, 14)': 2,
#    '(187, 177, 158)': 0,
#    '(135, 139, 133)': 0,
#    '(144, 121, 84)': 6301,
#    '(97, 54, 38)': 1619}},
#  '1777_mm_dd_i_Драка_в_Вента_Нуева.jpeg': {'path': '1777_mm_dd_i_Драка_в_Вента_Нуева.jpeg',
#   'name_of_painting': 'Драка в Вента Нуева',
#   'year': '1777',
#   'most_common_colors_ever': {'(43, 37, 31)': 13783,
#    '(91, 79, 63)': 907,
#    '(16, 15, 14)': 2182,
#    '(187, 177, 158)': 5,
#    '(135, 139, 133)': 3,
#    '(144, 121, 84)': 368,
#    '(97, 54, 38)': 203}},
#  '1789_mm_dd_i_Королева_Мария_Луиза.jpeg': {'path': '1789_mm_dd_i_Королева_Мария_Луиза.jpeg',
#   'name_of_painting': 'Королева Мария Луиза',
#   'year': '1789',
#   'most_common_colors_ever': {'(43, 37, 31)': 3346,
#    '(91, 79, 63)': 1130,
#    '(16, 15, 14)': 8458,
#    '(187, 177, 158)': 1,
#    '(135, 139, 133)': 1,
#    '(144, 121, 84)': 1260,
#    '(97, 54, 38)': 562}},
#  '1823_mm_dd_i_Портрет_дона_Рамона_Сатуэ.jpeg': {'path': '1823_mm_dd_i_Портрет_дона_Рамона_Сатуэ.jpeg',
#   'name_of_painting': 'Портрет дона Рамона Сатуэ',
#   'year': '1823',
#   'most_common_colors_ever': {'(43, 37, 31)': 12187,
#    '(91, 79, 63)': 1469,
#    '(16, 15, 14)': 6855,
#    '(187, 177, 158)': 0,
#    '(135, 139, 133)': 0,
#    '(144, 121, 84)': 482,
#    '(97, 54, 38)': 711}},
#  '1807_mm_dd_i_Портрет_министра_юстиции_Испании_Хосе_Антонио_Маркеса_Кабальеро.jpeg': {'path': '1807_mm_dd_i_Портрет_министра_юстиции_Испании_Хосе_Антонио_Маркеса_Кабальеро.jpeg',
#   'name_of_painting': 'Портрет министра юстиции Испании Хосе Антонио Маркеса Кабальеро',
#   'year': '1807',
#   'most_common_colors_ever': {'(43, 37, 31)': 172,
#    '(91, 79, 63)': 160,
#    '(16, 15, 14)': 14422,
#    '(187, 177, 158)': 70,
#    '(135, 139, 133)': 45,
#    '(144, 121, 84)': 70,
#    '(97, 54, 38)': 53}},
#  '1787_mm_dd_i_Портрет_графа_Альтамира.jpeg': {'path': '1787_mm_dd_i_Портрет_графа_Альтамира.jpeg',
#   'name_of_painting': 'Портрет графа Альтамира',
#   'year': '1787',
#   'most_common_colors_ever': {'(43, 37, 31)': 3132,
#    '(91, 79, 63)': 1521,
#    '(16, 15, 14)': 3793,
#    '(187, 177, 158)': 299,
#    '(135, 139, 133)': 1262,
#    '(144, 121, 84)': 109,
#    '(97, 54, 38)': 668}},
#  '1820_mm_dd_i_Читающие_мужчины.jpeg': {'path': '1820_mm_dd_i_Читающие_мужчины.jpeg',
#   'name_of_painting': 'Читающие мужчины',
#   'year': '1820',
#   'most_common_colors_ever': {'(43, 37, 31)': 10160,
#    '(91, 79, 63)': 1778,
#    '(16, 15, 14)': 3680,
#    '(187, 177, 158)': 0,
#    '(135, 139, 133)': 0,
#    '(144, 121, 84)': 215,
#    '(97, 54, 38)': 1488}},
#  '1786_mm_dd_i_Цветочницы,_или_весной.jpeg': {'path': '1786_mm_dd_i_Цветочницы,_или_весной.jpeg',
#   'name_of_painting': 'Цветочницы, или весной',
#   'year': '1786',
#   'most_common_colors_ever': {'(43, 37, 31)': 6807,
#    '(91, 79, 63)': 790,
#    '(16, 15, 14)': 4092,
#    '(187, 177, 158)': 49,
#    '(135, 139, 133)': 442,
#    '(144, 121, 84)': 553,
#    '(97, 54, 38)': 1786}},
#  '1779_mm_dd_i_Солдат_и_сеньора.jpeg': {'path': '1779_mm_dd_i_Солдат_и_сеньора.jpeg',
#   'name_of_painting': 'Солдат и сеньора',
#   'year': '1779',
#   'most_common_colors_ever': {'(43, 37, 31)': 12213,
#    '(91, 79, 63)': 1030,
#    '(16, 15, 14)': 1141,
#    '(187, 177, 158)': 8,
#    '(135, 139, 133)': 2,
#    '(144, 121, 84)': 359,
#    '(97, 54, 38)': 152}},
#  '1799_mm_dd_i_Портрет_герцога_де_Осуна.jpeg': {'path': '1799_mm_dd_i_Портрет_герцога_де_Осуна.jpeg',
#   'name_of_painting': 'Портрет герцога де Осуна',
#   'year': '1799',
#   'most_common_colors_ever': {'(43, 37, 31)': 12958,
#    '(91, 79, 63)': 1374,
#    '(16, 15, 14)': 3576,
#    '(187, 177, 158)': 52,
#    '(135, 139, 133)': 154,
#    '(144, 121, 84)': 100,
#    '(97, 54, 38)': 441}},
#  '1778_mm_dd_i_Игроки_в_карты.jpeg': {'path': '1778_mm_dd_i_Игроки_в_карты.jpeg',
#   'name_of_painting': 'Игроки в карты',
#   'year': '1778',
#   'most_common_colors_ever': {'(43, 37, 31)': 13128,
#    '(91, 79, 63)': 793,
#    '(16, 15, 14)': 5596,
#    '(187, 177, 158)': 14,
#    '(135, 139, 133)': 76,
#    '(144, 121, 84)': 332,
#    '(97, 54, 38)': 226}},
#  '1823_mm_dd_i_Сатурн,_пожирающий_своих_детей.jpeg': {'path': '1823_mm_dd_i_Сатурн,_пожирающий_своих_детей.jpeg',
#   'name_of_painting': 'Сатурн, пожирающий своих детей',
#   'year': '1823',
#   'most_common_colors_ever': {'(43, 37, 31)': 6566,
#    '(91, 79, 63)': 3115,
#    '(16, 15, 14)': 3366,
#    '(187, 177, 158)': 0,
#    '(135, 139, 133)': 0,
#    '(144, 121, 84)': 462,
#    '(97, 54, 38)': 1872}},
#  '1788_mm_dd_s_Жмурки_(эскиз).jpeg': {'path': '1788_mm_dd_s_Жмурки_(эскиз).jpeg',
#   'name_of_painting': 'Жмурки (эскиз)',
#   'year': '1788',
#   'most_common_colors_ever': {'(43, 37, 31)': 2071,
#    '(91, 79, 63)': 1137,
#    '(16, 15, 14)': 1749,
#    '(187, 177, 158)': 481,
#    '(135, 139, 133)': 144,
#    '(144, 121, 84)': 2473,
#    '(97, 54, 38)': 398}},
#  '1777_mm_dd_i_Выпивоха.jpeg': {'path': '1777_mm_dd_i_Выпивоха.jpeg',
#   'name_of_painting': 'Выпивоха',
#   'year': '1777',
#   'most_common_colors_ever': {'(43, 37, 31)': 9177,
#    '(91, 79, 63)': 2380,
#    '(16, 15, 14)': 2770,
#    '(187, 177, 158)': 8,
#    '(135, 139, 133)': 1,
#    '(144, 121, 84)': 126,
#    '(97, 54, 38)': 1022}},
#  '1788_mm_dd_i_Луг_Сан-Исидро.jpeg': {'path': '1788_mm_dd_i_Луг_Сан-Исидро.jpeg',
#   'name_of_painting': 'Луг Сан-Исидро',
#   'year': '1788',
#   'most_common_colors_ever': {'(43, 37, 31)': 5512,
#    '(91, 79, 63)': 491,
#    '(16, 15, 14)': 965,
#    '(187, 177, 158)': 0,
#    '(135, 139, 133)': 0,
#    '(144, 121, 84)': 154,
#    '(97, 54, 38)': 3269}},
#  '1775_mm_dd_i_Собаки_на_поводке.jpeg': {'path': '1775_mm_dd_i_Собаки_на_поводке.jpeg',
#   'name_of_painting': 'Собаки на поводке',
#   'year': '1775',
#   'most_common_colors_ever': {'(43, 37, 31)': 232,
#    '(91, 79, 63)': 729,
#    '(16, 15, 14)': 8,
#    '(187, 177, 158)': 0,
#    '(135, 139, 133)': 0,
#    '(144, 121, 84)': 67,
#    '(97, 54, 38)': 2705}},
#  '1775_mm_dd_i_Охотник_с_собакой.jpeg': {'path': '1775_mm_dd_i_Охотник_с_собакой.jpeg',
#   'name_of_painting': 'Охотник с собакой',
#   'year': '1775',
#   'most_common_colors_ever': {'(43, 37, 31)': 6771,
#    '(91, 79, 63)': 1831,
#    '(16, 15, 14)': 3016,
#    '(187, 177, 158)': 225,
#    '(135, 139, 133)': 1547,
#    '(144, 121, 84)': 180,
#    '(97, 54, 38)': 107}},
#  '1812_mm_dd_i_Натюрморт_с_ощипанной_индейкой_и_сковородой_с_рыбой.jpeg': {'path': '1812_mm_dd_i_Натюрморт_с_ощипанной_индейкой_и_сковородой_с_рыбой.jpeg',
#   'name_of_painting': 'Натюрморт с ощипанной индейкой и сковородой с рыбой',
#   'year': '1812',
#   'most_common_colors_ever': {'(43, 37, 31)': 2947,
#    '(91, 79, 63)': 1969,
#    '(16, 15, 14)': 1888,
#    '(187, 177, 158)': 54,
#    '(135, 139, 133)': 1493,
#    '(144, 121, 84)': 819,
#    '(97, 54, 38)': 99}},
#  '1819_mm_dd_i_Портрет_Хуана_Антонио_Куэрво.jpeg': {'path': '1819_mm_dd_i_Портрет_Хуана_Антонио_Куэрво.jpeg',
#   'name_of_painting': 'Портрет Хуана Антонио Куэрво',
#   'year': '1819',
#   'most_common_colors_ever': {'(43, 37, 31)': 8976,
#    '(91, 79, 63)': 271,
#    '(16, 15, 14)': 12481,
#    '(187, 177, 158)': 413,
#    '(135, 139, 133)': 48,
#    '(144, 121, 84)': 180,
#    '(97, 54, 38)': 197}},
#  '1823_mm_dd_i_Юдифь_и_Олоферн.jpeg': {'path': '1823_mm_dd_i_Юдифь_и_Олоферн.jpeg',
#   'name_of_painting': 'Юдифь и Олоферн',
#   'year': '1823',
#   'most_common_colors_ever': {'(43, 37, 31)': 6549,
#    '(91, 79, 63)': 5449,
#    '(16, 15, 14)': 1301,
#    '(187, 177, 158)': 178,
#    '(135, 139, 133)': 80,
#    '(144, 121, 84)': 78,
#    '(97, 54, 38)': 54}},
#  '1783_mm_dd_i_Портрет_Марии_Терезы_де_Бурбон_и_Валлабриг.jpeg': {'path': '1783_mm_dd_i_Портрет_Марии_Терезы_де_Бурбон_и_Валлабриг.jpeg',
#   'name_of_painting': 'Портрет Марии Терезы де Бурбон и Валлабриг',
#   'year': '1783',
#   'most_common_colors_ever': {'(43, 37, 31)': 2769,
#    '(91, 79, 63)': 2408,
#    '(16, 15, 14)': 1109,
#    '(187, 177, 158)': 109,
#    '(135, 139, 133)': 33,
#    '(144, 121, 84)': 1938,
#    '(97, 54, 38)': 1545}},
#  '1827_mm_dd_i_Хуан_Баутиста_де_Мугиро.jpeg': {'path': '1827_mm_dd_i_Хуан_Баутиста_де_Мугиро.jpeg',
#   'name_of_painting': 'Хуан Баутиста де Мугиро',
#   'year': '1827',
#   'most_common_colors_ever': {'(43, 37, 31)': 6331,
#    '(91, 79, 63)': 1,
#    '(16, 15, 14)': 807,
#    '(187, 177, 158)': 0,
#    '(135, 139, 133)': 0,
#    '(144, 121, 84)': 8,
#    '(97, 54, 38)': 1539}}}

# %%
for i in files: 
    print(' '.join((i.split('_')[4:])).replace('.jpg', ''))
# Out:
# Тирана.jpeg
# Совет Филиппин.jpeg
# Охота.jpeg
# Деревенская коррида.jpeg
# Портрет испанского короля Карла III.jpeg
# Махи на балконе.jpeg
# Герцогиня Альба и дуэнья "Ла Беата".jpeg
# Портрет Тибурсио Переса-и-Куэрво.jpeg
# Жозефа Байе или Леокадия Вейс.jpeg
# Хосе Монино Редондо, граф Флоридабланка.jpeg
# Автопортрет.jpeg
# Портрет доньи Антонии Сарате.jpeg
# Портрет Фердинанда VII де Бурбона, короля Испании.jpeg
# Расстрел повстанцев 3 мая 1808 года в Мадриде.jpeg
# Карл IV.jpeg
# Фреска часовни Св. Антония Флоридского, деталь 4.jpeg
# Кузница.jpeg
# Граф Тахо.jpeg
# Точильщик.jpeg
# Прогулка в Андалусии.jpeg
# Мёртвая индейка.jpeg
# Портрет матадора Педро Ромеро.jpeg
# Портрет Бартоломе Суреда-и-Мизероль.jpeg
# Женщина с двумя мальчиками у фонтана.jpeg
# Охота на приманку.jpeg
# Бродячие комедианты.jpeg
# Победоносный Ганнибал впервые видит Италию с вершин Альп.jpeg
# Пьяный каменщик (эскиз).jpeg
# Процессия флагеллантов (бичующихся).jpeg
# Портрет дона Себастьяна Габриеля де Борбона-и-Браганца.jpeg
# Венера и Адонис.jpeg
# Мальчики с мастифом.jpeg
# Ходули.jpeg
# Портрет доктора Андреса дель Пераля.jpeg
# Мальчики собирают фрукты.jpeg
# Свадьба.jpeg
# Две женщины и мужчина.jpeg
#
# Серия мрачных картин. Два монаха.jpeg
# Падение.jpeg
# Серия мрачных картин- Паломники.jpeg
# Св. Григорий Магно.jpeg
# Графиня Карпио, маркиза де ла Солана.jpeg
# Дон Педро де Алькантара из рода Тельес-Хиронов, 9-й герцог Осуна.jpeg
# Сон.jpeg
# Молодая дама в мантилье и баскине.jpeg
# Мария Тереза де Виллабрига1.jpeg
# Метель.jpeg
# Фреска часовни Св. Антония Флоридского, деталь 5.jpeg
# Восстание 2 мая 1808 года в Мадриде.jpeg
# Молодая женщина с письмом.jpeg
# Портрет Леандро Фернандеса Моратина.jpeg
# Портрет актрисы Антонии Сарате.jpeg
# Двор сумасшедшего дома.jpeg
# Портрет Мартина Сапатера.jpeg
# Маркиза фон Виллафранка.jpeg
# Портрет художницы Лолы Хименес.jpeg
# Трибунал инквизиции.jpeg
# Танец на берегу реки Мансанарес.jpeg
# Портрет Луиса Марии де Кистуэ-и-Мартинеса.jpeg
# Мануэль Годой, герцог Алькудии, "принц мира".jpeg
# Портрет Карлоса IV.jpeg
# Прачки.jpeg
# Портрет Педро Мокарте, певца собора Толедо.jpeg
# Пикадор, оказавшись на быке.jpeg
# Портрет графини-герцогини Бенавенте.jpeg
# Портрет дамы.jpeg
# Коррида на разделенной арене.jpeg
# Портрет Дон Хосе Керальто.jpeg
# Обрезание.jpeg
# Чудо святого Антония Падуанского (фрагмент).jpeg
# Фреска часовни Св. Антония Флоридского, деталь 2.jpeg
# Портрет доньи Нарсисы Бараньяна де Гойкоечеа.jpeg
# Себастьян Мартинес и Перес.jpeg
# Портрет художника Хулио Асенсио.jpeg
# Фернандо III Наварры и VII Кастилии.jpeg
# Богородица, как королева мучеников (фрагмент).jpeg
# Портрет Марии Терезы де Валлабриг на коне.jpeg
# Зонтик.jpeg
# Маха на балконе.jpeg
# Любительская коррида.jpeg
# Ковен, или великий козел.jpeg
# Ведьмы в воздухе.jpeg
# Мануэль Осорио де Зунига (фрагмент).jpeg
# Автопортрет с доктором Арриетой.jpeg
# Игра "Конь и всадник".jpeg
# Ярмарка в Мадриде.jpeg
# Маха и Селестина на балконе.jpeg
# Автопортрет в очках.jpeg
# Качели.jpeg
# Кардинал Луис Мария де Борон.jpeg
# Асмодей, или Фантастическое видение.jpeg
# Последователи. Штурм крепости на скале.jpeg
# Жмурки.jpeg
# Рождение Богородицы.jpeg
# Портрет Хуана Антонио Льоренте.jpeg
# Пикадор.jpeg
# Эскизы гобеленов для королевских дворцов Прадо и Эскориал. Мальчики с мастифом.jpeg
# Стычка с мамелюками 2 мая 1808 года в Мадриде.jpeg
# Фердинанд Гиймарде — французский посол в Испании.jpeg
# Лето.jpeg
# Два старика за едой.jpeg
# Шабаш ведьм.jpeg
# Король Испании Карл IV и его семья.jpeg
# С гитарой.jpeg
# Чудо Св. Антония.jpeg
# Похороны сардинки.jpeg
# Портрет французского посла в Испании Фердинанда Гиймардета.jpeg
# Портрет маркизы Сантьяго.jpeg
# Бой быков. Суэрте де варас.jpeg
# Заклинание.jpeg
# Портрет актера Исидро Маркеса.jpeg
# Хосе Пио де Молина.jpeg
# Портрет Марии Луизы де Бурбон.jpeg
# Портрет сеньоры Кеан Бермудес, жены Хуана Агостино Бермудеса.jpeg
# Соломенное чучело (Марионетка).jpeg
# Хосе Моньино, 1-й граф Флоридабланка.jpeg
# Мария Тереза де Виллабрига.jpeg
# Фреска часовни Св. Антония Флоридского, деталь 3.jpeg
# Портрет Хосе Коста-и-Бонелиса по прозвищу Пепито.jpeg
# Мальчики взбирались на дерево (картон для гобелена).jpeg
# Тонущая собака.jpeg
# Девушки с кувшинами.jpeg
# Обнаженная Маха.jpeg
# Дон Мануэль Осорио Манрике де Суньига, ребёнок.jpeg
# Портрет графини Чинчон.jpeg
# Натюрморт с рёбрами и головой ягнёнка - прилавок мясника.jpeg
# Тюремная сцена.jpeg
# Автопортрет.jpeg
# Поединок на дубинах.jpeg
# Хосе Альварес де Толедо, маркиз Виллафранка и герцог Альба.jpeg
# Молочница из Бордо.jpeg
# Натюрморт с мертвой птицей.jpeg
# Донья Леокадия Соррилья (домработница художника).jpeg
# Фреска часовни Св. Антония Флоридского "Чудо Святого Антония".jpeg
# Девушка с кувшином.jpeg
# Два старика.jpeg
# Столб с призами.jpeg
# Портрет герцогини Альтамира с дочерью Марией Августиной.jpeg
# Семья Карла IV, фрагмент.jpeg
# Врач.jpeg
# Донья Тереза Луиза де Суреда.jpeg
# Жертвоприношение для Весты.jpeg
# Распятый Христос.jpeg
# Пороховой завод в Сьерра.jpeg
# Король испанский Фердинанд VII.jpeg
# Колосс.jpeg
# Дантист.jpeg
# Портрет Мариано Гойи, внука художника.jpeg
# Разносчица воды.jpeg
# Жертвоприношение Пану.jpeg
# Портрет герцога Веллингтона.jpeg
# Карнавал.jpeg
# Портрет Марианы Вальдштейн.jpeg
# Портрет доньи Терезы Суреда.jpeg
# Портрет Марии Терезы Кайетана де Сильва, герцогини Альба.jpeg
# Гаспар Мельчос де Ховельянос.jpeg
# Дьявольская лампа.jpeg
# Цикл картин "Ужасы войны". Визит монаха.jpeg
# Хосефа Байеу, жена художника.jpeg
# Сон Святого Иосифа.jpeg
# Дегустация вина около церкви Святого Исидора в День святого Спаса.jpeg
# Благовещение.jpeg
# Портрет жены Хуана Агустина Бермудеса.jpeg
# Святой Франциск Борджиа изгоняет.jpeg
# Карл III в костюме охотника.jpeg
# Фреска часовни Св. Антония Флоридского, деталь 1.jpeg
# Бой с молодым быком.jpeg
# Герцог Веллингтон.jpeg
# Автопортрет за работой.jpeg
# Слепой гитарист1.jpeg
# Игра Пелота.jpeg
# Мальчики надувают мочевой пузырь.jpeg
# Расчленение трупа иезуита Бребёфа.jpeg
# Портрет семьи герцога Осуна с детьми.jpeg
# Портрет королевы Марии Луизы в мантилье.jpeg
# Женщина с веером.jpeg
# Сбор винограда или осень.jpeg
# Пикник.jpeg
# Сцена боя быков.jpeg
# Святое семейство1.jpeg
# Большой козел или шабаш ведьм.jpeg
# Портрет маркизы де Понтехос и Сандоваль, герцогини Понтехо.jpeg
# Прежде и теперь.jpeg
# Поклонение Божьему имени или Слава.jpeg
# Дон Валентин Беллвис де Монсада и Писарро.png
# Интерьер тюрьмы.jpeg
# Драка в таверне.jpeg
# Портрет Виктора Гая.jpeg
# maha odetaya.jpeg
# Маркиза де Санта Круз.jpeg
# Луис Мария де Бурбон-и-Вальябрига.jpeg
# Хуан Мартин Диас.jpeg
# Пикник.jpeg
# Неравный брак.jpeg
# Огонь в ночи.jpeg
# Маскарад в Андалусии.jpeg
# Рандеву.jpeg
# Последнее причастие святого Иосифа Каласанса.jpeg
# Донья Тадея Ариас де Энрикес.jpeg
# Портрет художника Франсиско Байеу.jpeg
# Портрет герцогини Альба.jpeg
# Автопортрет1.jpeg
# Мальчики играют в солдатиков.jpeg
# Аллегория города Мадрида.jpeg
# Полет ведьм.jpeg
# Портрет доньи Исабель Кобос де Порсель.jpeg
# Воздушный змей.jpeg
# Тюремная сцена.jpeg
# Эскизы гобеленов для королевских дворцов Прадо и Эскориал. Полдник на лоне природы.jpeg
# Дровосеки.jpeg
# Паломничество в Сан-Исидро.jpeg
# Цикл картин "Ужасы войны". Чумной барак.jpeg
# Разбой.jpeg
# Архитектор Дон Тибурсио.jpeg
# Фреска часовни Св. Антония Флоридского, деталь 6.jpeg
# Майское дерево.jpeg
# Портрет Мариано Гойи, внука художника.jpeg
# Портрет графа Фернанда Нуньеса VII.jpeg
# Семья инфанта Дона Луиса де Бурбона.jpeg
# Продавщицы посуды.jpeg
# Автопортрет.jpeg
# Святой Иоанн Креститель в пустыне.jpeg
# Госпожа Франсиска Сабас Гарсия.jpeg
# Драка в Вента Нуева.jpeg
# Королева Мария Луиза.jpeg
# Портрет дона Рамона Сатуэ.jpeg
# Портрет министра юстиции Испании Хосе Антонио Маркеса Кабальеро.jpeg
# Портрет графа Альтамира.jpeg
# Читающие мужчины.jpeg
# Цветочницы, или весной.jpeg
# Солдат и сеньора.jpeg
# Портрет герцога де Осуна.jpeg
# Игроки в карты.jpeg
# Сатурн, пожирающий своих детей.jpeg
# Жмурки (эскиз).jpeg
# Выпивоха.jpeg
# Луг Сан-Исидро.jpeg
# Собаки на поводке.jpeg
# Охотник с собакой.jpeg
# Натюрморт с ощипанной индейкой и сковородой с рыбой.jpeg
# Портрет Хуана Антонио Куэрво.jpeg
# Юдифь и Олоферн.jpeg
# Портрет Марии Терезы де Бурбон и Валлабриг.jpeg
# Хуан Баутиста де Мугиро.jpeg

# %% [markdown]
# #### BayesianGaussianMixture:

# %%
results_BGM, years = analyze_most_popular_ever_colors(folder_path, np.array(most_common_colors_gaussbayes))

# %%
plot_bar_distribution(results_BGM, years, model_name='BayesianGaussianMixture')

# %%
df_BGM = pd.DataFrame.from_dict(results_BGM, orient='index', columns=years)
df_BGM = df_BGM.T
df_BGM = df_BGM.reset_index().rename(columns={'index': 'year'})
df_BGM = df_BGM.groupby('year', as_index=False).sum()
df_BGM.head()
# Out:
#    year  (126, 124, 113)  (51, 50, 49)  (125, 78, 53)  (199, 164, 114)  \
# 0  1882              471         11074            229             1465
# 1  1883              814           321           1403             1988
# 2  1885              577          6982            126              103
# 3  1886              307          5684            612              469
# 4  1888              333          2897           1588             1141
#
#    (201, 195, 184)  (21, 22, 24)  (55, 73, 93)
# 0              303         11192          1388
# 1              492           135            17
# 2              561          2532           481
# 3              154          4721           477
# 4               20          1710            20

# %%
len(df_BGM)
# Out:
# 49

# %% [markdown]
# #### KMeans (без перевода в LAB):

# %%
results_gb, years = analyze_most_popular_ever_colors(folder_path, np.array(most_common_colors_nolab))

# %%
plot_bar_distribution(results_gb, years, model_name='KMeans (RGB)')

# %% [markdown]
# ### Смотрим отдельно основные цвета

# %%
def is_color_in_range(lab_pixel, lower_bound, upper_bound):
    return np.all((lab_pixel >= lower_bound) & (lab_pixel <= upper_bound))

# %%
def count_pixels_in_color_range(image_path, lower_bound, upper_bound):
    img = cv2.imread(image_path)
    
    img = cv2.resize(img, (128, 128)) 
    img_lab = cv2.cvtColor(img, cv2.COLOR_BGR2LAB)
    lab_array = img_lab.reshape(-1, 3)
    
    mask = np.apply_along_axis(is_color_in_range, 1, lab_array, lower_bound, upper_bound)
    total_pixels = lab_array.shape[0]
    
    color_pixel_count = np.sum(mask)
    return color_pixel_count, total_pixels

# %%
def analyze_images_in_range(folder_path, lower_bound, upper_bound):
    results = {}
    total_pixels_per_year = {}
    
    for filename in sorted(os.listdir(folder_path)):
        if filename.lower().endswith(('.png', '.jpg', '.jpeg')):
            image_path = os.path.join(folder_path, filename)
            
            year = extract_year_from_filename(filename)
            if year is None:
                continue
            
            color_count, total_pixels = count_pixels_in_color_range(image_path, lower_bound, upper_bound)
            
            if year in results:
                results[year] += color_count
                total_pixels_per_year[year] += total_pixels
            else:
                results[year] = color_count
                total_pixels_per_year[year] = total_pixels
    
    years = np.array(list(results.keys()))
    normalized_counts = np.array([results[year] for year in years]) # / total_pixels_per_year[year] for year in years])
    
    sorted_indices = np.argsort(years)
    years = years[sorted_indices]
    normalized_counts = normalized_counts[sorted_indices]
    
    return normalized_counts, years

# %%
def plot_color_distribution(results, years, color_name, color_hex):
    sns.set_theme(style="white")
    plt.rcParams['font.family'] = 'serif'
    plt.rcParams['font.serif'] = ['Times New Roman']
    
    plt.figure(figsize=(15, 10))
    plt.bar(range(len(years)), results, color=color_hex, label=f'{color_name} диапазон')
    plt.title(f'Распределение цвета ({color_name}) по годам', fontdict={'fontsize': 16, 'fontweight': 'bold'})
    plt.xlabel('Год', fontdict={'fontsize': 12})
    plt.ylabel('Доля пикселей в изображениях', fontdict={'fontsize': 12})
    plt.xticks(ticks=range(len(years)), labels=years, rotation=45)
    # plt.legend(loc='upper left')
    plt.xlim(-0.5, len(years) - 0.5)
    plt.show()

# %%
def get_lab_color_range(lab_center, tolerance):
    lower_bound = np.clip(lab_center - tolerance, [0, -128, -128], [100, 127, 127])
    upper_bound = np.clip(lab_center + tolerance, [0, -128, -128], [100, 127, 127])
    return lower_bound, upper_bound

# %%
def analyze_images_by_color_mean(folder_path, color):
    results = {}
    total_pixels_per_year = {}
    for filename in sorted(os.listdir(folder_path)):
        if filename.lower().endswith(('.png', '.jpg', '.jpeg')):
            image_path = os.path.join(folder_path, filename)
            
            year = extract_year_from_filename(filename)
            im = cv2.imread(image_path, cv2.IMREAD_COLOR)
            im = cv2.resize(im, (128, 128))
            if color == 'red':
                im = im[:, :, 0]
            elif color == 'green':
                im = im[:, :,1]
            elif color == 'blue':
                im = im[:, :, 2]
            elif color == 'yellow':
                im = im[:, :, 0].astype(float) / 2 + im[:, :, 1].astype(float) / 2
            color_count = im.mean() / 256.

            if year is None:
                continue

            if year in results:
                results[year].append(color_count)
            else:
                results[year] = [color_count]

    for year in results:
        results[year] = np.mean(results[year])

    years = np.array(list(results.keys()))
    normalized_counts = np.array(list(results.values()))
    sorted_indices = np.argsort(years)
    years = years[sorted_indices]
    normalized_counts = normalized_counts[sorted_indices]
    

    return normalized_counts, years

# %% [markdown]
# #### Красный:

# %%
results, years = analyze_images_by_color_mean(folder_path, color='red')
results
# Out:
# array([0.15827646, 0.11685479, 0.22710907, 0.39117593, 0.34759378,
#        0.34941157, 0.30679855, 0.28520525, 0.25358588, 0.2195456 ,
#        0.20100226, 0.16075444, 0.34723401, 0.41672312, 0.34928819,
#        0.35090516, 0.25672588, 0.22502971, 0.17337084, 0.36428431,
#        0.29485731, 0.28479725, 0.26642405, 0.31754661, 0.24869184,
#        0.21988835, 0.19356537, 0.16695809, 0.15876222, 0.17827916,
#        0.25158882, 0.23356926, 0.16306273, 0.15962601, 0.15402102,
#        0.23456883, 0.15739264, 0.15288591, 0.18893235, 0.20995969,
#        0.2174032 , 0.21931326, 0.330616  , 0.18938583, 0.15890431,
#        0.11586595, 0.1819764 , 0.17229283, 0.22513247, 0.21129799,
#        0.1928637 ])

# %%
color_hex = '#{:02x}{:02x}{:02x}'.format(152, 79, 50)
plot_color_distribution(results, years, color_name="красный", color_hex=color_hex)

# %% [markdown]
# #### Зеленый:

# %%
results, years = analyze_images_by_color_mean(folder_path, color='green')

# %%
color_hex = '#{:02x}{:02x}{:02x}'.format(145, 130, 104)
plot_color_distribution(results, years, color_name="зеленый", color_hex=color_hex)

# %% [markdown]
# #### Синий:

# %%
results, years = analyze_images_by_color_mean(folder_path, color='blue')

# %%
color_hex = '#{:02x}{:02x}{:02x}'.format(102, 118, 146)
plot_color_distribution(results, years, color_name="синий", color_hex=color_hex)

# %% [markdown]
# #### Желтый:

# %%
results, years = analyze_images_by_color_mean(folder_path, color='yellow')

# %%
color_hex = '#{:02x}{:02x}{:02x}'.format(198, 159, 82)
plot_color_distribution(results, years, color_name="желтый", color_hex=color_hex)

# %% [markdown]
# ### Смотрим 7 самых часто используемых цветов за каждый год

# %%
def rgb_to_lab(rgb_pixels):
    rgb_pixels = rgb_pixels / 255.0
    lab_pixels = scolor.rgb2lab(rgb_pixels.reshape(-1, 1, 3)).reshape(-1, 3)
    return lab_pixels

# def rgb_to_lab(rgb_pixels):
#     rgb_pixels = np.array(rgb_pixels, dtype=np.float64) / 255.0
#     lab_pixels = scolor.rgb2lab(rgb_pixels.reshape(-1, 1, 3)).reshape(-1, 3)
#     return lab_pixels

def lab_to_rgb(lab_color):
    lab_color = np.array(lab_color).reshape(1, 1, 3)
    rgb_color = scolor.lab2rgb(lab_color).reshape(3) * 255
    rgb_color = np.clip(rgb_color, 0, 255).astype(int)
    return tuple(rgb_color)

# %%
def get_most_common_colors(image_path, classifier, num_colors=7, resize_dim=(128, 128), rounding=10):
# def get_most_common_colors(image_path, classifier, num_colors=7, resize_dim=(50, 50), rounding=10):
    image = Image.open(image_path).convert('RGB')
    image = image.resize(resize_dim)
    pixels = np.array(image).reshape(-1, 3)
    pixels = rgb_to_lab(pixels)

    if classifier == 'Counter':
        pixels = (pixels // rounding) * rounding
        color_counter = Counter(map(tuple, pixels))  # Преобразуем в кортежи
        most_common = color_counter.most_common(num_colors)
    
    elif classifier == 'KMeans':
        kmeans = KMeans(n_clusters=num_colors, random_state=42)
        kmeans.fit(pixels)
        labels = kmeans.labels_
        cluster_centers = kmeans.cluster_centers_
        
        color_counter = Counter(labels)
        most_common1 = color_counter.most_common(num_colors)
        
        most_common = []
        for cluster_idx, count in most_common1:
            lab_color = cluster_centers[cluster_idx]
            rgb_color = lab_to_rgb(lab_color)
            # most_common.append((rgb_color, count))
            # most_common.append((tuple(rgb_color.astype(int)), count))
            most_common.append((rgb_color, count))
            

    elif classifier == 'GM':
        gmm = GaussianMixture(n_components=num_colors, random_state=42)
        gmm.fit(pixels)
        labels = gmm.predict(pixels)
        cluster_centers = gmm.means_

        # Подсчет количества пикселей в каждом кластере
        color_counter = Counter(labels)
        most_common_labels = color_counter.most_common(num_colors)

        most_common = []
        for cluster_idx, count in most_common_labels:
            lab_color = cluster_centers[cluster_idx]
            rgb_color = scolor.lab2rgb(lab_color.reshape(1, 1, 3)).reshape(3) * 255  # LAB → RGB
            most_common.append((tuple(rgb_color.astype(int)), count))  # Преобразуем в кортеж
            
    elif classifier == 'GMM':
        gmm = BayesianGaussianMixture(n_components=num_colors, random_state=42)
        gmm.fit(pixels)
        labels = gmm.predict(pixels)
        cluster_centers = gmm.means_
        
        color_counter = Counter(labels)
        most_common1 = color_counter.most_common(num_colors)
        
        most_common = []
        for cluster_idx, count in most_common1:
            lab_color = cluster_centers[cluster_idx]
            rgb_color = lab_to_rgb(lab_color)
            most_common.append((rgb_color, count))

    return most_common  # Список (цвет, количество пикселей)

# %%
# def get_colors_by_year(images_folder, classifier):
    
#     colors_by_year = {}
    
#     for file in os.listdir(images_folder):
#         if file.endswith('.jpeg') or file.endswith('.jpg') or file.endswith('.png'):
#             try:
#                 year = file.split('_')[0]
#                 year = int(year)
#             except ValueError:
#                 continue
            
#             image_path = os.path.join(images_folder, file)
#             common_colors = get_most_common_colors(image_path, classifier)
            
#             if year not in colors_by_year:
#                 colors_by_year[year] = []
            
#             # add color codes and pixel counts
#             for color, count in common_colors:
#                 colors_by_year[year].append((color, count))
    
#     # top-7 by each year
#     top_colors_by_year = {}
#     for year, colors in colors_by_year.items():
#         if classifier == 'KMeans':
#             # color_counter = Counter({tuple(color): count for color, count in colors.items()})
#             color_counter = Counter(dict(colors)) 
#         else:
#             color_counter = Counter(dict(colors)) # count the number of pixels for each color
#         top_colors = color_counter.most_common(7)
#         top_colors_by_year[year] = {color: count for color, count in top_colors}
        
#     print(top_colors_by_year)
    
#     return top_colors_by_year

def get_colors_by_year(images_folder, classifier):
    
    colors_by_year = {}
    
    for file in os.listdir(images_folder):
        if file.endswith('.jpeg') or file.endswith('.jpg') or file.endswith('.png'):
            # try:
            #     year = file.split('_')[0]
            #     year = int(year)
            # except ValueError:
            #     continue
            year = file
            
            image_path = os.path.join(images_folder, file)
            common_colors = get_most_common_colors(image_path, classifier)
            
            if year not in colors_by_year:
                colors_by_year[year] = []
            
            # add color codes and pixel counts
            for color, count in common_colors:
                colors_by_year[year].append((color, count))
    
    # top-7 by each year
    top_colors_by_year = {}
    for year, colors in colors_by_year.items():
        if classifier == 'KMeans':
            # color_counter = Counter({tuple(color): count for color, count in colors.items()})
            color_counter = Counter(dict(colors)) 
        else:
            color_counter = Counter(dict(colors)) # count the number of pixels for each color
        top_colors = color_counter.most_common(7)
        top_colors_by_year[year] = {str(color): count for color, count in top_colors}
    
    return top_colors_by_year

# %%
def sort_colors_by_luminance(colors):
    # Calculate luminance (L channel) for each color in LAB space and sort by it
    lab_colors = np.array(colors)
    luminance = lab_colors[:, 0]  # L channel in LAB space
    sorted_indices = np.argsort(luminance)  # Sort based on luminance (L channel)
    return np.array(colors)[sorted_indices]

def calculate_brightness(lab_color):
    return lab_color[0]

# %%
def plot_color_distribution(colors_by_year, how, classifier):
    years = [year for year in sorted(colors_by_year.keys()) if colors_by_year[year]] # filter the years for which there is data
    print(years)
    
    # all colors
    all_colors = set()
    for color_dict in colors_by_year.values():
        all_colors.update(color_dict.keys())
    all_colors = list(all_colors)
    
    data = {color: [] for color in all_colors}
    
    # Normalize data on the Y axis (0 to 1) for each year
    for year in years:
        year_data = colors_by_year.get(year, {})
        total_pixels = sum(year_data.values())  # sum of all pixels for one year
        if total_pixels == 0: 
            total_pixels = 1
        for color in all_colors:
            count = year_data.get(color, 0)
            normalized_count = count / total_pixels  # normalizing
            data[color].append(normalized_count)
        
    if how == 'sorted':
        # if classifier == 'GM' or classifier == 'KMeans':
        if classifier in {'GM', 'KMeans', 'GMM'}:
            all_colors = sorted(all_colors, key=lambda color: calculate_brightness(rgb_to_lab(np.array([color]))[0]), reverse=False)
        # sorted_colors = sorted(all_colors, key=lambda color: calculate_brightness(rgb_to_lab(np.array([color]))[0]), reverse=False)
        else:
            all_colors = sort_colors_by_luminance(list(all_colors))
    
    bottom = np.zeros(len(years))
    
    plt.rcParams['font.family'] = 'serif'
    plt.rcParams['font.serif'] = ['Times New Roman']

    plt.figure(figsize=(15, 8))
    
    for color in all_colors:
        # Converting from LAB to RGB for display on a graph
        if classifier == 'Counter':
            lab_color = np.array(color).reshape(1, 1, 3)
            rgb_color = scolor.lab2rgb(lab_color).reshape(3) 
            rgb_color = np.clip(rgb_color, 0, 1)
        
        if how == 'not_sorted':
            if classifier == 'GM':
                # plt.bar(range(len(years)), data[color], bottom=bottom, color=np.array(color)/255.0, label=str(color))
                rgb = ensure_rgb_tuple(color)
                plt.bar(range(len(years)), data[color], bottom=bottom, color=np.array(rgb)/255.0, label=str(rgb))
                bottom += np.array(data[color])
            elif classifier == 'KMeans':
                plt.bar(range(len(years)), data[color], bottom=bottom, color=np.array(color)/255.0, label=str(color))
                bottom += np.array(data[color])
            elif classifier == 'GMM':
                plt.bar(range(len(years)), data[color], bottom=bottom, color=np.array(color)/255.0, label=str(color))
                bottom += np.array(data[color])
            else:
                plt.bar(range(len(years)), data[color], bottom=bottom, color=rgb_color, label=str(color))
                bottom += np.array(data[color])
    
        elif how == 'sorted':
            if classifier == 'GM':
                # plt.bar(range(len(years)), data[color], bottom=bottom, color=np.array(color)/255.0, label=str(color))
                color_tuple = tuple(color) 
                # plt.bar(range(len(years)), data[color_tuple], bottom=bottom, color=np.array(color)/255.0, label=str(color))
                rgb = ensure_rgb_tuple(color)
                plt.bar(range(len(years)), data[color], bottom=bottom, color=np.array(rgb)/255.0, label=str(rgb))
                bottom += np.array(data[color_tuple])
            elif classifier == 'KMeans':
                plt.bar(range(len(years)), data[color], bottom=bottom, color=np.array(color)/255.0, label=str(color))
                bottom += np.array(data[color])
            elif classifier == 'GMM':
                plt.bar(range(len(years)), data[color], bottom=bottom, color=np.array(color)/255.0, label=str(color))
                bottom += np.array(data[color])
            else:
                plt.bar(range(len(years)), data[tuple(color)], bottom=bottom, color=rgb_color, label=str(color))
                bottom += np.array(data[tuple(color)])
    
    plt.xlabel('Год', fontdict={'fontsize': 12})
    plt.ylabel('Нормализованное количество пикселей', fontdict={'fontsize': 12})
    plt.title('Частота использования топ-7 цветов на картинах по годам', fontdict={'fontsize': 16, 'fontweight': 'bold'})
    plt.xticks(ticks=range(len(years)), labels=years, rotation=45)
    plt.show()
    
import ast

def ensure_rgb_tuple(color):
    if isinstance(color, str):
        return ast.literal_eval(color)
    return color

# %% [markdown]
# #### Counter:

# %%
colors_by_year = get_colors_by_year(folder_path, classifier='Counter')

# %%
# pprint(colors_by_year)

# %%
rows = []
for year, colors in colors_by_year.items():
    for (r, g, b), count in colors.items():
        rows.append((year, r, g, b, count))

df = pd.DataFrame(rows, columns=['year', 'R', 'G', 'B', 'Count'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[77], line 3
#       1 rows = []
#       2 for year, colors in colors_by_year.items():
# ----> 3     for (r, g, b), count in colors.items():
#       4         rows.append((year, r, g, b, count))
#       6 df = pd.DataFrame(rows, columns=['year', 'R', 'G', 'B', 'Count'])
#
# ValueError: too many values to unpack (expected 3)

# %%
df
# Out:
#      year     R     G     B  Count
# 0    1938  70.0 -10.0   0.0   1429
# 1    1938  80.0 -10.0   0.0    695
# 2    1938  60.0 -10.0   0.0    497
# 3    1938   0.0   0.0 -10.0    423
# 4    1938  10.0   0.0 -10.0    397
# ..    ...   ...   ...   ...    ...
# 338  1910  60.0   0.0  30.0    805
# 339  1910  70.0 -10.0   0.0    753
# 340  1910  60.0   0.0  20.0    687
# 341  1910  20.0 -10.0 -10.0    659
# 342  1910  50.0   0.0  20.0    644
#
# [343 rows x 5 columns]

# %%
plot_color_distribution(colors_by_year, how='not_sorted', classifier='Counter')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[74], line 1
# ----> 1 plot_color_distribution(colors_by_year, how='not_sorted', classifier='Counter')
#
# Cell In[72], line 41, in plot_color_distribution(colors_by_year, how, classifier)
#      38 for color in all_colors:
#      39     # Converting from LAB to RGB for display on a graph
#      40     if classifier == 'Counter':
# ---> 41         lab_color = np.array(color).reshape(1, 1, 3)
#      42         rgb_color = scolor.lab2rgb(lab_color).reshape(3)
#      43         rgb_color = np.clip(rgb_color, 0, 1)
#
# ValueError: cannot reshape array of size 1 into shape (1,1,3)

# %% [markdown]
# Отсортировано по яркости:

# %%
plot_color_distribution(colors_by_year, how='sorted', classifier='Counter')

# %% [markdown]
# #### GaussianMixture:

# %%
info_dict
# Out:
# {'1799_mm_dd_i_Тирана.jpeg': {'path': '1799_mm_dd_i_Тирана.jpeg',
#   'name_of_painting': 'Тирана',
#   'year': '1799',
#   'most_common_colors_ever': {'(43, 37, 31)': 5026,
#    '(91, 79, 63)': 0,
#    '(16, 15, 14)': 9495,
#    '(187, 177, 158)': 0,
#    '(135, 139, 133)': 0,
#    '(144, 121, 84)': 1,
#    '(97, 54, 38)': 683}},
#  '1775_mm_dd_i_Охота.jpeg': {'path': '1775_mm_dd_i_Охота.jpeg',
#   'name_of_painting': 'Охота',
#   'year': '1775',
#   'most_common_colors_ever': {'(43, 37, 31)': 9265,
#    '(91, 79, 63)': 767,
#    '(16, 15, 14)': 4769,
#    '(187, 177, 158)': 94,
#    '(135, 139, 133)': 2,
#    '(144, 121, 84)': 243,
#    '(97, 54, 38)': 607}},
#  '1812_mm_dd_i_Деревенская_коррида.jpeg': {'path': '1812_mm_dd_i_Деревенская_коррида.jpeg',
#   'name_of_painting': 'Деревенская коррида',
#   'year': '1812',
#   'most_common_colors_ever': {'(43, 37, 31)': 5111,
#    '(91, 79, 63)': 775,
#    '(16, 15, 14)': 8957,
#    '(187, 177, 158)': 0,
#    '(135, 139, 133)': 0,
#    '(144, 121, 84)': 147,
#    '(97, 54, 38)': 1180}},
#  '1787_mm_dd_i_Портрет_испанского_короля_Карла_III.jpeg': {'path': '1787_mm_dd_i_Портрет_испанского_короля_Карла_III.jpeg',
#   'name_of_painting': 'Портрет испанского короля Карла III',
#   'year': '1787',
#   'most_common_colors_ever': {'(43, 37, 31)': 5304,
#    '(91, 79, 63)': 1031,
#    '(16, 15, 14)': 791,
#    '(187, 177, 158)': 0,
#    '(135, 139, 133)': 4,
#    '(144, 121, 84)': 204,
#    '(97, 54, 38)': 2458}},
#  '1814_mm_dd_i_Махи_на_балконе.jpeg': {'path': '1814_mm_dd_i_Махи_на_балконе.jpeg',
#   'name_of_painting': 'Махи на балконе',
#   'year': '1814',
#   'most_common_colors_ever': {'(43, 37, 31)': 2295,
#    '(91, 79, 63)': 3040,
#    '(16, 15, 14)': 217,
#    '(187, 177, 158)': 584,
#    '(135, 139, 133)': 878,
#    '(144, 121, 84)': 752,
#    '(97, 54, 38)': 1026}},
#  '1795_mm_dd_i_Герцогиня_Альба_и_дуэнья_"Ла_Беата".jpeg': {'path': '1795_mm_dd_i_Герцогиня_Альба_и_дуэнья_"Ла_Беата".jpeg',
#   'name_of_painting': 'Герцогиня Альба и дуэнья "Ла Беата"',
#   'year': '1795',
#   'most_common_colors_ever': {'(43, 37, 31)': 1724,
#    '(91, 79, 63)': 11,
#    '(16, 15, 14)': 3603,
#    '(187, 177, 158)': 0,
#    '(135, 139, 133)': 0,
#    '(144, 121, 84)': 5,
#    '(97, 54, 38)': 2974}},
#  '1820_mm_dd_i_Портрет_Тибурсио_Переса-и-Куэрво.jpeg': {'path': '1820_mm_dd_i_Портрет_Тибурсио_Переса-и-Куэрво.jpeg',
#   'name_of_painting': 'Портрет Тибурсио Переса-и-Куэрво',
#   'year': '1820',
#   'most_common_colors_ever': {'(43, 37, 31)': 9365,
#    '(91, 79, 63)': 2453,
#    '(16, 15, 14)': 1181,
#    '(187, 177, 158)': 0,
#    '(135, 139, 133)': 38,
#    '(144, 121, 84)': 179,
#    '(97, 54, 38)': 1527}},
#  '1814_mm_dd_i_Жозефа_Байе_или_Леокадия_Вейс.jpeg': {'path': '1814_mm_dd_i_Жозефа_Байе_или_Леокадия_Вейс.jpeg',
#   'name_of_painting': 'Жозефа Байе или Леокадия Вейс',
#   'year': '1814',
#   'most_common_colors_ever': {'(43, 37, 31)': 754,
#    '(91, 79, 63)': 646,
#    '(16, 15, 14)': 51,
#    '(187, 177, 158)': 163,
#    '(135, 139, 133)': 18,
#    '(144, 121, 84)': 448,
#    '(97, 54, 38)': 2768}},
#  '1783_mm_dd_i_Хосе_Монино_Редондо,_граф_Флоридабланка.jpeg': {'path': '1783_mm_dd_i_Хосе_Монино_Редондо,_граф_Флоридабланка.jpeg',
#   'name_of_painting': 'Хосе Монино Редондо, граф Флоридабланка',
#   'year': '1783',
#   'most_common_colors_ever': {'(43, 37, 31)': 3240,
#    '(91, 79, 63)': 152,
#    '(16, 15, 14)': 535,
#    '(187, 177, 158)': 288,
#    '(135, 139, 133)': 1,
#    '(144, 121, 84)': 351,
#    '(97, 54, 38)': 3924}},
#  '1783_mm_dd_a_Автопортрет.jpeg': {'path': '1783_mm_dd_a_Автопортрет.jpeg',
#   'name_of_painting': 'Автопортрет',
#   'year': '1783',
#   'most_common_colors_ever': {'(43, 37, 31)': 2308,
#    '(91, 79, 63)': 2282,
#    '(16, 15, 14)': 3,
#    '(187, 177, 158)': 861,
#    '(135, 139, 133)': 93,
#    '(144, 121, 84)': 1530,
#    '(97, 54, 38)': 1455}},
#  '1806_mm_dd_i_Портрет_доньи_Антонии_Сарате.jpeg': {'path': '1806_mm_dd_i_Портрет_доньи_Антонии_Сарате.jpeg',
#   'name_of_painting': 'Портрет доньи Антонии Сарате',
#   'year': '1806',
#   'most_common_colors_ever': {'(43, 37, 31)': 2023,
#    '(91, 79, 63)': 360,
#    '(16, 15, 14)': 1085,
#    '(187, 177, 158)': 1052,
#    '(135, 139, 133)': 935,
#    '(144, 121, 84)': 1353,
#    '(97, 54, 38)': 885}},
#  '1815_mm_dd_i_Портрет_Фердинанда_VII_де_Бурбона,_короля_Испании.jpeg': {'path': '1815_mm_dd_i_Портрет_Фердинанда_VII_де_Бурбона,_короля_Испании.jpeg',
#   'name_of_painting': 'Портрет Фердинанда VII де Бурбона, короля Испании',
#   'year': '1815',
#   'most_common_colors_ever': {'(43, 37, 31)': 2337,
#    '(91, 79, 63)': 1240,
#    '(16, 15, 14)': 191,
#    '(187, 177, 158)': 295,
#    '(135, 139, 133)': 246,
#    '(144, 121, 84)': 1116,
#    '(97, 54, 38)': 751}},
#  '1814_mm_dd_i_Расстрел_повстанцев_3_мая_1808_года_в_Мадриде.jpeg': {'path': '1814_mm_dd_i_Расстрел_повстанцев_3_мая_1808_года_в_Мадриде.jpeg',
#   'name_of_painting': 'Расстрел повстанцев 3 мая 1808 года в Мадриде',
#   'year': '1814',
#   'most_common_colors_ever': {'(43, 37, 31)': 2364,
#    '(91, 79, 63)': 1683,
#    '(16, 15, 14)': 981,
#    '(187, 177, 158)': 161,
#    '(135, 139, 133)': 167,
#    '(144, 121, 84)': 848,
#    '(97, 54, 38)': 282}},
#  '1789_mm_dd_i_Карл_IV.jpeg': {'path': '1789_mm_dd_i_Карл_IV.jpeg',
#   'name_of_painting': 'Карл IV',
#   'year': '1789',
#   'most_common_colors_ever': {'(43, 37, 31)': 1140,
#    '(91, 79, 63)': 1657,
#    '(16, 15, 14)': 0,
#    '(187, 177, 158)': 1734,
#    '(135, 139, 133)': 1460,
#    '(144, 121, 84)': 681,
#    '(97, 54, 38)': 1526}},
#  '1798_mm_dd_i_Фреска_часовни_Св._Антония_Флоридского,_деталь_4.jpeg': {'path': '1798_mm_dd_i_Фреска_часовни_Св._Антония_Флоридского,_деталь_4.jpeg',
#   'name_of_painting': 'Фреска часовни Св. Антония Флоридского, деталь 4',
#   'year': '1798',
#   'most_common_colors_ever': {'(43, 37, 31)': 922,
#    '(91, 79, 63)': 2806,
#    '(16, 15, 14)': 0,
#    '(187, 177, 158)': 1369,
#    '(135, 139, 133)': 400,
#    '(144, 121, 84)': 1128,
#    '(97, 54, 38)': 1587}},
#  '1819_mm_dd_i_Кузница.jpeg': {'path': '1819_mm_dd_i_Кузница.jpeg',
#   'name_of_painting': 'Кузница',
#   'year': '1819',
#   'most_common_colors_ever': {'(43, 37, 31)': 1291,
#    '(91, 79, 63)': 3207,
#    '(16, 15, 14)': 5,
#    '(187, 177, 158)': 1148,
#    '(135, 139, 133)': 320,
#    '(144, 121, 84)': 1881,
#    '(97, 54, 38)': 1358}},
#  '1800_mm_dd_i_Граф_Тахо.jpeg': {'path': '1800_mm_dd_i_Граф_Тахо.jpeg',
#   'name_of_painting': 'Граф Тахо',
#   'year': '1800',
#   'most_common_colors_ever': {'(43, 37, 31)': 1907,
#    '(91, 79, 63)': 1617,
#    '(16, 15, 14)': 398,
#    '(187, 177, 158)': 1278,
#    '(135, 139, 133)': 827,
#    '(144, 121, 84)': 1251,
#    '(97, 54, 38)': 2350}},
#  '1812_mm_dd_i_Точильщик.jpeg': {'path': '1812_mm_dd_i_Точильщик.jpeg',
#   'name_of_painting': 'Точильщик',
#   'year': '1812',
#   'most_common_colors_ever': {'(43, 37, 31)': 3907,
#    '(91, 79, 63)': 1393,
#    '(16, 15, 14)': 1437,
#    '(187, 177, 158)': 1113,
#    '(135, 139, 133)': 822,
#    '(144, 121, 84)': 563,
#    '(97, 54, 38)': 712}},
#  '1777_mm_dd_i_Прогулка_в_Андалусии.jpeg': {'path': '1777_mm_dd_i_Прогулка_в_Андалусии.jpeg',
#   'name_of_painting': 'Прогулка в Андалусии',
#   'year': '1777',
#   'most_common_colors_ever': {'(43, 37, 31)': 7680,
#    '(91, 79, 63)': 1974,
#    '(16, 15, 14)': 99,
#    '(187, 177, 158)': 266,
#    '(135, 139, 133)': 374,
#    '(144, 121, 84)': 571,
#    '(97, 54, 38)': 1201}},
#  '1812_mm_dd_i_Мёртвая_индейка.jpeg': {'path': '1812_mm_dd_i_Мёртвая_индейка.jpeg',
#   'name_of_painting': 'Мёртвая индейка',
#   'year': '1812',
#   'most_common_colors_ever': {'(43, 37, 31)': 2302,
#    '(91, 79, 63)': 910,
#    '(16, 15, 14)': 1643,
#    '(187, 177, 158)': 830,
#    '(135, 139, 133)': 2172,
#    '(144, 121, 84)': 288,
#    '(97, 54, 38)': 271}},
#  '1798_mm_dd_i_Портрет_матадора_Педро_Ромеро.jpeg': {'path': '1798_mm_dd_i_Портрет_матадора_Педро_Ромеро.jpeg',
#   'name_of_painting': 'Портрет матадора Педро Ромеро',
#   'year': '1798',
#   'most_common_colors_ever': {'(43, 37, 31)': 1622,
#    '(91, 79, 63)': 2251,
#    '(16, 15, 14)': 0,
#    '(187, 177, 158)': 1280,
#    '(135, 139, 133)': 1509,
#    '(144, 121, 84)': 1333,
#    '(97, 54, 38)': 402}},
#  '1804_mm_dd_i_Портрет_Бартоломе_Суреда-и-Мизероль.jpeg': {'path': '1804_mm_dd_i_Портрет_Бартоломе_Суреда-и-Мизероль.jpeg',
#   'name_of_painting': 'Портрет Бартоломе Суреда-и-Мизероль',
#   'year': '1804',
#   'most_common_colors_ever': {'(43, 37, 31)': 2583,
#    '(91, 79, 63)': 1381,
#    '(16, 15, 14)': 796,
#    '(187, 177, 158)': 1292,
#    '(135, 139, 133)': 273,
#    '(144, 121, 84)': 372,
#    '(97, 54, 38)': 1032}},
#  '1787_mm_dd_i_Женщина_с_двумя_мальчиками_у_фонтана.jpeg': {'path': '1787_mm_dd_i_Женщина_с_двумя_мальчиками_у_фонтана.jpeg',
#   'name_of_painting': 'Женщина с двумя мальчиками у фонтана',
#   'year': '1787',
#   'most_common_colors_ever': {'(43, 37, 31)': 4306,
#    '(91, 79, 63)': 942,
#    '(16, 15, 14)': 440,
#    '(187, 177, 158)': 198,
#    '(135, 139, 133)': 129,
#    '(144, 121, 84)': 504,
#    '(97, 54, 38)': 643}},
#  '1775_mm_dd_i_Охота_на_приманку.jpeg': {'path': '1775_mm_dd_i_Охота_на_приманку.jpeg',
#   'name_of_painting': 'Охота на приманку',
#   'year': '1775',
#   'most_common_colors_ever': {'(43, 37, 31)': 3927,
#    '(91, 79, 63)': 1863,
#    '(16, 15, 14)': 673,
#    '(187, 177, 158)': 1334,
#    '(135, 139, 133)': 444,
#    '(144, 121, 84)': 759,
#    '(97, 54, 38)': 2004}},
#  '1793_mm_dd_i_Бродячие_комедианты.jpeg': {'path': '1793_mm_dd_i_Бродячие_комедианты.jpeg',
#   'name_of_painting': 'Бродячие комедианты',
#   'year': '1793',
#   'most_common_colors_ever': {'(43, 37, 31)': 2193,
#    '(91, 79, 63)': 673,
#    '(16, 15, 14)': 3550,
#    '(187, 177, 158)': 31,
#    '(135, 139, 133)': 226,
#    '(144, 121, 84)': 237,
#    '(97, 54, 38)': 272}},
#  '1771_mm_dd_i_Победоносный_Ганнибал_впервые_видит_Италию_с_вершин_Альп.jpeg': {'path': '1771_mm_dd_i_Победоносный_Ганнибал_впервые_видит_Италию_с_вершин_Альп.jpeg',
#   'name_of_painting': 'Победоносный Ганнибал впервые видит Италию с вершин Альп',
#   'year': '1771',
#   'most_common_colors_ever': {'(43, 37, 31)': 4824,
#    '(91, 79, 63)': 1296,
#    '(16, 15, 14)': 42,
#    '(187, 177, 158)': 1083,
#    '(135, 139, 133)': 27,
#    '(144, 121, 84)': 216,
#    '(97, 54, 38)': 2396}},
#  '1786_mm_dd_s_Пьяный_каменщик_(эскиз).jpeg': {'path': '1786_mm_dd_s_Пьяный_каменщик_(эскиз).jpeg',
#   'name_of_painting': 'Пьяный каменщик (эскиз)',
#   'year': '1786',
#   'most_common_colors_ever': {'(43, 37, 31)': 5351,
#    '(91, 79, 63)': 1595,
#    '(16, 15, 14)': 1071,
#    '(187, 177, 158)': 709,
#    '(135, 139, 133)': 2554,
#    '(144, 121, 84)': 588,
#    '(97, 54, 38)': 705}},
#  '1814_mm_dd_i_Процессия_флагеллантов_(бичующихся).jpeg': {'path': '1814_mm_dd_i_Процессия_флагеллантов_(бичующихся).jpeg',
#   'name_of_painting': 'Процессия флагеллантов (бичующихся)',
#   'year': '1814',
#   'most_common_colors_ever': {'(43, 37, 31)': 1943,
#    '(91, 79, 63)': 730,
#    '(16, 15, 14)': 2239,
#    '(187, 177, 158)': 645,
#    '(135, 139, 133)': 533,
#    '(144, 121, 84)': 350,
#    '(97, 54, 38)': 369}},
#  '1822_mm_dd_i_Портрет_дона_Себастьяна_Габриеля_де_Борбона-и-Браганца.jpeg': {'path': '1822_mm_dd_i_Портрет_дона_Себастьяна_Габриеля_де_Борбона-и-Браганца.jpeg',
#   'name_of_painting': 'Портрет дона Себастьяна Габриеля де Борбона-и-Браганца',
#   'year': '1822',
#   'most_common_colors_ever': {'(43, 37, 31)': 3604,
#    '(91, 79, 63)': 2281,
#    '(16, 15, 14)': 5,
#    '(187, 177, 158)': 0,
#    '(135, 139, 133)': 1,
#    '(144, 121, 84)': 1279,
#    '(97, 54, 38)': 3364}},
#  '1771_mm_dd_i_Венера_и_Адонис.jpeg': {'path': '1771_mm_dd_i_Венера_и_Адонис.jpeg',
#   'name_of_painting': 'Венера и Адонис',
#   'year': '1771',
#   'most_common_colors_ever': {'(43, 37, 31)': 2453,
#    '(91, 79, 63)': 1719,
#    '(16, 15, 14)': 3,
#    '(187, 177, 158)': 186,
#    '(135, 139, 133)': 1461,
#    '(144, 121, 84)': 452,
#    '(97, 54, 38)': 1503}},
#  '1786_mm_dd_i_Мальчики_с_мастифом.jpeg': {'path': '1786_mm_dd_i_Мальчики_с_мастифом.jpeg',
#   'name_of_painting': 'Мальчики с мастифом',
#   'year': '1786',
#   'most_common_colors_ever': {'(43, 37, 31)': 4246,
#    '(91, 79, 63)': 1918,
#    '(16, 15, 14)': 929,
#    '(187, 177, 158)': 332,
#    '(135, 139, 133)': 1279,
#    '(144, 121, 84)': 346,
#    '(97, 54, 38)': 901}},
#  '1792_mm_dd_i_Ходули.jpeg': {'path': '1792_mm_dd_i_Ходули.jpeg',
#   'name_of_painting': 'Ходули',
#   'year': '1792',
#   'most_common_colors_ever': {'(43, 37, 31)': 3169,
#    '(91, 79, 63)': 1967,
#    '(16, 15, 14)': 224,
#    '(187, 177, 158)': 451,
#    '(135, 139, 133)': 1187,
#    '(144, 121, 84)': 992,
#    '(97, 54, 38)': 1780}},
#  '1798_mm_dd_i_Портрет_доктора_Андреса_дель_Пераля.jpeg': {'path': '1798_mm_dd_i_Портрет_доктора_Андреса_дель_Пераля.jpeg',
#   'name_of_painting': 'Портрет доктора Андреса дель Пераля',
#   'year': '1798',
#   'most_common_colors_ever': {'(43, 37, 31)': 14184,
#    '(91, 79, 63)': 190,
#    '(16, 15, 14)': 12661,
#    '(187, 177, 158)': 0,
#    '(135, 139, 133)': 0,
#    '(144, 121, 84)': 113,
#    '(97, 54, 38)': 283}},
#  '1778_mm_dd_i_Мальчики_собирают_фрукты.jpeg': {'path': '1778_mm_dd_i_Мальчики_собирают_фрукты.jpeg',
#   'name_of_painting': 'Мальчики собирают фрукты',
#   'year': '1778',
#   'most_common_colors_ever': {'(43, 37, 31)': 2914,
#    '(91, 79, 63)': 3192,
#    '(16, 15, 14)': 129,
#    '(187, 177, 158)': 879,
#    '(135, 139, 133)': 1095,
#    '(144, 121, 84)': 517,
#    '(97, 54, 38)': 1526}},
#  '1792_mm_dd_i_Свадьба.jpeg': {'path': '1792_mm_dd_i_Свадьба.jpeg',
#   'name_of_painting': 'Свадьба',
#   'year': '1792',
#   'most_common_colors_ever': {'(43, 37, 31)': 5405,
#    '(91, 79, 63)': 480,
#    '(16, 15, 14)': 124,
#    '(187, 177, 158)': 2,
#    '(135, 139, 133)': 850,
#    '(144, 121, 84)': 198,
#    '(97, 54, 38)': 1617}},
#  '1823_mm_dd_i_Две_женщины_и_мужчина.jpeg': {'path': '1823_mm_dd_i_Две_женщины_и_мужчина.jpeg',
#   'name_of_painting': 'Две женщины и мужчина',
#   'year': '1823',
#   'most_common_colors_ever': {'(43, 37, 31)': 3047,
#    '(91, 79, 63)': 2841,
#    '(16, 15, 14)': 96,
#    '(187, 177, 158)': 1203,
#    '(135, 139, 133)': 1314,
#    '(144, 121, 84)': 440,
#    '(97, 54, 38)': 2225}},
#  '1823_mm_dd_i_Серия_мрачных_картин._Два_монаха.jpeg': {'path': '1823_mm_dd_i_Серия_мрачных_картин._Два_монаха.jpeg',
#   'name_of_painting': 'Серия мрачных картин. Два монаха',
#   'year': '1823',
#   'most_common_colors_ever': {'(43, 37, 31)': 959,
#    '(91, 79, 63)': 2197,
#    '(16, 15, 14)': 0,
#    '(187, 177, 158)': 320,
#    '(135, 139, 133)': 307,
#    '(144, 121, 84)': 539,
#    '(97, 54, 38)': 990}},
#  '1786_mm_dd_i_Падение.jpeg': {'path': '1786_mm_dd_i_Падение.jpeg',
#   'name_of_painting': 'Падение',
#   'year': '1786',
#   'most_common_colors_ever': {'(43, 37, 31)': 6505,
#    '(91, 79, 63)': 2017,
#    '(16, 15, 14)': 3571,
#    '(187, 177, 158)': 67,
#    '(135, 139, 133)': 168,
#    '(144, 121, 84)': 295,
#    '(97, 54, 38)': 823}},
#  '1823_mm_dd_i_Серия_мрачных_картин-_Паломники.jpeg': {'path': '1823_mm_dd_i_Серия_мрачных_картин-_Паломники.jpeg',
#   'name_of_painting': 'Серия мрачных картин- Паломники',
#   'year': '1823',
#   'most_common_colors_ever': {'(43, 37, 31)': 6456,
#    '(91, 79, 63)': 356,
#    '(16, 15, 14)': 10433,
#    '(187, 177, 158)': 117,
#    '(135, 139, 133)': 0,
#    '(144, 121, 84)': 583,
#    '(97, 54, 38)': 246}},
#  '1799_mm_dd_i_Св._Григорий_Магно.jpeg': {'path': '1799_mm_dd_i_Св._Григорий_Магно.jpeg',
#   'name_of_painting': 'Св. Григорий Магно',
#   'year': '1799',
#   'most_common_colors_ever': {'(43, 37, 31)': 11110,
#    '(91, 79, 63)': 1068,
#    '(16, 15, 14)': 2422,
#    '(187, 177, 158)': 121,
#    '(135, 139, 133)': 15,
#    '(144, 121, 84)': 349,
#    '(97, 54, 38)': 573}},
#  '1793_mm_dd_i_Графиня_Карпио,_маркиза_де_ла_Солана.jpeg': {'path': '1793_mm_dd_i_Графиня_Карпио,_маркиза_де_ла_Солана.jpeg',
#   'name_of_painting': 'Графиня Карпио, маркиза де ла Солана',
#   'year': '1793',
#   'most_common_colors_ever': {'(43, 37, 31)': 921,
#    '(91, 79, 63)': 312,
#    '(16, 15, 14)': 43,
#    '(187, 177, 158)': 11,
#    '(135, 139, 133)': 21,
#    '(144, 121, 84)': 425,
#    '(97, 54, 38)': 3037}},
#  '1798_mm_dd_i_Дон_Педро_де_Алькантара_из_рода_Тельес-Хиронов,_9-й_герцог_Осуна.jpeg': {'path': '1798_mm_dd_i_Дон_Педро_де_Алькантара_из_рода_Тельес-Хиронов,_9-й_герцог_Осуна.jpeg',
#   'name_of_painting': 'Дон Педро де Алькантара из рода Тельес-Хиронов, 9-й герцог Осуна',
#   'year': '1798',
#   'most_common_colors_ever': {'(43, 37, 31)': 6193,
#    '(91, 79, 63)': 1063,
#    '(16, 15, 14)': 2365,
#    '(187, 177, 158)': 177,
#    '(135, 139, 133)': 116,
#    '(144, 121, 84)': 1560,
#    '(97, 54, 38)': 1069}},
#  '1800_mm_dd_i_Сон.jpeg': {'path': '1800_mm_dd_i_Сон.jpeg',
#   'name_of_painting': 'Сон',
#   'year': '1800',
#   'most_common_colors_ever': {'(43, 37, 31)': 2965,
#    '(91, 79, 63)': 290,
#    '(16, 15, 14)': 11764,
#    '(187, 177, 158)': 92,
#    '(135, 139, 133)': 96,
#    '(144, 121, 84)': 83,
#    '(97, 54, 38)': 326}},
#  '1805_mm_dd_i_Молодая_дама_в_мантилье_и_баскине.jpeg': {'path': '1805_mm_dd_i_Молодая_дама_в_мантилье_и_баскине.jpeg',
#   'name_of_painting': 'Молодая дама в мантилье и баскине',
#   'year': '1805',
#   'most_common_colors_ever': {'(43, 37, 31)': 5193,
#    '(91, 79, 63)': 2191,
#    '(16, 15, 14)': 4069,
#    '(187, 177, 158)': 313,
#    '(135, 139, 133)': 423,
#    '(144, 121, 84)': 722,
#    '(97, 54, 38)': 530}},
#  '1783_mm_dd_i_Мария_Тереза_де_Виллабрига1.jpeg': {'path': '1783_mm_dd_i_Мария_Тереза_де_Виллабрига1.jpeg',
#   'name_of_painting': 'Мария Тереза де Виллабрига1',
#   'year': '1783',
#   'most_common_colors_ever': {'(43, 37, 31)': 3905,
#    '(91, 79, 63)': 2112,
#    '(16, 15, 14)': 1599,
#    '(187, 177, 158)': 614,
#    '(135, 139, 133)': 2604,
#    '(144, 121, 84)': 1004,
#    '(97, 54, 38)': 268}},
#  '1787_mm_dd_i_Метель.jpeg': {'path': '1787_mm_dd_i_Метель.jpeg',
#   'name_of_painting': 'Метель',
#   'year': '1787',
#   'most_common_colors_ever': {'(43, 37, 31)': 1984,
#    '(91, 79, 63)': 647,
#    '(16, 15, 14)': 10331,
#    '(187, 177, 158)': 1149,
#    '(135, 139, 133)': 897,
#    '(144, 121, 84)': 88,
#    '(97, 54, 38)': 120}},
#  '1798_mm_dd_i_Фреска_часовни_Св._Антония_Флоридского,_деталь_5.jpeg': {'path': '1798_mm_dd_i_Фреска_часовни_Св._Антония_Флоридского,_деталь_5.jpeg',
#   'name_of_painting': 'Фреска часовни Св. Антония Флоридского, деталь 5',
#   'year': '1798',
#   'most_common_colors_ever': {'(43, 37, 31)': 8180,
#    '(91, 79, 63)': 92,
#    '(16, 15, 14)': 11126,
#    '(187, 177, 158)': 7,
#    '(135, 139, 133)': 0,
#    '(144, 121, 84)': 57,
#    '(97, 54, 38)': 401}},
#  '1814_mm_dd_i_Восстание_2_мая_1808_года_в_Мадриде.jpeg': {'path': '1814_mm_dd_i_Восстание_2_мая_1808_года_в_Мадриде.jpeg',
#   'name_of_painting': 'Восстание 2 мая 1808 года в Мадриде',
#   'year': '1814',
#   'most_common_colors_ever': {'(43, 37, 31)': 1082,
#    '(91, 79, 63)': 336,
#    '(16, 15, 14)': 9925,
#    '(187, 177, 158)': 94,
#    '(135, 139, 133)': 74,
#    '(144, 121, 84)': 48,
#    '(97, 54, 38)': 37}},
#  '1819_mm_dd_i_Молодая_женщина_с_письмом.jpeg': {'path': '1819_mm_dd_i_Молодая_женщина_с_письмом.jpeg',
#   'name_of_painting': 'Молодая женщина с письмом',
#   'year': '1819',
#   'most_common_colors_ever': {'(43, 37, 31)': 5424,
#    '(91, 79, 63)': 723,
#    '(16, 15, 14)': 2018,
#    '(187, 177, 158)': 149,
#    '(135, 139, 133)': 75,
#    '(144, 121, 84)': 476,
#    '(97, 54, 38)': 1679}},
#  '1779_mm_dd_i_Портрет_Леандро_Фернандеса_Моратина.jpeg': {'path': '1779_mm_dd_i_Портрет_Леандро_Фернандеса_Моратина.jpeg',
#   'name_of_painting': 'Портрет Леандро Фернандеса Моратина',
#   'year': '1779',
#   'most_common_colors_ever': {'(43, 37, 31)': 685,
#    '(91, 79, 63)': 1354,
#    '(16, 15, 14)': 508,
#    '(187, 177, 158)': 2474,
#    '(135, 139, 133)': 1084,
#    '(144, 121, 84)': 954,
#    '(97, 54, 38)': 165}},
#  '1811_mm_dd_i_Портрет_актрисы_Антонии_Сарате.jpeg': {'path': '1811_mm_dd_i_Портрет_актрисы_Антонии_Сарате.jpeg',
#   'name_of_painting': 'Портрет актрисы Антонии Сарате',
#   'year': '1811',
#   'most_common_colors_ever': {'(43, 37, 31)': 5290,
#    '(91, 79, 63)': 1155,
#    '(16, 15, 14)': 7231,
#    '(187, 177, 158)': 323,
#    '(135, 139, 133)': 226,
#    '(144, 121, 84)': 397,
#    '(97, 54, 38)': 91}},
#  '1794_mm_dd_i_Двор_сумасшедшего_дома.jpeg': {'path': '1794_mm_dd_i_Двор_сумасшедшего_дома.jpeg',
#   'name_of_painting': 'Двор сумасшедшего дома',
#   'year': '1794',
#   'most_common_colors_ever': {'(43, 37, 31)': 838,
#    '(91, 79, 63)': 2510,
#    '(16, 15, 14)': 23,
#    '(187, 177, 158)': 1000,
#    '(135, 139, 133)': 1589,
#    '(144, 121, 84)': 2460,
#    '(97, 54, 38)': 1307}},
#  '1797_mm_dd_i_Портрет_Мартина_Сапатера.jpeg': {'path': '1797_mm_dd_i_Портрет_Мартина_Сапатера.jpeg',
#   'name_of_painting': 'Портрет Мартина Сапатера',
#   'year': '1797',
#   'most_common_colors_ever': {'(43, 37, 31)': 1388,
#    '(91, 79, 63)': 1728,
#    '(16, 15, 14)': 146,
#    '(187, 177, 158)': 281,
#    '(135, 139, 133)': 240,
#    '(144, 121, 84)': 1949,
#    '(97, 54, 38)': 1142}},
#  '1804_mm_dd_i_Маркиза_фон_Виллафранка.jpeg': {'path': '1804_mm_dd_i_Маркиза_фон_Виллафранка.jpeg',
#   'name_of_painting': 'Маркиза фон Виллафранка',
#   'year': '1804',
#   'most_common_colors_ever': {'(43, 37, 31)': 2020,
#    '(91, 79, 63)': 1779,
#    '(16, 15, 14)': 1618,
#    '(187, 177, 158)': 821,
#    '(135, 139, 133)': 586,
#    '(144, 121, 84)': 652,
#    '(97, 54, 38)': 154}},
#  '1813_mm_dd_i_Портрет_художницы_Лолы_Хименес.jpeg': {'path': '1813_mm_dd_i_Портрет_художницы_Лолы_Хименес.jpeg',
#   'name_of_painting': 'Портрет художницы Лолы Хименес',
#   'year': '1813',
#   'most_common_colors_ever': {'(43, 37, 31)': 561,
#    '(91, 79, 63)': 1378,
#    '(16, 15, 14)': 1794,
#    '(187, 177, 158)': 1108,
#    '(135, 139, 133)': 2001,
#    '(144, 121, 84)': 2109,
#    '(97, 54, 38)': 1419}},
#  '1814_mm_dd_i_Трибунал_инквизиции.jpeg': {'path': '1814_mm_dd_i_Трибунал_инквизиции.jpeg',
#   'name_of_painting': 'Трибунал инквизиции',
#   'year': '1814',
#   'most_common_colors_ever': {'(43, 37, 31)': 1301,
#    '(91, 79, 63)': 1429,
#    '(16, 15, 14)': 1304,
#    '(187, 177, 158)': 790,
#    '(135, 139, 133)': 1020,
#    '(144, 121, 84)': 723,
#    '(97, 54, 38)': 544}},
#  '1777_mm_dd_i_Танец_на_берегу_реки_Мансанарес.jpeg': {'path': '1777_mm_dd_i_Танец_на_берегу_реки_Мансанарес.jpeg',
#   'name_of_painting': 'Танец на берегу реки Мансанарес',
#   'year': '1777',
#   'most_common_colors_ever': {'(43, 37, 31)': 1319,
#    '(91, 79, 63)': 593,
#    '(16, 15, 14)': 1353,
#    '(187, 177, 158)': 867,
#    '(135, 139, 133)': 851,
#    '(144, 121, 84)': 782,
#    '(97, 54, 38)': 341}},
#  '1791_mm_dd_i_Портрет_Луиса_Марии_де_Кистуэ-и-Мартинеса.jpeg': {'path': '1791_mm_dd_i_Портрет_Луиса_Марии_де_Кистуэ-и-Мартинеса.jpeg',
#   'name_of_painting': 'Портрет Луиса Марии де Кистуэ-и-Мартинеса',
#   'year': '1791',
#   'most_common_colors_ever': {'(43, 37, 31)': 1218,
#    '(91, 79, 63)': 1405,
#    '(16, 15, 14)': 371,
#    '(187, 177, 158)': 1967,
#    '(135, 139, 133)': 2658,
#    '(144, 121, 84)': 329,
#    '(97, 54, 38)': 239}},
#  '1801_mm_dd_i_Мануэль_Годой,_герцог_Алькудии,_"принц_мира".jpeg': {'path': '1801_mm_dd_i_Мануэль_Годой,_герцог_Алькудии,_"принц_мира".jpeg',
#   'name_of_painting': 'Мануэль Годой, герцог Алькудии, "принц мира"',
#   'year': '1801',
#   'most_common_colors_ever': {'(43, 37, 31)': 784,
#    '(91, 79, 63)': 1618,
#    '(16, 15, 14)': 910,
#    '(187, 177, 158)': 182,
#    '(135, 139, 133)': 126,
#    '(144, 121, 84)': 887,
#    '(97, 54, 38)': 134}},
#  '1789_mm_dd_i_Портрет_Карлоса_IV.jpeg': {'path': '1789_mm_dd_i_Портрет_Карлоса_IV.jpeg',
#   'name_of_painting': 'Портрет Карлоса IV',
#   'year': '1789',
#   'most_common_colors_ever': {'(43, 37, 31)': 893,
#    '(91, 79, 63)': 1436,
#    '(16, 15, 14)': 2057,
#    '(187, 177, 158)': 2831,
#    '(135, 139, 133)': 1014,
#    '(144, 121, 84)': 415,
#    '(97, 54, 38)': 1085}},
#  '1780_mm_dd_i_Прачки.jpeg': {'path': '1780_mm_dd_i_Прачки.jpeg',
#   'name_of_painting': 'Прачки',
#   'year': '1780',
#   'most_common_colors_ever': {'(43, 37, 31)': 3006,
#    '(91, 79, 63)': 2130,
#    '(16, 15, 14)': 2054,
#    '(187, 177, 158)': 58,
#    '(135, 139, 133)': 13,
#    '(144, 121, 84)': 392,
#    '(97, 54, 38)': 511}},
#  '1806_mm_dd_i_Портрет_Педро_Мокарте,_певца_собора_Толедо.jpeg': {'path': '1806_mm_dd_i_Портрет_Педро_Мокарте,_певца_собора_Толедо.jpeg',
#   'name_of_painting': 'Портрет Педро Мокарте, певца собора Толедо',
#   'year': '1806',
#   'most_common_colors_ever': {'(43, 37, 31)': 829,
#    '(91, 79, 63)': 794,
#    '(16, 15, 14)': 784,
#    '(187, 177, 158)': 2006,
#    '(135, 139, 133)': 1260,
#    '(144, 121, 84)': 893,
#    '(97, 54, 38)': 596}},
#  '1793_mm_dd_i_Пикадор,_оказавшись_на_быке.jpeg': {'path': '1793_mm_dd_i_Пикадор,_оказавшись_на_быке.jpeg',
#   'name_of_painting': 'Пикадор, оказавшись на быке',
#   'year': '1793',
#   'most_common_colors_ever': {'(43, 37, 31)': 448,
#    '(91, 79, 63)': 732,
#    '(16, 15, 14)': 184,
#    '(187, 177, 158)': 1541,
#    '(135, 139, 133)': 4038,
#    '(144, 121, 84)': 1143,
#    '(97, 54, 38)': 630}},
#  '1785_mm_dd_i_Портрет_графини-герцогини_Бенавенте.jpeg': {'path': '1785_mm_dd_i_Портрет_графини-герцогини_Бенавенте.jpeg',
#   'name_of_painting': 'Портрет графини-герцогини Бенавенте',
#   'year': '1785',
#   'most_common_colors_ever': {'(43, 37, 31)': 5243,
#    '(91, 79, 63)': 2169,
#    '(16, 15, 14)': 1608,
#    '(187, 177, 158)': 169,
#    '(135, 139, 133)': 91,
#    '(144, 121, 84)': 413,
#    '(97, 54, 38)': 859}},
#  '1807_mm_dd_i_Портрет_дамы.jpeg': {'path': '1807_mm_dd_i_Портрет_дамы.jpeg',
#   'name_of_painting': 'Портрет дамы',
#   'year': '1807',
#   'most_common_colors_ever': {'(43, 37, 31)': 74,
#    '(91, 79, 63)': 646,
#    '(16, 15, 14)': 0,
#    '(187, 177, 158)': 451,
#    '(135, 139, 133)': 2177,
#    '(144, 121, 84)': 131,
#    '(97, 54, 38)': 36}},
#  '1816_mm_dd_i_Коррида_на_разделенной_арене.jpeg': {'path': '1816_mm_dd_i_Коррида_на_разделенной_арене.jpeg',
#   'name_of_painting': 'Коррида на разделенной арене',
#   'year': '1816',
#   'most_common_colors_ever': {'(43, 37, 31)': 5089,
#    '(91, 79, 63)': 4654,
#    '(16, 15, 14)': 1997,
#    '(187, 177, 158)': 152,
#    '(135, 139, 133)': 1222,
#    '(144, 121, 84)': 65,
#    '(97, 54, 38)': 715}},
#  '1802_mm_dd_i_Портрет_Дон_Хосе_Керальто.jpeg': {'path': '1802_mm_dd_i_Портрет_Дон_Хосе_Керальто.jpeg',
#   'name_of_painting': 'Портрет Дон Хосе Керальто',
#   'year': '1802',
#   'most_common_colors_ever': {'(43, 37, 31)': 2669,
#    '(91, 79, 63)': 1260,
#    '(16, 15, 14)': 928,
#    '(187, 177, 158)': 3585,
#    '(135, 139, 133)': 2266,
#    '(144, 121, 84)': 1362,
#    '(97, 54, 38)': 257}},
#  '1774_mm_dd_i_Обрезание.jpeg': {'path': '1774_mm_dd_i_Обрезание.jpeg',
#   'name_of_painting': 'Обрезание',
#   'year': '1774',
#   'most_common_colors_ever': {'(43, 37, 31)': 262,
#    '(91, 79, 63)': 1937,
#    '(16, 15, 14)': 5,
#    '(187, 177, 158)': 3932,
#    '(135, 139, 133)': 234,
#    '(144, 121, 84)': 1194,
#    '(97, 54, 38)': 161}},
#  '1798_mm_dd_i_Чудо_святого_Антония_Падуанского_(фрагмент).jpeg': {'path': '1798_mm_dd_i_Чудо_святого_Антония_Падуанского_(фрагмент).jpeg',
#   'name_of_painting': 'Чудо святого Антония Падуанского (фрагмент)',
#   'year': '1798',
#   'most_common_colors_ever': {'(43, 37, 31)': 1461,
#    '(91, 79, 63)': 788,
#    '(16, 15, 14)': 5738,
#    '(187, 177, 158)': 98,
#    '(135, 139, 133)': 3,
#    '(144, 121, 84)': 1404,
#    '(97, 54, 38)': 680}},
#  '1798_mm_dd_i_Фреска_часовни_Св._Антония_Флоридского,_деталь_2.jpeg': {'path': '1798_mm_dd_i_Фреска_часовни_Св._Антония_Флоридского,_деталь_2.jpeg',
#   'name_of_painting': 'Фреска часовни Св. Антония Флоридского, деталь 2',
#   'year': '1798',
#   'most_common_colors_ever': {'(43, 37, 31)': 1865,
#    '(91, 79, 63)': 4884,
#    '(16, 15, 14)': 1251,
#    '(187, 177, 158)': 1262,
#    '(135, 139, 133)': 433,
#    '(144, 121, 84)': 1049,
#    '(97, 54, 38)': 941}},
#  '1810_mm_dd_i_Портрет_доньи_Нарсисы_Бараньяна_де_Гойкоечеа.jpeg': {'path': '1810_mm_dd_i_Портрет_доньи_Нарсисы_Бараньяна_де_Гойкоечеа.jpeg',
#   'name_of_painting': 'Портрет доньи Нарсисы Бараньяна де Гойкоечеа',
#   'year': '1810',
#   'most_common_colors_ever': {'(43, 37, 31)': 2580,
#    '(91, 79, 63)': 3519,
#    '(16, 15, 14)': 3034,
#    '(187, 177, 158)': 494,
#    '(135, 139, 133)': 659,
#    '(144, 121, 84)': 1215,
#    '(97, 54, 38)': 75}},
#  '1792_mm_dd_i_Себастьян_Мартинес_и_Перес.jpeg': {'path': '1792_mm_dd_i_Себастьян_Мартинес_и_Перес.jpeg',
#   'name_of_painting': 'Себастьян Мартинес и Перес',
#   'year': '1792',
#   'most_common_colors_ever': {'(43, 37, 31)': 1692,
#    '(91, 79, 63)': 193,
#    '(16, 15, 14)': 4305,
#    '(187, 177, 158)': 0,
#    '(135, 139, 133)': 0,
#    '(144, 121, 84)': 29,
#    '(97, 54, 38)': 270}},
#  '1798_mm_dd_i_Портрет_художника_Хулио_Асенсио.jpeg': {'path': '1798_mm_dd_i_Портрет_художника_Хулио_Асенсио.jpeg',
#   'name_of_painting': 'Портрет художника Хулио Асенсио',
#   'year': '1798',
#   'most_common_colors_ever': {'(43, 37, 31)': 876,
#    '(91, 79, 63)': 1441,
#    '(16, 15, 14)': 82,
#    '(187, 177, 158)': 5227,
#    '(135, 139, 133)': 518,
#    '(144, 121, 84)': 628,
#    '(97, 54, 38)': 313}},
#  '1814_mm_dd_i_Фернандо_III_Наварры_и_VII_Кастилии.jpeg': {'path': '1814_mm_dd_i_Фернандо_III_Наварры_и_VII_Кастилии.jpeg',
#   'name_of_painting': 'Фернандо III Наварры и VII Кастилии',
#   'year': '1814',
#   'most_common_colors_ever': {'(43, 37, 31)': 3449,
#    '(91, 79, 63)': 1431,
#    '(16, 15, 14)': 5698,
#    '(187, 177, 158)': 716,
#    '(135, 139, 133)': 795,
#    '(144, 121, 84)': 177,
#    '(97, 54, 38)': 597}},
#  '1781_mm_dd_i_Богородица,_как_королева_мучеников_(фрагмент).jpeg': {'path': '1781_mm_dd_i_Богородица,_как_королева_мучеников_(фрагмент).jpeg',
#   'name_of_painting': 'Богородица, как королева мучеников (фрагмент)',
#   'year': '1781',
#   'most_common_colors_ever': {'(43, 37, 31)': 5283,
#    '(91, 79, 63)': 813,
#    '(16, 15, 14)': 7246,
#    '(187, 177, 158)': 664,
#    '(135, 139, 133)': 185,
#    '(144, 121, 84)': 876,
#    '(97, 54, 38)': 780}},
#  '1783_mm_dd_i_Портрет_Марии_Терезы_де_Валлабриг_на_коне.jpeg': {'path': '1783_mm_dd_i_Портрет_Марии_Терезы_де_Валлабриг_на_коне.jpeg',
#   'name_of_painting': 'Портрет Марии Терезы де Валлабриг на коне',
#   'year': '1783',
#   'most_common_colors_ever': {'(43, 37, 31)': 4403,
#    '(91, 79, 63)': 2860,
#    '(16, 15, 14)': 305,
#    '(187, 177, 158)': 26,
#    '(135, 139, 133)': 4,
#    '(144, 121, 84)': 1001,
#    '(97, 54, 38)': 2443}},
#  '1777_mm_dd_i_Зонтик.jpeg': {'path': '1777_mm_dd_i_Зонтик.jpeg',
#   'name_of_painting': 'Зонтик',
#   'year': '1777',
#   'most_common_colors_ever': {'(43, 37, 31)': 5984,
#    '(91, 79, 63)': 407,
#    '(16, 15, 14)': 6699,
#    '(187, 177, 158)': 12,
#    '(135, 139, 133)': 35,
#    '(144, 121, 84)': 65,
#    '(97, 54, 38)': 1174}},
#  '1812_mm_dd_i_Маха_на_балконе.jpeg': {'path': '1812_mm_dd_i_Маха_на_балконе.jpeg',
#   'name_of_painting': 'Маха на балконе',
#   'year': '1812',
#   'most_common_colors_ever': {'(43, 37, 31)': 1869,
#    '(91, 79, 63)': 5020,
#    '(16, 15, 14)': 353,
#    '(187, 177, 158)': 1441,
#    '(135, 139, 133)': 1139,
#    '(144, 121, 84)': 489,
#    '(97, 54, 38)': 471}},
#  '1780_mm_dd_i_Любительская_коррида.jpeg': {'path': '1780_mm_dd_i_Любительская_коррида.jpeg',
#   'name_of_painting': 'Любительская коррида',
#   'year': '1780',
#   'most_common_colors_ever': {'(43, 37, 31)': 2062,
#    '(91, 79, 63)': 1602,
#    '(16, 15, 14)': 483,
#    '(187, 177, 158)': 4735,
#    '(135, 139, 133)': 1843,
#    '(144, 121, 84)': 933,
#    '(97, 54, 38)': 293}},
#  '1823_mm_dd_i_Ковен,_или_великий_козел.jpeg': {'path': '1823_mm_dd_i_Ковен,_или_великий_козел.jpeg',
#   'name_of_painting': 'Ковен, или великий козел',
#   'year': '1823',
#   'most_common_colors_ever': {'(43, 37, 31)': 3470,
#    '(91, 79, 63)': 1434,
#    '(16, 15, 14)': 5714,
#    '(187, 177, 158)': 707,
#    '(135, 139, 133)': 789,
#    '(144, 121, 84)': 179,
#    '(97, 54, 38)': 597}},
#  '1798_mm_dd_i_Ведьмы_в_воздухе.jpeg': {'path': '1798_mm_dd_i_Ведьмы_в_воздухе.jpeg',
#   'name_of_painting': 'Ведьмы в воздухе',
#   'year': '1798',
#   'most_common_colors_ever': {'(43, 37, 31)': 5913,
#    '(91, 79, 63)': 2939,
#    '(16, 15, 14)': 3769,
#    '(187, 177, 158)': 142,
#    '(135, 139, 133)': 97,
#    '(144, 121, 84)': 414,
#    '(97, 54, 38)': 782}},
#  '1788_mm_dd_i_Мануэль_Осорио_де_Зунига_(фрагмент).jpeg': {'path': '1788_mm_dd_i_Мануэль_Осорио_де_Зунига_(фрагмент).jpeg',
#   'name_of_painting': 'Мануэль Осорио де Зунига (фрагмент)',
#   'year': '1788',
#   'most_common_colors_ever': {'(43, 37, 31)': 1659,
#    '(91, 79, 63)': 2461,
#    '(16, 15, 14)': 1528,
#    '(187, 177, 158)': 458,
#    '(135, 139, 133)': 642,
#    '(144, 121, 84)': 849,
#    '(97, 54, 38)': 673}},
#  '1820_mm_dd_a_Автопортрет с доктором Арриетой.jpeg': {'path': '1820_mm_dd_a_Автопортрет с доктором Арриетой.jpeg',
#   'name_of_painting': 'Автопортрет с доктором Арриетой',
#   'year': '1820',
#   'most_common_colors_ever': {'(43, 37, 31)': 1051,
#    '(91, 79, 63)': 2180,
#    '(16, 15, 14)': 26,
#    '(187, 177, 158)': 1443,
#    '(135, 139, 133)': 1178,
#    '(144, 121, 84)': 2172,
#    '(97, 54, 38)': 723}},
#  '1792_mm_dd_i_Игра_"Конь_и_всадник".jpeg': {'path': '1792_mm_dd_i_Игра_"Конь_и_всадник".jpeg',
#   'name_of_painting': 'Игра "Конь и всадник"',
#   'year': '1792',
#   'most_common_colors_ever': {'(43, 37, 31)': 1281,
#    '(91, 79, 63)': 1230,
#    '(16, 15, 14)': 109,
#    '(187, 177, 158)': 892,
#    '(135, 139, 133)': 1077,
#    '(144, 121, 84)': 1994,
#    '(97, 54, 38)': 631}},
#  '1779_mm_dd_i_Ярмарка_в_Мадриде.jpeg': {'path': '1779_mm_dd_i_Ярмарка_в_Мадриде.jpeg',
#   'name_of_painting': 'Ярмарка в Мадриде',
#   'year': '1779',
#   'most_common_colors_ever': {'(43, 37, 31)': 2250,
#    '(91, 79, 63)': 4975,
#    '(16, 15, 14)': 765,
#    '(187, 177, 158)': 129,
#    '(135, 139, 133)': 604,
#    '(144, 121, 84)': 2069,
#    '(97, 54, 38)': 1244}},
#  '1812_mm_dd_i_Маха_и_Селестина_на_балконе.jpeg': {'path': '1812_mm_dd_i_Маха_и_Селестина_на_балконе.jpeg',
#   'name_of_painting': 'Маха и Селестина на балконе',
#   'year': '1812',
#   'most_common_colors_ever': {'(43, 37, 31)': 7812,
#    '(91, 79, 63)': 1419,
#    '(16, 15, 14)': 3496,
#    '(187, 177, 158)': 33,
#    '(135, 139, 133)': 142,
#    '(144, 121, 84)': 305,
#    '(97, 54, 38)': 1152}},
#  '1800_mm_dd_a_Автопортрет_в_очках.jpeg': {'path': '1800_mm_dd_a_Автопортрет_в_очках.jpeg',
#   'name_of_painting': 'Автопортрет в очках',
#   'year': '1800',
#   'most_common_colors_ever': {'(43, 37, 31)': 1673,
#    '(91, 79, 63)': 744,
#    '(16, 15, 14)': 1838,
#    '(187, 177, 158)': 764,
#    '(135, 139, 133)': 2549,
#    '(144, 121, 84)': 753,
#    '(97, 54, 38)': 1284}},
#  '1779_mm_dd_i_Качели.jpeg': {'path': '1779_mm_dd_i_Качели.jpeg',
#   'name_of_painting': 'Качели',
#   'year': '1779',
#   'most_common_colors_ever': {'(43, 37, 31)': 1443,
#    '(91, 79, 63)': 2569,
#    '(16, 15, 14)': 258,
#    '(187, 177, 158)': 2246,
#    '(135, 139, 133)': 619,
#    '(144, 121, 84)': 1067,
#    '(97, 54, 38)': 1054}},
#  '1798_mm_dd_i_Кардинал_Луис_Мария_де_Борон.jpeg': {'path': '1798_mm_dd_i_Кардинал_Луис_Мария_де_Борон.jpeg',
#   'name_of_painting': 'Кардинал Луис Мария де Борон',
#   'year': '1798',
#   'most_common_colors_ever': {'(43, 37, 31)': 1996,
#    '(91, 79, 63)': 1711,
#    '(16, 15, 14)': 1450,
#    '(187, 177, 158)': 1551,
#    '(135, 139, 133)': 519,
#    '(144, 121, 84)': 781,
#    '(97, 54, 38)': 587}},
#  '1823_mm_dd_i_Асмодей,_или_Фантастическое_видение.jpeg': {'path': '1823_mm_dd_i_Асмодей,_или_Фантастическое_видение.jpeg',
#   'name_of_painting': 'Асмодей, или Фантастическое видение',
#   'year': '1823',
#   'most_common_colors_ever': {'(43, 37, 31)': 6206,
#    '(91, 79, 63)': 1416,
#    '(16, 15, 14)': 8023,
#    '(187, 177, 158)': 275,
#    '(135, 139, 133)': 161,
#    '(144, 121, 84)': 594,
#    '(97, 54, 38)': 478}},
#  '1813_mm_dd_i_Последователи._Штурм_крепости_на_скале.jpeg': {'path': '1813_mm_dd_i_Последователи._Штурм_крепости_на_скале.jpeg',
#   'name_of_painting': 'Последователи. Штурм крепости на скале',
#   'year': '1813',
#   'most_common_colors_ever': {'(43, 37, 31)': 728,
#    '(91, 79, 63)': 1107,
#    '(16, 15, 14)': 4146,
#    '(187, 177, 158)': 100,
#    '(135, 139, 133)': 264,
#    '(144, 121, 84)': 32,
#    '(97, 54, 38)': 6}},
#  '1789_mm_dd_i_Жмурки.jpeg': {'path': '1789_mm_dd_i_Жмурки.jpeg',
#   'name_of_painting': 'Жмурки',
#   'year': '1789',
#   'most_common_colors_ever': {'(43, 37, 31)': 1986,
#    '(91, 79, 63)': 3209,
#    '(16, 15, 14)': 463,
#    '(187, 177, 158)': 1789,
#    '(135, 139, 133)': 1399,
#    '(144, 121, 84)': 573,
#    '(97, 54, 38)': 737}},
#  '1774_mm_dd_i_Рождение_Богородицы.jpeg': {'path': '1774_mm_dd_i_Рождение_Богородицы.jpeg',
#   'name_of_painting': 'Рождение Богородицы',
#   'year': '1774',
#   'most_common_colors_ever': {'(43, 37, 31)': 4093,
#    '(91, 79, 63)': 1057,
#    '(16, 15, 14)': 9101,
#    '(187, 177, 158)': 241,
#    '(135, 139, 133)': 189,
#    '(144, 121, 84)': 269,
#    '(97, 54, 38)': 333}},
#  '1811_mm_dd_i_Портрет_Хуана_Антонио_Льоренте.jpeg': {'path': '1811_mm_dd_i_Портрет_Хуана_Антонио_Льоренте.jpeg',
#   'name_of_painting': 'Портрет Хуана Антонио Льоренте',
#   'year': '1811',
#   'most_common_colors_ever': {'(43, 37, 31)': 5973,
#    '(91, 79, 63)': 2259,
#    '(16, 15, 14)': 5128,
#    '(187, 177, 158)': 93,
#    '(135, 139, 133)': 50,
#    '(144, 121, 84)': 424,
#    '(97, 54, 38)': 577}},
#  '1795_mm_dd_i_Пикадор.jpeg': {'path': '1795_mm_dd_i_Пикадор.jpeg',
#   'name_of_painting': 'Пикадор',
#   'year': '1795',
#   'most_common_colors_ever': {'(43, 37, 31)': 3243,
#    '(91, 79, 63)': 1497,
#    '(16, 15, 14)': 3129,
#    '(187, 177, 158)': 21,
#    '(135, 139, 133)': 1932,
#    '(144, 121, 84)': 51,
#    '(97, 54, 38)': 598}},
#  '1787_mm_dd_i_Эскизы_гобеленов_для_королевских_дворцов_Прадо_и_Эскориал._Мальчики_с_мастифом.jpeg': {'path': '1787_mm_dd_i_Эскизы_гобеленов_для_королевских_дворцов_Прадо_и_Эскориал._Мальчики_с_мастифом.jpeg',
#   'name_of_painting': 'Эскизы гобеленов для королевских дворцов Прадо и Эскориал. Мальчики с мастифом',
#   'year': '1787',
#   'most_common_colors_ever': {'(43, 37, 31)': 4450,
#    '(91, 79, 63)': 2634,
#    '(16, 15, 14)': 2964,
#    '(187, 177, 158)': 762,
#    '(135, 139, 133)': 482,
#    '(144, 121, 84)': 812,
#    '(97, 54, 38)': 439}},
#  '1814_mm_dd_i_Стычка_с_мамелюками_2_мая_1808_года_в_Мадриде.jpeg': {'path': '1814_mm_dd_i_Стычка_с_мамелюками_2_мая_1808_года_в_Мадриде.jpeg',
#   'name_of_painting': 'Стычка с мамелюками 2 мая 1808 года в Мадриде',
#   'year': '1814',
#   'most_common_colors_ever': {'(43, 37, 31)': 6028,
#    '(91, 79, 63)': 878,
#    '(16, 15, 14)': 7838,
#    '(187, 177, 158)': 574,
#    '(135, 139, 133)': 88,
#    '(144, 121, 84)': 310,
#    '(97, 54, 38)': 649}},
#  '1798_mm_dd_i_Фердинанд_Гиймарде_—_французский_посол_в_Испании.jpeg': {'path': '1798_mm_dd_i_Фердинанд_Гиймарде_—_французский_посол_в_Испании.jpeg',
#   'name_of_painting': 'Фердинанд Гиймарде — французский посол в Испании',
#   'year': '1798',
#   'most_common_colors_ever': {'(43, 37, 31)': 9769,
#    '(91, 79, 63)': 2330,
#    '(16, 15, 14)': 2499,
#    '(187, 177, 158)': 116,
#    '(135, 139, 133)': 417,
#    '(144, 121, 84)': 201,
#    '(97, 54, 38)': 641}},
#  '1786_mm_dd_i_Лето.jpeg': {'path': '1786_mm_dd_i_Лето.jpeg',
#   'name_of_painting': 'Лето',
#   'year': '1786',
#   'most_common_colors_ever': {'(43, 37, 31)': 2664,
#    '(91, 79, 63)': 1051,
#    '(16, 15, 14)': 8055,
#    '(187, 177, 158)': 405,
#    '(135, 139, 133)': 176,
#    '(144, 121, 84)': 672,
#    '(97, 54, 38)': 408}},
#  '1823_mm_dd_i_Два_старика_за_едой.jpeg': {'path': '1823_mm_dd_i_Два_старика_за_едой.jpeg',
#   'name_of_painting': 'Два старика за едой',
#   'year': '1823',
#   'most_common_colors_ever': {'(43, 37, 31)': 530,
#    '(91, 79, 63)': 836,
#    '(16, 15, 14)': 245,
#    '(187, 177, 158)': 1996,
#    '(135, 139, 133)': 7048,
#    '(144, 121, 84)': 722,
#    '(97, 54, 38)': 112}},
#  '1798_mm_dd_i_Шабаш_ведьм.jpeg': {'path': '1798_mm_dd_i_Шабаш_ведьм.jpeg',
#   'name_of_painting': 'Шабаш ведьм',
#   'year': '1798',
#   'most_common_colors_ever': {'(43, 37, 31)': 3804,
#    '(91, 79, 63)': 1002,
#    '(16, 15, 14)': 1104,
#    '(187, 177, 158)': 346,
#    '(135, 139, 133)': 3146,
#    '(144, 121, 84)': 445,
#    '(97, 54, 38)': 826}},
#  '1800_mm_dd_i_Король_Испании_Карл_IV_и_его_семья.jpeg': {'path': '1800_mm_dd_i_Король_Испании_Карл_IV_и_его_семья.jpeg',
#   'name_of_painting': 'Король Испании Карл IV и его семья',
#   'year': '1800',
#   'most_common_colors_ever': {'(43, 37, 31)': 7900,
#    '(91, 79, 63)': 1547,
#    '(16, 15, 14)': 3294,
#    '(187, 177, 158)': 114,
#    '(135, 139, 133)': 1479,
#    '(144, 121, 84)': 140,
#    '(97, 54, 38)': 120}},
#  '1779_mm_dd_i_С_гитарой.jpeg': {'path': '1779_mm_dd_i_С_гитарой.jpeg',
#   'name_of_painting': 'С гитарой',
#   'year': '1779',
#   'most_common_colors_ever': {'(43, 37, 31)': 8548,
#    '(91, 79, 63)': 1692,
#    '(16, 15, 14)': 4350,
#    '(187, 177, 158)': 23,
#    '(135, 139, 133)': 0,
#    '(144, 121, 84)': 2224,
#    '(97, 54, 38)': 475}},
#  '1798_mm_dd_i_Чудо_Св._Антония.jpeg': {'path': '1798_mm_dd_i_Чудо_Св._Антония.jpeg',
#   'name_of_painting': 'Чудо Св. Антония',
#   'year': '1798',
#   'most_common_colors_ever': {'(43, 37, 31)': 1643,
#    '(91, 79, 63)': 872,
#    '(16, 15, 14)': 6640,
#    '(187, 177, 158)': 35,
#    '(135, 139, 133)': 31,
#    '(144, 121, 84)': 832,
#    '(97, 54, 38)': 452}},
#  '1810_mm_dd_i_Похороны_сардинки.jpeg': {'path': '1810_mm_dd_i_Похороны_сардинки.jpeg',
#   'name_of_painting': 'Похороны сардинки',
#   'year': '1810',
#   'most_common_colors_ever': {'(43, 37, 31)': 5032,
#    '(91, 79, 63)': 3169,
#    '(16, 15, 14)': 4955,
#    '(187, 177, 158)': 123,
#    '(135, 139, 133)': 81,
#    '(144, 121, 84)': 355,
#    '(97, 54, 38)': 763}},
#  '1798_mm_dd_i_Портрет_французского_посла_в_Испании_Фердинанда_Гиймардета.jpeg': {'path': '1798_mm_dd_i_Портрет_французского_посла_в_Испании_Фердинанда_Гиймардета.jpeg',
#   'name_of_painting': 'Портрет французского посла в Испании Фердинанда Гиймардета',
#   'year': '1798',
#   'most_common_colors_ever': {'(43, 37, 31)': 4303,
#    '(91, 79, 63)': 5291,
#    '(16, 15, 14)': 1203,
#    '(187, 177, 158)': 227,
#    '(135, 139, 133)': 223,
#    '(144, 121, 84)': 847,
#    '(97, 54, 38)': 394}},
#  '1804_mm_dd_i_Портрет_маркизы_Сантьяго.jpeg': {'path': '1804_mm_dd_i_Портрет_маркизы_Сантьяго.jpeg',
#   'name_of_painting': 'Портрет маркизы Сантьяго',
#   'year': '1804',
#   'most_common_colors_ever': {'(43, 37, 31)': 2463,
#    '(91, 79, 63)': 3127,
#    '(16, 15, 14)': 3969,
#    '(187, 177, 158)': 2413,
#    '(135, 139, 133)': 347,
#    '(144, 121, 84)': 219,
#    '(97, 54, 38)': 247}},
#  '1824_mm_dd_i_Бой_быков._Суэрте_де_варас.jpeg': {'path': '1824_mm_dd_i_Бой_быков._Суэрте_де_варас.jpeg',
#   'name_of_painting': 'Бой быков. Суэрте де варас',
#   'year': '1824',
#   'most_common_colors_ever': {'(43, 37, 31)': 2877,
#    '(91, 79, 63)': 2280,
#    '(16, 15, 14)': 1914,
#    '(187, 177, 158)': 43,
#    '(135, 139, 133)': 5565,
#    '(144, 121, 84)': 1977,
#    '(97, 54, 38)': 615}},
#  '1798_mm_dd_i_Заклинание.jpeg': {'path': '1798_mm_dd_i_Заклинание.jpeg',
#   'name_of_painting': 'Заклинание',
#   'year': '1798',
#   'most_common_colors_ever': {'(43, 37, 31)': 4095,
#    '(91, 79, 63)': 2455,
#    '(16, 15, 14)': 1387,
#    '(187, 177, 158)': 525,
#    '(135, 139, 133)': 2254,
#    '(144, 121, 84)': 359,
#    '(97, 54, 38)': 577}},
#  '1807_mm_dd_i_Портрет_актера_Исидро_Маркеса.jpeg': {'path': '1807_mm_dd_i_Портрет_актера_Исидро_Маркеса.jpeg',
#   'name_of_painting': 'Портрет актера Исидро Маркеса',
#   'year': '1807',
#   'most_common_colors_ever': {'(43, 37, 31)': 1020,
#    '(91, 79, 63)': 819,
#    '(16, 15, 14)': 3098,
#    '(187, 177, 158)': 378,
#    '(135, 139, 133)': 351,
#    '(144, 121, 84)': 727,
#    '(97, 54, 38)': 300}},
#  '1828_mm_dd_i_Хосе_Пио_де_Молина.jpeg': {'path': '1828_mm_dd_i_Хосе_Пио_де_Молина.jpeg',
#   'name_of_painting': 'Хосе Пио де Молина',
#   'year': '1828',
#   'most_common_colors_ever': {'(43, 37, 31)': 3802,
#    '(91, 79, 63)': 1788,
#    '(16, 15, 14)': 3742,
#    '(187, 177, 158)': 1817,
#    '(135, 139, 133)': 1342,
#    '(144, 121, 84)': 667,
#    '(97, 54, 38)': 353}},
#  '1801_mm_dd_i_Портрет_Марии_Луизы_де_Бурбон.jpeg': {'path': '1801_mm_dd_i_Портрет_Марии_Луизы_де_Бурбон.jpeg',
#   'name_of_painting': 'Портрет Марии Луизы де Бурбон',
#   'year': '1801',
#   'most_common_colors_ever': {'(43, 37, 31)': 18,
#    '(91, 79, 63)': 1215,
#    '(16, 15, 14)': 0,
#    '(187, 177, 158)': 2778,
#    '(135, 139, 133)': 2088,
#    '(144, 121, 84)': 1482,
#    '(97, 54, 38)': 45}},
#  '1795_mm_dd_i_Портрет_сеньоры_Кеан_Бермудес,_жены_Хуана_Агостино_Бермудеса.jpeg': {'path': '1795_mm_dd_i_Портрет_сеньоры_Кеан_Бермудес,_жены_Хуана_Агостино_Бермудеса.jpeg',
#   'name_of_painting': 'Портрет сеньоры Кеан Бермудес, жены Хуана Агостино Бермудеса',
#   'year': '1795',
#   'most_common_colors_ever': {'(43, 37, 31)': 221,
#    '(91, 79, 63)': 443,
#    '(16, 15, 14)': 82,
#    '(187, 177, 158)': 579,
#    '(135, 139, 133)': 230,
#    '(144, 121, 84)': 1261,
#    '(97, 54, 38)': 1030}},
#  '1792_mm_dd_i_Соломенное_чучело_(Марионетка).jpeg': {'path': '1792_mm_dd_i_Соломенное_чучело_(Марионетка).jpeg',
#   'name_of_painting': 'Соломенное чучело (Марионетка)',
#   'year': '1792',
#   'most_common_colors_ever': {'(43, 37, 31)': 1330,
#    '(91, 79, 63)': 1231,
#    '(16, 15, 14)': 2238,
#    '(187, 177, 158)': 809,
#    '(135, 139, 133)': 1625,
#    '(144, 121, 84)': 466,
#    '(97, 54, 38)': 614}},
#  '1783_mm_dd_i_Хосе_Моньино,_1-й_граф_Флоридабланка.jpeg': {'path': '1783_mm_dd_i_Хосе_Моньино,_1-й_граф_Флоридабланка.jpeg',
#   'name_of_painting': 'Хосе Моньино, 1-й граф Флоридабланка',
#   'year': '1783',
#   'most_common_colors_ever': {'(43, 37, 31)': 3900,
#    '(91, 79, 63)': 2553,
#    '(16, 15, 14)': 2873,
#    '(187, 177, 158)': 620,
#    '(135, 139, 133)': 1976,
#    '(144, 121, 84)': 479,
#    '(97, 54, 38)': 625}},
#  '1783_mm_dd_i_Мария_Тереза_де_Виллабрига.jpeg': {'path': '1783_mm_dd_i_Мария_Тереза_де_Виллабрига.jpeg',
#   'name_of_painting': 'Мария Тереза де Виллабрига',
#   'year': '1783',
#   'most_common_colors_ever': {'(43, 37, 31)': 2089,
#    '(91, 79, 63)': 2329,
#    '(16, 15, 14)': 135,
#    '(187, 177, 158)': 583,
#    '(135, 139, 133)': 2050,
#    '(144, 121, 84)': 339,
#    '(97, 54, 38)': 240}},
#  '1798_mm_dd_i_Фреска_часовни_Св._Антония_Флоридского,_деталь_3.jpeg': {'path': '1798_mm_dd_i_Фреска_часовни_Св._Антония_Флоридского,_деталь_3.jpeg',
#   'name_of_painting': 'Фреска часовни Св. Антония Флоридского, деталь 3',
#   'year': '1798',
#   'most_common_colors_ever': {'(43, 37, 31)': 3159,
#    '(91, 79, 63)': 2915,
#    '(16, 15, 14)': 3099,
#    '(187, 177, 158)': 158,
#    '(135, 139, 133)': 167,
#    '(144, 121, 84)': 639,
#    '(97, 54, 38)': 1067}},
#  '1813_mm_dd_i_Портрет_Хосе_Коста-и-Бонелиса_по_прозвищу_Пепито.jpeg': {'path': '1813_mm_dd_i_Портрет_Хосе_Коста-и-Бонелиса_по_прозвищу_Пепито.jpeg',
#   'name_of_painting': 'Портрет Хосе Коста-и-Бонелиса по прозвищу Пепито',
#   'year': '1813',
#   'most_common_colors_ever': {'(43, 37, 31)': 3061,
#    '(91, 79, 63)': 2474,
#    '(16, 15, 14)': 5503,
#    '(187, 177, 158)': 34,
#    '(135, 139, 133)': 604,
#    '(144, 121, 84)': 393,
#    '(97, 54, 38)': 153}},
#  '1792_mm_dd_i_Мальчики_взбирались_на_дерево_(картон_для_гобелена).jpeg': {'path': '1792_mm_dd_i_Мальчики_взбирались_на_дерево_(картон_для_гобелена).jpeg',
#   'name_of_painting': 'Мальчики взбирались на дерево (картон для гобелена)',
#   'year': '1792',
#   'most_common_colors_ever': {'(43, 37, 31)': 773,
#    '(91, 79, 63)': 1354,
#    '(16, 15, 14)': 1064,
#    '(187, 177, 158)': 1396,
#    '(135, 139, 133)': 1092,
#    '(144, 121, 84)': 1248,
#    '(97, 54, 38)': 1169}},
#  '1823_mm_dd_i_Тонущая_собака.jpeg': {'path': '1823_mm_dd_i_Тонущая_собака.jpeg',
#   'name_of_painting': 'Тонущая собака',
#   'year': '1823',
#   'most_common_colors_ever': {'(43, 37, 31)': 3085,
#    '(91, 79, 63)': 2502,
#    '(16, 15, 14)': 5491,
#    '(187, 177, 158)': 37,
#    '(135, 139, 133)': 600,
#    '(144, 121, 84)': 396,
#    '(97, 54, 38)': 152}},
#  '1792_mm_dd_i_Девушки_с_кувшинами.jpeg': {'path': '1792_mm_dd_i_Девушки_с_кувшинами.jpeg',
#   'name_of_painting': 'Девушки с кувшинами',
#   'year': '1792',
#   'most_common_colors_ever': {'(43, 37, 31)': 2068,
#    '(91, 79, 63)': 378,
#    '(16, 15, 14)': 11478,
#    '(187, 177, 158)': 109,
#    '(135, 139, 133)': 72,
#    '(144, 121, 84)': 879,
#    '(97, 54, 38)': 425}},
#  '1800_mm_dd_i_Обнаженная_Маха.jpeg': {'path': '1800_mm_dd_i_Обнаженная_Маха.jpeg',
#   'name_of_painting': 'Обнаженная Маха',
#   'year': '1800',
#   'most_common_colors_ever': {'(43, 37, 31)': 5151,
#    '(91, 79, 63)': 1318,
#    '(16, 15, 14)': 5737,
#    '(187, 177, 158)': 232,
#    '(135, 139, 133)': 499,
#    '(144, 121, 84)': 1246,
#    '(97, 54, 38)': 413}},
#  '1788_mm_dd_i_Дон_Мануэль_Осорио_Манрике_де_Суньига,_ребёнок.jpeg': {'path': '1788_mm_dd_i_Дон_Мануэль_Осорио_Манрике_де_Суньига,_ребёнок.jpeg',
#   'name_of_painting': 'Дон Мануэль Осорио Манрике де Суньига, ребёнок',
#   'year': '1788',
#   'most_common_colors_ever': {'(43, 37, 31)': 2336,
#    '(91, 79, 63)': 482,
#    '(16, 15, 14)': 12348,
#    '(187, 177, 158)': 127,
#    '(135, 139, 133)': 42,
#    '(144, 121, 84)': 249,
#    '(97, 54, 38)': 174}},
#  '1803_mm_dd_i_Портрет_графини_Чинчон.jpeg': {'path': '1803_mm_dd_i_Портрет_графини_Чинчон.jpeg',
#   'name_of_painting': 'Портрет графини Чинчон',
#   'year': '1803',
#   'most_common_colors_ever': {'(43, 37, 31)': 6444,
#    '(91, 79, 63)': 2307,
#    '(16, 15, 14)': 4936,
#    '(187, 177, 158)': 75,
#    '(135, 139, 133)': 83,
#    '(144, 121, 84)': 2304,
# ...
#   'name_of_painting': 'Мальчики играют в солдатиков',
#   'year': '1779',
#   'most_common_colors_ever': {'(43, 37, 31)': 1851,
#    '(91, 79, 63)': 3802,
#    '(16, 15, 14)': 261,
#    '(187, 177, 158)': 511,
#    '(135, 139, 133)': 1806,
#    '(144, 121, 84)': 1308,
#    '(97, 54, 38)': 2124}},
#  '1809_mm_dd_i_Аллегория_города_Мадрида.jpeg': {'path': '1809_mm_dd_i_Аллегория_города_Мадрида.jpeg',
#   'name_of_painting': 'Аллегория города Мадрида',
#   'year': '1809',
#   'most_common_colors_ever': {'(43, 37, 31)': 11744,
#    '(91, 79, 63)': 528,
#    '(16, 15, 14)': 2884,
#    '(187, 177, 158)': 25,
#    '(135, 139, 133)': 52,
#    '(144, 121, 84)': 128,
#    '(97, 54, 38)': 367}},
#  '1798_mm_dd_i_Полет_ведьм.jpeg': {'path': '1798_mm_dd_i_Полет_ведьм.jpeg',
#   'name_of_painting': 'Полет ведьм',
#   'year': '1798',
#   'most_common_colors_ever': {'(43, 37, 31)': 10141,
#    '(91, 79, 63)': 1368,
#    '(16, 15, 14)': 1924,
#    '(187, 177, 158)': 410,
#    '(135, 139, 133)': 138,
#    '(144, 121, 84)': 367,
#    '(97, 54, 38)': 531}},
#  '1806_mm_dd_i_Портрет_доньи_Исабель_Кобос_де_Порсель.jpeg': {'path': '1806_mm_dd_i_Портрет_доньи_Исабель_Кобос_де_Порсель.jpeg',
#   'name_of_painting': 'Портрет доньи Исабель Кобос де Порсель',
#   'year': '1806',
#   'most_common_colors_ever': {'(43, 37, 31)': 3887,
#    '(91, 79, 63)': 936,
#    '(16, 15, 14)': 3081,
#    '(187, 177, 158)': 128,
#    '(135, 139, 133)': 189,
#    '(144, 121, 84)': 231,
#    '(97, 54, 38)': 910}},
#  '1778_mm_dd_i_Воздушный_змей.jpeg': {'path': '1778_mm_dd_i_Воздушный_змей.jpeg',
#   'name_of_painting': 'Воздушный змей',
#   'year': '1778',
#   'most_common_colors_ever': {'(43, 37, 31)': 2281,
#    '(91, 79, 63)': 4159,
#    '(16, 15, 14)': 1463,
#    '(187, 177, 158)': 110,
#    '(135, 139, 133)': 2194,
#    '(144, 121, 84)': 765,
#    '(97, 54, 38)': 806}},
#  '1808_mm_dd_i_Тюремная_сцена.jpeg': {'path': '1808_mm_dd_i_Тюремная_сцена.jpeg',
#   'name_of_painting': 'Тюремная сцена',
#   'year': '1808',
#   'most_common_colors_ever': {'(43, 37, 31)': 9729,
#    '(91, 79, 63)': 19,
#    '(16, 15, 14)': 2260,
#    '(187, 177, 158)': 0,
#    '(135, 139, 133)': 0,
#    '(144, 121, 84)': 1,
#    '(97, 54, 38)': 580}},
#  '1788_mm_dd_s_Эскизы_гобеленов_для_королевских_дворцов_Прадо_и_Эскориал._Полдник_на_лоне_природы.jpeg': {'path': '1788_mm_dd_s_Эскизы_гобеленов_для_королевских_дворцов_Прадо_и_Эскориал._Полдник_на_лоне_природы.jpeg',
#   'name_of_painting': 'Эскизы гобеленов для королевских дворцов Прадо и Эскориал. Полдник на лоне природы',
#   'year': '1788',
#   'most_common_colors_ever': {'(43, 37, 31)': 2402,
#    '(91, 79, 63)': 1116,
#    '(16, 15, 14)': 1587,
#    '(187, 177, 158)': 83,
#    '(135, 139, 133)': 3116,
#    '(144, 121, 84)': 607,
#    '(97, 54, 38)': 1418}},
#  '1780_mm_dd_i_Дровосеки.jpeg': {'path': '1780_mm_dd_i_Дровосеки.jpeg',
#   'name_of_painting': 'Дровосеки',
#   'year': '1780',
#   'most_common_colors_ever': {'(43, 37, 31)': 555,
#    '(91, 79, 63)': 1194,
#    '(16, 15, 14)': 71,
#    '(187, 177, 158)': 394,
#    '(135, 139, 133)': 599,
#    '(144, 121, 84)': 1277,
#    '(97, 54, 38)': 1703}},
#  '1823_mm_dd_i_Паломничество_в_Сан-Исидро.jpeg': {'path': '1823_mm_dd_i_Паломничество_в_Сан-Исидро.jpeg',
#   'name_of_painting': 'Паломничество в Сан-Исидро',
#   'year': '1823',
#   'most_common_colors_ever': {'(43, 37, 31)': 10188,
#    '(91, 79, 63)': 998,
#    '(16, 15, 14)': 12032,
#    '(187, 177, 158)': 0,
#    '(135, 139, 133)': 2,
#    '(144, 121, 84)': 44,
#    '(97, 54, 38)': 274}},
#  '1810_mm_dd_i_Цикл_картин_"Ужасы_войны"._Чумной_барак.jpeg': {'path': '1810_mm_dd_i_Цикл_картин_"Ужасы_войны"._Чумной_барак.jpeg',
#   'name_of_painting': 'Цикл картин "Ужасы войны". Чумной барак',
#   'year': '1810',
#   'most_common_colors_ever': {'(43, 37, 31)': 2252,
#    '(91, 79, 63)': 1168,
#    '(16, 15, 14)': 10984,
#    '(187, 177, 158)': 209,
#    '(135, 139, 133)': 290,
#    '(144, 121, 84)': 133,
#    '(97, 54, 38)': 195}},
#  '1794_mm_dd_i_Разбой.jpeg': {'path': '1794_mm_dd_i_Разбой.jpeg',
#   'name_of_painting': 'Разбой',
#   'year': '1794',
#   'most_common_colors_ever': {'(43, 37, 31)': 4512,
#    '(91, 79, 63)': 3772,
#    '(16, 15, 14)': 3602,
#    '(187, 177, 158)': 49,
#    '(135, 139, 133)': 123,
#    '(144, 121, 84)': 189,
#    '(97, 54, 38)': 49}},
#  '1820_mm_dd_i_Архитектор_Дон_Тибурсио.jpeg': {'path': '1820_mm_dd_i_Архитектор_Дон_Тибурсио.jpeg',
#   'name_of_painting': 'Архитектор Дон Тибурсио',
#   'year': '1820',
#   'most_common_colors_ever': {'(43, 37, 31)': 1395,
#    '(91, 79, 63)': 1539,
#    '(16, 15, 14)': 4600,
#    '(187, 177, 158)': 479,
#    '(135, 139, 133)': 1559,
#    '(144, 121, 84)': 1055,
#    '(97, 54, 38)': 210}},
#  '1798_mm_dd_i_Фреска_часовни_Св._Антония_Флоридского,_деталь_6.jpeg': {'path': '1798_mm_dd_i_Фреска_часовни_Св._Антония_Флоридского,_деталь_6.jpeg',
#   'name_of_painting': 'Фреска часовни Св. Антония Флоридского, деталь 6',
#   'year': '1798',
#   'most_common_colors_ever': {'(43, 37, 31)': 2224,
#    '(91, 79, 63)': 1447,
#    '(16, 15, 14)': 9014,
#    '(187, 177, 158)': 386,
#    '(135, 139, 133)': 356,
#    '(144, 121, 84)': 922,
#    '(97, 54, 38)': 434}},
#  '1816_mm_dd_i_Майское_дерево.jpeg': {'path': '1816_mm_dd_i_Майское_дерево.jpeg',
#   'name_of_painting': 'Майское дерево',
#   'year': '1816',
#   'most_common_colors_ever': {'(43, 37, 31)': 364,
#    '(91, 79, 63)': 225,
#    '(16, 15, 14)': 15063,
#    '(187, 177, 158)': 5,
#    '(135, 139, 133)': 228,
#    '(144, 121, 84)': 70,
#    '(97, 54, 38)': 87}},
#  '1827_mm_dd_i_Портрет_Мариано_Гойи,_внука_художника.jpeg': {'path': '1827_mm_dd_i_Портрет_Мариано_Гойи,_внука_художника.jpeg',
#   'name_of_painting': 'Портрет Мариано Гойи, внука художника',
#   'year': '1827',
#   'most_common_colors_ever': {'(43, 37, 31)': 7889,
#    '(91, 79, 63)': 2369,
#    '(16, 15, 14)': 1775,
#    '(187, 177, 158)': 0,
#    '(135, 139, 133)': 1,
#    '(144, 121, 84)': 687,
#    '(97, 54, 38)': 684}},
#  '1803_mm_dd_i_Портрет_графа_Фернанда_Нуньеса_VII.jpeg': {'path': '1803_mm_dd_i_Портрет_графа_Фернанда_Нуньеса_VII.jpeg',
#   'name_of_painting': 'Портрет графа Фернанда Нуньеса VII',
#   'year': '1803',
#   'most_common_colors_ever': {'(43, 37, 31)': 373,
#    '(91, 79, 63)': 228,
#    '(16, 15, 14)': 15052,
#    '(187, 177, 158)': 10,
#    '(135, 139, 133)': 226,
#    '(144, 121, 84)': 74,
#    '(97, 54, 38)': 88}},
#  '1784_mm_dd_i_Семья_инфанта_Дона_Луиса_де_Бурбона.jpeg': {'path': '1784_mm_dd_i_Семья_инфанта_Дона_Луиса_де_Бурбона.jpeg',
#   'name_of_painting': 'Семья инфанта Дона Луиса де Бурбона',
#   'year': '1784',
#   'most_common_colors_ever': {'(43, 37, 31)': 774,
#    '(91, 79, 63)': 1841,
#    '(16, 15, 14)': 0,
#    '(187, 177, 158)': 1858,
#    '(135, 139, 133)': 414,
#    '(144, 121, 84)': 1474,
#    '(97, 54, 38)': 1393}},
#  '1779_mm_dd_i_Продавщицы_посуды.jpeg': {'path': '1779_mm_dd_i_Продавщицы_посуды.jpeg',
#   'name_of_painting': 'Продавщицы посуды',
#   'year': '1779',
#   'most_common_colors_ever': {'(43, 37, 31)': 9987,
#    '(91, 79, 63)': 1555,
#    '(16, 15, 14)': 8593,
#    '(187, 177, 158)': 79,
#    '(135, 139, 133)': 7,
#    '(144, 121, 84)': 367,
#    '(97, 54, 38)': 374}},
#  '1771_mm_dd_a_Автопортрет.jpeg': {'path': '1771_mm_dd_a_Автопортрет.jpeg',
#   'name_of_painting': 'Автопортрет',
#   'year': '1771',
#   'most_common_colors_ever': {'(43, 37, 31)': 5065,
#    '(91, 79, 63)': 640,
#    '(16, 15, 14)': 9031,
#    '(187, 177, 158)': 21,
#    '(135, 139, 133)': 169,
#    '(144, 121, 84)': 256,
#    '(97, 54, 38)': 243}},
#  '1812_mm_dd_i_Святой_Иоанн_Креститель_в_пустыне.jpeg': {'path': '1812_mm_dd_i_Святой_Иоанн_Креститель_в_пустыне.jpeg',
#   'name_of_painting': 'Святой Иоанн Креститель в пустыне',
#   'year': '1812',
#   'most_common_colors_ever': {'(43, 37, 31)': 12060,
#    '(91, 79, 63)': 1418,
#    '(16, 15, 14)': 6490,
#    '(187, 177, 158)': 51,
#    '(135, 139, 133)': 15,
#    '(144, 121, 84)': 356,
#    '(97, 54, 38)': 215}},
#  '1808_mm_dd_i_Госпожа_Франсиска_Сабас_Гарсия.jpeg': {'path': '1808_mm_dd_i_Госпожа_Франсиска_Сабас_Гарсия.jpeg',
#   'name_of_painting': 'Госпожа Франсиска Сабас Гарсия',
#   'year': '1808',
#   'most_common_colors_ever': {'(43, 37, 31)': 448,
#    '(91, 79, 63)': 464,
#    '(16, 15, 14)': 2,
#    '(187, 177, 158)': 0,
#    '(135, 139, 133)': 0,
#    '(144, 121, 84)': 6301,
#    '(97, 54, 38)': 1619}},
#  '1777_mm_dd_i_Драка_в_Вента_Нуева.jpeg': {'path': '1777_mm_dd_i_Драка_в_Вента_Нуева.jpeg',
#   'name_of_painting': 'Драка в Вента Нуева',
#   'year': '1777',
#   'most_common_colors_ever': {'(43, 37, 31)': 13783,
#    '(91, 79, 63)': 907,
#    '(16, 15, 14)': 2182,
#    '(187, 177, 158)': 5,
#    '(135, 139, 133)': 3,
#    '(144, 121, 84)': 368,
#    '(97, 54, 38)': 203}},
#  '1789_mm_dd_i_Королева_Мария_Луиза.jpeg': {'path': '1789_mm_dd_i_Королева_Мария_Луиза.jpeg',
#   'name_of_painting': 'Королева Мария Луиза',
#   'year': '1789',
#   'most_common_colors_ever': {'(43, 37, 31)': 3346,
#    '(91, 79, 63)': 1130,
#    '(16, 15, 14)': 8458,
#    '(187, 177, 158)': 1,
#    '(135, 139, 133)': 1,
#    '(144, 121, 84)': 1260,
#    '(97, 54, 38)': 562}},
#  '1823_mm_dd_i_Портрет_дона_Рамона_Сатуэ.jpeg': {'path': '1823_mm_dd_i_Портрет_дона_Рамона_Сатуэ.jpeg',
#   'name_of_painting': 'Портрет дона Рамона Сатуэ',
#   'year': '1823',
#   'most_common_colors_ever': {'(43, 37, 31)': 12187,
#    '(91, 79, 63)': 1469,
#    '(16, 15, 14)': 6855,
#    '(187, 177, 158)': 0,
#    '(135, 139, 133)': 0,
#    '(144, 121, 84)': 482,
#    '(97, 54, 38)': 711}},
#  '1807_mm_dd_i_Портрет_министра_юстиции_Испании_Хосе_Антонио_Маркеса_Кабальеро.jpeg': {'path': '1807_mm_dd_i_Портрет_министра_юстиции_Испании_Хосе_Антонио_Маркеса_Кабальеро.jpeg',
#   'name_of_painting': 'Портрет министра юстиции Испании Хосе Антонио Маркеса Кабальеро',
#   'year': '1807',
#   'most_common_colors_ever': {'(43, 37, 31)': 172,
#    '(91, 79, 63)': 160,
#    '(16, 15, 14)': 14422,
#    '(187, 177, 158)': 70,
#    '(135, 139, 133)': 45,
#    '(144, 121, 84)': 70,
#    '(97, 54, 38)': 53}},
#  '1787_mm_dd_i_Портрет_графа_Альтамира.jpeg': {'path': '1787_mm_dd_i_Портрет_графа_Альтамира.jpeg',
#   'name_of_painting': 'Портрет графа Альтамира',
#   'year': '1787',
#   'most_common_colors_ever': {'(43, 37, 31)': 3132,
#    '(91, 79, 63)': 1521,
#    '(16, 15, 14)': 3793,
#    '(187, 177, 158)': 299,
#    '(135, 139, 133)': 1262,
#    '(144, 121, 84)': 109,
#    '(97, 54, 38)': 668}},
#  '1820_mm_dd_i_Читающие_мужчины.jpeg': {'path': '1820_mm_dd_i_Читающие_мужчины.jpeg',
#   'name_of_painting': 'Читающие мужчины',
#   'year': '1820',
#   'most_common_colors_ever': {'(43, 37, 31)': 10160,
#    '(91, 79, 63)': 1778,
#    '(16, 15, 14)': 3680,
#    '(187, 177, 158)': 0,
#    '(135, 139, 133)': 0,
#    '(144, 121, 84)': 215,
#    '(97, 54, 38)': 1488}},
#  '1786_mm_dd_i_Цветочницы,_или_весной.jpeg': {'path': '1786_mm_dd_i_Цветочницы,_или_весной.jpeg',
#   'name_of_painting': 'Цветочницы, или весной',
#   'year': '1786',
#   'most_common_colors_ever': {'(43, 37, 31)': 6807,
#    '(91, 79, 63)': 790,
#    '(16, 15, 14)': 4092,
#    '(187, 177, 158)': 49,
#    '(135, 139, 133)': 442,
#    '(144, 121, 84)': 553,
#    '(97, 54, 38)': 1786}},
#  '1779_mm_dd_i_Солдат_и_сеньора.jpeg': {'path': '1779_mm_dd_i_Солдат_и_сеньора.jpeg',
#   'name_of_painting': 'Солдат и сеньора',
#   'year': '1779',
#   'most_common_colors_ever': {'(43, 37, 31)': 12213,
#    '(91, 79, 63)': 1030,
#    '(16, 15, 14)': 1141,
#    '(187, 177, 158)': 8,
#    '(135, 139, 133)': 2,
#    '(144, 121, 84)': 359,
#    '(97, 54, 38)': 152}},
#  '1799_mm_dd_i_Портрет_герцога_де_Осуна.jpeg': {'path': '1799_mm_dd_i_Портрет_герцога_де_Осуна.jpeg',
#   'name_of_painting': 'Портрет герцога де Осуна',
#   'year': '1799',
#   'most_common_colors_ever': {'(43, 37, 31)': 12958,
#    '(91, 79, 63)': 1374,
#    '(16, 15, 14)': 3576,
#    '(187, 177, 158)': 52,
#    '(135, 139, 133)': 154,
#    '(144, 121, 84)': 100,
#    '(97, 54, 38)': 441}},
#  '1778_mm_dd_i_Игроки_в_карты.jpeg': {'path': '1778_mm_dd_i_Игроки_в_карты.jpeg',
#   'name_of_painting': 'Игроки в карты',
#   'year': '1778',
#   'most_common_colors_ever': {'(43, 37, 31)': 13128,
#    '(91, 79, 63)': 793,
#    '(16, 15, 14)': 5596,
#    '(187, 177, 158)': 14,
#    '(135, 139, 133)': 76,
#    '(144, 121, 84)': 332,
#    '(97, 54, 38)': 226}},
#  '1823_mm_dd_i_Сатурн,_пожирающий_своих_детей.jpeg': {'path': '1823_mm_dd_i_Сатурн,_пожирающий_своих_детей.jpeg',
#   'name_of_painting': 'Сатурн, пожирающий своих детей',
#   'year': '1823',
#   'most_common_colors_ever': {'(43, 37, 31)': 6566,
#    '(91, 79, 63)': 3115,
#    '(16, 15, 14)': 3366,
#    '(187, 177, 158)': 0,
#    '(135, 139, 133)': 0,
#    '(144, 121, 84)': 462,
#    '(97, 54, 38)': 1872}},
#  '1788_mm_dd_s_Жмурки_(эскиз).jpeg': {'path': '1788_mm_dd_s_Жмурки_(эскиз).jpeg',
#   'name_of_painting': 'Жмурки (эскиз)',
#   'year': '1788',
#   'most_common_colors_ever': {'(43, 37, 31)': 2071,
#    '(91, 79, 63)': 1137,
#    '(16, 15, 14)': 1749,
#    '(187, 177, 158)': 481,
#    '(135, 139, 133)': 144,
#    '(144, 121, 84)': 2473,
#    '(97, 54, 38)': 398}},
#  '1777_mm_dd_i_Выпивоха.jpeg': {'path': '1777_mm_dd_i_Выпивоха.jpeg',
#   'name_of_painting': 'Выпивоха',
#   'year': '1777',
#   'most_common_colors_ever': {'(43, 37, 31)': 9177,
#    '(91, 79, 63)': 2380,
#    '(16, 15, 14)': 2770,
#    '(187, 177, 158)': 8,
#    '(135, 139, 133)': 1,
#    '(144, 121, 84)': 126,
#    '(97, 54, 38)': 1022}},
#  '1788_mm_dd_i_Луг_Сан-Исидро.jpeg': {'path': '1788_mm_dd_i_Луг_Сан-Исидро.jpeg',
#   'name_of_painting': 'Луг Сан-Исидро',
#   'year': '1788',
#   'most_common_colors_ever': {'(43, 37, 31)': 5512,
#    '(91, 79, 63)': 491,
#    '(16, 15, 14)': 965,
#    '(187, 177, 158)': 0,
#    '(135, 139, 133)': 0,
#    '(144, 121, 84)': 154,
#    '(97, 54, 38)': 3269}},
#  '1775_mm_dd_i_Собаки_на_поводке.jpeg': {'path': '1775_mm_dd_i_Собаки_на_поводке.jpeg',
#   'name_of_painting': 'Собаки на поводке',
#   'year': '1775',
#   'most_common_colors_ever': {'(43, 37, 31)': 232,
#    '(91, 79, 63)': 729,
#    '(16, 15, 14)': 8,
#    '(187, 177, 158)': 0,
#    '(135, 139, 133)': 0,
#    '(144, 121, 84)': 67,
#    '(97, 54, 38)': 2705}},
#  '1775_mm_dd_i_Охотник_с_собакой.jpeg': {'path': '1775_mm_dd_i_Охотник_с_собакой.jpeg',
#   'name_of_painting': 'Охотник с собакой',
#   'year': '1775',
#   'most_common_colors_ever': {'(43, 37, 31)': 6771,
#    '(91, 79, 63)': 1831,
#    '(16, 15, 14)': 3016,
#    '(187, 177, 158)': 225,
#    '(135, 139, 133)': 1547,
#    '(144, 121, 84)': 180,
#    '(97, 54, 38)': 107}},
#  '1812_mm_dd_i_Натюрморт_с_ощипанной_индейкой_и_сковородой_с_рыбой.jpeg': {'path': '1812_mm_dd_i_Натюрморт_с_ощипанной_индейкой_и_сковородой_с_рыбой.jpeg',
#   'name_of_painting': 'Натюрморт с ощипанной индейкой и сковородой с рыбой',
#   'year': '1812',
#   'most_common_colors_ever': {'(43, 37, 31)': 2947,
#    '(91, 79, 63)': 1969,
#    '(16, 15, 14)': 1888,
#    '(187, 177, 158)': 54,
#    '(135, 139, 133)': 1493,
#    '(144, 121, 84)': 819,
#    '(97, 54, 38)': 99}},
#  '1819_mm_dd_i_Портрет_Хуана_Антонио_Куэрво.jpeg': {'path': '1819_mm_dd_i_Портрет_Хуана_Антонио_Куэрво.jpeg',
#   'name_of_painting': 'Портрет Хуана Антонио Куэрво',
#   'year': '1819',
#   'most_common_colors_ever': {'(43, 37, 31)': 8976,
#    '(91, 79, 63)': 271,
#    '(16, 15, 14)': 12481,
#    '(187, 177, 158)': 413,
#    '(135, 139, 133)': 48,
#    '(144, 121, 84)': 180,
#    '(97, 54, 38)': 197}},
#  '1823_mm_dd_i_Юдифь_и_Олоферн.jpeg': {'path': '1823_mm_dd_i_Юдифь_и_Олоферн.jpeg',
#   'name_of_painting': 'Юдифь и Олоферн',
#   'year': '1823',
#   'most_common_colors_ever': {'(43, 37, 31)': 6549,
#    '(91, 79, 63)': 5449,
#    '(16, 15, 14)': 1301,
#    '(187, 177, 158)': 178,
#    '(135, 139, 133)': 80,
#    '(144, 121, 84)': 78,
#    '(97, 54, 38)': 54}},
#  '1783_mm_dd_i_Портрет_Марии_Терезы_де_Бурбон_и_Валлабриг.jpeg': {'path': '1783_mm_dd_i_Портрет_Марии_Терезы_де_Бурбон_и_Валлабриг.jpeg',
#   'name_of_painting': 'Портрет Марии Терезы де Бурбон и Валлабриг',
#   'year': '1783',
#   'most_common_colors_ever': {'(43, 37, 31)': 2769,
#    '(91, 79, 63)': 2408,
#    '(16, 15, 14)': 1109,
#    '(187, 177, 158)': 109,
#    '(135, 139, 133)': 33,
#    '(144, 121, 84)': 1938,
#    '(97, 54, 38)': 1545}},
#  '1827_mm_dd_i_Хуан_Баутиста_де_Мугиро.jpeg': {'path': '1827_mm_dd_i_Хуан_Баутиста_де_Мугиро.jpeg',
#   'name_of_painting': 'Хуан Баутиста де Мугиро',
#   'year': '1827',
#   'most_common_colors_ever': {'(43, 37, 31)': 6331,
#    '(91, 79, 63)': 1,
#    '(16, 15, 14)': 807,
#    '(187, 177, 158)': 0,
#    '(135, 139, 133)': 0,
#    '(144, 121, 84)': 8,
#    '(97, 54, 38)': 1539}}}

# %%
len(info_dict)
# Out:
# 241

# %%
colors_by_year_gm = get_colors_by_year(folder_path, classifier='GM')

# %%
keys_in_colors = set(colors_by_year_gm.keys())
keys_in_info = set(info_dict.keys())

missing_in_info = keys_in_colors - keys_in_info
print("❗ Ключи, которых нет в info_dict:")
for k in missing_in_info:
    print(k)
# Out:
# ❗ Ключи, которых нет в info_dict:
# yyyy_mm_dd_i_Портрет_доньи_Терезы_Суреда.jpeg
# yyyy_mm_dd_i_Совет_Филиппин.jpeg
# yyyy_mm_dd_i_Маскарад_в_Андалусии.jpeg

# %%
# for i in colors_by_year_gm:
#     if i.split('_')[0] != 'yyyy':
#         if i in colors_by_year_gm:
#             info_dict[i]['most_common_colors'] = colors_by_year_gm[i]

for i in colors_by_year_gm:
    if i.split('_')[0] != 'yyyy':
        if i in info_dict:
            info_dict[i]['most_common_colors'] = colors_by_year_gm[i]
        else:
            print(f"⚠️ {i} not found in info_dict")

# %%
info_dict
# Out:
# {'1799_mm_dd_i_Тирана.jpeg': {'path': '1799_mm_dd_i_Тирана.jpeg',
#   'name_of_painting': 'Тирана',
#   'year': '1799',
#   'most_common_colors_ever': {'(43, 37, 31)': 5026,
#    '(91, 79, 63)': 0,
#    '(16, 15, 14)': 9495,
#    '(187, 177, 158)': 0,
#    '(135, 139, 133)': 0,
#    '(144, 121, 84)': 1,
#    '(97, 54, 38)': 683},
#   'most_common_colors': {'(71, 58, 47)': 5240,
#    '(78, 50, 40)': 4617,
#    '(90, 74, 58)': 2097,
#    '(157, 93, 73)': 1278,
#    '(116, 52, 51)': 1237,
#    '(199, 157, 122)': 1064,
#    '(24, 12, 12)': 851}},
#  '1775_mm_dd_i_Охота.jpeg': {'path': '1775_mm_dd_i_Охота.jpeg',
#   'name_of_painting': 'Охота',
#   'year': '1775',
#   'most_common_colors_ever': {'(43, 37, 31)': 9265,
#    '(91, 79, 63)': 767,
#    '(16, 15, 14)': 4769,
#    '(187, 177, 158)': 94,
#    '(135, 139, 133)': 2,
#    '(144, 121, 84)': 243,
#    '(97, 54, 38)': 607},
#   'most_common_colors': {'(75, 63, 38)': 6465,
#    '(113, 92, 53)': 3217,
#    '(153, 130, 83)': 2307,
#    '(191, 200, 180)': 1859,
#    '(139, 169, 159)': 1213,
#    '(214, 193, 150)': 941,
#    '(51, 51, 43)': 382}},
#  '1812_mm_dd_i_Деревенская_коррида.jpeg': {'path': '1812_mm_dd_i_Деревенская_коррида.jpeg',
#   'name_of_painting': 'Деревенская коррида',
#   'year': '1812',
#   'most_common_colors_ever': {'(43, 37, 31)': 5111,
#    '(91, 79, 63)': 775,
#    '(16, 15, 14)': 8957,
#    '(187, 177, 158)': 0,
#    '(135, 139, 133)': 0,
#    '(144, 121, 84)': 147,
#    '(97, 54, 38)': 1180},
#   'most_common_colors': {'(81, 73, 63)': 3690,
#    '(131, 136, 134)': 3483,
#    '(54, 47, 42)': 2879,
#    '(111, 101, 84)': 2367,
#    '(145, 138, 112)': 1871,
#    '(88, 67, 51)': 1197,
#    '(176, 172, 157)': 897}},
#  '1787_mm_dd_i_Портрет_испанского_короля_Карла_III.jpeg': {'path': '1787_mm_dd_i_Портрет_испанского_короля_Карла_III.jpeg',
#   'name_of_painting': 'Портрет испанского короля Карла III',
#   'year': '1787',
#   'most_common_colors_ever': {'(43, 37, 31)': 5304,
#    '(91, 79, 63)': 1031,
#    '(16, 15, 14)': 791,
#    '(187, 177, 158)': 0,
#    '(135, 139, 133)': 4,
#    '(144, 121, 84)': 204,
#    '(97, 54, 38)': 2458},
#   'most_common_colors': {'(71, 61, 41)': 4586,
#    '(69, 77, 46)': 2864,
#    '(182, 180, 93)': 2280,
#    '(220, 223, 165)': 2221,
#    '(21, 22, 22)': 1895,
#    '(130, 124, 64)': 1718,
#    '(169, 151, 106)': 820}},
#  '1814_mm_dd_i_Махи_на_балконе.jpeg': {'path': '1814_mm_dd_i_Махи_на_балконе.jpeg',
#   'name_of_painting': 'Махи на балконе',
#   'year': '1814',
#   'most_common_colors_ever': {'(43, 37, 31)': 2295,
#    '(91, 79, 63)': 3040,
#    '(16, 15, 14)': 217,
#    '(187, 177, 158)': 584,
#    '(135, 139, 133)': 878,
#    '(144, 121, 84)': 752,
#    '(97, 54, 38)': 1026},
#   'most_common_colors': {'(44, 41, 32)': 4746,
#    '(75, 65, 50)': 4164,
#    '(27, 27, 24)': 2447,
#    '(113, 94, 71)': 2439,
#    '(62, 42, 27)': 1082,
#    '(172, 158, 136)': 857,
#    '(166, 133, 97)': 649}},
#  '1795_mm_dd_i_Герцогиня_Альба_и_дуэнья_"Ла_Беата".jpeg': {'path': '1795_mm_dd_i_Герцогиня_Альба_и_дуэнья_"Ла_Беата".jpeg',
#   'name_of_painting': 'Герцогиня Альба и дуэнья "Ла Беата"',
#   'year': '1795',
#   'most_common_colors_ever': {'(43, 37, 31)': 1724,
#    '(91, 79, 63)': 11,
#    '(16, 15, 14)': 3603,
#    '(187, 177, 158)': 0,
#    '(135, 139, 133)': 0,
#    '(144, 121, 84)': 5,
#    '(97, 54, 38)': 2974},
#   'most_common_colors': {'(28, 28, 23)': 4336,
#    '(41, 41, 29)': 3499,
#    '(80, 69, 49)': 2404,
#    '(59, 59, 38)': 2299,
#    '(142, 112, 77)': 1806,
#    '(165, 146, 104)': 1567,
#    '(136, 108, 68)': 473}},
#  '1820_mm_dd_i_Портрет_Тибурсио_Переса-и-Куэрво.jpeg': {'path': '1820_mm_dd_i_Портрет_Тибурсио_Переса-и-Куэрво.jpeg',
#   'name_of_painting': 'Портрет Тибурсио Переса-и-Куэрво',
#   'year': '1820',
#   'most_common_colors_ever': {'(43, 37, 31)': 9365,
#    '(91, 79, 63)': 2453,
#    '(16, 15, 14)': 1181,
#    '(187, 177, 158)': 0,
#    '(135, 139, 133)': 38,
#    '(144, 121, 84)': 179,
#    '(97, 54, 38)': 1527},
#   'most_common_colors': {'(0, 0, 0)': 11524,
#    '(2, 0, 1)': 3013,
#    '(97, 86, 83)': 604,
#    '(21, 16, 18)': 538,
#    '(68, 43, 38)': 309,
#    '(152, 143, 135)': 221,
#    '(143, 107, 90)': 175}},
#  '1814_mm_dd_i_Жозефа_Байе_или_Леокадия_Вейс.jpeg': {'path': '1814_mm_dd_i_Жозефа_Байе_или_Леокадия_Вейс.jpeg',
#   'name_of_painting': 'Жозефа Байе или Леокадия Вейс',
#   'year': '1814',
#   'most_common_colors_ever': {'(43, 37, 31)': 754,
#    '(91, 79, 63)': 646,
#    '(16, 15, 14)': 51,
#    '(187, 177, 158)': 163,
#    '(135, 139, 133)': 18,
#    '(144, 121, 84)': 448,
#    '(97, 54, 38)': 2768},
#   'most_common_colors': {'(9, 12, 12)': 4845,
#    '(101, 100, 88)': 3448,
#    '(8, 11, 10)': 3047,
#    '(38, 34, 24)': 2680,
#    '(206, 206, 187)': 806,
#    '(110, 93, 68)': 798,
#    '(210, 185, 172)': 760}},
#  '1783_mm_dd_i_Хосе_Монино_Редондо,_граф_Флоридабланка.jpeg': {'path': '1783_mm_dd_i_Хосе_Монино_Редондо,_граф_Флоридабланка.jpeg',
#   'name_of_painting': 'Хосе Монино Редондо, граф Флоридабланка',
#   'year': '1783',
#   'most_common_colors_ever': {'(43, 37, 31)': 3240,
#    '(91, 79, 63)': 152,
#    '(16, 15, 14)': 535,
#    '(187, 177, 158)': 288,
#    '(135, 139, 133)': 1,
#    '(144, 121, 84)': 351,
#    '(97, 54, 38)': 3924},
#   'most_common_colors': {'(7, 8, 7)': 7928,
#    '(20, 16, 13)': 3214,
#    '(43, 39, 31)': 2092,
#    '(118, 102, 68)': 943,
#    '(60, 37, 19)': 856,
#    '(102, 40, 16)': 733,
#    '(175, 173, 173)': 618}},
#  '1783_mm_dd_a_Автопортрет.jpeg': {'path': '1783_mm_dd_a_Автопортрет.jpeg',
#   'name_of_painting': 'Автопортрет',
#   'year': '1783',
#   'most_common_colors_ever': {'(43, 37, 31)': 2308,
#    '(91, 79, 63)': 2282,
#    '(16, 15, 14)': 3,
#    '(187, 177, 158)': 861,
#    '(135, 139, 133)': 93,
#    '(144, 121, 84)': 1530,
#    '(97, 54, 38)': 1455},
#   'most_common_colors': {'(26, 25, 24)': 7111,
#    '(16, 11, 9)': 3795,
#    '(33, 22, 15)': 2014,
#    '(45, 41, 37)': 1549,
#    '(69, 44, 25)': 858,
#    '(139, 93, 60)': 612,
#    '(214, 159, 111)': 445}},
#  '1806_mm_dd_i_Портрет_доньи_Антонии_Сарате.jpeg': {'path': '1806_mm_dd_i_Портрет_доньи_Антонии_Сарате.jpeg',
#   'name_of_painting': 'Портрет доньи Антонии Сарате',
#   'year': '1806',
#   'most_common_colors_ever': {'(43, 37, 31)': 2023,
#    '(91, 79, 63)': 360,
#    '(16, 15, 14)': 1085,
#    '(187, 177, 158)': 1052,
#    '(135, 139, 133)': 935,
#    '(144, 121, 84)': 1353,
#    '(97, 54, 38)': 885},
#   'most_common_colors': {'(13, 11, 13)': 3816,
#    '(126, 93, 70)': 3544,
#    '(89, 69, 62)': 2866,
#    '(51, 40, 39)': 2207,
#    '(120, 92, 76)': 1882,
#    '(218, 190, 155)': 1152,
#    '(188, 137, 83)': 917}},
#  '1815_mm_dd_i_Портрет_Фердинанда_VII_де_Бурбона,_короля_Испании.jpeg': {'path': '1815_mm_dd_i_Портрет_Фердинанда_VII_де_Бурбона,_короля_Испании.jpeg',
#   'name_of_painting': 'Портрет Фердинанда VII де Бурбона, короля Испании',
#   'year': '1815',
#   'most_common_colors_ever': {'(43, 37, 31)': 2337,
#    '(91, 79, 63)': 1240,
#    '(16, 15, 14)': 191,
#    '(187, 177, 158)': 295,
#    '(135, 139, 133)': 246,
#    '(144, 121, 84)': 1116,
#    '(97, 54, 38)': 751},
#   'most_common_colors': {'(115, 113, 106)': 7257,
#    '(91, 79, 62)': 3150,
#    '(61, 52, 44)': 2172,
#    '(26, 25, 24)': 1525,
#    '(132, 118, 83)': 944,
#    '(158, 142, 125)': 740,
#    '(139, 91, 60)': 596}},
#  '1814_mm_dd_i_Расстрел_повстанцев_3_мая_1808_года_в_Мадриде.jpeg': {'path': '1814_mm_dd_i_Расстрел_повстанцев_3_мая_1808_года_в_Мадриде.jpeg',
#   'name_of_painting': 'Расстрел повстанцев 3 мая 1808 года в Мадриде',
#   'year': '1814',
#   'most_common_colors_ever': {'(43, 37, 31)': 2364,
#    '(91, 79, 63)': 1683,
#    '(16, 15, 14)': 981,
#    '(187, 177, 158)': 161,
#    '(135, 139, 133)': 167,
#    '(144, 121, 84)': 848,
#    '(97, 54, 38)': 282},
#   'most_common_colors': {'(51, 40, 28)': 4443,
#    '(26, 26, 24)': 3812,
#    '(88, 69, 46)': 2881,
#    '(152, 120, 82)': 2399,
#    '(34, 32, 28)': 1777,
#    '(112, 82, 52)': 834,
#    '(193, 174, 147)': 238}},
#  '1789_mm_dd_i_Карл_IV.jpeg': {'path': '1789_mm_dd_i_Карл_IV.jpeg',
#   'name_of_painting': 'Карл IV',
#   'year': '1789',
#   'most_common_colors_ever': {'(43, 37, 31)': 1140,
#    '(91, 79, 63)': 1657,
#    '(16, 15, 14)': 0,
#    '(187, 177, 158)': 1734,
#    '(135, 139, 133)': 1460,
#    '(144, 121, 84)': 681,
#    '(97, 54, 38)': 1526},
#   'most_common_colors': {'(22, 22, 17)': 5400,
#    '(85, 36, 26)': 2907,
#    '(35, 38, 23)': 2090,
#    '(66, 71, 36)': 1916,
#    '(150, 46, 30)': 1830,
#    '(117, 80, 60)': 1385,
#    '(58, 65, 64)': 856}},
#  '1798_mm_dd_i_Фреска_часовни_Св._Антония_Флоридского,_деталь_4.jpeg': {'path': '1798_mm_dd_i_Фреска_часовни_Св._Антония_Флоридского,_деталь_4.jpeg',
#   'name_of_painting': 'Фреска часовни Св. Антония Флоридского, деталь 4',
#   'year': '1798',
#   'most_common_colors_ever': {'(43, 37, 31)': 922,
#    '(91, 79, 63)': 2806,
#    '(16, 15, 14)': 0,
#    '(187, 177, 158)': 1369,
#    '(135, 139, 133)': 400,
#    '(144, 121, 84)': 1128,
#    '(97, 54, 38)': 1587},
#   'most_common_colors': {'(69, 64, 62)': 3701,
#    '(147, 141, 133)': 3386,
#    '(107, 97, 94)': 2767,
#    '(49, 47, 51)': 2021,
#    '(119, 87, 69)': 1792,
#    '(177, 174, 188)': 1758,
#    '(207, 208, 225)': 959}},
#  '1819_mm_dd_i_Кузница.jpeg': {'path': '1819_mm_dd_i_Кузница.jpeg',
#   'name_of_painting': 'Кузница',
#   'year': '1819',
#   'most_common_colors_ever': {'(43, 37, 31)': 1291,
#    '(91, 79, 63)': 3207,
#    '(16, 15, 14)': 5,
#    '(187, 177, 158)': 1148,
#    '(135, 139, 133)': 320,
#    '(144, 121, 84)': 1881,
#    '(97, 54, 38)': 1358},
#   'most_common_colors': {'(50, 42, 45)': 6273,
#    '(69, 55, 57)': 3276,
#    '(15, 13, 16)': 2512,
#    '(94, 81, 79)': 1700,
#    '(95, 86, 76)': 1429,
#    '(170, 141, 111)': 620,
#    '(201, 207, 204)': 574}},
#  '1800_mm_dd_i_Граф_Тахо.jpeg': {'path': '1800_mm_dd_i_Граф_Тахо.jpeg',
#   'name_of_painting': 'Граф Тахо',
#   'year': '1800',
#   'most_common_colors_ever': {'(43, 37, 31)': 1907,
#    '(91, 79, 63)': 1617,
#    '(16, 15, 14)': 398,
#    '(187, 177, 158)': 1278,
#    '(135, 139, 133)': 827,
#    '(144, 121, 84)': 1251,
#    '(97, 54, 38)': 2350},
#   'most_common_colors': {'(36, 32, 26)': 7437,
#    '(50, 38, 29)': 3803,
#    '(31, 23, 21)': 2411,
#    '(54, 45, 35)': 1300,
#    '(111, 97, 79)': 780,
#    '(164, 141, 115)': 457,
#    '(211, 206, 197)': 196}},
#  '1812_mm_dd_i_Точильщик.jpeg': {'path': '1812_mm_dd_i_Точильщик.jpeg',
#   'name_of_painting': 'Точильщик',
#   'year': '1812',
#   'most_common_colors_ever': {'(43, 37, 31)': 3907,
#    '(91, 79, 63)': 1393,
#    '(16, 15, 14)': 1437,
#    '(187, 177, 158)': 1113,
#    '(135, 139, 133)': 822,
#    '(144, 121, 84)': 563,
#    '(97, 54, 38)': 712},
#   'most_common_colors': {'(138, 120, 77)': 4249,
#    '(22, 20, 15)': 3751,
#    '(124, 104, 61)': 2842,
#    '(41, 26, 20)': 2262,
#    '(96, 71, 39)': 2009,
#    '(183, 120, 60)': 654,
#    '(171, 154, 120)': 617}},
#  '1777_mm_dd_i_Прогулка_в_Андалусии.jpeg': {'path': '1777_mm_dd_i_Прогулка_в_Андалусии.jpeg',
#   'name_of_painting': 'Прогулка в Андалусии',
#   'year': '1777',
#   'most_common_colors_ever': {'(43, 37, 31)': 7680,
#    '(91, 79, 63)': 1974,
#    '(16, 15, 14)': 99,
#    '(187, 177, 158)': 266,
#    '(135, 139, 133)': 374,
#    '(144, 121, 84)': 571,
#    '(97, 54, 38)': 1201},
#   'most_common_colors': {'(53, 47, 33)': 6711,
#    '(63, 51, 36)': 2873,
#    '(122, 109, 81)': 2637,
#    '(105, 118, 103)': 1676,
#    '(87, 78, 46)': 1357,
#    '(90, 53, 35)': 794,
#    '(198, 187, 147)': 336}},
#  '1812_mm_dd_i_Мёртвая_индейка.jpeg': {'path': '1812_mm_dd_i_Мёртвая_индейка.jpeg',
#   'name_of_painting': 'Мёртвая индейка',
#   'year': '1812',
#   'most_common_colors_ever': {'(43, 37, 31)': 2302,
#    '(91, 79, 63)': 910,
#    '(16, 15, 14)': 1643,
#    '(187, 177, 158)': 830,
#    '(135, 139, 133)': 2172,
#    '(144, 121, 84)': 288,
#    '(97, 54, 38)': 271},
#   'most_common_colors': {'(31, 29, 25)': 6094,
#    '(56, 51, 43)': 4281,
#    '(80, 64, 51)': 2624,
#    '(152, 121, 95)': 1408,
#    '(125, 109, 92)': 896,
#    '(132, 95, 74)': 615,
#    '(247, 247, 246)': 466}},
#  '1798_mm_dd_i_Портрет_матадора_Педро_Ромеро.jpeg': {'path': '1798_mm_dd_i_Портрет_матадора_Педро_Ромеро.jpeg',
#   'name_of_painting': 'Портрет матадора Педро Ромеро',
#   'year': '1798',
#   'most_common_colors_ever': {'(43, 37, 31)': 1622,
#    '(91, 79, 63)': 2251,
#    '(16, 15, 14)': 0,
#    '(187, 177, 158)': 1280,
#    '(135, 139, 133)': 1509,
#    '(144, 121, 84)': 1333,
#    '(97, 54, 38)': 402},
#   'most_common_colors': {'(80, 61, 49)': 3933,
#    '(53, 56, 51)': 3763,
#    '(39, 44, 40)': 3530,
#    '(21, 26, 24)': 1814,
#    '(114, 109, 94)': 1656,
#    '(162, 110, 62)': 1150,
#    '(156, 77, 44)': 538}},
#  '1804_mm_dd_i_Портрет_Бартоломе_Суреда-и-Мизероль.jpeg': {'path': '1804_mm_dd_i_Портрет_Бартоломе_Суреда-и-Мизероль.jpeg',
#   'name_of_painting': 'Портрет Бартоломе Суреда-и-Мизероль',
#   'year': '1804',
#   'most_common_colors_ever': {'(43, 37, 31)': 2583,
#    '(91, 79, 63)': 1381,
#    '(16, 15, 14)': 796,
#    '(187, 177, 158)': 1292,
#    '(135, 139, 133)': 273,
#    '(144, 121, 84)': 372,
#    '(97, 54, 38)': 1032},
#   'most_common_colors': {'(57, 60, 45)': 6721,
#    '(40, 43, 31)': 5308,
#    '(25, 27, 24)': 1666,
#    '(75, 91, 74)': 1303,
#    '(105, 89, 69)': 724,
#    '(174, 183, 179)': 395,
#    '(135, 77, 55)': 267}},
#  '1787_mm_dd_i_Женщина_с_двумя_мальчиками_у_фонтана.jpeg': {'path': '1787_mm_dd_i_Женщина_с_двумя_мальчиками_у_фонтана.jpeg',
#   'name_of_painting': 'Женщина с двумя мальчиками у фонтана',
#   'year': '1787',
#   'most_common_colors_ever': {'(43, 37, 31)': 4306,
#    '(91, 79, 63)': 942,
#    '(16, 15, 14)': 440,
#    '(187, 177, 158)': 198,
#    '(135, 139, 133)': 129,
#    '(144, 121, 84)': 504,
#    '(97, 54, 38)': 643},
#   'most_common_colors': {'(136, 122, 108)': 4009,
#    '(75, 107, 117)': 3545,
#    '(159, 169, 157)': 3365,
#    '(65, 51, 33)': 1911,
#    '(123, 95, 65)': 1744,
#    '(187, 168, 133)': 1152,
#    '(12, 21, 20)': 658}},
#  '1775_mm_dd_i_Охота_на_приманку.jpeg': {'path': '1775_mm_dd_i_Охота_на_приманку.jpeg',
#   'name_of_painting': 'Охота на приманку',
#   'year': '1775',
#   'most_common_colors_ever': {'(43, 37, 31)': 3927,
#    '(91, 79, 63)': 1863,
#    '(16, 15, 14)': 673,
#    '(187, 177, 158)': 1334,
#    '(135, 139, 133)': 444,
#    '(144, 121, 84)': 759,
#    '(97, 54, 38)': 2004},
#   'most_common_colors': {'(130, 154, 157)': 3559,
#    '(65, 50, 21)': 3004,
#    '(149, 134, 93)': 2932,
#    '(108, 88, 43)': 2375,
#    '(185, 175, 139)': 1982,
#    '(153, 176, 170)': 1420,
#    '(26, 27, 14)': 1112}},
#  '1793_mm_dd_i_Бродячие_комедианты.jpeg': {'path': '1793_mm_dd_i_Бродячие_комедианты.jpeg',
#   'name_of_painting': 'Бродячие комедианты',
#   'year': '1793',
#   'most_common_colors_ever': {'(43, 37, 31)': 2193,
#    '(91, 79, 63)': 673,
#    '(16, 15, 14)': 3550,
#    '(187, 177, 158)': 31,
#    '(135, 139, 133)': 226,
#    '(144, 121, 84)': 237,
#    '(97, 54, 38)': 272},
#   'most_common_colors': {'(90, 83, 61)': 5264,
#    '(121, 122, 110)': 2564,
#    '(66, 52, 33)': 2368,
#    '(189, 189, 176)': 2319,
#    '(163, 164, 156)': 2074,
#    '(222, 218, 200)': 1229,
#    '(26, 32, 31)': 566}},
#  '1771_mm_dd_i_Победоносный_Ганнибал_впервые_видит_Италию_с_вершин_Альп.jpeg': {'path': '1771_mm_dd_i_Победоносный_Ганнибал_впервые_видит_Италию_с_вершин_Альп.jpeg',
#   'name_of_painting': 'Победоносный Ганнибал впервые видит Италию с вершин Альп',
#   'year': '1771',
#   'most_common_colors_ever': {'(43, 37, 31)': 4824,
#    '(91, 79, 63)': 1296,
#    '(16, 15, 14)': 42,
#    '(187, 177, 158)': 1083,
#    '(135, 139, 133)': 27,
#    '(144, 121, 84)': 216,
#    '(97, 54, 38)': 2396},
#   'most_common_colors': {'(78, 75, 67)': 4012,
#    '(56, 65, 69)': 3384,
#    '(124, 123, 109)': 3038,
#    '(75, 47, 36)': 2152,
#    '(122, 98, 78)': 1884,
#    '(45, 43, 40)': 1284,
#    '(184, 161, 133)': 630}},
#  '1786_mm_dd_s_Пьяный_каменщик_(эскиз).jpeg': {'path': '1786_mm_dd_s_Пьяный_каменщик_(эскиз).jpeg',
#   'name_of_painting': 'Пьяный каменщик (эскиз)',
#   'year': '1786',
#   'most_common_colors_ever': {'(43, 37, 31)': 5351,
#    '(91, 79, 63)': 1595,
#    '(16, 15, 14)': 1071,
#    '(187, 177, 158)': 709,
#    '(135, 139, 133)': 2554,
#    '(144, 121, 84)': 588,
#    '(97, 54, 38)': 705},
#   'most_common_colors': {'(140, 134, 116)': 4357,
#    '(189, 188, 179)': 3088,
#    '(124, 139, 142)': 2736,
#    '(59, 56, 48)': 2203,
#    '(90, 106, 107)': 1652,
#    '(83, 74, 63)': 1453,
#    '(169, 166, 152)': 895}},
#  '1814_mm_dd_i_Процессия_флагеллантов_(бичующихся).jpeg': {'path': '1814_mm_dd_i_Процессия_флагеллантов_(бичующихся).jpeg',
#   'name_of_painting': 'Процессия флагеллантов (бичующихся)',
#   'year': '1814',
#   'most_common_colors_ever': {'(43, 37, 31)': 1943,
#    '(91, 79, 63)': 730,
#    '(16, 15, 14)': 2239,
#    '(187, 177, 158)': 645,
#    '(135, 139, 133)': 533,
#    '(144, 121, 84)': 350,
#    '(97, 54, 38)': 369},
#   'most_common_colors': {'(67, 49, 41)': 3818,
#    '(9, 6, 8)': 3490,
#    '(30, 24, 25)': 3316,
#    '(119, 110, 101)': 1714,
#    '(86, 102, 111)': 1607,
#    '(110, 81, 63)': 1251,
#    '(146, 121, 102)': 1188}},
#  '1822_mm_dd_i_Портрет_дона_Себастьяна_Габриеля_де_Борбона-и-Браганца.jpeg': {'path': '1822_mm_dd_i_Портрет_дона_Себастьяна_Габриеля_де_Борбона-и-Браганца.jpeg',
#   'name_of_painting': 'Портрет дона Себастьяна Габриеля де Борбона-и-Браганца',
#   'year': '1822',
#   'most_common_colors_ever': {'(43, 37, 31)': 3604,
#    '(91, 79, 63)': 2281,
#    '(16, 15, 14)': 5,
#    '(187, 177, 158)': 0,
#    '(135, 139, 133)': 1,
#    '(144, 121, 84)': 1279,
#    '(97, 54, 38)': 3364},
#   'most_common_colors': {'(35, 37, 41)': 4020,
#    '(0, 0, 0)': 3967,
#    '(8, 3, 6)': 2948,
#    '(58, 45, 39)': 2587,
#    '(46, 51, 51)': 1885,
#    '(144, 133, 110)': 785,
#    '(108, 41, 32)': 192}},
#  '1771_mm_dd_i_Венера_и_Адонис.jpeg': {'path': '1771_mm_dd_i_Венера_и_Адонис.jpeg',
#   'name_of_painting': 'Венера и Адонис',
#   'year': '1771',
#   'most_common_colors_ever': {'(43, 37, 31)': 2453,
#    '(91, 79, 63)': 1719,
#    '(16, 15, 14)': 3,
#    '(187, 177, 158)': 186,
#    '(135, 139, 133)': 1461,
#    '(144, 121, 84)': 452,
#    '(97, 54, 38)': 1503},
#   'most_common_colors': {'(26, 35, 31)': 7538,
#    '(39, 49, 43)': 3871,
#    '(49, 39, 33)': 1780,
#    '(67, 64, 49)': 1410,
#    '(106, 84, 54)': 737,
#    '(168, 150, 112)': 534,
#    '(142, 102, 43)': 514}},
#  '1786_mm_dd_i_Мальчики_с_мастифом.jpeg': {'path': '1786_mm_dd_i_Мальчики_с_мастифом.jpeg',
#   'name_of_painting': 'Мальчики с мастифом',
#   'year': '1786',
#   'most_common_colors_ever': {'(43, 37, 31)': 4246,
#    '(91, 79, 63)': 1918,
#    '(16, 15, 14)': 929,
#    '(187, 177, 158)': 332,
#    '(135, 139, 133)': 1279,
#    '(144, 121, 84)': 346,
#    '(97, 54, 38)': 901},
#   'most_common_colors': {'(75, 62, 47)': 4021,
#    '(230, 226, 205)': 3463,
#    '(159, 136, 99)': 2863,
#    '(162, 183, 176)': 2106,
#    '(129, 118, 99)': 1484,
#    '(140, 91, 58)': 1462,
#    '(224, 202, 175)': 985}},
#  '1792_mm_dd_i_Ходули.jpeg': {'path': '1792_mm_dd_i_Ходули.jpeg',
#   'name_of_painting': 'Ходули',
#   'year': '1792',
#   'most_common_colors_ever': {'(43, 37, 31)': 3169,
#    '(91, 79, 63)': 1967,
#    '(16, 15, 14)': 224,
#    '(187, 177, 158)': 451,
#    '(135, 139, 133)': 1187,
#    '(144, 121, 84)': 992,
#    '(97, 54, 38)': 1780},
#   'most_common_colors': {'(85, 75, 51)': 4191,
#    '(177, 167, 139)': 2977,
#    '(135, 104, 62)': 2827,
#    '(212, 192, 157)': 2571,
#    '(42, 46, 28)': 1521,
#    '(149, 114, 76)': 1396,
#    '(113, 137, 138)': 901}},
#  '1798_mm_dd_i_Портрет_доктора_Андреса_дель_Пераля.jpeg': {'path': '1798_mm_dd_i_Портрет_доктора_Андреса_дель_Пераля.jpeg',
#   'name_of_painting': 'Портрет доктора Андреса дель Пераля',
#   'year': '1798',
#   'most_common_colors_ever': {'(43, 37, 31)': 14184,
#    '(91, 79, 63)': 190,
#    '(16, 15, 14)': 12661,
#    '(187, 177, 158)': 0,
#    '(135, 139, 133)': 0,
#    '(144, 121, 84)': 113,
#    '(97, 54, 38)': 283},
#   'most_common_colors': {'(16, 14, 15)': 5934,
#    '(19, 17, 17)': 4417,
#    '(44, 42, 35)': 2736,
#    '(83, 81, 67)': 1435,
#    '(106, 102, 86)': 925,
#    '(106, 84, 62)': 694,
#    '(151, 145, 127)': 243}},
#  '1778_mm_dd_i_Мальчики_собирают_фрукты.jpeg': {'path': '1778_mm_dd_i_Мальчики_собирают_фрукты.jpeg',
#   'name_of_painting': 'Мальчики собирают фрукты',
#   'year': '1778',
#   'most_common_colors_ever': {'(43, 37, 31)': 2914,
#    '(91, 79, 63)': 3192,
#    '(16, 15, 14)': 129,
#    '(187, 177, 158)': 879,
#    '(135, 139, 133)': 1095,
#    '(144, 121, 84)': 517,
#    '(97, 54, 38)': 1526},
#   'most_common_colors': {'(51, 42, 30)': 3727,
#    '(92, 85, 53)': 3044,
#    '(79, 50, 36)': 3019,
#    '(182, 179, 152)': 2603,
#    '(147, 116, 80)': 2386,
#    '(215, 191, 158)': 1123,
#    '(40, 48, 54)': 482}},
#  '1792_mm_dd_i_Свадьба.jpeg': {'path': '1792_mm_dd_i_Свадьба.jpeg',
#   'name_of_painting': 'Свадьба',
#   'year': '1792',
#   'most_common_colors_ever': {'(43, 37, 31)': 5405,
#    '(91, 79, 63)': 480,
#    '(16, 15, 14)': 124,
#    '(187, 177, 158)': 2,
#    '(135, 139, 133)': 850,
#    '(144, 121, 84)': 198,
#    '(97, 54, 38)': 1617},
#   'most_common_colors': {'(95, 79, 64)': 3695,
#    '(50, 42, 35)': 3041,
#    '(138, 115, 86)': 2870,
#    '(139, 163, 169)': 2452,
#    '(123, 110, 94)': 2374,
#    '(87, 63, 47)': 1269,
#    '(202, 193, 188)': 683}},
#  '1823_mm_dd_i_Две_женщины_и_мужчина.jpeg': {'path': '1823_mm_dd_i_Две_женщины_и_мужчина.jpeg',
#   'name_of_painting': 'Две женщины и мужчина',
#   'year': '1823',
#   'most_common_colors_ever': {'(43, 37, 31)': 3047,
#    '(91, 79, 63)': 2841,
#    '(16, 15, 14)': 96,
#    '(187, 177, 158)': 1203,
#    '(135, 139, 133)': 1314,
#    '(144, 121, 84)': 440,
#    '(97, 54, 38)': 2225},
#   'most_common_colors': {'(44, 43, 38)': 5896,
#    '(53, 51, 45)': 4235,
#    '(62, 59, 51)': 2169,
#    '(36, 36, 32)': 1981,
#    '(103, 95, 71)': 937,
#    '(70, 62, 49)': 845,
#    '(161, 146, 108)': 321}},
#  '1823_mm_dd_i_Серия_мрачных_картин._Два_монаха.jpeg': {'path': '1823_mm_dd_i_Серия_мрачных_картин._Два_монаха.jpeg',
#   'name_of_painting': 'Серия мрачных картин. Два монаха',
#   'year': '1823',
#   'most_common_colors_ever': {'(43, 37, 31)': 959,
#    '(91, 79, 63)': 2197,
#    '(16, 15, 14)': 0,
#    '(187, 177, 158)': 320,
#    '(135, 139, 133)': 307,
#    '(144, 121, 84)': 539,
#    '(97, 54, 38)': 990},
#   'most_common_colors': {'(32, 31, 36)': 5844,
#    '(36, 34, 37)': 3973,
#    '(51, 46, 45)': 2685,
#    '(40, 40, 46)': 1792,
#    '(82, 67, 57)': 1352,
#    '(132, 100, 75)': 410,
#    '(159, 132, 96)': 328}},
#  '1786_mm_dd_i_Падение.jpeg': {'path': '1786_mm_dd_i_Падение.jpeg',
#   'name_of_painting': 'Падение',
#   'year': '1786',
#   'most_common_colors_ever': {'(43, 37, 31)': 6505,
#    '(91, 79, 63)': 2017,
#    '(16, 15, 14)': 3571,
#    '(187, 177, 158)': 67,
#    '(135, 139, 133)': 168,
#    '(144, 121, 84)': 295,
#    '(97, 54, 38)': 823},
#   'most_common_colors': {'(63, 69, 56)': 4099,
#    '(175, 193, 167)': 3079,
#    '(203, 214, 210)': 2589,
#    '(103, 91, 64)': 2206,
#    '(132, 145, 115)': 2024,
#    '(22, 22, 21)': 1561,
#    '(193, 167, 103)': 826}},
#  '1823_mm_dd_i_Серия_мрачных_картин-_Паломники.jpeg': {'path': '1823_mm_dd_i_Серия_мрачных_картин-_Паломники.jpeg',
#   'name_of_painting': 'Серия мрачных картин- Паломники',
#   'year': '1823',
#   'most_common_colors_ever': {'(43, 37, 31)': 6456,
#    '(91, 79, 63)': 356,
#    '(16, 15, 14)': 10433,
#    '(187, 177, 158)': 117,
#    '(135, 139, 133)': 0,
#    '(144, 121, 84)': 583,
#    '(97, 54, 38)': 246},
#   'most_common_colors': {'(26, 9, 12)': 4664,
#    '(45, 25, 25)': 3588,
#    '(14, 1, 4)': 3450,
#    '(88, 67, 55)': 1893,
#    '(135, 115, 85)': 1164,
#    '(178, 149, 97)': 1094,
#    '(150, 120, 93)': 531}},
#  '1799_mm_dd_i_Св._Григорий_Магно.jpeg': {'path': '1799_mm_dd_i_Св._Григорий_Магно.jpeg',
#   'name_of_painting': 'Св. Григорий Магно',
#   'year': '1799',
#   'most_common_colors_ever': {'(43, 37, 31)': 11110,
#    '(91, 79, 63)': 1068,
#    '(16, 15, 14)': 2422,
#    '(187, 177, 158)': 121,
#    '(135, 139, 133)': 15,
#    '(144, 121, 84)': 349,
#    '(97, 54, 38)': 573},
#   'most_common_colors': {'(41, 31, 32)': 5361,
#    '(36, 25, 29)': 3352,
#    '(101, 73, 62)': 3266,
#    '(111, 104, 105)': 1482,
#    '(16, 11, 15)': 1475,
#    '(143, 130, 117)': 979,
#    '(206, 204, 217)': 469}},
#  '1793_mm_dd_i_Графиня_Карпио,_маркиза_де_ла_Солана.jpeg': {'path': '1793_mm_dd_i_Графиня_Карпио,_маркиза_де_ла_Солана.jpeg',
#   'name_of_painting': 'Графиня Карпио, маркиза де ла Солана',
#   'year': '1793',
#   'most_common_colors_ever': {'(43, 37, 31)': 921,
#    '(91, 79, 63)': 312,
#    '(16, 15, 14)': 43,
#    '(187, 177, 158)': 11,
#    '(135, 139, 133)': 21,
#    '(144, 121, 84)': 425,
#    '(97, 54, 38)': 3037},
#   'most_common_colors': {'(48, 61, 69)': 4656,
#    '(8, 9, 15)': 3699,
#    '(69, 79, 70)': 3398,
#    '(88, 105, 89)': 2085,
#    '(125, 145, 102)': 1152,
#    '(188, 203, 190)': 787,
#    '(164, 158, 117)': 607}},
#  '1798_mm_dd_i_Дон_Педро_де_Алькантара_из_рода_Тельес-Хиронов,_9-й_герцог_Осуна.jpeg': {'path': '1798_mm_dd_i_Дон_Педро_де_Алькантара_из_рода_Тельес-Хиронов,_9-й_герцог_Осуна.jpeg',
#   'name_of_painting': 'Дон Педро де Алькантара из рода Тельес-Хиронов, 9-й герцог Осуна',
#   'year': '1798',
#   'most_common_colors_ever': {'(43, 37, 31)': 6193,
#    '(91, 79, 63)': 1063,
#    '(16, 15, 14)': 2365,
#    '(187, 177, 158)': 177,
#    '(135, 139, 133)': 116,
#    '(144, 121, 84)': 1560,
#    '(97, 54, 38)': 1069},
#   'most_common_colors': {'(4, 4, 5)': 4993,
#    '(11, 10, 9)': 4846,
#    '(21, 31, 28)': 2492,
#    '(43, 39, 37)': 1839,
#    '(119, 84, 56)': 851,
#    '(84, 76, 59)': 778,
#    '(174, 163, 133)': 585}},
#  '1800_mm_dd_i_Сон.jpeg': {'path': '1800_mm_dd_i_Сон.jpeg',
#   'name_of_painting': 'Сон',
#   'year': '1800',
#   'most_common_colors_ever': {'(43, 37, 31)': 2965,
#    '(91, 79, 63)': 290,
#    '(16, 15, 14)': 11764,
#    '(187, 177, 158)': 92,
#    '(135, 139, 133)': 96,
#    '(144, 121, 84)': 83,
#    '(97, 54, 38)': 326},
#   'most_common_colors': {'(23, 23, 23)': 4377,
#    '(38, 37, 35)': 4219,
#    '(77, 70, 62)': 2936,
#    '(104, 93, 78)': 1802,
#    '(128, 124, 110)': 1629,
#    '(171, 166, 151)': 840,
#    '(212, 213, 210)': 581}},
#  '1805_mm_dd_i_Молодая_дама_в_мантилье_и_баскине.jpeg': {'path': '1805_mm_dd_i_Молодая_дама_в_мантилье_и_баскине.jpeg',
#   'name_of_painting': 'Молодая дама в мантилье и баскине',
#   'year': '1805',
#   'most_common_colors_ever': {'(43, 37, 31)': 5193,
#    '(91, 79, 63)': 2191,
#    '(16, 15, 14)': 4069,
#    '(187, 177, 158)': 313,
#    '(135, 139, 133)': 423,
#    '(144, 121, 84)': 722,
#    '(97, 54, 38)': 530},
#   'most_common_colors': {'(40, 47, 44)': 8882,
#    '(30, 35, 35)': 2728,
#    '(71, 63, 50)': 1356,
#    '(118, 115, 95)': 1177,
#    '(173, 162, 138)': 1010,
#    '(144, 120, 90)': 746,
#    '(179, 121, 82)': 485}},
#  '1783_mm_dd_i_Мария_Тереза_де_Виллабрига1.jpeg': {'path': '1783_mm_dd_i_Мария_Тереза_де_Виллабрига1.jpeg',
#   'name_of_painting': 'Мария Тереза де Виллабрига1',
#   'year': '1783',
#   'most_common_colors_ever': {'(43, 37, 31)': 3905,
#    '(91, 79, 63)': 2112,
#    '(16, 15, 14)': 1599,
#    '(187, 177, 158)': 614,
#    '(135, 139, 133)': 2604,
#    '(144, 121, 84)': 1004,
#    '(97, 54, 38)': 268},
#   'most_common_colors': {'(1, 4, 9)': 6823,
#    '(7, 9, 12)': 2264,
#    '(160, 178, 218)': 2175,
#    '(46, 42, 39)': 1801,
#    '(189, 161, 163)': 1385,
#    '(68, 85, 114)': 1339,
#    '(244, 231, 243)': 597}},
#  '1787_mm_dd_i_Метель.jpeg': {'path': '1787_mm_dd_i_Метель.jpeg',
#   'name_of_painting': 'Метель',
#   'year': '1787',
#   'most_common_colors_ever': {'(43, 37, 31)': 1984,
#    '(91, 79, 63)': 647,
#    '(16, 15, 14)': 10331,
#    '(187, 177, 158)': 1149,
#    '(135, 139, 133)': 897,
#    '(144, 121, 84)': 88,
#    '(97, 54, 38)': 120},
#   'most_common_colors': {'(123, 125, 115)': 4410,
#    '(162, 150, 121)': 3474,
#    '(154, 154, 148)': 2451,
#    '(125, 111, 82)': 1997,
#    '(216, 200, 171)': 1994,
#    '(91, 68, 40)': 1740,
#    '(36, 25, 20)': 318}},
#  '1798_mm_dd_i_Фреска_часовни_Св._Антония_Флоридского,_деталь_5.jpeg': {'path': '1798_mm_dd_i_Фреска_часовни_Св._Антония_Флоридского,_деталь_5.jpeg',
#   'name_of_painting': 'Фреска часовни Св. Антония Флоридского, деталь 5',
#   'year': '1798',
#   'most_common_colors_ever': {'(43, 37, 31)': 8180,
#    '(91, 79, 63)': 92,
#    '(16, 15, 14)': 11126,
#    '(187, 177, 158)': 7,
#    '(135, 139, 133)': 0,
#    '(144, 121, 84)': 57,
#    '(97, 54, 38)': 401},
#   'most_common_colors': {'(40, 28, 29)': 2957,
#    '(67, 51, 48)': 2814,
#    '(147, 140, 136)': 2676,
#    '(110, 86, 71)': 2453,
#    '(98, 88, 88)': 2013,
#    '(18, 8, 14)': 1755,
#    '(157, 151, 147)': 1716}},
#  '1814_mm_dd_i_Восстание_2_мая_1808_года_в_Мадриде.jpeg': {'path': '1814_mm_dd_i_Восстание_2_мая_1808_года_в_Мадриде.jpeg',
#   'name_of_painting': 'Восстание 2 мая 1808 года в Мадриде',
#   'year': '1814',
#   'most_common_colors_ever': {'(43, 37, 31)': 1082,
#    '(91, 79, 63)': 336,
#    '(16, 15, 14)': 9925,
#    '(187, 177, 158)': 94,
#    '(135, 139, 133)': 74,
#    '(144, 121, 84)': 48,
#    '(97, 54, 38)': 37},
#   'most_common_colors': {'(86, 66, 52)': 4637,
#    '(117, 104, 96)': 3243,
#    '(138, 119, 97)': 2843,
#    '(53, 41, 33)': 1980,
#    '(135, 130, 135)': 1940,
#    '(131, 92, 65)': 1031,
#    '(193, 187, 171)': 710}},
#  '1819_mm_dd_i_Молодая_женщина_с_письмом.jpeg': {'path': '1819_mm_dd_i_Молодая_женщина_с_письмом.jpeg',
#   'name_of_painting': 'Молодая женщина с письмом',
#   'year': '1819',
#   'most_common_colors_ever': {'(43, 37, 31)': 5424,
#    '(91, 79, 63)': 723,
#    '(16, 15, 14)': 2018,
#    '(187, 177, 158)': 149,
#    '(135, 139, 133)': 75,
#    '(144, 121, 84)': 476,
#    '(97, 54, 38)': 1679},
#   'most_common_colors': {'(6, 7, 11)': 3308,
#    '(89, 74, 64)': 2982,
#    '(34, 35, 41)': 2672,
#    '(91, 92, 96)': 2580,
#    '(129, 113, 97)': 2207,
#    '(178, 168, 158)': 1373,
#    '(129, 136, 143)': 1262}},
#  '1779_mm_dd_i_Портрет_Леандро_Фернандеса_Моратина.jpeg': {'path': '1779_mm_dd_i_Портрет_Леандро_Фернандеса_Моратина.jpeg',
#   'name_of_painting': 'Портрет Леандро Фернандеса Моратина',
#   'year': '1779',
#   'most_common_colors_ever': {'(43, 37, 31)': 685,
#    '(91, 79, 63)': 1354,
#    '(16, 15, 14)': 508,
#    '(187, 177, 158)': 2474,
#    '(135, 139, 133)': 1084,
#    '(144, 121, 84)': 954,
#    '(97, 54, 38)': 165},
#   'most_common_colors': {'(24, 24, 23)': 7781,
#    '(28, 27, 24)': 4722,
#    '(46, 35, 25)': 2658,
#    '(55, 44, 34)': 536,
#    '(117, 82, 56)': 486,
#    '(84, 59, 38)': 117,
#    '(167, 131, 94)': 84}},
#  '1811_mm_dd_i_Портрет_актрисы_Антонии_Сарате.jpeg': {'path': '1811_mm_dd_i_Портрет_актрисы_Антонии_Сарате.jpeg',
#   'name_of_painting': 'Портрет актрисы Антонии Сарате',
#   'year': '1811',
#   'most_common_colors_ever': {'(43, 37, 31)': 5290,
#    '(91, 79, 63)': 1155,
#    '(16, 15, 14)': 7231,
#    '(187, 177, 158)': 323,
#    '(135, 139, 133)': 226,
#    '(144, 121, 84)': 397,
#    '(97, 54, 38)': 91},
#   'most_common_colors': {'(36, 26, 26)': 7805,
#    '(139, 117, 97)': 2347,
#    '(52, 38, 31)': 2069,
#    '(96, 79, 61)': 1241,
#    '(76, 36, 26)': 1100,
#    '(195, 159, 132)': 1015,
#    '(127, 95, 70)': 807}},
#  '1794_mm_dd_i_Двор_сумасшедшего_дома.jpeg': {'path': '1794_mm_dd_i_Двор_сумасшедшего_дома.jpeg',
#   'name_of_painting': 'Двор сумасшедшего дома',
#   'year': '1794',
#   'most_common_colors_ever': {'(43, 37, 31)': 838,
#    '(91, 79, 63)': 2510,
#    '(16, 15, 14)': 23,
#    '(187, 177, 158)': 1000,
#    '(135, 139, 133)': 1589,
#    '(144, 121, 84)': 2460,
#    '(97, 54, 38)': 1307},
#   'most_common_colors': {'(27, 27, 22)': 3598,
#    '(43, 40, 29)': 2728,
#    '(215, 219, 220)': 2451,
#    '(76, 69, 50)': 2413,
#    '(118, 107, 81)': 1940,
#    '(11, 11, 10)': 1756,
#    '(75, 64, 45)': 1498}},
#  '1797_mm_dd_i_Портрет_Мартина_Сапатера.jpeg': {'path': '1797_mm_dd_i_Портрет_Мартина_Сапатера.jpeg',
#   'name_of_painting': 'Портрет Мартина Сапатера',
#   'year': '1797',
#   'most_common_colors_ever': {'(43, 37, 31)': 1388,
#    '(91, 79, 63)': 1728,
#    '(16, 15, 14)': 146,
#    '(187, 177, 158)': 281,
#    '(135, 139, 133)': 240,
#    '(144, 121, 84)': 1949,
#    '(97, 54, 38)': 1142},
#   'most_common_colors': {'(69, 78, 59)': 5443,
#    '(13, 13, 10)': 2978,
#    '(181, 178, 161)': 2910,
#    '(36, 30, 23)': 1932,
#    '(96, 86, 66)': 1845,
#    '(174, 175, 161)': 729,
#    '(184, 149, 122)': 547}},
#  '1804_mm_dd_i_Маркиза_фон_Виллафранка.jpeg': {'path': '1804_mm_dd_i_Маркиза_фон_Виллафранка.jpeg',
#   'name_of_painting': 'Маркиза фон Виллафранка',
#   'year': '1804',
#   'most_common_colors_ever': {'(43, 37, 31)': 2020,
#    '(91, 79, 63)': 1779,
#    '(16, 15, 14)': 1618,
#    '(187, 177, 158)': 821,
#    '(135, 139, 133)': 586,
#    '(144, 121, 84)': 652,
#    '(97, 54, 38)': 154},
#   'most_common_colors': {'(73, 47, 47)': 4055,
#    '(85, 72, 62)': 3600,
#    '(106, 94, 84)': 3545,
#    '(25, 25, 25)': 1703,
#    '(180, 159, 128)': 1415,
#    '(129, 113, 98)': 1295,
#    '(201, 166, 119)': 771}},
#  '1813_mm_dd_i_Портрет_художницы_Лолы_Хименес.jpeg': {'path': '1813_mm_dd_i_Портрет_художницы_Лолы_Хименес.jpeg',
#   'name_of_painting': 'Портрет художницы Лолы Хименес',
#   'year': '1813',
#   'most_common_colors_ever': {'(43, 37, 31)': 561,
#    '(91, 79, 63)': 1378,
#    '(16, 15, 14)': 1794,
#    '(187, 177, 158)': 1108,
#    '(135, 139, 133)': 2001,
#    '(144, 121, 84)': 2109,
#    '(97, 54, 38)': 1419},
#   'most_common_colors': {'(27, 17, 6)': 5689,
#    '(31, 27, 17)': 3479,
#    '(41, 21, 8)': 2009,
#    '(106, 30, 18)': 1853,
#    '(83, 56, 26)': 1283,
#    '(79, 25, 12)': 1118,
#    '(146, 97, 51)': 953}},
#  '1814_mm_dd_i_Трибунал_инквизиции.jpeg': {'path': '1814_mm_dd_i_Трибунал_инквизиции.jpeg',
#   'name_of_painting': 'Трибунал инквизиции',
#   'year': '1814',
#   'most_common_colors_ever': {'(43, 37, 31)': 1301,
#    '(91, 79, 63)': 1429,
#    '(16, 15, 14)': 1304,
#    '(187, 177, 158)': 790,
#    '(135, 139, 133)': 1020,
#    '(144, 121, 84)': 723,
#    '(97, 54, 38)': 544},
#   'most_common_colors': {'(34, 28, 30)': 3621,
#    '(68, 57, 59)': 3056,
#    '(107, 92, 80)': 2326,
#    '(10, 6, 8)': 2278,
#    '(72, 56, 50)': 2185,
#    '(2, 1, 1)': 1914,
#    '(146, 130, 104)': 1004}},
#  '1777_mm_dd_i_Танец_на_берегу_реки_Мансанарес.jpeg': {'path': '1777_mm_dd_i_Танец_на_берегу_реки_Мансанарес.jpeg',
#   'name_of_painting': 'Танец на берегу реки Мансанарес',
#   'year': '1777',
#   'most_common_colors_ever': {'(43, 37, 31)': 1319,
#    '(91, 79, 63)': 593,
#    '(16, 15, 14)': 1353,
#    '(187, 177, 158)': 867,
#    '(135, 139, 133)': 851,
#    '(144, 121, 84)': 782,
#    '(97, 54, 38)': 341},
#   'most_common_colors': {'(154, 154, 137)': 3740,
#    '(96, 100, 85)': 3470,
#    '(29, 31, 26)': 2520,
#    '(93, 130, 166)': 2224,
#    '(138, 156, 163)': 1972,
#    '(58, 46, 32)': 1491,
#    '(196, 198, 188)': 967}},
#  '1791_mm_dd_i_Портрет_Луиса_Марии_де_Кистуэ-и-Мартинеса.jpeg': {'path': '1791_mm_dd_i_Портрет_Луиса_Марии_де_Кистуэ-и-Мартинеса.jpeg',
#   'name_of_painting': 'Портрет Луиса Марии де Кистуэ-и-Мартинеса',
#   'year': '1791',
#   'most_common_colors_ever': {'(43, 37, 31)': 1218,
#    '(91, 79, 63)': 1405,
#    '(16, 15, 14)': 371,
#    '(187, 177, 158)': 1967,
#    '(135, 139, 133)': 2658,
#    '(144, 121, 84)': 329,
#    '(97, 54, 38)': 239},
#   'most_common_colors': {'(37, 41, 30)': 4696,
#    '(74, 78, 56)': 3028,
#    '(66, 51, 34)': 2831,
#    '(119, 92, 64)': 2791,
#    '(18, 19, 13)': 2072,
#    '(133, 124, 105)': 612,
#    '(149, 104, 98)': 354}},
#  '1801_mm_dd_i_Мануэль_Годой,_герцог_Алькудии,_"принц_мира".jpeg': {'path': '1801_mm_dd_i_Мануэль_Годой,_герцог_Алькудии,_"принц_мира".jpeg',
#   'name_of_painting': 'Мануэль Годой, герцог Алькудии, "принц мира"',
#   'year': '1801',
#   'most_common_colors_ever': {'(43, 37, 31)': 784,
#    '(91, 79, 63)': 1618,
#    '(16, 15, 14)': 910,
#    '(187, 177, 158)': 182,
#    '(135, 139, 133)': 126,
#    '(144, 121, 84)': 887,
#    '(97, 54, 38)': 134},
#   'most_common_colors': {'(47, 50, 45)': 4945,
#    '(65, 73, 73)': 3624,
#    '(21, 21, 24)': 2600,
#    '(68, 55, 29)': 2191,
#    '(113, 101, 75)': 1362,
#    '(90, 53, 29)': 1154,
#    '(204, 149, 73)': 508}},
#  '1789_mm_dd_i_Портрет_Карлоса_IV.jpeg': {'path': '1789_mm_dd_i_Портрет_Карлоса_IV.jpeg',
#   'name_of_painting': 'Портрет Карлоса IV',
#   'year': '1789',
#   'most_common_colors_ever': {'(43, 37, 31)': 893,
#    '(91, 79, 63)': 1436,
#    '(16, 15, 14)': 2057,
#    '(187, 177, 158)': 2831,
#    '(135, 139, 133)': 1014,
#    '(144, 121, 84)': 415,
#    '(97, 54, 38)': 1085},
#   'most_common_colors': {'(23, 24, 19)': 3648,
#    '(43, 39, 28)': 2934,
#    '(7, 8, 6)': 2865,
#    '(148, 139, 120)': 2811,
#    '(125, 93, 52)': 1718,
#    '(79, 50, 33)': 1441,
#    '(111, 103, 62)': 967}},
#  '1780_mm_dd_i_Прачки.jpeg': {'path': '1780_mm_dd_i_Прачки.jpeg',
#   'name_of_painting': 'Прачки',
#   'year': '1780',
#   'most_common_colors_ever': {'(43, 37, 31)': 3006,
#    '(91, 79, 63)': 2130,
#    '(16, 15, 14)': 2054,
#    '(187, 177, 158)': 58,
#    '(135, 139, 133)': 13,
#    '(144, 121, 84)': 392,
#    '(97, 54, 38)': 511},
#   'most_common_colors': {'(69, 62, 44)': 4981,
#    '(141, 183, 192)': 2838,
#    '(128, 133, 114)': 2619,
#    '(111, 78, 49)': 1595,
#    '(216, 209, 188)': 1540,
#    '(103, 161, 174)': 1418,
#    '(157, 125, 79)': 1393}},
#  '1806_mm_dd_i_Портрет_Педро_Мокарте,_певца_собора_Толедо.jpeg': {'path': '1806_mm_dd_i_Портрет_Педро_Мокарте,_певца_собора_Толедо.jpeg',
#   'name_of_painting': 'Портрет Педро Мокарте, певца собора Толедо',
#   'year': '1806',
#   'most_common_colors_ever': {'(43, 37, 31)': 829,
#    '(91, 79, 63)': 794,
#    '(16, 15, 14)': 784,
#    '(187, 177, 158)': 2006,
#    '(135, 139, 133)': 1260,
#    '(144, 121, 84)': 893,
#    '(97, 54, 38)': 596},
#   'most_common_colors': {'(8, 10, 9)': 6650,
#    '(45, 38, 32)': 4302,
#    '(10, 13, 12)': 1709,
#    '(65, 54, 43)': 1472,
#    '(103, 95, 77)': 913,
#    '(145, 108, 80)': 708,
#    '(194, 182, 159)': 630}},
#  '1793_mm_dd_i_Пикадор,_оказавшись_на_быке.jpeg': {'path': '1793_mm_dd_i_Пикадор,_оказавшись_на_быке.jpeg',
#   'name_of_painting': 'Пикадор, оказавшись на быке',
#   'year': '1793',
#   'most_common_colors_ever': {'(43, 37, 31)': 448,
#    '(91, 79, 63)': 732,
#    '(16, 15, 14)': 184,
#    '(187, 177, 158)': 1541,
#    '(135, 139, 133)': 4038,
#    '(144, 121, 84)': 1143,
#    '(97, 54, 38)': 630},
#   'most_common_colors': {'(135, 122, 104)': 4216,
#    '(200, 184, 156)': 3911,
#    '(63, 53, 42)': 2990,
#    '(230, 223, 218)': 2123,
#    '(22, 20, 17)': 1352,
#    '(143, 109, 69)': 1006,
#    '(176, 189, 214)': 786}},
#  '1785_mm_dd_i_Портрет_графини-герцогини_Бенавенте.jpeg': {'path': '1785_mm_dd_i_Портрет_графини-герцогини_Бенавенте.jpeg',
#   'name_of_painting': 'Портрет графини-герцогини Бенавенте',
#   'year': '1785',
#   'most_common_colors_ever': {'(43, 37, 31)': 5243,
#    '(91, 79, 63)': 2169,
#    '(16, 15, 14)': 1608,
#    '(187, 177, 158)': 169,
#    '(135, 139, 133)': 91,
#    '(144, 121, 84)': 413,
#    '(97, 54, 38)': 859},
#   'most_common_colors': {'(20, 20, 22)': 5973,
#    '(38, 39, 34)': 3267,
#    '(64, 61, 52)': 2203,
#    '(123, 118, 102)': 1969,
#    '(38, 46, 59)': 1274,
#    '(152, 120, 96)': 892,
#    '(217, 194, 167)': 806}},
#  '1807_mm_dd_i_Портрет_дамы.jpeg': {'path': '1807_mm_dd_i_Портрет_дамы.jpeg',
#   'name_of_painting': 'Портрет дамы',
#   'year': '1807',
#   'most_common_colors_ever': {'(43, 37, 31)': 74,
#    '(91, 79, 63)': 646,
#    '(16, 15, 14)': 0,
#    '(187, 177, 158)': 451,
#    '(135, 139, 133)': 2177,
#    '(144, 121, 84)': 131,
#    '(97, 54, 38)': 36},
#   'most_common_colors': {'(50, 41, 32)': 4947,
#    '(45, 36, 30)': 4081,
#    '(27, 22, 18)': 3568,
#    '(60, 52, 40)': 2014,
#    '(124, 103, 76)': 1118,
#    '(168, 137, 108)': 447,
#    '(198, 179, 157)': 209}},
#  '1816_mm_dd_i_Коррида_на_разделенной_арене.jpeg': {'path': '1816_mm_dd_i_Коррида_на_разделенной_арене.jpeg',
#   'name_of_painting': 'Коррида на разделенной арене',
#   'year': '1816',
#   'most_common_colors_ever': {'(43, 37, 31)': 5089,
#    '(91, 79, 63)': 4654,
#    '(16, 15, 14)': 1997,
#    '(187, 177, 158)': 152,
#    '(135, 139, 133)': 1222,
#    '(144, 121, 84)': 65,
#    '(97, 54, 38)': 715},
#   'most_common_colors': {'(90, 70, 38)': 3575,
#    '(148, 115, 65)': 2898,
#    '(76, 44, 15)': 2264,
#    '(206, 177, 111)': 2078,
#    '(145, 125, 88)': 1954,
#    '(212, 217, 202)': 1830,
#    '(149, 172, 166)': 1785}},
#  '1802_mm_dd_i_Портрет_Дон_Хосе_Керальто.jpeg': {'path': '1802_mm_dd_i_Портрет_Дон_Хосе_Керальто.jpeg',
#   'name_of_painting': 'Портрет Дон Хосе Керальто',
#   'year': '1802',
#   'most_common_colors_ever': {'(43, 37, 31)': 2669,
#    '(91, 79, 63)': 1260,
#    '(16, 15, 14)': 928,
#    '(187, 177, 158)': 3585,
#    '(135, 139, 133)': 2266,
#    '(144, 121, 84)': 1362,
#    '(97, 54, 38)': 257},
#   'most_common_colors': {'(34, 31, 29)': 5450,
#    '(34, 33, 34)': 4248,
#    '(43, 42, 43)': 2592,
#    '(31, 29, 28)': 1718,
#    '(78, 68, 66)': 1247,
#    '(132, 93, 81)': 843,
#    '(182, 159, 141)': 286}},
#  '1774_mm_dd_i_Обрезание.jpeg': {'path': '1774_mm_dd_i_Обрезание.jpeg',
#   'name_of_painting': 'Обрезание',
#   'year': '1774',
#   'most_common_colors_ever': {'(43, 37, 31)': 262,
#    '(91, 79, 63)': 1937,
#    '(16, 15, 14)': 5,
#    '(187, 177, 158)': 3932,
#    '(135, 139, 133)': 234,
#    '(144, 121, 84)': 1194,
#    '(97, 54, 38)': 161},
#   'most_common_colors': {'(121, 71, 57)': 4622,
#    '(135, 56, 31)': 3573,
#    '(179, 124, 105)': 2308,
#    '(74, 41, 31)': 2049,
#    '(205, 172, 182)': 1573,
#    '(109, 69, 105)': 1179,
#    '(175, 98, 48)': 1080}},
#  '1798_mm_dd_i_Чудо_святого_Антония_Падуанского_(фрагмент).jpeg': {'path': '1798_mm_dd_i_Чудо_святого_Антония_Падуанского_(фрагмент).jpeg',
#   'name_of_painting': 'Чудо святого Антония Падуанского (фрагмент)',
#   'year': '1798',
#   'most_common_colors_ever': {'(43, 37, 31)': 1461,
#    '(91, 79, 63)': 788,
#    '(16, 15, 14)': 5738,
#    '(187, 177, 158)': 98,
#    '(135, 139, 133)': 3,
#    '(144, 121, 84)': 1404,
#    '(97, 54, 38)': 680},
#   'most_common_colors': {'(152, 148, 133)': 3669,
#    '(32, 24, 28)': 3198,
#    '(96, 77, 69)': 2552,
#    '(62, 45, 46)': 1884,
#    '(209, 207, 180)': 1827,
#    '(154, 137, 112)': 1664,
#    '(14, 12, 16)': 1590}},
#  '1798_mm_dd_i_Фреска_часовни_Св._Антония_Флоридского,_деталь_2.jpeg': {'path': '1798_mm_dd_i_Фреска_часовни_Св._Антония_Флоридского,_деталь_2.jpeg',
#   'name_of_painting': 'Фреска часовни Св. Антония Флоридского, деталь 2',
#   'year': '1798',
#   'most_common_colors_ever': {'(43, 37, 31)': 1865,
#    '(91, 79, 63)': 4884,
#    '(16, 15, 14)': 1251,
#    '(187, 177, 158)': 1262,
#    '(135, 139, 133)': 433,
#    '(144, 121, 84)': 1049,
#    '(97, 54, 38)': 941},
#   'most_common_colors': {'(52, 35, 39)': 4068,
#    '(147, 148, 143)': 3691,
#    '(76, 56, 55)': 2490,
#    '(95, 89, 89)': 2307,
#    '(134, 114, 106)': 1684,
#    '(30, 17, 25)': 1523,
#    '(111, 97, 81)': 621}},
#  '1810_mm_dd_i_Портрет_доньи_Нарсисы_Бараньяна_де_Гойкоечеа.jpeg': {'path': '1810_mm_dd_i_Портрет_доньи_Нарсисы_Бараньяна_де_Гойкоечеа.jpeg',
#   'name_of_painting': 'Портрет доньи Нарсисы Бараньяна де Гойкоечеа',
#   'year': '1810',
#   'most_common_colors_ever': {'(43, 37, 31)': 2580,
#    '(91, 79, 63)': 3519,
#    '(16, 15, 14)': 3034,
#    '(187, 177, 158)': 494,
#    '(135, 139, 133)': 659,
#    '(144, 121, 84)': 1215,
#    '(97, 54, 38)': 75},
#   'most_common_colors': {'(113, 87, 71)': 5440,
#    '(6, 0, 1)': 4499,
#    '(66, 42, 37)': 2462,
#    '(21, 4, 5)': 1619,
#    '(103, 69, 55)': 1310,
#    '(136, 114, 105)': 611,
#    '(150, 102, 63)': 443}},
#  '1792_mm_dd_i_Себастьян_Мартинес_и_Перес.jpeg': {'path': '1792_mm_dd_i_Себастьян_Мартинес_и_Перес.jpeg',
#   'name_of_painting': 'Себастьян Мартинес и Перес',
#   'year': '1792',
#   'most_common_colors_ever': {'(43, 37, 31)': 1692,
#    '(91, 79, 63)': 193,
#    '(16, 15, 14)': 4305,
#    '(187, 177, 158)': 0,
#    '(135, 139, 133)': 0,
#    '(144, 121, 84)': 29,
#    '(97, 54, 38)': 270},
#   'most_common_colors': {'(28, 29, 23)': 4026,
#    '(73, 64, 47)': 3728,
#    '(49, 45, 26)': 2970,
#    '(158, 118, 42)': 1991,
#    '(62, 40, 21)': 1749,
#    '(121, 114, 96)': 1012,
#    '(145, 100, 57)': 908}},
#  '1798_mm_dd_i_Портрет_художника_Хулио_Асенсио.jpeg': {'path': '1798_mm_dd_i_Портрет_художника_Хулио_Асенсио.jpeg',
#   'name_of_painting': 'Портрет художника Хулио Асенсио',
#   'year': '1798',
#   'most_common_colors_ever': {'(43, 37, 31)': 876,
#    '(91, 79, 63)': 1441,
#    '(16, 15, 14)': 82,
#    '(187, 177, 158)': 5227,
#    '(135, 139, 133)': 518,
#    '(144, 121, 84)': 628,
#    '(97, 54, 38)': 313},
#   'most_common_colors': {'(33, 27, 24)': 4962,
#    '(45, 35, 30)': 3594,
#    '(75, 55, 42)': 2644,
#    '(118, 84, 55)': 2592,
#    '(146, 117, 86)': 1460,
#    '(129, 98, 70)': 965,
#    '(143, 88, 53)': 167}},
#  '1814_mm_dd_i_Фернандо_III_Наварры_и_VII_Кастилии.jpeg': {'path': '1814_mm_dd_i_Фернандо_III_Наварры_и_VII_Кастилии.jpeg',
#   'name_of_painting': 'Фернандо III Наварры и VII Кастилии',
#   'year': '1814',
#   'most_common_colors_ever': {'(43, 37, 31)': 3449,
#    '(91, 79, 63)': 1431,
#    '(16, 15, 14)': 5698,
#    '(187, 177, 158)': 716,
#    '(135, 139, 133)': 795,
#    '(144, 121, 84)': 177,
#    '(97, 54, 38)': 597},
#   'most_common_colors': {'(40, 48, 47)': 5400,
#    '(47, 57, 64)': 3129,
#    '(77, 74, 62)': 1862,
#    '(74, 57, 49)': 1861,
#    '(162, 71, 48)': 1844,
#    '(161, 138, 103)': 1398,
#    '(148, 96, 71)': 890}},
#  '1781_mm_dd_i_Богородица,_как_королева_мучеников_(фрагмент).jpeg': {'path': '1781_mm_dd_i_Богородица,_как_королева_мучеников_(фрагмент).jpeg',
#   'name_of_painting': 'Богородица, как королева мучеников (фрагмент)',
#   'year': '1781',
#   'most_common_colors_ever': {'(43, 37, 31)': 5283,
#    '(91, 79, 63)': 813,
#    '(16, 15, 14)': 7246,
#    '(187, 177, 158)': 664,
#    '(135, 139, 133)': 185,
#    '(144, 121, 84)': 876,
#    '(97, 54, 38)': 780},
#   'most_common_colors': {'(139, 59, 47)': 4291,
#    '(74, 45, 40)': 3844,
#    '(169, 87, 58)': 2620,
#    '(119, 60, 48)': 2231,
#    '(164, 127, 91)': 1862,
#    '(198, 131, 75)': 1239,
#    '(219, 171, 106)': 297}},
#  '1783_mm_dd_i_Портрет_Марии_Терезы_де_Валлабриг_на_коне.jpeg': {'path': '1783_mm_dd_i_Портрет_Марии_Терезы_де_Валлабриг_на_коне.jpeg',
#   'name_of_painting': 'Портрет Марии Терезы де Валлабриг на коне',
#   'year': '1783',
#   'most_common_colors_ever': {'(43, 37, 31)': 4403,
#    '(91, 79, 63)': 2860,
#    '(16, 15, 14)': 305,
#    '(187, 177, 158)': 26,
#    '(135, 139, 133)': 4,
#    '(144, 121, 84)': 1001,
#    '(97, 54, 38)': 2443},
#   'most_common_colors': {'(39, 33, 31)': 4834,
#    '(75, 73, 58)': 3352,
#    '(157, 161, 122)': 2695,
#    '(98, 77, 56)': 2231,
#    '(8, 7, 9)': 1988,
#    '(226, 216, 165)': 673,
#    '(190, 144, 80)': 611}},
#  '1777_mm_dd_i_Зонтик.jpeg': {'path': '1777_mm_dd_i_Зонтик.jpeg',
#   'name_of_painting': 'Зонтик',
#   'year': '1777',
#   'most_common_colors_ever': {'(43, 37, 31)': 5984,
#    '(91, 79, 63)': 407,
#    '(16, 15, 14)': 6699,
#    '(187, 177, 158)': 12,
#    '(135, 139, 133)': 35,
#    '(144, 121, 84)': 65,
#    '(97, 54, 38)': 1174},
#   'most_common_colors': {'(49, 45, 32)': 4036,
#    '(145, 137, 116)': 3736,
#    '(186, 181, 184)': 2829,
#    '(85, 63, 46)': 1917,
#    '(145, 162, 190)': 1616,
#    '(58, 70, 58)': 1349,
#    '(183, 145, 81)': 901}},
#  '1812_mm_dd_i_Маха_на_балконе.jpeg': {'path': '1812_mm_dd_i_Маха_на_балконе.jpeg',
#   'name_of_painting': 'Маха на балконе',
#   'year': '1812',
#   'most_common_colors_ever': {'(43, 37, 31)': 1869,
#    '(91, 79, 63)': 5020,
#    '(16, 15, 14)': 353,
#    '(187, 177, 158)': 1441,
#    '(135, 139, 133)': 1139,
#    '(144, 121, 84)': 489,
#    '(97, 54, 38)': 471},
#   'most_common_colors': {'(6, 6, 4)': 6668,
#    '(51, 32, 24)': 3459,
#    '(17, 14, 12)': 2610,
#    '(112, 73, 43)': 2013,
#    '(186, 160, 121)': 625,
#    '(172, 108, 59)': 558,
#    '(156, 115, 88)': 451}},
#  '1780_mm_dd_i_Любительская_коррида.jpeg': {'path': '1780_mm_dd_i_Любительская_коррида.jpeg',
#   'name_of_painting': 'Любительская коррида',
#   'year': '1780',
#   'most_common_colors_ever': {'(43, 37, 31)': 2062,
#    '(91, 79, 63)': 1602,
#    '(16, 15, 14)': 483,
#    '(187, 177, 158)': 4735,
#    '(135, 139, 133)': 1843,
#    '(144, 121, 84)': 933,
#    '(97, 54, 38)': 293},
#   'most_common_colors': {'(103, 107, 94)': 3617,
#    '(106, 75, 52)': 2821,
#    '(50, 36, 27)': 2794,
#    '(73, 53, 38)': 2775,
#    '(181, 180, 159)': 1626,
#    '(154, 133, 103)': 1605,
#    '(114, 153, 148)': 1146}},
#  '1823_mm_dd_i_Ковен,_или_великий_козел.jpeg': {'path': '1823_mm_dd_i_Ковен,_или_великий_козел.jpeg',
#   'name_of_painting': 'Ковен, или великий козел',
#   'year': '1823',
#   'most_common_colors_ever': {'(43, 37, 31)': 3470,
#    '(91, 79, 63)': 1434,
#    '(16, 15, 14)': 5714,
#    '(187, 177, 158)': 707,
#    '(135, 139, 133)': 789,
#    '(144, 121, 84)': 179,
#    '(97, 54, 38)': 597},
#   'most_common_colors': {'(40, 36, 28)': 3551,
#    '(58, 50, 35)': 3473,
#    '(28, 28, 25)': 2764,
#    '(64, 52, 29)': 2669,
#    '(81, 69, 48)': 2097,
#    '(93, 72, 37)': 1169,
#    '(108, 86, 55)': 661}},
#  '1798_mm_dd_i_Ведьмы_в_воздухе.jpeg': {'path': '1798_mm_dd_i_Ведьмы_в_воздухе.jpeg',
#   'name_of_painting': 'Ведьмы в воздухе',
#   'year': '1798',
#   'most_common_colors_ever': {'(43, 37, 31)': 5913,
#    '(91, 79, 63)': 2939,
#    '(16, 15, 14)': 3769,
#    '(187, 177, 158)': 142,
#    '(135, 139, 133)': 97,
#    '(144, 121, 84)': 414,
#    '(97, 54, 38)': 782},
#   'most_common_colors': {'(11, 12, 8)': 9702,
#    '(128, 102, 70)': 1988,
#    '(45, 38, 24)': 1983,
#    '(20, 19, 13)': 1206,
#    '(147, 128, 105)': 651,
#    '(76, 80, 60)': 460,
#    '(174, 125, 79)': 394}},
#  '1788_mm_dd_i_Мануэль_Осорио_де_Зунига_(фрагмент).jpeg': {'path': '1788_mm_dd_i_Мануэль_Осорио_де_Зунига_(фрагмент).jpeg',
#   'name_of_painting': 'Мануэль Осорио де Зунига (фрагмент)',
#   'year': '1788',
#   'most_common_colors_ever': {'(43, 37, 31)': 1659,
#    '(91, 79, 63)': 2461,
#    '(16, 15, 14)': 1528,
# ...
#    '(135, 139, 133)': 1,
#    '(144, 121, 84)': 687,
#    '(97, 54, 38)': 684},
#   'most_common_colors': {'(32, 32, 27)': 5853,
#    '(14, 13, 7)': 5052,
#    '(28, 26, 22)': 1960,
#    '(35, 30, 24)': 1670,
#    '(93, 70, 52)': 782,
#    '(170, 160, 142)': 541,
#    '(179, 141, 118)': 526}},
#  '1803_mm_dd_i_Портрет_графа_Фернанда_Нуньеса_VII.jpeg': {'path': '1803_mm_dd_i_Портрет_графа_Фернанда_Нуньеса_VII.jpeg',
#   'name_of_painting': 'Портрет графа Фернанда Нуньеса VII',
#   'year': '1803',
#   'most_common_colors_ever': {'(43, 37, 31)': 373,
#    '(91, 79, 63)': 228,
#    '(16, 15, 14)': 15052,
#    '(187, 177, 158)': 10,
#    '(135, 139, 133)': 226,
#    '(144, 121, 84)': 74,
#    '(97, 54, 38)': 88},
#   'most_common_colors': {'(78, 83, 82)': 4082,
#    '(71, 40, 28)': 3174,
#    '(0, 0, 0)': 2946,
#    '(9, 2, 3)': 2712,
#    '(57, 58, 56)': 1950,
#    '(144, 140, 126)': 794,
#    '(76, 52, 44)': 726}},
#  '1784_mm_dd_i_Семья_инфанта_Дона_Луиса_де_Бурбона.jpeg': {'path': '1784_mm_dd_i_Семья_инфанта_Дона_Луиса_де_Бурбона.jpeg',
#   'name_of_painting': 'Семья инфанта Дона Луиса де Бурбона',
#   'year': '1784',
#   'most_common_colors_ever': {'(43, 37, 31)': 774,
#    '(91, 79, 63)': 1841,
#    '(16, 15, 14)': 0,
#    '(187, 177, 158)': 1858,
#    '(135, 139, 133)': 414,
#    '(144, 121, 84)': 1474,
#    '(97, 54, 38)': 1393},
#   'most_common_colors': {'(64, 38, 23)': 4820,
#    '(32, 24, 21)': 2975,
#    '(51, 58, 33)': 2041,
#    '(178, 148, 113)': 2019,
#    '(77, 65, 48)': 1967,
#    '(121, 53, 30)': 1826,
#    '(168, 108, 62)': 736}},
#  '1779_mm_dd_i_Продавщицы_посуды.jpeg': {'path': '1779_mm_dd_i_Продавщицы_посуды.jpeg',
#   'name_of_painting': 'Продавщицы посуды',
#   'year': '1779',
#   'most_common_colors_ever': {'(43, 37, 31)': 9987,
#    '(91, 79, 63)': 1555,
#    '(16, 15, 14)': 8593,
#    '(187, 177, 158)': 79,
#    '(135, 139, 133)': 7,
#    '(144, 121, 84)': 367,
#    '(97, 54, 38)': 374},
#   'most_common_colors': {'(60, 54, 32)': 3894,
#    '(36, 21, 5)': 3582,
#    '(160, 167, 181)': 3404,
#    '(175, 156, 119)': 2242,
#    '(122, 154, 208)': 1286,
#    '(108, 68, 25)': 1159,
#    '(122, 128, 130)': 817}},
#  '1771_mm_dd_a_Автопортрет.jpeg': {'path': '1771_mm_dd_a_Автопортрет.jpeg',
#   'name_of_painting': 'Автопортрет',
#   'year': '1771',
#   'most_common_colors_ever': {'(43, 37, 31)': 5065,
#    '(91, 79, 63)': 640,
#    '(16, 15, 14)': 9031,
#    '(187, 177, 158)': 21,
#    '(135, 139, 133)': 169,
#    '(144, 121, 84)': 256,
#    '(97, 54, 38)': 243},
#   'most_common_colors': {'(34, 19, 16)': 6308,
#    '(21, 10, 9)': 5171,
#    '(47, 24, 16)': 2285,
#    '(114, 63, 26)': 1006,
#    '(192, 131, 53)': 631,
#    '(227, 184, 111)': 547,
#    '(143, 84, 31)': 436}},
#  '1812_mm_dd_i_Святой_Иоанн_Креститель_в_пустыне.jpeg': {'path': '1812_mm_dd_i_Святой_Иоанн_Креститель_в_пустыне.jpeg',
#   'name_of_painting': 'Святой Иоанн Креститель в пустыне',
#   'year': '1812',
#   'most_common_colors_ever': {'(43, 37, 31)': 12060,
#    '(91, 79, 63)': 1418,
#    '(16, 15, 14)': 6490,
#    '(187, 177, 158)': 51,
#    '(135, 139, 133)': 15,
#    '(144, 121, 84)': 356,
#    '(97, 54, 38)': 215},
#   'most_common_colors': {'(151, 107, 78)': 3162,
#    '(89, 76, 63)': 3024,
#    '(44, 30, 23)': 2983,
#    '(111, 81, 51)': 2360,
#    '(75, 54, 39)': 2307,
#    '(26, 13, 10)': 1302,
#    '(115, 129, 130)': 1246}},
#  '1808_mm_dd_i_Госпожа_Франсиска_Сабас_Гарсия.jpeg': {'path': '1808_mm_dd_i_Госпожа_Франсиска_Сабас_Гарсия.jpeg',
#   'name_of_painting': 'Госпожа Франсиска Сабас Гарсия',
#   'year': '1808',
#   'most_common_colors_ever': {'(43, 37, 31)': 448,
#    '(91, 79, 63)': 464,
#    '(16, 15, 14)': 2,
#    '(187, 177, 158)': 0,
#    '(135, 139, 133)': 0,
#    '(144, 121, 84)': 6301,
#    '(97, 54, 38)': 1619},
#   'most_common_colors': {'(24, 29, 27)': 8078,
#    '(64, 58, 27)': 2415,
#    '(27, 32, 30)': 2312,
#    '(69, 72, 53)': 1422,
#    '(121, 103, 27)': 1042,
#    '(131, 121, 76)': 659,
#    '(202, 186, 134)': 456}},
#  '1777_mm_dd_i_Драка_в_Вента_Нуева.jpeg': {'path': '1777_mm_dd_i_Драка_в_Вента_Нуева.jpeg',
#   'name_of_painting': 'Драка в Вента Нуева',
#   'year': '1777',
#   'most_common_colors_ever': {'(43, 37, 31)': 13783,
#    '(91, 79, 63)': 907,
#    '(16, 15, 14)': 2182,
#    '(187, 177, 158)': 5,
#    '(135, 139, 133)': 3,
#    '(144, 121, 84)': 368,
#    '(97, 54, 38)': 203},
#   'most_common_colors': {'(96, 78, 63)': 4092,
#    '(171, 148, 119)': 3519,
#    '(207, 182, 145)': 2787,
#    '(141, 123, 91)': 2242,
#    '(53, 45, 39)': 1365,
#    '(161, 170, 164)': 1248,
#    '(93, 67, 52)': 1131}},
#  '1789_mm_dd_i_Королева_Мария_Луиза.jpeg': {'path': '1789_mm_dd_i_Королева_Мария_Луиза.jpeg',
#   'name_of_painting': 'Королева Мария Луиза',
#   'year': '1789',
#   'most_common_colors_ever': {'(43, 37, 31)': 3346,
#    '(91, 79, 63)': 1130,
#    '(16, 15, 14)': 8458,
#    '(187, 177, 158)': 1,
#    '(135, 139, 133)': 1,
#    '(144, 121, 84)': 1260,
#    '(97, 54, 38)': 562},
#   'most_common_colors': {'(65, 42, 33)': 5876,
#    '(101, 80, 55)': 4698,
#    '(40, 26, 25)': 2103,
#    '(198, 176, 112)': 1714,
#    '(174, 131, 82)': 950,
#    '(251, 230, 141)': 694,
#    '(112, 89, 75)': 349}},
#  '1823_mm_dd_i_Портрет_дона_Рамона_Сатуэ.jpeg': {'path': '1823_mm_dd_i_Портрет_дона_Рамона_Сатуэ.jpeg',
#   'name_of_painting': 'Портрет дона Рамона Сатуэ',
#   'year': '1823',
#   'most_common_colors_ever': {'(43, 37, 31)': 12187,
#    '(91, 79, 63)': 1469,
#    '(16, 15, 14)': 6855,
#    '(187, 177, 158)': 0,
#    '(135, 139, 133)': 0,
#    '(144, 121, 84)': 482,
#    '(97, 54, 38)': 711},
#   'most_common_colors': {'(9, 17, 22)': 11178,
#    '(5, 7, 7)': 3793,
#    '(126, 101, 94)': 480,
#    '(49, 46, 44)': 395,
#    '(114, 36, 28)': 223,
#    '(174, 176, 168)': 159,
#    '(52, 21, 19)': 156}},
#  '1807_mm_dd_i_Портрет_министра_юстиции_Испании_Хосе_Антонио_Маркеса_Кабальеро.jpeg': {'path': '1807_mm_dd_i_Портрет_министра_юстиции_Испании_Хосе_Антонио_Маркеса_Кабальеро.jpeg',
#   'name_of_painting': 'Портрет министра юстиции Испании Хосе Антонио Маркеса Кабальеро',
#   'year': '1807',
#   'most_common_colors_ever': {'(43, 37, 31)': 172,
#    '(91, 79, 63)': 160,
#    '(16, 15, 14)': 14422,
#    '(187, 177, 158)': 70,
#    '(135, 139, 133)': 45,
#    '(144, 121, 84)': 70,
#    '(97, 54, 38)': 53},
#   'most_common_colors': {'(48, 22, 7)': 4995,
#    '(66, 39, 16)': 4087,
#    '(136, 48, 23)': 2018,
#    '(18, 7, 5)': 1573,
#    '(177, 119, 30)': 1357,
#    '(171, 123, 65)': 1269,
#    '(96, 83, 59)': 1085}},
#  '1787_mm_dd_i_Портрет_графа_Альтамира.jpeg': {'path': '1787_mm_dd_i_Портрет_графа_Альтамира.jpeg',
#   'name_of_painting': 'Портрет графа Альтамира',
#   'year': '1787',
#   'most_common_colors_ever': {'(43, 37, 31)': 3132,
#    '(91, 79, 63)': 1521,
#    '(16, 15, 14)': 3793,
#    '(187, 177, 158)': 299,
#    '(135, 139, 133)': 1262,
#    '(144, 121, 84)': 109,
#    '(97, 54, 38)': 668},
#   'most_common_colors': {'(86, 80, 47)': 5562,
#    '(57, 51, 32)': 2784,
#    '(32, 26, 14)': 2650,
#    '(169, 149, 71)': 1619,
#    '(85, 71, 30)': 1604,
#    '(119, 117, 93)': 1246,
#    '(141, 72, 28)': 919}},
#  '1820_mm_dd_i_Читающие_мужчины.jpeg': {'path': '1820_mm_dd_i_Читающие_мужчины.jpeg',
#   'name_of_painting': 'Читающие мужчины',
#   'year': '1820',
#   'most_common_colors_ever': {'(43, 37, 31)': 10160,
#    '(91, 79, 63)': 1778,
#    '(16, 15, 14)': 3680,
#    '(187, 177, 158)': 0,
#    '(135, 139, 133)': 0,
#    '(144, 121, 84)': 215,
#    '(97, 54, 38)': 1488},
#   'most_common_colors': {'(35, 32, 27)': 4057,
#    '(21, 19, 14)': 3935,
#    '(53, 45, 38)': 3924,
#    '(23, 21, 17)': 2310,
#    '(90, 78, 61)': 1386,
#    '(131, 109, 74)': 391,
#    '(178, 169, 134)': 381}},
#  '1786_mm_dd_i_Цветочницы,_или_весной.jpeg': {'path': '1786_mm_dd_i_Цветочницы,_или_весной.jpeg',
#   'name_of_painting': 'Цветочницы, или весной',
#   'year': '1786',
#   'most_common_colors_ever': {'(43, 37, 31)': 6807,
#    '(91, 79, 63)': 790,
#    '(16, 15, 14)': 4092,
#    '(187, 177, 158)': 49,
#    '(135, 139, 133)': 442,
#    '(144, 121, 84)': 553,
#    '(97, 54, 38)': 1786},
#   'most_common_colors': {'(165, 156, 115)': 4138,
#    '(92, 79, 45)': 2582,
#    '(91, 105, 93)': 2503,
#    '(147, 163, 160)': 2292,
#    '(28, 46, 36)': 2024,
#    '(232, 228, 208)': 1890,
#    '(28, 18, 13)': 955}},
#  '1779_mm_dd_i_Солдат_и_сеньора.jpeg': {'path': '1779_mm_dd_i_Солдат_и_сеньора.jpeg',
#   'name_of_painting': 'Солдат и сеньора',
#   'year': '1779',
#   'most_common_colors_ever': {'(43, 37, 31)': 12213,
#    '(91, 79, 63)': 1030,
#    '(16, 15, 14)': 1141,
#    '(187, 177, 158)': 8,
#    '(135, 139, 133)': 2,
#    '(144, 121, 84)': 359,
#    '(97, 54, 38)': 152},
#   'most_common_colors': {'(114, 132, 128)': 4505,
#    '(51, 44, 35)': 3820,
#    '(99, 81, 61)': 2759,
#    '(169, 177, 164)': 2019,
#    '(35, 32, 27)': 1866,
#    '(127, 112, 85)': 738,
#    '(69, 76, 62)': 677}},
#  '1799_mm_dd_i_Портрет_герцога_де_Осуна.jpeg': {'path': '1799_mm_dd_i_Портрет_герцога_де_Осуна.jpeg',
#   'name_of_painting': 'Портрет герцога де Осуна',
#   'year': '1799',
#   'most_common_colors_ever': {'(43, 37, 31)': 12958,
#    '(91, 79, 63)': 1374,
#    '(16, 15, 14)': 3576,
#    '(187, 177, 158)': 52,
#    '(135, 139, 133)': 154,
#    '(144, 121, 84)': 100,
#    '(97, 54, 38)': 441},
#   'most_common_colors': {'(24, 24, 23)': 12677,
#    '(38, 36, 36)': 1250,
#    '(59, 52, 53)': 1215,
#    '(147, 109, 110)': 499,
#    '(113, 106, 111)': 401,
#    '(161, 153, 158)': 195,
#    '(205, 199, 189)': 147}},
#  '1778_mm_dd_i_Игроки_в_карты.jpeg': {'path': '1778_mm_dd_i_Игроки_в_карты.jpeg',
#   'name_of_painting': 'Игроки в карты',
#   'year': '1778',
#   'most_common_colors_ever': {'(43, 37, 31)': 13128,
#    '(91, 79, 63)': 793,
#    '(16, 15, 14)': 5596,
#    '(187, 177, 158)': 14,
#    '(135, 139, 133)': 76,
#    '(144, 121, 84)': 332,
#    '(97, 54, 38)': 226},
#   'most_common_colors': {'(81, 58, 31)': 3113,
#    '(63, 65, 37)': 2988,
#    '(127, 161, 148)': 2757,
#    '(198, 184, 150)': 2600,
#    '(39, 38, 34)': 2529,
#    '(117, 114, 79)': 2142,
#    '(172, 104, 41)': 255}},
#  '1823_mm_dd_i_Сатурн,_пожирающий_своих_детей.jpeg': {'path': '1823_mm_dd_i_Сатурн,_пожирающий_своих_детей.jpeg',
#   'name_of_painting': 'Сатурн, пожирающий своих детей',
#   'year': '1823',
#   'most_common_colors_ever': {'(43, 37, 31)': 6566,
#    '(91, 79, 63)': 3115,
#    '(16, 15, 14)': 3366,
#    '(187, 177, 158)': 0,
#    '(135, 139, 133)': 0,
#    '(144, 121, 84)': 462,
#    '(97, 54, 38)': 1872},
#   'most_common_colors': {'(30, 30, 26)': 6094,
#    '(48, 44, 31)': 3200,
#    '(37, 36, 31)': 2883,
#    '(99, 82, 52)': 1960,
#    '(71, 61, 40)': 1501,
#    '(153, 130, 83)': 594,
#    '(117, 77, 46)': 152}},
#  '1788_mm_dd_s_Жмурки_(эскиз).jpeg': {'path': '1788_mm_dd_s_Жмурки_(эскиз).jpeg',
#   'name_of_painting': 'Жмурки (эскиз)',
#   'year': '1788',
#   'most_common_colors_ever': {'(43, 37, 31)': 2071,
#    '(91, 79, 63)': 1137,
#    '(16, 15, 14)': 1749,
#    '(187, 177, 158)': 481,
#    '(135, 139, 133)': 144,
#    '(144, 121, 84)': 2473,
#    '(97, 54, 38)': 398},
#   'most_common_colors': {'(195, 183, 167)': 5150,
#    '(146, 136, 122)': 3793,
#    '(158, 164, 166)': 2622,
#    '(218, 210, 199)': 1865,
#    '(57, 50, 41)': 1316,
#    '(136, 124, 96)': 1042,
#    '(98, 79, 62)': 596}},
#  '1777_mm_dd_i_Выпивоха.jpeg': {'path': '1777_mm_dd_i_Выпивоха.jpeg',
#   'name_of_painting': 'Выпивоха',
#   'year': '1777',
#   'most_common_colors_ever': {'(43, 37, 31)': 9177,
#    '(91, 79, 63)': 2380,
#    '(16, 15, 14)': 2770,
#    '(187, 177, 158)': 8,
#    '(135, 139, 133)': 1,
#    '(144, 121, 84)': 126,
#    '(97, 54, 38)': 1022},
#   'most_common_colors': {'(129, 123, 82)': 3725,
#    '(69, 59, 39)': 3538,
#    '(98, 76, 51)': 2843,
#    '(177, 183, 152)': 2077,
#    '(217, 190, 148)': 1681,
#    '(127, 164, 146)': 1311,
#    '(181, 122, 78)': 1209}},
#  '1788_mm_dd_i_Луг_Сан-Исидро.jpeg': {'path': '1788_mm_dd_i_Луг_Сан-Исидро.jpeg',
#   'name_of_painting': 'Луг Сан-Исидро',
#   'year': '1788',
#   'most_common_colors_ever': {'(43, 37, 31)': 5512,
#    '(91, 79, 63)': 491,
#    '(16, 15, 14)': 965,
#    '(187, 177, 158)': 0,
#    '(135, 139, 133)': 0,
#    '(144, 121, 84)': 154,
#    '(97, 54, 38)': 3269},
#   'most_common_colors': {'(191, 177, 143)': 4408,
#    '(199, 196, 177)': 3538,
#    '(151, 142, 111)': 2287,
#    '(211, 196, 166)': 2114,
#    '(82, 77, 60)': 2078,
#    '(104, 101, 77)': 1601,
#    '(125, 110, 83)': 358}},
#  '1775_mm_dd_i_Собаки_на_поводке.jpeg': {'path': '1775_mm_dd_i_Собаки_на_поводке.jpeg',
#   'name_of_painting': 'Собаки на поводке',
#   'year': '1775',
#   'most_common_colors_ever': {'(43, 37, 31)': 232,
#    '(91, 79, 63)': 729,
#    '(16, 15, 14)': 8,
#    '(187, 177, 158)': 0,
#    '(135, 139, 133)': 0,
#    '(144, 121, 84)': 67,
#    '(97, 54, 38)': 2705},
#   'most_common_colors': {'(97, 129, 177)': 5063,
#    '(74, 70, 49)': 3117,
#    '(37, 34, 25)': 2184,
#    '(125, 115, 79)': 1959,
#    '(131, 156, 193)': 1686,
#    '(189, 193, 202)': 1439,
#    '(99, 108, 106)': 936}},
#  '1775_mm_dd_i_Охотник_с_собакой.jpeg': {'path': '1775_mm_dd_i_Охотник_с_собакой.jpeg',
#   'name_of_painting': 'Охотник с собакой',
#   'year': '1775',
#   'most_common_colors_ever': {'(43, 37, 31)': 6771,
#    '(91, 79, 63)': 1831,
#    '(16, 15, 14)': 3016,
#    '(187, 177, 158)': 225,
#    '(135, 139, 133)': 1547,
#    '(144, 121, 84)': 180,
#    '(97, 54, 38)': 107},
#   'most_common_colors': {'(92, 83, 45)': 4874,
#    '(233, 223, 196)': 3245,
#    '(155, 141, 78)': 2282,
#    '(181, 186, 174)': 2194,
#    '(42, 39, 35)': 1658,
#    '(215, 182, 149)': 1425,
#    '(108, 71, 53)': 706}},
#  '1812_mm_dd_i_Натюрморт_с_ощипанной_индейкой_и_сковородой_с_рыбой.jpeg': {'path': '1812_mm_dd_i_Натюрморт_с_ощипанной_индейкой_и_сковородой_с_рыбой.jpeg',
#   'name_of_painting': 'Натюрморт с ощипанной индейкой и сковородой с рыбой',
#   'year': '1812',
#   'most_common_colors_ever': {'(43, 37, 31)': 2947,
#    '(91, 79, 63)': 1969,
#    '(16, 15, 14)': 1888,
#    '(187, 177, 158)': 54,
#    '(135, 139, 133)': 1493,
#    '(144, 121, 84)': 819,
#    '(97, 54, 38)': 99},
#   'most_common_colors': {'(8, 3, 4)': 4980,
#    '(2, 0, 1)': 4012,
#    '(37, 21, 17)': 2971,
#    '(174, 136, 106)': 1481,
#    '(153, 108, 79)': 1276,
#    '(77, 52, 37)': 955,
#    '(122, 72, 48)': 709}},
#  '1819_mm_dd_i_Портрет_Хуана_Антонио_Куэрво.jpeg': {'path': '1819_mm_dd_i_Портрет_Хуана_Антонио_Куэрво.jpeg',
#   'name_of_painting': 'Портрет Хуана Антонио Куэрво',
#   'year': '1819',
#   'most_common_colors_ever': {'(43, 37, 31)': 8976,
#    '(91, 79, 63)': 271,
#    '(16, 15, 14)': 12481,
#    '(187, 177, 158)': 413,
#    '(135, 139, 133)': 48,
#    '(144, 121, 84)': 180,
#    '(97, 54, 38)': 197},
#   'most_common_colors': {'(31, 31, 29)': 6517,
#    '(22, 22, 18)': 2438,
#    '(12, 14, 11)': 2307,
#    '(49, 49, 44)': 1801,
#    '(39, 32, 22)': 1394,
#    '(79, 65, 50)': 1325,
#    '(71, 72, 66)': 602}},
#  '1823_mm_dd_i_Юдифь_и_Олоферн.jpeg': {'path': '1823_mm_dd_i_Юдифь_и_Олоферн.jpeg',
#   'name_of_painting': 'Юдифь и Олоферн',
#   'year': '1823',
#   'most_common_colors_ever': {'(43, 37, 31)': 6549,
#    '(91, 79, 63)': 5449,
#    '(16, 15, 14)': 1301,
#    '(187, 177, 158)': 178,
#    '(135, 139, 133)': 80,
#    '(144, 121, 84)': 78,
#    '(97, 54, 38)': 54},
#   'most_common_colors': {'(29, 29, 29)': 6188,
#    '(42, 40, 36)': 3798,
#    '(39, 38, 35)': 3082,
#    '(67, 59, 51)': 1492,
#    '(98, 84, 70)': 919,
#    '(141, 117, 92)': 728,
#    '(208, 177, 150)': 177}},
#  '1783_mm_dd_i_Портрет_Марии_Терезы_де_Бурбон_и_Валлабриг.jpeg': {'path': '1783_mm_dd_i_Портрет_Марии_Терезы_де_Бурбон_и_Валлабриг.jpeg',
#   'name_of_painting': 'Портрет Марии Терезы де Бурбон и Валлабриг',
#   'year': '1783',
#   'most_common_colors_ever': {'(43, 37, 31)': 2769,
#    '(91, 79, 63)': 2408,
#    '(16, 15, 14)': 1109,
#    '(187, 177, 158)': 109,
#    '(135, 139, 133)': 33,
#    '(144, 121, 84)': 1938,
#    '(97, 54, 38)': 1545},
#   'most_common_colors': {'(52, 58, 50)': 4129,
#    '(144, 150, 148)': 3687,
#    '(111, 105, 95)': 3328,
#    '(136, 104, 75)': 1932,
#    '(26, 24, 19)': 1424,
#    '(51, 43, 26)': 1358,
#    '(172, 145, 124)': 526}},
#  '1827_mm_dd_i_Хуан_Баутиста_де_Мугиро.jpeg': {'path': '1827_mm_dd_i_Хуан_Баутиста_де_Мугиро.jpeg',
#   'name_of_painting': 'Хуан Баутиста де Мугиро',
#   'year': '1827',
#   'most_common_colors_ever': {'(43, 37, 31)': 6331,
#    '(91, 79, 63)': 1,
#    '(16, 15, 14)': 807,
#    '(187, 177, 158)': 0,
#    '(135, 139, 133)': 0,
#    '(144, 121, 84)': 8,
#    '(97, 54, 38)': 1539},
#   'most_common_colors': {'(69, 70, 66)': 6058,
#    '(32, 35, 36)': 4113,
#    '(74, 75, 65)': 2330,
#    '(50, 43, 36)': 1998,
#    '(57, 56, 49)': 828,
#    '(130, 112, 98)': 749,
#    '(195, 186, 166)': 308}}}

# %%
import json

with open("colors_data_goya.json", "w", encoding="utf-8") as f:
    json.dump(info_dict, f, default=str, ensure_ascii=False, indent=4)

# %%
plot_color_distribution(colors_by_year_gm, how='not_sorted', classifier='GM')
# Out:
# [1771, 1772, 1774, 1775, 1776, 1777, 1778, 1779, 1780, 1781, 1783, 1784, 1785, 1786, 1787, 1788, 1789, 1790, 1791, 1792, 1793, 1794, 1795, 1797, 1798, 1799, 1800, 1801, 1802, 1803, 1804, 1805, 1806, 1807, 1808, 1809, 1810, 1811, 1812, 1813, 1814, 1815, 1816, 1819, 1820, 1822, 1823, 1824, 1825, 1827, 1828]

# %% [markdown]
# Отсортировано по яркости:

# %%
plot_color_distribution(colors_by_year_gm, how='sorted', classifier='GM')
# Out:
# [1771, 1772, 1774, 1775, 1776, 1777, 1778, 1779, 1780, 1781, 1783, 1784, 1785, 1786, 1787, 1788, 1789, 1790, 1791, 1792, 1793, 1794, 1795, 1797, 1798, 1799, 1800, 1801, 1802, 1803, 1804, 1805, 1806, 1807, 1808, 1809, 1810, 1811, 1812, 1813, 1814, 1815, 1816, 1819, 1820, 1822, 1823, 1824, 1825, 1827, 1828]

# %%
# colors_by_year_gm

# %%
rows = []
for year, colors in colors_by_year_gm.items():
    color_list = list(colors.items())[:7]  # Оставляем только 7 цветов
    row = [year]
    for i, ((r, g, b), count) in enumerate(color_list):
        row.extend([r, g, b, count])  # Добавляем R, G, B и Count
    rows.append(row)
    
columns = ['year']
for i in range(1, 8):  # 7 цветов
    columns.extend([f'R{i}', f'G{i}', f'B{i}', f'Count{i}'])

# Создаем DataFrame
df = pd.DataFrame(rows, columns=columns)
df.head()
# Out:
#    year   R1   G1   B1  Count1   R2   G2   B2  Count2   R3  ...   B5  Count5  \
# 0  1938  181  189  177    4582  146  140  132    2878   34  ...  103    1676
# 1  1895   58   59   57    5652  212  122   72    5529   29  ...   29    4527
# 2  1902   18   26   34    5729   34   34   37    5106  183  ...   53    4566
# 3  1893    9    4    5    5059   35   14   13    5026  166  ...   44    3942
# 4  1888  114   97   67    3417   68   63   55    3248  155  ...  104    2073
#
#     R6   G6  B6  Count6   R7   G7   B7  Count7
# 0  103   56  52    1650  227  202  112    1548
# 1   67   61  54    4500   44   35   30    3950
# 2   27   35  41    4545  213  192  185    4505
# 3  162  112  77    3804  228  139   70    3518
# 4  122   82  44    1654  196  153   87    1131
#
# [5 rows x 29 columns]

# %%
# df_GM

# %%
df_GM = pd.merge(df_GM, df, on='year', how='inner')
df_GM.head()
# Out:
#    year  (35, 36, 39)  (73, 64, 55)  (139, 125, 100)  (192, 184, 173)  \
# 0  1882          9540          4024              844              230
# 1  1883           242           786             2828              410
# 2  1885          6573          3510              365              630
# 3  1886          5856          2217              830              376
# 4  1888          2551          2783              870               21
#
#    (82, 98, 120)  (137, 77, 48)  (199, 160, 96)   R1   G1  ...   B5  Count5  \
# 0             13             36             271   41   56  ...   21    3099
# 1              1            555             403  179  148  ...  196    1206
# 2            106             69              48   55   62  ...  182     860
# 3             37            330             120   43   50  ...  128    1949
# 4             10            945            1302  114   97  ...  104    2073
#
#     R6   G6   B6  Count6   R7   G7   B7  Count7
# 0  197  163  126    1913   74   64   52    1858
# 1  188  141  112     631   57   44   46     541
# 2  162  147  118     613  100   76   57     485
# 3  129   92   65     755  154  169  154     466
# 4  122   82   44    1654  196  153   87    1131
#
# [5 rows x 36 columns]

# %%
df_counts['year'] = df_counts['year'].astype(int)

# %%
df_GM = pd.merge(df_GM, df_counts, on='year', how='inner')

# %%
df_GM.head()
# Out:
#    year  (35, 36, 39)  (73, 64, 55)  (139, 125, 100)  (192, 184, 173)  \
# 0  1882          9540          4024              844              230
# 1  1883           242           786             2828              410
# 2  1885          6573          3510              365              630
# 3  1886          5856          2217              830              376
# 4  1888          2551          2783              870               21
#
#    (82, 98, 120)  (137, 77, 48)  (199, 160, 96)   R1   G1  ...  Count5   R6  \
# 0             13             36             271   41   56  ...    3099  197
# 1              1            555             403  179  148  ...    1206  188
# 2            106             69              48   55   62  ...     860  162
# 3             37            330             120   43   50  ...    1949  129
# 4             10            945            1302  114   97  ...    2073  122
#
#     G6   B6  Count6   R7   G7   B7  Count7  count
# 0  163  126    1913   74   64   52    1858      2
# 1  141  112     631   57   44   46     541      1
# 2  147  118     613  100   76   57     485      1
# 3   92   65     755  154  169  154     466      1
# 4   82   44    1654  196  153   87    1131      1
#
# [5 rows x 37 columns]

# %%
df_GM.to_csv('data_GM.csv', index=False)

# %% [markdown]
# #### KMeans:

# %%
colors_by_year_km = get_colors_by_year(folder_path, classifier='KMeans')
# Out:
# {1799: {(24, 24, 23): 13299, (30, 22, 25): 6639, (19, 19, 18): 5561, (68, 54, 44): 5475, (16, 12, 15): 4263, (50, 38, 38): 4076, (94, 75, 58): 3539}, 1775: {(96, 127, 175): 4847, (58, 50, 35): 3466, (85, 71, 41): 3316, (125, 151, 155): 3068, (230, 206, 171): 2950, (116, 94, 53): 2924, (74, 70, 49): 2841}, 1812: {(6, 2, 3): 9566, (11, 9, 7): 9565, (13, 13, 10): 8406, (32, 30, 25): 6836, (43, 44, 37): 6781, (39, 45, 53): 6431, (56, 57, 44): 5993}, 1787: {(56, 49, 28): 5487, (79, 138, 157): 5250, (120, 121, 107): 4969, (196, 167, 154): 4486, (61, 57, 40): 4171, (184, 171, 145): 3725, (75, 106, 116): 3643}, 1814: {(39, 35, 37): 11034, (10, 13, 12): 8833, (44, 51, 48): 7762, (15, 10, 12): 5327, (89, 80, 73): 4990, (18, 19, 21): 4976, (51, 46, 35): 4658}, 1795: {(21, 12, 7): 7722, (38, 37, 33): 6670, (14, 15, 12): 6612, (137, 144, 142): 6379, (28, 28, 22): 4803, (18, 18, 16): 4461, (36, 35, 32): 4440}, 1820: {(0, 0, 0): 14907, (11, 12, 13): 8205, (20, 18, 13): 5056, (37, 32, 27): 4804, (32, 29, 24): 4533, (72, 57, 51): 4062, (54, 47, 40): 3810}, 1783: {(11, 11, 9): 10775, (4, 7, 11): 9799, (12, 13, 13): 9755, (16, 12, 10): 6325, (36, 34, 21): 4850, (33, 38, 32): 4466, (28, 25, 23): 4263}, 1806: {(10, 12, 11): 9059, (58, 57, 29): 5572, (22, 17, 17): 5092, (16, 14, 16): 4636, (118, 90, 73): 3035, (89, 69, 61): 2932, (60, 48, 40): 2441}, 1815: {(50, 54, 59): 7060, (115, 113, 107): 5868, (38, 27, 24): 5834, (55, 51, 46): 5477, (59, 41, 32): 5276, (27, 24, 25): 4402, (45, 34, 32): 4069}, 1789: {(24, 23, 18): 6715, (17, 17, 13): 6187, (67, 43, 34): 4789, (166, 157, 149): 4094, (43, 37, 28): 3768, (92, 85, 66): 3210, (71, 81, 77): 3125}, 1798: {(12, 13, 8): 10809, (12, 13, 9): 10773, (9, 8, 8): 10568, (16, 15, 15): 9926, (41, 24, 23): 9879, (1, 0, 0): 9336, (34, 28, 25): 5922}, 1819: {(10, 11, 13): 10560, (31, 30, 28): 8163, (53, 43, 47): 4824, (11, 12, 16): 4687, (16, 16, 13): 4086, (73, 60, 61): 3830, (19, 17, 19): 3662}, 1800: {(11, 12, 11): 10234, (29, 24, 20): 9666, (33, 29, 26): 9512, (40, 34, 27): 7524, (25, 25, 25): 6728, (60, 53, 19): 5138, (13, 14, 14): 4584}, 1777: {(53, 44, 32): 6758, (46, 43, 32): 4753, (70, 60, 40): 4096, (89, 62, 37): 3994, (69, 58, 39): 3830, (171, 148, 117): 3367, (206, 182, 145): 3265}, 1804: {(27, 24, 18): 8912, (58, 61, 45): 7728, (39, 42, 30): 5365, (104, 90, 80): 5301, (110, 129, 122): 4682, (32, 27, 30): 3684, (57, 76, 81): 3337}, 1793: {(24, 22, 21): 8644, (13, 13, 11): 8470, (11, 13, 19): 4586, (94, 86, 63): 3474, (69, 80, 74): 3457, (44, 41, 32): 3264, (199, 185, 162): 3182}, 1771: {(21, 21, 20): 9256, (23, 11, 11): 7794, (26, 33, 30): 7691, (39, 21, 17): 4971, (41, 51, 44): 4949, (44, 30, 25): 4099, (56, 65, 68): 3946}, 1786: {(142, 133, 119): 4875, (225, 222, 203): 4361, (163, 138, 99): 3526, (161, 158, 148): 3413, (146, 145, 144): 3293, (112, 124, 140): 3279, (130, 107, 78): 3251}, 1822: {(6, 3, 5): 7874, (35, 37, 41): 4226, (59, 65, 63): 1542, (44, 33, 29): 1023, (149, 134, 110): 816, (107, 87, 71): 655, (109, 46, 36): 248}, 1792: {(94, 78, 62): 5422, (51, 45, 29): 5222, (27, 27, 22): 4140, (157, 160, 157): 3750, (207, 189, 155): 3701, (90, 76, 52): 3465, (74, 67, 52): 3296}, 1778: {(64, 63, 37): 4135, (20, 21, 16): 4095, (72, 56, 39): 3922, (151, 163, 156): 3919, (50, 60, 40): 3539, (70, 104, 78): 3527, (44, 38, 31): 3465}, 1823: {(6, 9, 10): 7619, (10, 19, 26): 7566, (28, 27, 32): 7047, (30, 30, 35): 6935, (30, 30, 26): 6726, (18, 4, 6): 6340, (35, 34, 32): 6330}, 1805: {(41, 47, 44): 8636, (43, 36, 33): 7710, (32, 28, 25): 6580, (31, 17, 16): 5439, (184, 166, 155): 3480, (30, 36, 36): 3435, (69, 49, 39): 2715}, 1779: {(24, 24, 23): 10561, (58, 45, 31): 6695, (36, 26, 11): 4788, (42, 38, 31): 4732, (115, 132, 128): 4723, (55, 43, 31): 4292, (61, 52, 37): 4200}, 1811: {(37, 26, 25): 8658, (7, 2, 3): 4699, (35, 20, 21): 3469, (54, 35, 33): 3405, (70, 54, 50): 2251, (93, 77, 68): 2161, (126, 101, 78): 1586}, 1794: {(18, 18, 18): 6244, (52, 43, 38): 3927, (21, 22, 24): 3922, (38, 31, 29): 3673,  ...

# %%
plot_color_distribution(colors_by_year_km, how='not_sorted', classifier='KMeans')
# Out:
# [1771, 1772, 1774, 1775, 1776, 1777, 1778, 1779, 1780, 1781, 1783, 1784, 1785, 1786, 1787, 1788, 1789, 1790, 1791, 1792, 1793, 1794, 1795, 1797, 1798, 1799, 1800, 1801, 1802, 1803, 1804, 1805, 1806, 1807, 1808, 1809, 1810, 1811, 1812, 1813, 1814, 1815, 1816, 1819, 1820, 1822, 1823, 1824, 1825, 1827, 1828]

# %% [markdown]
# Отсортировано по яркости:

# %%
plot_color_distribution(colors_by_year_km, how='sorted', classifier='KMeans')
# Out:
# [1771, 1772, 1774, 1775, 1776, 1777, 1778, 1779, 1780, 1781, 1783, 1784, 1785, 1786, 1787, 1788, 1789, 1790, 1791, 1792, 1793, 1794, 1795, 1797, 1798, 1799, 1800, 1801, 1802, 1803, 1804, 1805, 1806, 1807, 1808, 1809, 1810, 1811, 1812, 1813, 1814, 1815, 1816, 1819, 1820, 1822, 1823, 1824, 1825, 1827, 1828]

# %%
# colors_by_year_km

# %%
rows = []
for year, colors in colors_by_year_km.items():
    color_list = list(colors.items())[:7]  # Оставляем только 7 цветов
    row = [year]
    for i, ((r, g, b), count) in enumerate(color_list):
        row.extend([r, g, b, count])  # Добавляем R, G, B и Count
    rows.append(row)
    
columns = ['year']
for i in range(1, 8):  # 7 цветов
    columns.extend([f'R{i}', f'G{i}', f'B{i}', f'Count{i}'])

# Создаем DataFrame
df = pd.DataFrame(rows, columns=columns)
df.head()
# Out:
#    year   R1   G1   B1  Count1   R2   G2   B2  Count2   R3  ...   B5  Count5  \
# 0  1938  201  200  183    4054  146  149  141    3406   39  ...   97    1589
# 1  1895   59   61   58    7344   43   33   27    6505  212  ...   54    4498
# 2  1902   37   36   39    7135   18   24   31    6956   23  ...  171    4754
# 3  1893   15    8   10    7569   34   15   15    5083   33  ...   70    4076
# 4  1888   38   35   32    3126   76   68   57    2851  160  ...   41    2011
#
#     R6   G6   B6  Count6   R7   G7   B7  Count7
# 0  190  117   76    1460   99   56   54    1285
# 1   21   18   17    4462   49  119  166    4163
# 2  209  176  149    4731   22   32   38    4686
# 3  157  144  171    4014   63   61   45    3435
# 4  205  168  119    1766  202  151   80    1181
#
# [5 rows x 29 columns]

# %%
df_KMeans = pd.merge(df_KMeans, df, on='year', how='inner')
df_KMeans.head()
# Out:
#    year  (36, 35, 39)  (76, 70, 60)  (197, 189, 178)  (135, 123, 95)  \
# 0  1882          9503          3978              269             802
# 1  1883           252           884              463            2527
# 2  1885          6388          3420              602             407
# 3  1886          5862          1731              254             948
# 4  1888          2627          2598               22             990
#
#    (100, 117, 145)  (153, 80, 50)  (198, 159, 84)   R1   G1  ...   B5  Count5  \
# 0                0              5               7   44   58  ...   26    2584
# 1                0            189              68  165  129  ...  117    2070
# 2               22             49              29   33   42  ...  159     769
# 3               10            126              30   30   25  ...   70    1572
# 4                1            502            1049   38   35  ...   41    2011
#
#     R6   G6   B6  Count6   R7   G7   B7  Count7
# 0   49   42   35    2105  201  166  129    1593
# 1  224  210  194    1390   57   43   45     662
# 2  155  145  114     692  135   96   64     345
# 3  175  173  153    1112  103   93   78    1067
# 4  205  168  119    1766  202  151   80    1181
#
# [5 rows x 36 columns]

# %%
df_counts['year'] = df_counts['year'].astype(int)
df_KMeans = pd.merge(df_KMeans, df_counts, on='year', how='inner')

# %%
df_KMeans.head()
# Out:
#    year  (36, 35, 39)  (76, 70, 60)  (197, 189, 178)  (135, 123, 95)  \
# 0  1882          9503          3978              269             802
# 1  1883           252           884              463            2527
# 2  1885          6388          3420              602             407
# 3  1886          5862          1731              254             948
# 4  1888          2627          2598               22             990
#
#    (100, 117, 145)  (153, 80, 50)  (198, 159, 84)   R1   G1  ...  Count5   R6  \
# 0                0              5               7   44   58  ...    2584   49
# 1                0            189              68  165  129  ...    2070  224
# 2               22             49              29   33   42  ...     769  155
# 3               10            126              30   30   25  ...    1572  175
# 4                1            502            1049   38   35  ...    2011  205
#
#     G6   B6  Count6   R7   G7   B7  Count7  count
# 0   42   35    2105  201  166  129    1593      2
# 1  210  194    1390   57   43   45     662      1
# 2  145  114     692  135   96   64     345      1
# 3  173  153    1112  103   93   78    1067      1
# 4  168  119    1766  202  151   80    1181      1
#
# [5 rows x 37 columns]

# %%
df_KMeans.to_csv('data_KMeans.csv', index=False)

# %% [markdown]
# #### BayesianGaussianMixture:

# %%
colors_by_year_bgm = get_colors_by_year(folder_path, classifier='GMM')
# Out:
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/mixture/_base.py:269: ConvergenceWarning: Best performing initialization did not converge. Try different init parameters, or increase max_iter, tol, or check for degenerate data.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/mixture/_base.py:269: ConvergenceWarning: Best performing initialization did not converge. Try different init parameters, or increase max_iter, tol, or check for degenerate data.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/mixture/_base.py:269: ConvergenceWarning: Best performing initialization did not converge. Try different init parameters, or increase max_iter, tol, or check for degenerate data.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/mixture/_base.py:269: ConvergenceWarning: Best performing initialization did not converge. Try different init parameters, or increase max_iter, tol, or check for degenerate data.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/mixture/_base.py:269: ConvergenceWarning: Best performing initialization did not converge. Try different init parameters, or increase max_iter, tol, or check for degenerate data.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/mixture/_base.py:269: ConvergenceWarning: Best performing initialization did not converge. Try different init parameters, or increase max_iter, tol, or check for degenerate data.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/mixture/_base.py:269: ConvergenceWarning: Best performing initialization did not converge. Try different init parameters, or increase max_iter, tol, or check for degenerate data.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/mixture/_base.py:269: ConvergenceWarning: Best performing initialization did not converge. Try different init parameters, or increase max_iter, tol, or check for degenerate data.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/mixture/_base.py:269: ConvergenceWarning: Best performing initialization did not converge. Try different init parameters, or increase max_iter, tol, or check for degenerate data.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/mixture/_base.py:269: ConvergenceWarning: Best performing initialization did not converge. Try different init parameters, or increase max_iter, tol, or check for degenerate data.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/mixture/_base.py:269: ConvergenceWarning: Best performing initialization did not converge. Try different init parameters, or increase max_iter, tol, or check for degenerate data.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/mixture/_base.py:269: ConvergenceWarning: Best performing initialization did not converge. Try different init parameters, or increase max_iter, tol, or check for degenerate data.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/mixture/_base.py:269: ConvergenceWarning: Best performing initialization did not converge. Try different init parameters, or increase max_iter, tol, or check for degenerate data.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/mixture/_base.py:269: ConvergenceWarning: Best performing initialization did not converge. Try different init parameters, or increase max_iter, tol, or check for degenerate data.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/mixture/_base.py:269: ConvergenceWarning: Best performing initialization did not converge. Try different init parameters, or increase max_iter, tol, or check for degenerate data.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/mixture/_base.py:269: ConvergenceWarning: Best performing initialization did not converge. Try different init parameters, or increase max_iter, tol, or check for degenerate data.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/mixture/_base.py:269: ConvergenceWarning: Best performing initialization did not converge. Try different init parameters, or increase max_iter, tol, or check for degenerate data.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/mixture/_base.py:269: ConvergenceWarning: Best performing initialization did not converge. Try different init parameters, or increase max_iter, tol, or check for degenerate data.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/mixture/_base.py:269: ConvergenceWarning: Best performing initialization did not converge. Try different init parameters, or increase max_iter, tol, or check for degenerate data.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/mixture/_base.py:269: ConvergenceWarning: Best performing initialization did not converge. Try different init parameters, or increase max_iter, tol, or check for degenerate data.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/mixture/_base.py:269: ConvergenceWarning: Best performing initialization did not converge. Try different init parameters, or increase max_iter, tol, or check for degenerate data.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/mixture/_base.py:269: ConvergenceWarning: Best performing initialization did not converge. Try different init parameters, or increase max_iter, tol, or check for degenerate data.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/mixture/_base.py:269: ConvergenceWarning: Best performing initialization did not converge. Try different init parameters, or increase max_iter, tol, or check for degenerate data.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/mixture/_base.py:269: ConvergenceWarning: Best performing initialization did not converge. Try different init parameters, or increase max_iter, tol, or check for degenerate data.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/mixture/_base.py:269: ConvergenceWarning: Best performing initialization did not converge. Try different init parameters, or increase max_iter, tol, or check for degenerate data.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/mixture/_base.py:269: ConvergenceWarning: Best performing initialization did not converge. Try different init parameters, or increase max_iter, tol, or check for degenerate data.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/mixture/_base.py:269: ConvergenceWarning: Best performing initialization did not converge. Try different init parameters, or increase max_iter, tol, or check for degenerate data.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/mixture/_base.py:269: ConvergenceWarning: Best performing initialization did not converge. Try different init parameters, or increase max_iter, tol, or check for degenerate data.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/mixture/_base.py:269: ConvergenceWarning: Best performing initialization did not converge. Try different init parameters, or increase max_iter, tol, or check for degenerate data.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/mixture/_base.py:269: ConvergenceWarning: Best performing initialization did not converge. Try different init parameters, or increase max_iter, tol, or check for degenerate data.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/mixture/_base.py:269: ConvergenceWarning: Best performing initialization did not converge. Try different init parameters, or increase max_iter, tol, or check for degenerate data.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/mixture/_base.py:269: ConvergenceWarning: Best performing initialization did not converge. Try different init parameters, or increase max_iter, tol, or check for degenerate data.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/mixture/_base.py:269: ConvergenceWarning: Best performing initialization did not converge. Try different init parameters, or increase max_iter, tol, or check for degenerate data.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/mixture/_base.py:269: ConvergenceWarning: Best performing initialization did not converge. Try different init parameters, or increase max_iter, tol, or check for degenerate data.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/mixture/_base.py:269: ConvergenceWarning: Best performing initialization did not converge. Try different init parameters, or increase max_iter, tol, or check for degenerate data.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/mixture/_base.py:269: ConvergenceWarning: Best performing initialization did not converge. Try different init parameters, or increase max_iter, tol, or check for degenerate data.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/mixture/_base.py:269: ConvergenceWarning: Best performing initialization did not converge. Try different init parameters, or increase max_iter, tol, or check for degenerate data.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/mixture/_base.py:269: ConvergenceWarning: Best performing initialization did not converge. Try different init parameters, or increase max_iter, tol, or check for degenerate data.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/mixture/_base.py:269: ConvergenceWarning: Best performing initialization did not converge. Try different init parameters, or increase max_iter, tol, or check for degenerate data.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/mixture/_base.py:269: ConvergenceWarning: Best performing initialization did not converge. Try different init parameters, or increase max_iter, tol, or check for degenerate data.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/mixture/_base.py:269: ConvergenceWarning: Best performing initialization did not converge. Try different init parameters, or increase max_iter, tol, or check for degenerate data.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/mixture/_base.py:269: ConvergenceWarning: Best performing initialization did not converge. Try different init parameters, or increase max_iter, tol, or check for degenerate data.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/mixture/_base.py:269: ConvergenceWarning: Best performing initialization did not converge. Try different init parameters, or increase max_iter, tol, or check for degenerate data.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/mixture/_base.py:269: ConvergenceWarning: Best performing initialization did not converge. Try different init parameters, or increase max_iter, tol, or check for degenerate data.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/mixture/_base.py:269: ConvergenceWarning: Best performing initialization did not converge. Try different init parameters, or increase max_iter, tol, or check for degenerate data.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/mixture/_base.py:269: ConvergenceWarning: Best performing initialization did not converge. Try different init parameters, or increase max_iter, tol, or check for degenerate data.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/mixture/_base.py:269: ConvergenceWarning: Best performing initialization did not converge. Try different init parameters, or increase max_iter, tol, or check for degenerate data.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/mixture/_base.py:269: ConvergenceWarning: Best performing initialization did not converge. Try different init parameters, or increase max_iter, tol, or check for degenerate data.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/mixture/_base.py:269: ConvergenceWarning: Best performing initialization did not converge. Try different init parameters, or increase max_iter, tol, or check for degenerate data.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/mixture/_base.py:269: ConvergenceWarning: Best performing initialization did not converge. Try different init parameters, or increase max_iter, tol, or check for degenerate data.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/mixture/_base.py:269: ConvergenceWarning: Best performing initialization did not converge. Try different init parameters, or increase max_iter, tol, or check for degenerate data.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/mixture/_base.py:269: ConvergenceWarning: Best performing initialization did not converge. Try different init parameters, or increase max_iter, tol, or check for degenerate data.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/mixture/_base.py:269: ConvergenceWarning: Best performing initialization did not converge. Try different init parameters, or increase max_iter, tol, or check for degenerate data.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/mixture/_base.py:269: ConvergenceWarning: Best performing initialization did not converge. Try different init parameters, or increase max_iter, tol, or check for degenerate data.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/mixture/_base.py:269: ConvergenceWarning: Best performing initialization did not converge. Try different init parameters, or increase max_iter, tol, or check for degenerate data.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/mixture/_base.py:269: ConvergenceWarning: Best performing initialization did not converge. Try different init parameters, or increase max_iter, tol, or check for degenerate data.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/mixture/_base.py:269: ConvergenceWarning: Best performing initialization did not converge. Try different init parameters, or increase max_iter, tol, or check for degenerate data.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/mixture/_base.py:269: ConvergenceWarning: Best performing initialization did not converge. Try different init parameters, or increase max_iter, tol, or check for degenerate data.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/mixture/_base.py:269: ConvergenceWarning: Best performing initialization did not converge. Try different init parameters, or increase max_iter, tol, or check for degenerate data.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/mixture/_base.py:269: ConvergenceWarning: Best performing initialization did not converge. Try different init parameters, or increase max_iter, tol, or check for degenerate data.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/mixture/_base.py:269: ConvergenceWarning: Best performing initialization did not converge. Try different init parameters, or increase max_iter, tol, or check for degenerate data.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/mixture/_base.py:269: ConvergenceWarning: Best performing initialization did not converge. Try different init parameters, or increase max_iter, tol, or check for degenerate data.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/mixture/_base.py:269: ConvergenceWarning: Best performing initialization did not converge. Try different init parameters, or increase max_iter, tol, or check for degenerate data.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/mixture/_base.py:269: ConvergenceWarning: Best performing initialization did not converge. Try different init parameters, or increase max_iter, tol, or check for degenerate data.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/mixture/_base.py:269: ConvergenceWarning: Best performing initialization did not converge. Try different init parameters, or increase max_iter, tol, or check for degenerate data.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/mixture/_base.py:269: ConvergenceWarning: Best performing initialization did not converge. Try different init parameters, or increase max_iter, tol, or check for degenerate data.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/mixture/_base.py:269: ConvergenceWarning: Best performing initialization did not converge. Try different init parameters, or increase max_iter, tol, or check for degenerate data.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/mixture/_base.py:269: ConvergenceWarning: Best performing initialization did not converge. Try different init parameters, or increase max_iter, tol, or check for degenerate data.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/mixture/_base.py:269: ConvergenceWarning: Best performing initialization did not converge. Try different init parameters, or increase max_iter, tol, or check for degenerate data.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/mixture/_base.py:269: ConvergenceWarning: Best performing initialization did not converge. Try different init parameters, or increase max_iter, tol, or check for degenerate data.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/mixture/_base.py:269: ConvergenceWarning: Best performing initialization did not converge. Try different init parameters, or increase max_iter, tol, or check for degenerate data.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/mixture/_base.py:269: ConvergenceWarning: Best performing initialization did not converge. Try different init parameters, or increase max_iter, tol, or check for degenerate data.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/mixture/_base.py:269: ConvergenceWarning: Best performing initialization did not converge. Try different init parameters, or increase max_iter, tol, or check for degenerate data.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/mixture/_base.py:269: ConvergenceWarning: Best performing initialization did not converge. Try different init parameters, or increase max_iter, tol, or check for degenerate data.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/mixture/_base.py:269: ConvergenceWarning: Best performing initialization did not converge. Try different init parameters, or increase max_iter, tol, or check for degenerate data.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/mixture/_base.py:269: ConvergenceWarning: Best performing initialization did not converge. Try different init parameters, or increase max_iter, tol, or check for degenerate data.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/mixture/_base.py:269: ConvergenceWarning: Best performing initialization did not converge. Try different init parameters, or increase max_iter, tol, or check for degenerate data.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/mixture/_base.py:269: ConvergenceWarning: Best performing initialization did not converge. Try different init parameters, or increase max_iter, tol, or check for degenerate data.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/mixture/_base.py:269: ConvergenceWarning: Best performing initialization did not converge. Try different init parameters, or increase max_iter, tol, or check for degenerate data.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/mixture/_base.py:269: ConvergenceWarning: Best performing initialization did not converge. Try different init parameters, or increase max_iter, tol, or check for degenerate data.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/mixture/_base.py:269: ConvergenceWarning: Best performing initialization did not converge. Try different init parameters, or increase max_iter, tol, or check for degenerate data.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/mixture/_base.py:269: ConvergenceWarning: Best performing initialization did not converge. Try different init parameters, or increase max_iter, tol, or check for degenerate data.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/mixture/_base.py:269: ConvergenceWarning: Best performing initialization did not converge. Try different init parameters, or increase max_iter, tol, or check for degenerate data.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/mixture/_base.py:269: ConvergenceWarning: Best performing initialization did not converge. Try different init parameters, or increase max_iter, tol, or check for degenerate data.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/mixture/_base.py:269: ConvergenceWarning: Best performing initialization did not converge. Try different init parameters, or increase max_iter, tol, or check for degenerate data.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/mixture/_base.py:269: ConvergenceWarning: Best performing initialization did not converge. Try different init parameters, or increase max_iter, tol, or check for degenerate data.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/mixture/_base.py:269: ConvergenceWarning: Best performing initialization did not converge. Try different init parameters, or increase max_iter, tol, or check for degenerate data.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/mixture/_base.py:269: ConvergenceWarning: Best performing initialization did not converge. Try different init parameters, or increase max_iter, tol, or check for degenerate data.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/mixture/_base.py:269: ConvergenceWarning: Best performing initialization did not converge. Try different init parameters, or increase max_iter, tol, or check for degenerate data.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/mixture/_base.py:269: ConvergenceWarning: Best performing initialization did not converge. Try different init parameters, or increase max_iter, tol, or check for degenerate data.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/mixture/_base.py:269: ConvergenceWarning: Best performing initialization did not converge. Try different init parameters, or increase max_iter, tol, or check for degenerate data.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/mixture/_base.py:269: ConvergenceWarning: Best performing initialization did not converge. Try different init parameters, or increase max_iter, tol, or check for degenerate data.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/mixture/_base.py:269: ConvergenceWarning: Best performing initialization did not converge. Try different init parameters, or increase max_iter, tol, or check for degenerate data.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/mixture/_base.py:269: ConvergenceWarning: Best performing initialization did not converge. Try different init parameters, or increase max_iter, tol, or check for degenerate data.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/mixture/_base.py:269: ConvergenceWarning: Best performing initialization did not converge. Try different init parameters, or increase max_iter, tol, or check for degenerate data.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/mixture/_base.py:269: ConvergenceWarning: Best performing initialization did not converge. Try different init parameters, or increase max_iter, tol, or check for degenerate data.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/mixture/_base.py:269: ConvergenceWarning: Best performing initialization did not converge. Try different init parameters, or increase max_iter, tol, or check for degenerate data.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/mixture/_base.py:269: ConvergenceWarning: Best performing initialization did not converge. Try different init parameters, or increase max_iter, tol, or check for degenerate data.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/mixture/_base.py:269: ConvergenceWarning: Best performing initialization did not converge. Try different init parameters, or increase max_iter, tol, or check for degenerate data.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/mixture/_base.py:269: ConvergenceWarning: Best performing initialization did not converge. Try different init parameters, or increase max_iter, tol, or check for degenerate data.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/mixture/_base.py:269: ConvergenceWarning: Best performing initialization did not converge. Try different init parameters, or increase max_iter, tol, or check for degenerate data.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/mixture/_base.py:269: ConvergenceWarning: Best performing initialization did not converge. Try different init parameters, or increase max_iter, tol, or check for degenerate data.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/mixture/_base.py:269: ConvergenceWarning: Best performing initialization did not converge. Try different init parameters, or increase max_iter, tol, or check for degenerate data.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/mixture/_base.py:269: ConvergenceWarning: Best performing initialization did not converge. Try different init parameters, or increase max_iter, tol, or check for degenerate data.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/mixture/_base.py:269: ConvergenceWarning: Best performing initialization did not converge. Try different init parameters, or increase max_iter, tol, or check for degenerate data.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/mixture/_base.py:269: ConvergenceWarning: Best performing initialization did not converge. Try different init parameters, or increase max_iter, tol, or check for degenerate data.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/mixture/_base.py:269: ConvergenceWarning: Best performing initialization did not converge. Try different init parameters, or increase max_iter, tol, or check for degenerate data.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/mixture/_base.py:269: ConvergenceWarning: Best performing initialization did not converge. Try different init parameters, or increase max_iter, tol, or check for degenerate data.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/mixture/_base.py:269: ConvergenceWarning: Best performing initialization did not converge. Try different init parameters, or increase max_iter, tol, or check for degenerate data.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/mixture/_base.py:269: ConvergenceWarning: Best performing initialization did not converge. Try different init parameters, or increase max_iter, tol, or check for degenerate data.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/mixture/_base.py:269: ConvergenceWarning: Best performing initialization did not converge. Try different init parameters, or increase max_iter, tol, or check for degenerate data.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/mixture/_base.py:269: ConvergenceWarning: Best performing initialization did not converge. Try different init parameters, or increase max_iter, tol, or check for degenerate data.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/mixture/_base.py:269: ConvergenceWarning: Best performing initialization did not converge. Try different init parameters, or increase max_iter, tol, or check for degenerate data.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/mixture/_base.py:269: ConvergenceWarning: Best performing initialization did not converge. Try different init parameters, or increase max_iter, tol, or check for degenerate data.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/mixture/_base.py:269: ConvergenceWarning: Best performing initialization did not converge. Try different init parameters, or increase max_iter, tol, or check for degenerate data.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/mixture/_base.py:269: ConvergenceWarning: Best performing initialization did not converge. Try different init parameters, or increase max_iter, tol, or check for degenerate data.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/mixture/_base.py:269: ConvergenceWarning: Best performing initialization did not converge. Try different init parameters, or increase max_iter, tol, or check for degenerate data.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/mixture/_base.py:269: ConvergenceWarning: Best performing initialization did not converge. Try different init parameters, or increase max_iter, tol, or check for degenerate data.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/mixture/_base.py:269: ConvergenceWarning: Best performing initialization did not converge. Try different init parameters, or increase max_iter, tol, or check for degenerate data.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/mixture/_base.py:269: ConvergenceWarning: Best performing initialization did not converge. Try different init parameters, or increase max_iter, tol, or check for degenerate data.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/mixture/_base.py:269: ConvergenceWarning: Best performing initialization did not converge. Try different init parameters, or increase max_iter, tol, or check for degenerate data.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/mixture/_base.py:269: ConvergenceWarning: Best performing initialization did not converge. Try different init parameters, or increase max_iter, tol, or check for degenerate data.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/mixture/_base.py:269: ConvergenceWarning: Best performing initialization did not converge. Try different init parameters, or increase max_iter, tol, or check for degenerate data.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/mixture/_base.py:269: ConvergenceWarning: Best performing initialization did not converge. Try different init parameters, or increase max_iter, tol, or check for degenerate data.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/mixture/_base.py:269: ConvergenceWarning: Best performing initialization did not converge. Try different init parameters, or increase max_iter, tol, or check for degenerate data.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/mixture/_base.py:269: ConvergenceWarning: Best performing initialization did not converge. Try different init parameters, or increase max_iter, tol, or check for degenerate data.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/mixture/_base.py:269: ConvergenceWarning: Best performing initialization did not converge. Try different init parameters, or increase max_iter, tol, or check for degenerate data.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/mixture/_base.py:269: ConvergenceWarning: Best performing initialization did not converge. Try different init parameters, or increase max_iter, tol, or check for degenerate data.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/mixture/_base.py:269: ConvergenceWarning: Best performing initialization did not converge. Try different init parameters, or increase max_iter, tol, or check for degenerate data.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/mixture/_base.py:269: ConvergenceWarning: Best performing initialization did not converge. Try different init parameters, or increase max_iter, tol, or check for degenerate data.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/mixture/_base.py:269: ConvergenceWarning: Best performing initialization did not converge. Try different init parameters, or increase max_iter, tol, or check for degenerate data.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/mixture/_base.py:269: ConvergenceWarning: Best performing initialization did not converge. Try different init parameters, or increase max_iter, tol, or check for degenerate data.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/mixture/_base.py:269: ConvergenceWarning: Best performing initialization did not converge. Try different init parameters, or increase max_iter, tol, or check for degenerate data.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/mixture/_base.py:269: ConvergenceWarning: Best performing initialization did not converge. Try different init parameters, or increase max_iter, tol, or check for degenerate data.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/mixture/_base.py:269: ConvergenceWarning: Best performing initialization did not converge. Try different init parameters, or increase max_iter, tol, or check for degenerate data.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/mixture/_base.py:269: ConvergenceWarning: Best performing initialization did not converge. Try different init parameters, or increase max_iter, tol, or check for degenerate data.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/mixture/_base.py:269: ConvergenceWarning: Best performing initialization did not converge. Try different init parameters, or increase max_iter, tol, or check for degenerate data.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/mixture/_base.py:269: ConvergenceWarning: Best performing initialization did not converge. Try different init parameters, or increase max_iter, tol, or check for degenerate data.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/mixture/_base.py:269: ConvergenceWarning: Best performing initialization did not converge. Try different init parameters, or increase max_iter, tol, or check for degenerate data.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/mixture/_base.py:269: ConvergenceWarning: Best performing initialization did not converge. Try different init parameters, or increase max_iter, tol, or check for degenerate data.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/mixture/_base.py:269: ConvergenceWarning: Best performing initialization did not converge. Try different init parameters, or increase max_iter, tol, or check for degenerate data.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/mixture/_base.py:269: ConvergenceWarning: Best performing initialization did not converge. Try different init parameters, or increase max_iter, tol, or check for degenerate data.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/mixture/_base.py:269: ConvergenceWarning: Best performing initialization did not converge. Try different init parameters, or increase max_iter, tol, or check for degenerate data.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/mixture/_base.py:269: ConvergenceWarning: Best performing initialization did not converge. Try different init parameters, or increase max_iter, tol, or check for degenerate data.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/mixture/_base.py:269: ConvergenceWarning: Best performing initialization did not converge. Try different init parameters, or increase max_iter, tol, or check for degenerate data.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/mixture/_base.py:269: ConvergenceWarning: Best performing initialization did not converge. Try different init parameters, or increase max_iter, tol, or check for degenerate data.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/mixture/_base.py:269: ConvergenceWarning: Best performing initialization did not converge. Try different init parameters, or increase max_iter, tol, or check for degenerate data.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/mixture/_base.py:269: ConvergenceWarning: Best performing initialization did not converge. Try different init parameters, or increase max_iter, tol, or check for degenerate data.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/mixture/_base.py:269: ConvergenceWarning: Best performing initialization did not converge. Try different init parameters, or increase max_iter, tol, or check for degenerate data.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/mixture/_base.py:269: ConvergenceWarning: Best performing initialization did not converge. Try different init parameters, or increase max_iter, tol, or check for degenerate data.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/mixture/_base.py:269: ConvergenceWarning: Best performing initialization did not converge. Try different init parameters, or increase max_iter, tol, or check for degenerate data.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/mixture/_base.py:269: ConvergenceWarning: Best performing initialization did not converge. Try different init parameters, or increase max_iter, tol, or check for degenerate data.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/mixture/_base.py:269: ConvergenceWarning: Best performing initialization did not converge. Try different init parameters, or increase max_iter, tol, or check for degenerate data.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/mixture/_base.py:269: ConvergenceWarning: Best performing initialization did not converge. Try different init parameters, or increase max_iter, tol, or check for degenerate data.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/mixture/_base.py:269: ConvergenceWarning: Best performing initialization did not converge. Try different init parameters, or increase max_iter, tol, or check for degenerate data.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/mixture/_base.py:269: ConvergenceWarning: Best performing initialization did not converge. Try different init parameters, or increase max_iter, tol, or check for degenerate data.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/mixture/_base.py:269: ConvergenceWarning: Best performing initialization did not converge. Try different init parameters, or increase max_iter, tol, or check for degenerate data.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/mixture/_base.py:269: ConvergenceWarning: Best performing initialization did not converge. Try different init parameters, or increase max_iter, tol, or check for degenerate data.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/mixture/_base.py:269: ConvergenceWarning: Best performing initialization did not converge. Try different init parameters, or increase max_iter, tol, or check for degenerate data.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/mixture/_base.py:269: ConvergenceWarning: Best performing initialization did not converge. Try different init parameters, or increase max_iter, tol, or check for degenerate data.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/mixture/_base.py:269: ConvergenceWarning: Best performing initialization did not converge. Try different init parameters, or increase max_iter, tol, or check for degenerate data.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/mixture/_base.py:269: ConvergenceWarning: Best performing initialization did not converge. Try different init parameters, or increase max_iter, tol, or check for degenerate data.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/mixture/_base.py:269: ConvergenceWarning: Best performing initialization did not converge. Try different init parameters, or increase max_iter, tol, or check for degenerate data.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/mixture/_base.py:269: ConvergenceWarning: Best performing initialization did not converge. Try different init parameters, or increase max_iter, tol, or check for degenerate data.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/mixture/_base.py:269: ConvergenceWarning: Best performing initialization did not converge. Try different init parameters, or increase max_iter, tol, or check for degenerate data.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/mixture/_base.py:269: ConvergenceWarning: Best performing initialization did not converge. Try different init parameters, or increase max_iter, tol, or check for degenerate data.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/mixture/_base.py:269: ConvergenceWarning: Best performing initialization did not converge. Try different init parameters, or increase max_iter, tol, or check for degenerate data.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/mixture/_base.py:269: ConvergenceWarning: Best performing initialization did not converge. Try different init parameters, or increase max_iter, tol, or check for degenerate data.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/mixture/_base.py:269: ConvergenceWarning: Best performing initialization did not converge. Try different init parameters, or increase max_iter, tol, or check for degenerate data.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/mixture/_base.py:269: ConvergenceWarning: Best performing initialization did not converge. Try different init parameters, or increase max_iter, tol, or check for degenerate data.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/mixture/_base.py:269: ConvergenceWarning: Best performing initialization did not converge. Try different init parameters, or increase max_iter, tol, or check for degenerate data.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/mixture/_base.py:269: ConvergenceWarning: Best performing initialization did not converge. Try different init parameters, or increase max_iter, tol, or check for degenerate data.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/mixture/_base.py:269: ConvergenceWarning: Best performing initialization did not converge. Try different init parameters, or increase max_iter, tol, or check for degenerate data.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/mixture/_base.py:269: ConvergenceWarning: Best performing initialization did not converge. Try different init parameters, or increase max_iter, tol, or check for degenerate data.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/mixture/_base.py:269: ConvergenceWarning: Best performing initialization did not converge. Try different init parameters, or increase max_iter, tol, or check for degenerate data.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/mixture/_base.py:269: ConvergenceWarning: Best performing initialization did not converge. Try different init parameters, or increase max_iter, tol, or check for degenerate data.
#   warnings.warn(
# {1799: {(23, 23, 22): 10042, (74, 61, 50): 6062, (42, 31, 33): 4426, (36, 26, 29): 4257, (15, 17, 16): 4164, (83, 52, 41): 3899, (111, 133, 127): 3855}, 1775: {(98, 130, 177): 5230, (104, 85, 49): 5163, (84, 79, 54): 4727, (86, 77, 42): 4408, (63, 55, 34): 4378, (131, 156, 159): 3866, (67, 53, 22): 3478}, 1812: {(46, 47, 39): 8914, (37, 42, 52): 8831, (3, 1, 1): 6729, (10, 10, 8): 6370, (90, 97, 90): 6255, (31, 29, 25): 6210, (6, 6, 3): 6147}, 1787: {(86, 80, 47): 5624, (79, 138, 156): 5436, (100, 69, 65): 4449, (70, 60, 40): 4446, (124, 127, 116): 4387, (198, 169, 156): 3815, (77, 108, 118): 3706}, 1814: {(39, 36, 37): 9608, (84, 75, 71): 8256, (9, 11, 11): 7304, (88, 71, 67): 6349, (39, 48, 47): 5161, (86, 65, 51): 4992, (83, 58, 51): 4910}, 1795: {(19, 10, 6): 6472, (37, 37, 33): 6049, (138, 144, 143): 5985, (80, 85, 77): 5336, (9, 11, 8): 4679, (251, 230, 197): 4641, (98, 96, 70): 4562}, 1820: {(0, 0, 0): 12237, (8, 9, 10): 6025, (41, 38, 34): 4798, (22, 19, 14): 4260, (36, 33, 28): 3813, (44, 38, 31): 3638, (64, 55, 43): 3479}, 1783: {(10, 12, 12): 8867, (7, 8, 7): 8067, (1, 5, 9): 7668, (27, 26, 25): 7500, (40, 34, 32): 4664, (54, 58, 51): 4248, (143, 148, 145): 4148}, 1806: {(8, 10, 9): 7508, (59, 58, 29): 5582, (13, 12, 14): 3894, (19, 15, 16): 3557, (47, 39, 33): 3554, (88, 69, 62): 3193, (120, 90, 69): 2949}, 1815: {(115, 112, 106): 7326, (49, 54, 58): 5834, (45, 31, 27): 5559, (53, 50, 45): 4893, (86, 74, 59): 4184, (45, 33, 32): 3759, (26, 24, 23): 3612}, 1789: {(65, 42, 33): 5675, (22, 22, 18): 5547, (119, 109, 96): 4887, (179, 168, 156): 4794, (31, 29, 23): 4267, (99, 78, 54): 4264, (85, 82, 68): 4240}, 1798: {(11, 12, 8): 9871, (1, 0, 0): 8889, (39, 23, 23): 7045, (16, 14, 15): 6692, (47, 47, 41): 5501, (4, 4, 5): 5478, (158, 145, 138): 5402}, 1819: {(7, 8, 10): 7329, (31, 31, 29): 6672, (50, 42, 45): 6108, (49, 48, 47): 4017, (6, 7, 12): 3510, (68, 54, 56): 3172, (136, 126, 119): 2989}, 1800: {(33, 29, 26): 9240, (36, 31, 26): 7438, (9, 11, 10): 7244, (33, 26, 23): 5032, (59, 51, 17): 4695, (81, 71, 61): 4122, (155, 136, 108): 3984}, 1777: {(53, 47, 33): 6503, (50, 47, 33): 4166, (153, 154, 138): 4050, (98, 79, 64): 3885, (142, 134, 112): 3858, (128, 121, 80): 3789, (61, 46, 28): 3736}, 1804: {(27, 24, 17): 7825, (57, 60, 45): 6085, (40, 43, 31): 5448, (112, 132, 126): 4627, (84, 70, 60): 3922, (105, 94, 84): 3631, (73, 45, 47): 3437}, 1793: {(9, 9, 8): 5938, (92, 84, 62): 5635, (18, 18, 18): 4764, (122, 109, 93): 4650, (49, 62, 70): 4638, (198, 180, 150): 4054, (30, 27, 26): 3914}, 1771: {(26, 35, 32): 7946, (16, 17, 17): 5238, (64, 44, 28): 4845, (21, 9, 10): 4790, (30, 17, 16): 4205, (25, 26, 23): 3796, (57, 65, 69): 3563}, 1786: {(174, 171, 167): 4798, (164, 155, 115): 4507, (141, 135, 122): 4308, (76, 63, 47): 4141, (65, 71, 57): 3971, (230, 225, 204): 3557, (186, 185, 177): 3271}, 1822: {(1, 0, 0): 5034, (35, 37, 41): 4055, (12, 6, 9): 2200, (57, 43, 37): 2085, (49, 54, 54): 1742, (133, 123, 102): 1031, (101, 40, 32): 237}, 1792: {(85, 75, 51): 4189, (28, 29, 23): 3967, (75, 65, 48): 3808, (136, 131, 106): 3555, (95, 79, 64): 3494, (163, 146, 127): 3474, (73, 59, 43): 3437}, 1778: {(87, 114, 80): 4102, (161, 153, 128): 4012, (75, 49, 35): 3793, (48, 57, 37): 3733, (106, 96, 45): 3354, (105, 87, 51): 3270, (49, 42, 29): 3045}, 1823: {(9, 17, 23): 10293, (37, 37, 34): 8562, (44, 43, 39): 6626, (133, 112, 65): 6224, (58, 51, 31): 5989, (31, 30, 36): 5869, (28, 27, 32): 5491}, 1805: {(40, 47, 44): 8848, (40, 32, 27): 5338, (66, 64, 66): 4550, (28, 26, 24): 4159, (80, 52, 44): 3821, (37, 21, 19): 3568, (44, 34, 29): 3477}, 1779: {(24, 24, 23): 7897, (61, 46, 33): 5304, (60, 47, 34): 4934, (114, 132, 128): 4498, (27, 27, 24): 4426, (69, 47, 31): 4423, (61, 55, 32): 4308}, 1811: {(36, 26, 25): 7730, (43, 25, 25): 4271, (4, 1, 1): 3735, (59, 42, 40): 3546, (123, 103, 84): 3022, (89, 73, 66): 2624, (50, 37, 31): 1888}, 1794: {(57, 48, 43): 5334, (16, 16, 16): 5243, (42, 44, 48): 4674, (31, 31, 25): 4477, (91, 88,  ...

# %%
plot_color_distribution(colors_by_year_bgm, classifier='GMM', how='not_sorted')
# Out:
# [1771, 1772, 1774, 1775, 1776, 1777, 1778, 1779, 1780, 1781, 1783, 1784, 1785, 1786, 1787, 1788, 1789, 1790, 1791, 1792, 1793, 1794, 1795, 1797, 1798, 1799, 1800, 1801, 1802, 1803, 1804, 1805, 1806, 1807, 1808, 1809, 1810, 1811, 1812, 1813, 1814, 1815, 1816, 1819, 1820, 1822, 1823, 1824, 1825, 1827, 1828]

# %% [markdown]
# Отсортировано по яркости:

# %%
plot_color_distribution(colors_by_year_bgm, how='sorted', classifier='GMM')
# Out:
# [1771, 1772, 1774, 1775, 1776, 1777, 1778, 1779, 1780, 1781, 1783, 1784, 1785, 1786, 1787, 1788, 1789, 1790, 1791, 1792, 1793, 1794, 1795, 1797, 1798, 1799, 1800, 1801, 1802, 1803, 1804, 1805, 1806, 1807, 1808, 1809, 1810, 1811, 1812, 1813, 1814, 1815, 1816, 1819, 1820, 1822, 1823, 1824, 1825, 1827, 1828]

# %%
rows = []
for year, colors in colors_by_year_bgm.items():
    color_list = list(colors.items())[:7]  # Оставляем только 7 цветов
    row = [year]
    for i, ((r, g, b), count) in enumerate(color_list):
        row.extend([r, g, b, count])  # Добавляем R, G, B и Count
    rows.append(row)
    
columns = ['year']
for i in range(1, 8):  # 7 цветов
    columns.extend([f'R{i}', f'G{i}', f'B{i}', f'Count{i}'])

# Создаем DataFrame
df = pd.DataFrame(rows, columns=columns)
df.head()
# Out:
#    year   R1   G1   B1  Count1   R2   G2   B2  Count2   R3  ...  B5  Count5  \
# 0  1938  187  193  181    4209  134  131  127    3502   34  ...  55    1773
# 1  1895   58   60   58    5745  212  121   72    5558   48  ...  21    4262
# 2  1902   19   27   35    6699   34   34   37    5286  179  ...  45    4358
# 3  1893  116   98   84    5873   36   15   14    5363    9  ...  35    4438
# 4  1888   65   61   53    3415  113   96   66    3336  134  ...  34    2058
#
#     R6   G6   B6  Count6   R7   G7   B7  Count7
# 0  227  202  107    1413   84  119  115    1327
# 1   77   97  131    4215   67   61   54    3840
# 2  211  174  147    4336  215  194  187    4202
# 3  168  154  178    4128  165  113   77    4076
# 4  178  144   87    1979  143   83   37     767
#
# [5 rows x 29 columns]

# %%
df_BGM = pd.merge(df_BGM, df, on='year', how='inner')
df_BGM.head()
# Out:
#    year  (126, 124, 113)  (51, 50, 49)  (125, 78, 53)  (199, 164, 114)  \
# 0  1882              471         11074            229             1465
# 1  1883              814           321           1403             1988
# 2  1885              577          6982            126              103
# 3  1886              307          5684            612              469
# 4  1888              333          2897           1588             1141
#
#    (201, 195, 184)  (21, 22, 24)  (55, 73, 93)   R1   G1  ...   B5  Count5  \
# 0              303         11192          1388   41   56  ...   22    2946
# 1              492           135            17  178  147  ...  198    1148
# 2              561          2532           481   66   72  ...  176    1061
# 3              154          4721           477   44   50  ...  128    2013
# 4               20          1710            20   65   61  ...   34    2058
#
#     R6   G6   B6  Count6   R7  G7  B7  Count7
# 0  195  161  125    2053   93  81  74    1882
# 1  195  148  122     576   56  43  46     521
# 2  137  122   99     912   84  59  43     350
# 3  146  161  147     532  121  77  57     299
# 4  178  144   87    1979  143  83  37     767
#
# [5 rows x 36 columns]

# %%
df_counts['year'] = df_counts['year'].astype(int)
df_BGM = pd.merge(df_BGM, df_counts, on='year', how='inner')

# %%
df_BGM.head()
# Out:
#    year  (126, 124, 113)  (51, 50, 49)  (125, 78, 53)  (199, 164, 114)  \
# 0  1882              471         11074            229             1465
# 1  1883              814           321           1403             1988
# 2  1885              577          6982            126              103
# 3  1886              307          5684            612              469
# 4  1888              333          2897           1588             1141
#
#    (201, 195, 184)  (21, 22, 24)  (55, 73, 93)   R1   G1  ...  Count5   R6  \
# 0              303         11192          1388   41   56  ...    2946  195
# 1              492           135            17  178  147  ...    1148  195
# 2              561          2532           481   66   72  ...    1061  137
# 3              154          4721           477   44   50  ...    2013  146
# 4               20          1710            20   65   61  ...    2058  178
#
#     G6   B6  Count6   R7  G7  B7  Count7  count
# 0  161  125    2053   93  81  74    1882      2
# 1  148  122     576   56  43  46     521      1
# 2  122   99     912   84  59  43     350      1
# 3  161  147     532  121  77  57     299      1
# 4  144   87    1979  143  83  37     767      1
#
# [5 rows x 37 columns]

# %%
df_BGM.to_csv('data_BGM.csv', index=False)
