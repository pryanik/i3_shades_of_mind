# %%
import cv2
import os
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from pprint import pprint
import pandas as pd
from sklearn.mixture import GaussianMixture
from sklearn.mixture import BayesianGaussianMixture
# from sklearn.cluster import DBSCAN
from sklearn.cluster import KMeans
from collections import Counter
from skimage import color as scolor
from PIL import Image
from datetime import datetime
from dotenv import load_dotenv

# %%
load_dotenv()
folder_path = os.getenv('path_vrubel_pics')
# df_lines_circles = os.getenv('dataset_lines_circles')
# folder_path = './data/paintings'
# folder_path

# %%
files = os.listdir(folder_path)
target_files = []
for f in files:
    if ('.jpg' in f) or ('.jpeg' in f):
        target_files.append(os.path.join(folder_path, f))

print('Количество картин в датасете:', len(target_files))
# Out:
# Количество картин в датасете: 133

# %% [markdown]
# ### Смотрим, сколько картин художник написал за каждый год жизни

# %%
dates = []
for i in target_files:
    date = i.split('/')[-1].split('_')[0]
    dates.append(date)

# %%
from collections import Counter

year_counts = dict(Counter(dates))
del year_counts['yyyy']

# %%
df = pd.DataFrame(dates, columns=['year'])
df.shape
# Out:
# (133, 1)

# %%
df['unknown'] = df.year.apply(lambda x: True if x == 'yyyy' else False)
df.unknown.value_counts()
# Out:
# unknown
# False    128
# True       5
# Name: count, dtype: int64

# %%
result = df.groupby('year', as_index=False).agg({'unknown': 'count'}).rename(columns={'unknown': 'count'})

# %%
mask = df[df.unknown == False].year.to_list()
mask.sort()
# mask

# %%
mask.extend(['yyyy' for _ in range(4)])
len(mask)
# Out:
# 132

# %%
sns.set_theme(style="white")

# %%
plt.rcParams['font.family'] = 'serif'
plt.rcParams['font.serif'] = ['Times New Roman']

plt.figure(figsize=(15, 8))

color_hex = '#{:02x}{:02x}{:02x}'.format(102, 118, 146)
bar_plot = sns.barplot(data=result, x='year', y='count', color=color_hex, order=mask)

plt.title('Распределение картин по годам', fontdict={'fontsize': 16, 'fontweight': 'bold'})
plt.xlabel('Год', fontdict={'fontsize': 12})
plt.ylabel('Количество картин', fontdict={'fontsize': 12})
plt.xticks(rotation=45)


for p in bar_plot.patches:
    bar_plot.annotate(format(int(p.get_height())), 
                        (p.get_x() + p.get_width() / 2., p.get_height()), 
                        ha='center', va='bottom', fontsize=10, color='black', 
                        xytext=(0, 5), textcoords='offset points')

plt.show()

# %%
df_counts = pd.DataFrame(year_counts.items(), columns=['year', 'count'])
df_counts.head()
# Out:
#    year  count
# 0  1890     12
# 1  1897      6
# 2  1901      3
# 3  1894      5
# 4  1891      5

# %% [markdown]
# ### Смотрим 7 самых часто встречающихся диапазонов цветов на всех картинках

# %%
def rgb_to_lab(rgb_array):

    rgb_array = rgb_array / 255.0  # normalizing RGB
    lab_array = scolor.rgb2lab(rgb_array)
    
    return lab_array

# %%
def get_pixels_from_folder(folder_path, rgb_lab):

    all_pixels = []

    for filename in os.listdir(folder_path):
        if filename.lower().endswith(('.png', '.jpg', '.jpeg')):
            image_path = os.path.join(folder_path, filename)
            try:
                img = Image.open(image_path).convert('RGB')
                img = img.resize((128, 128))
                pixels = np.array(img)
                all_pixels.append(pixels.reshape(-1, 3))

            except Exception as e:
                print(f"Can't open {filename}: {e}")

    # combine all pixels into one vector
    if all_pixels:
        rgb_vector = np.vstack(all_pixels) 
        if rgb_lab == 'RGB':
            return rgb_vector
        elif rgb_lab == 'LAB':
            lab_vector = rgb_to_lab(rgb_vector)
            return lab_vector
    else:
        return np.array([])

# %%
# finding the n most common color ranges in the !RGB vector! and sort them by frequency
def find_most_common_colors(vector, rgb_lab, classifier_type, n_colors=7):
    
    if vector.size == 0:
        print("Vector is empty")
        return []

    if classifier_type == 'KMeans':
        results_cluster = KMeans(n_clusters=n_colors)
        results_cluster.fit(vector)
        colors = results_cluster.cluster_centers_
    elif classifier_type == 'GM':
        results_cluster = GaussianMixture(n_components=n_colors, random_state=42)
        results_cluster.fit(vector)
        colors = results_cluster.means_
        labels = results_cluster.predict(vector) # 'GaussianMixture' object has no attribute 'labels_'
    elif classifier_type == 'GMM':
        gmm = BayesianGaussianMixture(n_components=n_colors, random_state=42)
        gmm.fit(vector)
        colors = gmm.means_
        labels = gmm.predict(vector)
        
        
    # colors = results_cluster.cluster_centers_
    
    if rgb_lab == 'LAB':
        rgb_colors = scolor.lab2rgb(colors.reshape(1, -1, 3)).reshape(-1, 3) * 255 # LAB to RGB
    elif rgb_lab == 'RGB':
        rgb_colors = colors        
    rgb_colors = np.clip(rgb_colors, 0, 255).astype(int)

    # counting pixels of each cluster by color
    if classifier_type == 'KMeans':
        labels = results_cluster.labels_
        label_counts = Counter(labels)
    elif classifier_type == 'GM':
        label_counts = Counter(labels)
    elif classifier_type == 'GMM':
        # labels = gmm.predict(lab_vector)
        label_counts = Counter(labels)

    sorted_colors = sorted(label_counts.items(), key=lambda x: x[1], reverse=True)
    sorted_rgb_colors = rgb_colors[[color[0] for color in sorted_colors]]

    return sorted_rgb_colors

# %%
def plot_colors(colors):
    plt.figure(figsize=(15, 6))
    plt.imshow([colors], aspect='auto')
    
    for i, color in enumerate(colors):
        plt.text(i, 0, str(i+1), ha='center', va='center', fontsize=20, color='white')
    
    plt.axis('off')
    plt.show()

# %% [markdown]
# ##### Без перевода из RGB в Lab с помощью KMeans:

# %%
pixels_vector = get_pixels_from_folder(folder_path, rgb_lab='RGB')

# %%
most_common_colors_nolab = find_most_common_colors(pixels_vector, rgb_lab='RGB', classifier_type='KMeans', n_colors=7)

# %%
most_common_colors_nolab
# Out:
# array([[ 67,  58,  51],
#        [100,  87,  75],
#        [135, 118, 100],
#        [ 34,  30,  27],
#        [170, 152, 127],
#        [200, 188, 169],
#        [236, 233, 225]])

# %%
print("Семь самых распространенных цветов (RGB):")
c = 1
for i in most_common_colors_nolab:
    print(f'Цвет {c}: {i}')
    c += 1

plot_colors(most_common_colors_nolab)
# Out:
# Семь самых распространенных цветов (RGB):
# Цвет 1: [67 58 51]
# Цвет 2: [100  87  75]
# Цвет 3: [135 118 100]
# Цвет 4: [34 30 27]
# Цвет 5: [170 152 127]
# Цвет 6: [200 188 169]
# Цвет 7: [236 233 225]

# %% [markdown]
# ##### С переводом из RGB в LAB с помощью KMeans:

# %%
pixels_vector = get_pixels_from_folder(folder_path, rgb_lab='LAB')

# %%
most_common_colors = find_most_common_colors(pixels_vector, rgb_lab='LAB', classifier_type='KMeans', n_colors=7)

# %%
print("Семь самых распространенных цветов (RGB -> LAB -> RGB):")
c = 1
for i in most_common_colors:
    print(f'Цвет {c}: {i}')
    c += 1

plot_colors(most_common_colors)
# Out:
# Семь самых распространенных цветов (RGB -> LAB -> RGB):
# Цвет 1: [40 36 35]
# Цвет 2: [80 68 55]
# Цвет 3: [144 136 124]
# Цвет 4: [ 91  93 100]
# Цвет 5: [214 208 198]
# Цвет 6: [134  91  64]
# Цвет 7: [189 160 109]

# %% [markdown]
# ##### С переводом из RGB в LAB с помощью GaussianMixture:

# %%
pixels_vector = get_pixels_from_folder(folder_path, rgb_lab='LAB')

# %%
most_common_colors_gauss = find_most_common_colors(pixels_vector, rgb_lab='LAB', classifier_type='GM', n_colors=7)

# %%
print("Семь самых распространенных цветов (RGB):")
c = 1
for i in most_common_colors_gauss:
    print(f'Цвет {c}: {i}')
    c += 1

plot_colors(most_common_colors_gauss)
# Out:
# Семь самых распространенных цветов (RGB):
# Цвет 1: [74 64 57]
# Цвет 2: [144 131 116]
# Цвет 3: [39 38 36]
# Цвет 4: [121  88  67]
# Цвет 5: [213 206 194]
# Цвет 6: [183 156 112]
# Цвет 7: [102 101 105]

# %% [markdown]
# ##### С переводом из RGB в LAB с помощью BayesianGaussianMixture:

# %%
pixels_vector = get_pixels_from_folder(folder_path, rgb_lab='LAB')

# %%
most_common_colors_gaussbayes = find_most_common_colors(pixels_vector, rgb_lab='LAB', classifier_type='GMM', n_colors=7)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/mixture/_base.py:269: ConvergenceWarning: Best performing initialization did not converge. Try different init parameters, or increase max_iter, tol, or check for degenerate data.
#   warnings.warn(

# %%
print("Семь самых распространенных цветов (RGB):")
c = 1
for i in most_common_colors_gaussbayes:
    print(f'Цвет {c}: {i}')
    c += 1

plot_colors(most_common_colors_gaussbayes)
# Out:
# Семь самых распространенных цветов (RGB):
# Цвет 1: [162 152 138]
# Цвет 2: [65 61 59]
# Цвет 3: [93 72 56]
# Цвет 4: [179 135  97]
# Цвет 5: [30 29 28]
# Цвет 6: [114 118 111]
# Цвет 7: [248 248 248]

# %% [markdown]
# ### Смотрим, как часто эти цвета встречаются по годам

# %%
def sum_pixels_by_year(results, years):

    summed_results = {color: [] for color in results.keys()}
    unique_years = sorted(list(set(years)))

    for year in unique_years:
        indices = [i for i, y in enumerate(years) if y == year]
        for color in results.keys():
            summed_value = np.sum([results[color][i] for i in indices])
            summed_results[color].append(summed_value)

    return summed_results, unique_years

# %%
def min_max_normalization(data):
    min_val = min(data)
    max_val = max(data)
    return [(x - min_val) / (max_val - min_val) for x in data]

# %%
def count_pixels_in_range(image_path, color, tolerance=20):
    img = Image.open(image_path).convert('RGB')
    img = img.resize((128, 128))
    img_array = np.array(img)

    # defining the boundaries for each channel
    lower_bound = np.array(color) - tolerance
    upper_bound = np.array(color) + tolerance

    # mask for pixels falling within the range
    mask = np.all((img_array >= lower_bound) & (img_array <= upper_bound), axis=-1)

    return np.sum(mask)  # number of pixels corresponding to color

# %%
def extract_date_from_filename(filename):
    try:
        year, month, day = map(int, filename.split('_')[:3])
        return datetime(year, month, day)
    except (IndexError, ValueError):
        return None
    
def extract_year_from_filename(filename):
    try:
        year = int(filename.split('_')[0])
        return year
    except (IndexError, ValueError):
        return None

# %%
# analyzing the images in the specified folder and returns the number of pixels for each color
def analyze_most_popular_ever_colors(folder_path, colors):

    results = {tuple(color): [] for color in colors}
    years = []
    files = []

    for filename in sorted(os.listdir(folder_path)):
        if filename.lower().endswith(('.png', '.jpg', '.jpeg', '.bmp', '.gif')):
            # files.append(filename)
            image_path = os.path.join(folder_path, filename)
            
            year = extract_year_from_filename(filename)
            if year is None:
                continue
            years.append(year)
            files.append(filename)

            pixel_counts = []
            for color in colors:
                count = count_pixels_in_range(image_path, color, tolerance=20)
                pixel_counts.append(count)

            for i, color in enumerate(colors):
                results[tuple(color)].append(pixel_counts[i])

    # converting the results into a numpy array for sorting
    # years = np.array(years)
    # for color in results:
    #     results[color] = np.array(results[color])

    # # sorting by year
    # sorted_indices = np.argsort(years)
    # years = years[sorted_indices]
    # for color in results:
    #     results[color] = results[color][sorted_indices]

    return results, years, files

# %%
def plot_bar_distribution(results, years, model_name):
    
    results, years = sum_pixels_by_year(results, years)

    colors = list(results.keys())
    counts = np.array(list(results.values()))

    year_pixel_counts = {year: np.zeros(len(colors)) for year in years}

    # sum pixels by year
    for i, year in enumerate(years):
        for j, color in enumerate(colors):
            year_pixel_counts[year][j] += counts[j][i]

    # converting the data into an array to build a graph
    summed_counts = np.array(list(year_pixel_counts.values()))
    summed_counts = summed_counts / summed_counts.sum(axis=1, keepdims=True)

    # convert colors to format for matplotlib (from 0 to 1)
    color_palette = [(r/255, g/255, b/255) for r, g, b in colors]

    sns.set_theme(style="white")
    
    plt.rcParams['font.family'] = 'serif'
    plt.rcParams['font.serif'] = ['Times New Roman']
    
    plt.figure(figsize=(15, 10))

    bottom = np.zeros(len(years))
    for i, color in enumerate(colors):
        plt.bar(range(len(years)), summed_counts[:, i], bottom=bottom, color=color_palette[i], label=f'Color {color}')
        bottom += summed_counts[:, i]  # update the lower limit for accumulation

    plt.title(f'Распределение 7 самых часто встречающихся цветов по годам ({model_name})', fontdict={'fontsize': 16, 'fontweight': 'bold'})
    plt.xlabel('Год', fontdict={'fontsize': 12})
    plt.ylabel('Количество пикселей (нормализованное)', fontdict={'fontsize': 12})
    plt.xticks(ticks=range(len(years)), labels=years, rotation=45)
    plt.show()

# %% [markdown]
# #### KMeans:

# %%
results, years, files = analyze_most_popular_ever_colors(folder_path, np.array(most_common_colors))

# %%
plot_bar_distribution(results, years, model_name='KMeans')

# %%
from pprint import pprint

pprint(results)
# Out:
# {(36, 35, 39): array([4176, 5327,  252, 6388, 5862, 2627, 1317, 1811, 1190,  520, 4914,
#         983, 1291, 2738, 3411, 3474,  961, 5304, 1058,   23, 1357,  175,
#        1063, 1191, 6181, 6676,  200, 1295, 4430, 4405, 2730, 3231,   52,
#        1114, 6089, 5393,    9, 5296, 2052, 1742, 2104, 1645, 2789, 2263,
#         769, 3340,  340, 3438,    5, 2154, 2344, 4371, 1434, 1266,  300,
#         218, 5565, 5422, 2357, 6088, 1142, 2779, 2884, 2751,  590, 8034,
#        4015, 2967, 3934,  964, 1792,  309,   12,  633,  904, 4790,  877,
#        5103, 2574,  991, 5499, 1300, 1126, 3075,  557, 4041, 6543, 8137,
#        4510, 6195, 4586, 1088, 5990, 1092, 4730,  695, 3304, 4185, 3707,
#        7420, 2045, 3307, 4149, 6222, 6997,  102, 3534,  326, 2605, 5572,
#         283, 2512, 1723, 1373, 2138,  330, 8528,  820, 2769, 1991, 2531,
#        1695, 1242, 2190, 1226, 1639, 1322, 3739, 1315, 1187,  455,  215,
#        3188, 4959, 4921, 3022, 5127, 4329, 4286, 2600,  940,  441,  657,
#        3934, 3322, 1678, 4534, 1910, 1082, 1853, 5756, 2160, 1065, 1124,
#          34, 1095, 1481, 2081, 1624, 3365,    7, 2731,  801, 4323,  723,
#         605, 2221, 1038, 1622, 3193,  203,  505, 2498, 4321, 1716,   59,
#        2668,  748, 3176,  446,  421,  250,  348, 4803,  805,  847, 2433,
#        2848,  814, 4186,  838, 1729, 3128,  905, 4124,  173, 2758, 1267,
#        3973,  349, 3465, 2520,   72, 2313, 1294, 3840, 2937,  765, 1427,
#        3380, 1578,  549,    6, 2093, 2938,  658, 1282]),
#  (76, 70, 60): array([2518, 1460,  884, 3420, 1731, 2598, 1269, 2166,  902,  587,  853,
#        1305,   87, 2283, 2094, 2271,  611, 3567,  395, 3094,  842,  209,
#        1708, 1393, 2964, 1689, 6740, 2000, 4645,  734, 2609,  448,  496,
#        5782, 1896, 2105, 7474, 2129,  764,  511, 1448,  154, 1416,  223,
#         230, 5968, 2314, 4300, 1334, 3644, 4868,  188, 1353, 1505,  664,
#        1542, 1707, 5834,  200, 1041, 2368, 6111, 3007,  742,  596, 2949,
#         100,  644, 1971,  421, 1113,  262,  556,   68, 3146, 2011,  554,
#        1943, 1272,  731, 1475,  606, 1305, 1613, 1082,  977,  525, 1560,
#         738,  814,  285,  748,  912,  656,   64,  312, 1992, 1089,  743,
#        1528, 3374, 1778,  670, 2190, 1750,  804, 1374, 2825,  751, 1105,
#        1513, 1619, 1694,  836, 1619,  696,  894,  352,  834, 1377,  897,
#        1476, 2792, 1614, 1846, 1091, 1031, 1532,  909, 1296,  781, 1213,
#         983,  943,  989, 1295,  300, 1938, 1219, 1089,  302,  218, 1832,
#         567,   92, 2303, 1466,  530,  215, 1703, 1644,  905,  884,  319,
#         106,  222, 1132, 2589,  676, 1312,  848, 1161, 1580, 1435, 2396,
#        1238, 1031,  190, 2298, 1212,  241, 1052,  891, 4278, 1268,  849,
#        2409,  654,  411,  244,   55, 1550,  814, 3857,  599, 1077,  812,
#         581,  601,  668,  472, 1204,  717,  477, 4396, 1882,  737, 1356,
#        1024, 1110,  512, 2686,   54, 1426,  835, 1162, 2013,  338,  377,
#         887,  912,  353, 2338, 1781, 1773, 1856,  732]),
#  (100, 117, 145): array([   0,    0,    0,   22,   10,    1,   42,    3,  362,  154,  535,
#        1444,    0,  163,  783,    0,  953,    0,   11,    3,  100,  231,
#          12,   24,    0,    0,    3,    0,    7,    2,    0,  330, 1997,
#           2,    0,  131,    0,  135,  115,    0, 1333, 2269,  204, 2378,
#          55,    7,  102,    1,    0,    0,    4,    5,    0, 1106,    0,
#         299,    0,    0,  360,    0,   96,   34,    3,   40,    0,    2,
#           0,   19,    5,   94,   24,   11,  209, 1064,    0,    0,   44,
#         329,  798,    0,  279,  158,    7,  802, 1497,   89,  128,   59,
#          68,  166, 1478,  318,   41,  384,  644,  165,  224,   56, 1674,
#         228,   65,    6,    0,  137,    5, 1209,    2,  128,   70,  181,
#         169,  133,  154,   67,    0,  119,    0,    0,  142,  528,    4,
#         129,    8,  216,   86,   22,    8,   17,   85,   43,  962,  117,
#         256,    0,    0,  179,  344,   92,  263,   14,    0,  689, 1733,
#         824,   30, 3756,  766,   17,  748,  179,    0,    0,   15,  274,
#         972,   85,  175,  755,  114,  150,    3,    2,    0,  226,  482,
#         626,  195,  470,   20,  267,   73,  602,  936,    0,   80,  686,
#         540,   37,  415,  353,    1,  153,  132,   53,   38,   86,   24,
#         253,   39,    0,  468,  265,  943, 1022,  179,   15,  453,  192,
#         424,   60,  662,    0,  765,  526,   97,  104,    0,   79,  240,
#         321,   13,  255,   10,  112,  133,  122,   29]),
#  (135, 123, 95): array([ 379,  423, 2527,  407,  948,  990, 1126, 2026,  603,  750,  138,
#        1221,  115,  772,  446,   53, 1734, 2305,  226, 3057,  633,  132,
#         921,  673,  612,  233,  971,  158,  912,  557,  279,   54,  693,
#         277,   14,  128, 2427,  123,  301,  382,  118,  137,  608,   30,
#          49,  279, 3062, 1406,  963,  238,  485,  133, 2477,  757,  111,
#         824,  416,   31,  157,    6, 1331,   94,  704,  164, 1430,  129,
#          47,  124,  310,  188,  820,  164,  352,   25,  898,  135,  535,
#         475,  267,  265,  623,  510,  531,  277,  284,  155,  188,  104,
#         195,   60,    3,  515,  501,  851,    6,  489, 1735, 1991, 2017,
#         134,  556, 1503,   86,  427,  147, 1301,  152,  749,  243,  122,
#         501,  160,  859,  535,   53,  714,  321,  405,  261,  587,  124,
#         432, 1380, 1043, 2608,  208, 1063, 1248,  510, 1147,  379, 2780,
#         306,   36,   40,  696,   26,  916,  354,  277,  174,  193,  517,
#         119,  111,  636,   50,  271,  194,  259,  590,  153, 1399,  329,
#         665,   22,  458,  425,  354,  369, 5490,  398,  696,  843,  951,
#         212,  371,  573, 1165,  218,  923,  891,  376,  436,  254,  940,
#        1032,  471,  119,  970,   62,  460, 1648,  136,  332,  814,  565,
#         309,  334,  351,  581,  406,  108,  239,  462, 1330,  429,  200,
#         230,  977,   85, 1127,  116,  486, 1067,  455,  643,  262,  368,
#         451,  819,  253, 3254,  589,  711,  921,  473]),
#  (153, 80, 50): array([   0,    5,  189,   49,  126,  502,    1,  120,    1,   62,   16,
#           4,  155,    1,  566, 2298,   13,   15,  406, 1599,   63,   21,
#        1009,  634,    6,  486,  262,  892,   60,  250,  878,   87,    9,
#         973,  294,    0,    0,    0,  366,    0,   59,  104,  402,    0,
#         301,    9,  164,  180, 1622,  297,   54,  635,  604,   11, 2759,
#         839,  223,  182,   66,  744,  195,    0,   29,  310,  162,  293,
#         306,  542,  208,  560,  389,  420,  388,  290,  622,  224,    7,
#           8,  342,  153,    0,  288,  240,  934,  126,   14,  123,    9,
#           0,   35,    0,    1,   54,  249,    0,   13,    0,   89,   84,
#           0,  253,  460,   59,   34,  344,  164,  271,  479,  358,   40,
#         370,  680,  547,   64, 1583,  108,    1, 1512,  162,  226,  454,
#         256,  452,   71,  163,  239,  174,   88,  136,  109,  433,  257,
#          96, 1696, 1761,   23,    1,  306,  111,  682,   30,  307,   97,
#        2268,   45,   10,   30,  207,  202,  197,  577,  302,  331,  101,
#          10,  223,  499,   48,   82,  228,  630,  290,   15,  139,   41,
#         110,  121,  128, 1068,   63,  179, 1298,    1,    0,  734,   23,
#          31,  152,   49,  126,   32,   91,   81,  377,  318,  373,  366,
#         195,  324,  292,  295,  652,    4,   50,   99, 1163,   21,   80,
#         102,  144,   77,  449,   37,  162,  715,  489,  575,  661,  188,
#         294,  175,  419,  192,  139,  273,  211,  367]),
#  (197, 189, 178): array([  95,  174,  463,  602,  254,   22,  430,  933,    4, 1939,  115,
#         195,    2,  481,   17,   85,  163,  274, 1563,    0, 1062, 1193,
#          88,  114,    6,    0,  509,    8,  224,  370,  656,  102,   57,
#        1937,    6,   61,  389,   63,  139,  385,  367,  106,  548,   14,
#           6,  222,    0,  146,  139,    2,  316,    9,    0, 1301,    0,
#          15,    0,    0,   32,    0,    0,  399,    2, 1173,   46,    0,
#           1,   32,  532,  593, 2270,  628,  152,  108,    3,    1, 2754,
#         494,  444,    6, 1248,  438,  994,  269,  106, 2368,   83,   64,
#        1125,  317,    0, 6204, 1232,  461,  124, 1874,  211,  365,  326,
#        1191,  298,   26,    0,    2,   40,  734,  468,  191, 1531,   96,
#        1160,  138,  247, 2777,    2,  777,  116,  421, 2341,  854,    0,
#         628,  524,  651,   75,    9, 3588,  255, 1782, 1333,   10, 1372,
#         529,    0,    0, 1467,  866,   94,  741,  134,    1,  190,  794,
#         402,   37,   91,  297,  164, 3887, 2763,  236,   83,  126,  422,
#         140,    5, 1239,  758,  645,  282,   28,  350,    0,  443,  728,
#        1696,  688, 2519,    0, 1898,  276,  197, 1138,  226,  707, 1060,
#         930, 4945,  836,  610,  677, 3445, 1981,    0,  303,  975,  258,
#        1089,  302, 1800,  386,  557,  142, 1166,   64, 1254,  658, 1416,
#         306,  441,  885,    1,  402, 1261,  988, 1239,  327,  585, 1673,
#         239,  885,  236,  413,  574, 1092,   23,  674]),
#  (198, 159, 84): array([   5,    2,   68,   29,   30, 1049,  143,   42,    9,  214,  141,
#         156,    5,  117,  106,  154,    3,   83,   10,    8,    0,    0,
#         957,   64,  245,  742,  378,  429,    6,    2,  132,   38,  523,
#           0,    0,    1,    0,    1,   20,    0,   23,   44,  184,    5,
#          28,    2,    0,   14, 2510,    0,   79,   51,    0,    0,  340,
#         278, 1126,    0,  352,  244,  747,    0,   47,   52,  442,    4,
#         117,  139,    5,  316,    8,  831, 1800,   64,  820,  329,    3,
#          18,  102,  481,   28,  299,   34,    0,    2,  163,   91,    1,
#           0,   10,    0,    0,   12,  142,    0,  309,    0,   47,   13,
#           0,   15,  495,  338,    0,   96,  847,  269,   53,  262,   12,
#          79,  623,  248,  265,   20,  429,  391,  320,   81,  101,  746,
#         337,  144,  395,  120,    2,  203,  201,  556,  287,  683,   35,
#         377,  412,  426,   59,    0,   22,   19,   39,   24,  165,  217,
#          22,    4,    8,    4,   16,   40,    4,    3,  171,  689,  229,
#         107,    2,  330,   13,   46,  851,  331,  846, 1811,   18,   16,
#         177,  430,   54, 1367,   40,  107,  537,    9,    0,   22,  264,
#          19,  121,   13,  594,  125,   82,  255,  728,  135,  170, 1411,
#         218,  135,   29,  638,  568,   18,   29,  240,   33,   93,  361,
#         298,  410,   23,  307,   50,   31,  252,  272,  275,   40,  261,
#         425,   42,  378,  234,  366,  238,  102,  425])}

# %%
df_KMeans = pd.DataFrame.from_dict(results, orient='index', columns=years)
df_KMeans = df_KMeans.T
df_KMeans = df_KMeans.reset_index().rename(columns={'index': 'year'})

# %%
df_KMeans = df_KMeans.groupby('year', as_index=False).sum()

# %%
df_KMeans.head()
# Out:
#    year  (36, 35, 39)  (76, 70, 60)  (197, 189, 178)  (135, 123, 95)  \
# 0  1882          9503          3978              269             802
# 1  1883           252           884              463            2527
# 2  1885          6388          3420              602             407
# 3  1886          5862          1731              254             948
# 4  1888          2627          2598               22             990
#
#    (100, 117, 145)  (153, 80, 50)  (198, 159, 84)
# 0                0              5               7
# 1                0            189              68
# 2               22             49              29
# 3               10            126              30
# 4                1            502            1049

# %% [markdown]
# #### GaussianMixture:

# %%
results_GM, years, files = analyze_most_popular_ever_colors(folder_path, np.array(most_common_colors_gauss))

# %%
plot_bar_distribution(results_GM, years, model_name='GaussianMixture')

# %%
df_GM = pd.DataFrame.from_dict(results_GM, orient='index', columns=years)
df_GM = df_GM.T
df_GM = df_GM.reset_index().rename(columns={'index': 'year'})
df_GM = df_GM.groupby('year', as_index=False).sum()
df_GM.head()
# Out:
#    year  (35, 36, 39)  (73, 64, 55)  (139, 125, 100)  (192, 184, 173)  \
# 0  1882          9540          4024              844              230
# 1  1883           242           786             2828              410
# 2  1885          6573          3510              365              630
# 3  1886          5856          2217              830              376
# 4  1888          2551          2783              870               21
#
#    (82, 98, 120)  (137, 77, 48)  (199, 160, 96)
# 0             13             36             271
# 1              1            555             403
# 2            106             69              48
# 3             37            330             120
# 4             10            945            1302

# %%
len(df_GM)
# Out:
# 49

# %%
len(files)
# Out:
# 217

# %%
len(results_GM)
# Out:
# 7

# %%
popular_colors = {}

for i in results_GM:

# %%
num = 1
sl = {}
for i in results_GM:
    print(results_GM[i][num])
    print(i)
# Out:
# (35, 36, 39)
# (73, 64, 55)
# (139, 125, 100)
# (192, 184, 173)
# (82, 98, 120)
# (137, 77, 48)
# (199, 160, 96)

# %%
info_dict = {}

num = 0
for i in files:
    col = {}
    for j in results_GM:
        col[str(j)] = results_GM[j][num]
    info_dict[i] = {
        'path': i,
        'name_of_painting': ' '.join((i.split('_')[4:])).replace('.jpg', ''),
        'year': i.split('_')[0],
        'most_common_colors_ever': col
    }
    num += 1

# %%
info_dict
# Out:
# {'1882_mm_dd_a_Автопортрет.jpg': {'path': '1882_mm_dd_a_Автопортрет.jpg',
#   'name_of_painting': 'Автопортрет',
#   'year': '1882',
#   'most_common_colors_ever': {'(35, 36, 39)': 4381,
#    '(73, 64, 55)': 2151,
#    '(139, 125, 100)': 429,
#    '(192, 184, 173)': 61,
#    '(82, 98, 120)': 13,
#    '(137, 77, 48)': 0,
#    '(199, 160, 96)': 259}},
#  '1882_mm_dd_a_Автопортрет_в_19_лет.jpg': {'path': '1882_mm_dd_a_Автопортрет_в_19_лет.jpg',
#   'name_of_painting': 'Автопортрет в 19 лет',
#   'year': '1882',
#   'most_common_colors_ever': {'(35, 36, 39)': 5159,
#    '(73, 64, 55)': 1873,
#    '(139, 125, 100)': 415,
#    '(192, 184, 173)': 169,
#    '(82, 98, 120)': 0,
#    '(137, 77, 48)': 36,
#    '(199, 160, 96)': 12}},
#  '1883_mm_dd_i_Девушка.jpg': {'path': '1883_mm_dd_i_Девушка.jpg',
#   'name_of_painting': 'Девушка',
#   'year': '1883',
#   'most_common_colors_ever': {'(35, 36, 39)': 242,
#    '(73, 64, 55)': 786,
#    '(139, 125, 100)': 2828,
#    '(192, 184, 173)': 410,
#    '(82, 98, 120)': 1,
#    '(137, 77, 48)': 555,
#    '(199, 160, 96)': 403}},
#  '1885_mm_dd_i_Больная_девочка.jpg': {'path': '1885_mm_dd_i_Больная_девочка.jpg',
#   'name_of_painting': 'Больная девочка',
#   'year': '1885',
#   'most_common_colors_ever': {'(35, 36, 39)': 6573,
#    '(73, 64, 55)': 3510,
#    '(139, 125, 100)': 365,
#    '(192, 184, 173)': 630,
#    '(82, 98, 120)': 106,
#    '(137, 77, 48)': 69,
#    '(199, 160, 96)': 48}},
#  '1886_mm_dd_a_Автопортрет.jpg': {'path': '1886_mm_dd_a_Автопортрет.jpg',
#   'name_of_painting': 'Автопортрет',
#   'year': '1886',
#   'most_common_colors_ever': {'(35, 36, 39)': 5856,
#    '(73, 64, 55)': 2217,
#    '(139, 125, 100)': 830,
#    '(192, 184, 173)': 376,
#    '(82, 98, 120)': 37,
#    '(137, 77, 48)': 330,
#    '(199, 160, 96)': 120}},
#  '1888_mm_dd_a_Автопортрет.jpg': {'path': '1888_mm_dd_a_Автопортрет.jpg',
#   'name_of_painting': 'Автопортрет',
#   'year': '1888',
#   'most_common_colors_ever': {'(35, 36, 39)': 2551,
#    '(73, 64, 55)': 2783,
#    '(139, 125, 100)': 870,
#    '(192, 184, 173)': 21,
#    '(82, 98, 120)': 10,
#    '(137, 77, 48)': 945,
#    '(199, 160, 96)': 1302}},
#  '1889_mm_dd_i_Летняя_ночь_(Ингер_на_берегу).jpg': {'path': '1889_mm_dd_i_Летняя_ночь_(Ингер_на_берегу).jpg',
#   'name_of_painting': 'Летняя ночь (Ингер на берегу)',
#   'year': '1889',
#   'most_common_colors_ever': {'(35, 36, 39)': 1476,
#    '(73, 64, 55)': 1034,
#    '(139, 125, 100)': 882,
#    '(192, 184, 173)': 408,
#    '(82, 98, 120)': 74,
#    '(137, 77, 48)': 6,
#    '(199, 160, 96)': 131}},
#  '1889_mm_xx_i_Весна.jpg': {'path': '1889_mm_xx_i_Весна.jpg',
#   'name_of_painting': 'Весна',
#   'year': '1889',
#   'most_common_colors_ever': {'(35, 36, 39)': 1946,
#    '(73, 64, 55)': 1650,
#    '(139, 125, 100)': 1863,
#    '(192, 184, 173)': 1266,
#    '(82, 98, 120)': 21,
#    '(137, 77, 48)': 176,
#    '(199, 160, 96)': 69}},
#  '1891_mm_dd_i_Ночь_в_Ницце.jpg': {'path': '1891_mm_dd_i_Ночь_в_Ницце.jpg',
#   'name_of_painting': 'Ночь в Ницце',
#   'year': '1891',
#   'most_common_colors_ever': {'(35, 36, 39)': 1183,
#    '(73, 64, 55)': 834,
#    '(139, 125, 100)': 689,
#    '(192, 184, 173)': 6,
#    '(82, 98, 120)': 1567,
#    '(137, 77, 48)': 2,
#    '(199, 160, 96)': 11}},
#  '1891_mm_dd_i_Улица_Лафайет.jpg': {'path': '1891_mm_dd_i_Улица_Лафайет.jpg',
#   'name_of_painting': 'Улица Лафайет',
#   'year': '1891',
#   'most_common_colors_ever': {'(35, 36, 39)': 527,
#    '(73, 64, 55)': 563,
#    '(139, 125, 100)': 839,
#    '(192, 184, 173)': 2065,
#    '(82, 98, 120)': 173,
#    '(137, 77, 48)': 81,
#    '(199, 160, 96)': 413}},
#  '1892_mm_dd_a_Автопортрет_под_женской_маской.jpg': {'path': '1892_mm_dd_a_Автопортрет_под_женской_маской.jpg',
#   'name_of_painting': 'Автопортрет под женской маской',
#   'year': '1892',
#   'most_common_colors_ever': {'(35, 36, 39)': 3311,
#    '(73, 64, 55)': 3473,
#    '(139, 125, 100)': 75,
#    '(192, 184, 173)': 73,
#    '(82, 98, 120)': 0,
#    '(137, 77, 48)': 2823,
#    '(199, 160, 96)': 89}},
#  '1892_mm_dd_i_Вечер_на_улице_Карла_Иоанна.jpg': {'path': '1892_mm_dd_i_Вечер_на_улице_Карла_Иоанна.jpg',
#   'name_of_painting': 'Вечер на улице Карла Иоанна',
#   'year': '1892',
#   'most_common_colors_ever': {'(35, 36, 39)': 3387,
#    '(73, 64, 55)': 2082,
#    '(139, 125, 100)': 583,
#    '(192, 184, 173)': 15,
#    '(82, 98, 120)': 757,
#    '(137, 77, 48)': 834,
#    '(199, 160, 96)': 202}},
#  '1892_mm_dd_i_Лунный_свет_на_берегу.jpg': {'path': '1892_mm_dd_i_Лунный_свет_на_берегу.jpg',
#   'name_of_painting': 'Лунный свет на берегу',
#   'year': '1892',
#   'most_common_colors_ever': {'(35, 36, 39)': 2952,
#    '(73, 64, 55)': 1892,
#    '(139, 125, 100)': 786,
#    '(192, 184, 173)': 487,
#    '(82, 98, 120)': 148,
#    '(137, 77, 48)': 0,
#    '(199, 160, 96)': 368}},
#  '1892_mm_dd_i_Меланхолия.jpg': {'path': '1892_mm_dd_i_Меланхолия.jpg',
#   'name_of_painting': 'Меланхолия',
#   'year': '1892',
#   'most_common_colors_ever': {'(35, 36, 39)': 1042,
#    '(73, 64, 55)': 507,
#    '(139, 125, 100)': 2120,
#    '(192, 184, 173)': 393,
#    '(82, 98, 120)': 467,
#    '(137, 77, 48)': 22,
#    '(199, 160, 96)': 33}},
#  '1892_mm_dd_i_Портрет_Ингер_Мунк.jpg': {'path': '1892_mm_dd_i_Портрет_Ингер_Мунк.jpg',
#   'name_of_painting': 'Портрет Ингер Мунк',
#   'year': '1892',
#   'most_common_colors_ever': {'(35, 36, 39)': 1199,
#    '(73, 64, 55)': 158,
#    '(139, 125, 100)': 174,
#    '(192, 184, 173)': 8,
#    '(82, 98, 120)': 0,
#    '(137, 77, 48)': 187,
#    '(199, 160, 96)': 85}},
#  '1892_mm_dd_i_Тайна_летней_ночи.jpg': {'path': '1892_mm_dd_i_Тайна_летней_ночи.jpg',
#   'name_of_painting': 'Тайна летней ночи',
#   'year': '1892',
#   'most_common_colors_ever': {'(35, 36, 39)': 1009,
#    '(73, 64, 55)': 1148,
#    '(139, 125, 100)': 1234,
#    '(192, 184, 173)': 228,
#    '(82, 98, 120)': 3035,
#    '(137, 77, 48)': 13,
#    '(199, 160, 96)': 531}},
#  '1892_mm_dd_Отчаяние.jpg': {'path': '1892_mm_dd_Отчаяние.jpg',
#   'name_of_painting': '',
#   'year': '1892',
#   'most_common_colors_ever': {'(35, 36, 39)': 4915,
#    '(73, 64, 55)': 846,
#    '(139, 125, 100)': 130,
#    '(192, 184, 173)': 110,
#    '(82, 98, 120)': 1294,
#    '(137, 77, 48)': 25,
#    '(199, 160, 96)': 219}},
#  '1893_mm_dd_i_Буря.jpg': {'path': '1893_mm_dd_i_Буря.jpg',
#   'name_of_painting': 'Буря',
#   'year': '1893',
#   'most_common_colors_ever': {'(35, 36, 39)': 5392,
#    '(73, 64, 55)': 3810,
#    '(139, 125, 100)': 2252,
#    '(192, 184, 173)': 295,
#    '(82, 98, 120)': 1,
#    '(137, 77, 48)': 92,
#    '(199, 160, 96)': 105}},
#  '1893_mm_dd_i_Голос.jpg': {'path': '1893_mm_dd_i_Голос.jpg',
#   'name_of_painting': 'Голос',
#   'year': '1893',
#   'most_common_colors_ever': {'(35, 36, 39)': 978,
#    '(73, 64, 55)': 526,
#    '(139, 125, 100)': 251,
#    '(192, 184, 173)': 1565,
#    '(82, 98, 120)': 0,
#    '(137, 77, 48)': 439,
#    '(199, 160, 96)': 36}},
#  '1893_mm_dd_i_Крик.jpg': {'path': '1893_mm_dd_i_Крик.jpg',
#   'name_of_painting': 'Крик',
#   'year': '1893',
#   'most_common_colors_ever': {'(35, 36, 39)': 13,
#    '(73, 64, 55)': 2360,
#    '(139, 125, 100)': 2634,
#    '(192, 184, 173)': 0,
#    '(82, 98, 120)': 314,
#    '(137, 77, 48)': 706,
#    '(199, 160, 96)': 26}},
#  '1893_mm_dd_i_Лунный_свет.jpg': {'path': '1893_mm_dd_i_Лунный_свет.jpg',
#   'name_of_painting': 'Лунный свет',
#   'year': '1893',
#   'most_common_colors_ever': {'(35, 36, 39)': 1300,
#    '(73, 64, 55)': 913,
#    '(139, 125, 100)': 571,
#    '(192, 184, 173)': 969,
#    '(82, 98, 120)': 132,
#    '(137, 77, 48)': 295,
#    '(199, 160, 96)': 0}},
#  '1893_mm_dd_i_Меланхолия.jpg': {'path': '1893_mm_dd_i_Меланхолия.jpg',
#   'name_of_painting': 'Меланхолия',
#   'year': '1893',
#   'most_common_colors_ever': {'(35, 36, 39)': 213,
#    '(73, 64, 55)': 156,
#    '(139, 125, 100)': 206,
#    '(192, 184, 173)': 1127,
#    '(82, 98, 120)': 95,
#    '(137, 77, 48)': 41,
#    '(199, 160, 96)': 1}},
#  '1893_mm_dd_i_Руки.jpg': {'path': '1893_mm_dd_i_Руки.jpg',
#   'name_of_painting': 'Руки',
#   'year': '1893',
#   'most_common_colors_ever': {'(35, 36, 39)': 1002,
#    '(73, 64, 55)': 2040,
#    '(139, 125, 100)': 912,
#    '(192, 184, 173)': 92,
#    '(82, 98, 120)': 114,
#    '(137, 77, 48)': 1120,
#    '(199, 160, 96)': 1137}},
#  '1893_mm_dd_i_Смерть_в_комнате_больного.jpg': {'path': '1893_mm_dd_i_Смерть_в_комнате_больного.jpg',
#   'name_of_painting': 'Смерть в комнате больного',
#   'year': '1893',
#   'most_common_colors_ever': {'(35, 36, 39)': 1171,
#    '(73, 64, 55)': 1448,
#    '(139, 125, 100)': 570,
#    '(192, 184, 173)': 121,
#    '(82, 98, 120)': 830,
#    '(137, 77, 48)': 648,
#    '(199, 160, 96)': 81}},
#  '1894_mm_dd_i_Мадонна.jpg.jpg': {'path': '1894_mm_dd_i_Мадонна.jpg.jpg',
#   'name_of_painting': 'Мадонна',
#   'year': '1894',
#   'most_common_colors_ever': {'(35, 36, 39)': 1210,
#    '(73, 64, 55)': 2328,
#    '(139, 125, 100)': 86,
#    '(192, 184, 173)': 7,
#    '(82, 98, 120)': 1,
#    '(137, 77, 48)': 1750,
#    '(199, 160, 96)': 392}},
#  '1894_mm_dd_i_Пепел.jpg': {'path': '1894_mm_dd_i_Пепел.jpg',
#   'name_of_painting': 'Пепел',
#   'year': '1894',
#   'most_common_colors_ever': {'(35, 36, 39)': 211,
#    '(73, 64, 55)': 6003,
#    '(139, 125, 100)': 899,
#    '(192, 184, 173)': 454,
#    '(82, 98, 120)': 75,
#    '(137, 77, 48)': 806,
#    '(199, 160, 96)': 517}},
#  '1894_mm_dd_i_Созревание.jpg': {'path': '1894_mm_dd_i_Созревание.jpg',
#   'name_of_painting': 'Созревание',
#   'year': '1894',
#   'most_common_colors_ever': {'(35, 36, 39)': 4337,
#    '(73, 64, 55)': 4940,
#    '(139, 125, 100)': 943,
#    '(192, 184, 173)': 331,
#    '(82, 98, 120)': 16,
#    '(137, 77, 48)': 189,
#    '(199, 160, 96)': 42}},
#  '1894_mm_dd_i_Тревога.jpg': {'path': '1894_mm_dd_i_Тревога.jpg',
#   'name_of_painting': 'Тревога',
#   'year': '1894',
#   'most_common_colors_ever': {'(35, 36, 39)': 6739,
#    '(73, 64, 55)': 1842,
#    '(139, 125, 100)': 185,
#    '(192, 184, 173)': 1,
#    '(82, 98, 120)': 31,
#    '(137, 77, 48)': 319,
#    '(199, 160, 96)': 659}},
#  '1894_mm_dd_i_Три_стадии_женщины_(Сфинкс).jpg': {'path': '1894_mm_dd_i_Три_стадии_женщины_(Сфинкс).jpg',
#   'name_of_painting': 'Три стадии женщины (Сфинкс)',
#   'year': '1894',
#   'most_common_colors_ever': {'(35, 36, 39)': 6170,
#    '(73, 64, 55)': 3557,
#    '(139, 125, 100)': 576,
#    '(192, 184, 173)': 6,
#    '(82, 98, 120)': 0,
#    '(137, 77, 48)': 23,
#    '(199, 160, 96)': 490}},
#  '1895_mm_dd_a_Автопортрет_с_зажженной_сигаретой.jpg': {'path': '1895_mm_dd_a_Автопортрет_с_зажженной_сигаретой.jpg',
#   'name_of_painting': 'Автопортрет с зажженной сигаретой',
#   'year': '1895',
#   'most_common_colors_ever': {'(35, 36, 39)': 5239,
#    '(73, 64, 55)': 2199,
#    '(139, 125, 100)': 145,
#    '(192, 184, 173)': 82,
#    '(82, 98, 120)': 986,
#    '(137, 77, 48)': 4,
#    '(199, 160, 96)': 7}},
#  '1895_mm_dd_a_Автопортрет_со_скелетом_руки.jpg': {'path': '1895_mm_dd_a_Автопортрет_со_скелетом_руки.jpg',
#   'name_of_painting': 'Автопортрет со скелетом руки',
#   'year': '1895',
#   'most_common_colors_ever': {'(35, 36, 39)': 3,
#    '(73, 64, 55)': 7115,
#    '(139, 125, 100)': 2396,
#    '(192, 184, 173)': 435,
#    '(82, 98, 120)': 0,
#    '(137, 77, 48)': 0,
#    '(199, 160, 96)': 2}},
#  '1895_mm_dd_i_Автопортрет_с_зажжённой_сигаретой.jpg': {'path': '1895_mm_dd_i_Автопортрет_с_зажжённой_сигаретой.jpg',
#   'name_of_painting': 'Автопортрет с зажжённой сигаретой',
#   'year': '1895',
#   'most_common_colors_ever': {'(35, 36, 39)': 5342,
#    '(73, 64, 55)': 2169,
#    '(139, 125, 100)': 148,
#    '(192, 184, 173)': 80,
#    '(82, 98, 120)': 952,
#    '(137, 77, 48)': 4,
#    '(199, 160, 96)': 9}},
#  '1895_mm_dd_i_Вампир.jpg': {'path': '1895_mm_dd_i_Вампир.jpg',
#   'name_of_painting': 'Вампир',
#   'year': '1895',
#   'most_common_colors_ever': {'(35, 36, 39)': 5821,
#    '(73, 64, 55)': 2986,
#    '(139, 125, 100)': 14,
#    '(192, 184, 173)': 7,
#    '(82, 98, 120)': 2,
#    '(137, 77, 48)': 305,
#    '(199, 160, 96)': 1}},
#  '1895_mm_dd_i_Запах_смерти.jpg': {'path': '1895_mm_dd_i_Запах_смерти.jpg',
#   'name_of_painting': 'Запах смерти',
#   'year': '1895',
#   'most_common_colors_ever': {'(35, 36, 39)': 2064,
#    '(73, 64, 55)': 984,
#    '(139, 125, 100)': 305,
#    '(192, 184, 173)': 177,
#    '(82, 98, 120)': 199,
#    '(137, 77, 48)': 285,
#    '(199, 160, 96)': 51}},
#  '1895_mm_dd_i_Крик_1.jpg': {'path': '1895_mm_dd_i_Крик_1.jpg',
#   'name_of_painting': 'Крик 1',
#   'year': '1895',
#   'most_common_colors_ever': {'(35, 36, 39)': 51,
#    '(73, 64, 55)': 414,
#    '(139, 125, 100)': 815,
#    '(192, 184, 173)': 182,
#    '(82, 98, 120)': 1608,
#    '(137, 77, 48)': 25,
#    '(199, 160, 96)': 792}},
#  '1895_mm_dd_i_Лунный_свет.jpg': {'path': '1895_mm_dd_i_Лунный_свет.jpg',
#   'name_of_painting': 'Лунный свет',
#   'year': '1895',
#   'most_common_colors_ever': {'(35, 36, 39)': 3233,
#    '(73, 64, 55)': 669,
#    '(139, 125, 100)': 51,
#    '(192, 184, 173)': 84,
#    '(82, 98, 120)': 386,
#    '(137, 77, 48)': 78,
#    '(199, 160, 96)': 76}},
#  '1895_mm_dd_i_Мадонна.jpg': {'path': '1895_mm_dd_i_Мадонна.jpg',
#   'name_of_painting': 'Мадонна',
#   'year': '1895',
#   'most_common_colors_ever': {'(35, 36, 39)': 1594,
#    '(73, 64, 55)': 7307,
#    '(139, 125, 100)': 274,
#    '(192, 184, 173)': 1580,
#    '(82, 98, 120)': 105,
#    '(137, 77, 48)': 1029,
#    '(199, 160, 96)': 0}},
#  '1895_mm_dd_i_Следующий_день.jpg': {'path': '1895_mm_dd_i_Следующий_день.jpg',
#   'name_of_painting': 'Следующий день',
#   'year': '1895',
#   'most_common_colors_ever': {'(35, 36, 39)': 2694,
#    '(73, 64, 55)': 3215,
#    '(139, 125, 100)': 286,
#    '(192, 184, 173)': 686,
#    '(82, 98, 120)': 69,
#    '(137, 77, 48)': 1818,
#    '(199, 160, 96)': 250}},
#  '1895_mm_dd_i_У_смертного_одра.jpg': {'path': '1895_mm_dd_i_У_смертного_одра.jpg',
#   'name_of_painting': 'У смертного одра',
#   'year': '1895',
#   'most_common_colors_ever': {'(35, 36, 39)': 4422,
#    '(73, 64, 55)': 945,
#    '(139, 125, 100)': 619,
#    '(192, 184, 173)': 355,
#    '(82, 98, 120)': 7,
#    '(137, 77, 48)': 757,
#    '(199, 160, 96)': 23}},
#  '1896_mm_dd_a_Автопортрет_со_скелетом_руки.jpg': {'path': '1896_mm_dd_a_Автопортрет_со_скелетом_руки.jpg',
#   'name_of_painting': 'Автопортрет со скелетом руки',
#   'year': '1896',
#   'most_common_colors_ever': {'(35, 36, 39)': 1726,
#    '(73, 64, 55)': 473,
#    '(139, 125, 100)': 412,
#    '(192, 184, 173)': 354,
#    '(82, 98, 120)': 0,
#    '(137, 77, 48)': 0,
#    '(199, 160, 96)': 0}},
#  '1896_mm_dd_i_Голос_(Летняя_ночь).jpg': {'path': '1896_mm_dd_i_Голос_(Летняя_ночь).jpg',
#   'name_of_painting': 'Голос (Летняя ночь)',
#   'year': '1896',
#   'most_common_colors_ever': {'(35, 36, 39)': 2134,
#    '(73, 64, 55)': 1733,
#    '(139, 125, 100)': 172,
#    '(192, 184, 173)': 338,
#    '(82, 98, 120)': 657,
#    '(137, 77, 48)': 273,
#    '(199, 160, 96)': 38}},
#  '1896_mm_dd_i_Девушка_на_берегу.jpg': {'path': '1896_mm_dd_i_Девушка_на_берегу.jpg',
#   'name_of_painting': 'Девушка на берегу',
#   'year': '1896',
#   'most_common_colors_ever': {'(35, 36, 39)': 1659,
#    '(73, 64, 55)': 131,
#    '(139, 125, 100)': 134,
#    '(192, 184, 173)': 79,
#    '(82, 98, 120)': 3152,
#    '(137, 77, 48)': 123,
#    '(199, 160, 96)': 11}},
#  '1896_mm_dd_i_Расставание.jpg': {'path': '1896_mm_dd_i_Расставание.jpg',
#   'name_of_painting': 'Расставание',
#   'year': '1896',
#   'most_common_colors_ever': {'(35, 36, 39)': 2762,
#    '(73, 64, 55)': 1498,
#    '(139, 125, 100)': 641,
#    '(192, 184, 173)': 510,
#    '(82, 98, 120)': 139,
#    '(137, 77, 48)': 559,
#    '(199, 160, 96)': 279}},
#  '1897_mm_dd_i_Мать_и_дочь.jpg': {'path': '1897_mm_dd_i_Мать_и_дочь.jpg',
#   'name_of_painting': 'Мать и дочь',
#   'year': '1897',
#   'most_common_colors_ever': {'(35, 36, 39)': 708,
#    '(73, 64, 55)': 480,
#    '(139, 125, 100)': 86,
#    '(192, 184, 173)': 13,
#    '(82, 98, 120)': 32,
#    '(137, 77, 48)': 589,
#    '(199, 160, 96)': 29}},
#  '1897_mm_dd_i_Поцелуй.jpg': {'path': '1897_mm_dd_i_Поцелуй.jpg',
#   'name_of_painting': 'Поцелуй',
#   'year': '1897',
#   'most_common_colors_ever': {'(35, 36, 39)': 3531,
#    '(73, 64, 55)': 6310,
#    '(139, 125, 100)': 311,
#    '(192, 184, 173)': 256,
#    '(82, 98, 120)': 27,
#    '(137, 77, 48)': 15,
#    '(199, 160, 96)': 1}},
#  '1897_mm_dd_i_Поцелуй.jpg.jpg': {'path': '1897_mm_dd_i_Поцелуй.jpg.jpg',
#   'name_of_painting': 'Поцелуй',
#   'year': '1897',
#   'most_common_colors_ever': {'(35, 36, 39)': 2518,
#    '(73, 64, 55)': 162,
#    '(139, 125, 100)': 29,
#    '(192, 184, 173)': 19,
#    '(82, 98, 120)': 1097,
#    '(137, 77, 48)': 0,
#    '(199, 160, 96)': 3}},
#  '1898_mm_dd_i_Вынос_гроба.jpg': {'path': '1898_mm_dd_i_Вынос_гроба.jpg',
#   'name_of_painting': 'Вынос гроба',
#   'year': '1898',
#   'most_common_colors_ever': {'(35, 36, 39)': 186,
#    '(73, 64, 55)': 1865,
#    '(139, 125, 100)': 1014,
#    '(192, 184, 173)': 26,
#    '(82, 98, 120)': 194,
#    '(137, 77, 48)': 750,
#    '(199, 160, 96)': 280}},
#  '1898_mm_dd_i_Две_женщины._Символический_этюд.jpg': {'path': '1898_mm_dd_i_Две_женщины._Символический_этюд.jpg',
#   'name_of_painting': 'Две женщины. Символический этюд',
#   'year': '1898',
#   'most_common_colors_ever': {'(35, 36, 39)': 301,
#    '(73, 64, 55)': 813,
#    '(139, 125, 100)': 118,
#    '(192, 184, 173)': 0,
#    '(82, 98, 120)': 4,
#    '(137, 77, 48)': 2624,
#    '(199, 160, 96)': 277}},
#  '1898_mm_dd_i_Женщина_у_фьорда_в_Осгорстранне.jpg': {'path': '1898_mm_dd_i_Женщина_у_фьорда_в_Осгорстранне.jpg',
#   'name_of_painting': 'Женщина у фьорда в Осгорстранне',
#   'year': '1898',
#   'most_common_colors_ever': {'(35, 36, 39)': 1228,
#    '(73, 64, 55)': 1645,
#    '(139, 125, 100)': 773,
#    '(192, 184, 173)': 1311,
#    '(82, 98, 120)': 362,
#    '(137, 77, 48)': 86,
#    '(199, 160, 96)': 0}},
#  '1898_mm_dd_i_Красный_дикий_виноград.jpg': {'path': '1898_mm_dd_i_Красный_дикий_виноград.jpg',
#   'name_of_painting': 'Красный дикий виноград',
#   'year': '1898',
#   'most_common_colors_ever': {'(35, 36, 39)': 1372,
#    '(73, 64, 55)': 1549,
#    '(139, 125, 100)': 2885,
#    '(192, 184, 173)': 0,
#    '(82, 98, 120)': 1,
#    '(137, 77, 48)': 1312,
#    '(199, 160, 96)': 4}},
#  '1898_mm_dd_i_Мужчина_и_женщина.jpg': {'path': '1898_mm_dd_i_Мужчина_и_женщина.jpg',
#   'name_of_painting': 'Мужчина и женщина',
#   'year': '1898',
#   'most_common_colors_ever': {'(35, 36, 39)': 5537,
#    '(73, 64, 55)': 2141,
#    '(139, 125, 100)': 281,
#    '(192, 184, 173)': 2,
#    '(82, 98, 120)': 4,
#    '(137, 77, 48)': 419,
#    '(199, 160, 96)': 1407}},
#  '1898_mm_dd_i_Обнаженная_в_профиль_справа.jpg': {'path': '1898_mm_dd_i_Обнаженная_в_профиль_справа.jpg',
#   'name_of_painting': 'Обнаженная в профиль справа',
#   'year': '1898',
#   'most_common_colors_ever': {'(35, 36, 39)': 2416,
#    '(73, 64, 55)': 5263,
#    '(139, 125, 100)': 405,
#    '(192, 184, 173)': 377,
#    '(82, 98, 120)': 159,
#    '(137, 77, 48)': 211,
#    '(199, 160, 96)': 104}},
#  '1898_mm_dd_i_Плодородие.jpg': {'path': '1898_mm_dd_i_Плодородие.jpg',
#   'name_of_painting': 'Плодородие',
#   'year': '1898',
#   'most_common_colors_ever': {'(35, 36, 39)': 3463,
#    '(73, 64, 55)': 4011,
#    '(139, 125, 100)': 1170,
#    '(192, 184, 173)': 134,
#    '(82, 98, 120)': 40,
#    '(137, 77, 48)': 128,
#    '(199, 160, 96)': 54}},
#  '1898_mm_dd_i_Пляж.jpg': {'path': '1898_mm_dd_i_Пляж.jpg',
#   'name_of_painting': 'Пляж',
#   'year': '1898',
#   'most_common_colors_ever': {'(35, 36, 39)': 330,
#    '(73, 64, 55)': 2048,
#    '(139, 125, 100)': 3076,
#    '(192, 184, 173)': 0,
#    '(82, 98, 120)': 523,
#    '(137, 77, 48)': 320,
#    '(199, 160, 96)': 0}},
#  '1898_mm_dd_i_Радуга.jpg': {'path': '1898_mm_dd_i_Радуга.jpg',
#   'name_of_painting': 'Радуга',
#   'year': '1898',
#   'most_common_colors_ever': {'(35, 36, 39)': 2192,
#    '(73, 64, 55)': 3545,
#    '(139, 125, 100)': 228,
#    '(192, 184, 173)': 4,
#    '(82, 98, 120)': 177,
#    '(137, 77, 48)': 386,
#    '(199, 160, 96)': 7}},
#  '1898_mm_dd_i_Ревность_в_купалье.jpg': {'path': '1898_mm_dd_i_Ревность_в_купалье.jpg',
#   'name_of_painting': 'Ревность в купалье',
#   'year': '1898',
#   'most_common_colors_ever': {'(35, 36, 39)': 6,
#    '(73, 64, 55)': 980,
#    '(139, 125, 100)': 804,
#    '(192, 184, 173)': 98,
#    '(82, 98, 120)': 18,
#    '(137, 77, 48)': 1637,
#    '(199, 160, 96)': 1962}},
#  '1898_mm_dd_i_Сидящая_обнаженная_на_пляже.jpg': {'path': '1898_mm_dd_i_Сидящая_обнаженная_на_пляже.jpg',
#   'name_of_painting': 'Сидящая обнаженная на пляже',
#   'year': '1898',
#   'most_common_colors_ever': {'(35, 36, 39)': 4275,
#    '(73, 64, 55)': 500,
#    '(139, 125, 100)': 154,
#    '(192, 184, 173)': 18,
#    '(82, 98, 120)': 8,
#    '(137, 77, 48)': 1721,
#    '(199, 160, 96)': 39}},
#  '1899_mm_dd_i_Дом_Мунка_в_Осгорстранне.jpg': {'path': '1899_mm_dd_i_Дом_Мунка_в_Осгорстранне.jpg',
#   'name_of_painting': 'Дом Мунка в Осгорстранне',
#   'year': '1899',
#   'most_common_colors_ever': {'(35, 36, 39)': 12,
#    '(73, 64, 55)': 501,
#    '(139, 125, 100)': 330,
#    '(192, 184, 173)': 121,
#    '(82, 98, 120)': 210,
#    '(137, 77, 48)': 387,
#    '(199, 160, 96)': 1612}},
#  '1899_mm_dd_i_Дом_и_мастерская_Мунка_в_Осгорстранне.jpg': {'path': '1899_mm_dd_i_Дом_и_мастерская_Мунка_в_Осгорстранне.jpg',
#   'name_of_painting': 'Дом и мастерская Мунка в Осгорстранне',
#   'year': '1899',
#   'most_common_colors_ever': {'(35, 36, 39)': 940,
#    '(73, 64, 55)': 551,
#    '(139, 125, 100)': 189,
#    '(192, 184, 173)': 1482,
#    '(82, 98, 120)': 8,
#    '(137, 77, 48)': 820,
#    '(199, 160, 96)': 178}},
#  '1899_mm_dd_i_Дом_с_красным_виноградом.jpg': {'path': '1899_mm_dd_i_Дом_с_красным_виноградом.jpg',
#   'name_of_painting': 'Дом с красным виноградом',
#   'year': '1899',
#   'most_common_colors_ever': {'(35, 36, 39)': 1895,
#    '(73, 64, 55)': 1108,
#    '(139, 125, 100)': 942,
#    '(192, 184, 173)': 1375,
#    '(82, 98, 120)': 106,
#    '(137, 77, 48)': 633,
#    '(199, 160, 96)': 49}},
#  '1899_mm_dd_i_Дом_с_красным_диким_виноградом.jpg': {'path': '1899_mm_dd_i_Дом_с_красным_диким_виноградом.jpg',
#   'name_of_painting': 'Дом с красным диким виноградом',
#   'year': '1899',
#   'most_common_colors_ever': {'(35, 36, 39)': 300,
#    '(73, 64, 55)': 279,
#    '(139, 125, 100)': 199,
#    '(192, 184, 173)': 1187,
#    '(82, 98, 120)': 4,
#    '(137, 77, 48)': 396,
#    '(199, 160, 96)': 953}},
#  '1899_mm_dd_i_Зима_в_лесу._Нурстранн.jpg': {'path': '1899_mm_dd_i_Зима_в_лесу._Нурстранн.jpg',
#   'name_of_painting': 'Зима в лесу. Нурстранн',
#   'year': '1899',
#   'most_common_colors_ever': {'(35, 36, 39)': 852,
#    '(73, 64, 55)': 677,
#    '(139, 125, 100)': 590,
#    '(192, 184, 173)': 2116,
#    '(82, 98, 120)': 49,
#    '(137, 77, 48)': 29,
#    '(199, 160, 96)': 8}},
#  '1899_mm_dd_i_Летняя_ночь_в_Студентерлюннене.jpg': {'path': '1899_mm_dd_i_Летняя_ночь_в_Студентерлюннене.jpg',
#   'name_of_painting': 'Летняя ночь в Студентерлюннене',
#   'year': '1899',
#   'most_common_colors_ever': {'(35, 36, 39)': 732,
#    '(73, 64, 55)': 84,
#    '(139, 125, 100)': 17,
#    '(192, 184, 173)': 79,
#    '(82, 98, 120)': 184,
#    '(137, 77, 48)': 586,
#    '(199, 160, 96)': 43}},
#  '1899_mm_dd_i_Метрвая_мать_и_ребенок.jpg': {'path': '1899_mm_dd_i_Метрвая_мать_и_ребенок.jpg',
#   'name_of_painting': 'Метрвая мать и ребенок',
#   'year': '1899',
#   'most_common_colors_ever': {'(35, 36, 39)': 945,
#    '(73, 64, 55)': 3282,
#    '(139, 125, 100)': 709,
#    '(192, 184, 173)': 2,
#    '(82, 98, 120)': 1,
#    '(137, 77, 48)': 783,
#    '(199, 160, 96)': 719}},
#  '1899_mm_dd_i_Обмен_веществ.jpg': {'path': '1899_mm_dd_i_Обмен_веществ.jpg',
#   'name_of_painting': 'Обмен веществ',
#   'year': '1899',
#   'most_common_colors_ever': {'(35, 36, 39)': 4818,
#    '(73, 64, 55)': 2697,
#    '(139, 125, 100)': 81,
#    '(192, 184, 173)': 1,
#    '(82, 98, 120)': 11,
#    '(137, 77, 48)': 669,
#    '(199, 160, 96)': 379}},
#  '1899_mm_dd_i_Осе_и_Харальд_Нёррегор.jpg': {'path': '1899_mm_dd_i_Осе_и_Харальд_Нёррегор.jpg',
#   'name_of_painting': 'Осе и Харальд Нёррегор',
#   'year': '1899',
#   'most_common_colors_ever': {'(35, 36, 39)': 2909,
#    '(73, 64, 55)': 1606,
#    '(139, 125, 100)': 120,
#    '(192, 184, 173)': 24,
#    '(82, 98, 120)': 54,
#    '(137, 77, 48)': 1294,
#    '(199, 160, 96)': 182}},
#  '1899_mm_dd_i_Плодородие.jpg': {'path': '1899_mm_dd_i_Плодородие.jpg',
#   'name_of_painting': 'Плодородие',
#   'year': '1899',
#   'most_common_colors_ever': {'(35, 36, 39)': 3955,
#    '(73, 64, 55)': 2161,
#    '(139, 125, 100)': 276,
#    '(192, 184, 173)': 441,
#    '(82, 98, 120)': 115,
#    '(137, 77, 48)': 317,
#    '(199, 160, 96)': 9}},
#  '1899_mm_dd_i_Портрет_Осе_Неррегор.jpg': {'path': '1899_mm_dd_i_Портрет_Осе_Неррегор.jpg',
#   'name_of_painting': 'Портрет Осе Неррегор',
#   'year': '1899',
#   'most_common_colors_ever': {'(35, 36, 39)': 4006,
#    '(73, 64, 55)': 220,
#    '(139, 125, 100)': 44,
#    '(192, 184, 173)': 0,
#    '(82, 98, 120)': 0,
#    '(137, 77, 48)': 2283,
#    '(199, 160, 96)': 198}},
#  '1899_mm_dd_i_Сидящая_обнажённая_женщина_и_три_мужские_головы.jpg': {'path': '1899_mm_dd_i_Сидящая_обнажённая_женщина_и_три_мужские_головы.jpg',
#   'name_of_painting': 'Сидящая обнажённая женщина и три мужские головы',
#   'year': '1899',
#   'most_common_colors_ever': {'(35, 36, 39)': 7955,
#    '(73, 64, 55)': 4061,
#    '(139, 125, 100)': 61,
#    '(192, 184, 173)': 0,
#    '(82, 98, 120)': 16,
#    '(137, 77, 48)': 271,
#    '(199, 160, 96)': 2}},
#  '1899_mm_dd_i_Смерть_и_ребенок.jpg': {'path': '1899_mm_dd_i_Смерть_и_ребенок.jpg',
#   'name_of_painting': 'Смерть и ребенок',
#   'year': '1899',
#   'most_common_colors_ever': {'(35, 36, 39)': 603,
#    '(73, 64, 55)': 578,
#    '(139, 125, 100)': 1160,
#    '(192, 184, 173)': 59,
#    '(82, 98, 120)': 4,
#    '(137, 77, 48)': 228,
#    '(199, 160, 96)': 533}},
#  '1899_mm_dd_i_Танец_жизни.jpg': {'path': '1899_mm_dd_i_Танец_жизни.jpg',
#   'name_of_painting': 'Танец жизни',
#   'year': '1899',
#   'most_common_colors_ever': {'(35, 36, 39)': 2805,
#    '(73, 64, 55)': 904,
#    '(139, 125, 100)': 182,
#    '(192, 184, 173)': 1316,
#    '(82, 98, 120)': 801,
#    '(137, 77, 48)': 427,
#    '(199, 160, 96)': 90}},
#  '1899_mm_dd_i_Темный_еловый_лес_1.jpg': {'path': '1899_mm_dd_i_Темный_еловый_лес_1.jpg',
#   'name_of_painting': 'Темный еловый лес 1',
#   'year': '1899',
#   'most_common_colors_ever': {'(35, 36, 39)': 2857,
#    '(73, 64, 55)': 3091,
#    '(139, 125, 100)': 508,
#    '(192, 184, 173)': 3,
#    '(82, 98, 120)': 57,
#    '(137, 77, 48)': 121,
#    '(199, 160, 96)': 56}},
#  '1899_mm_dd_i_Темный_еловый_лес_2.jpg': {'path': '1899_mm_dd_i_Темный_еловый_лес_2.jpg',
#   'name_of_painting': 'Темный еловый лес 2',
#   'year': '1899',
#   'most_common_colors_ever': {'(35, 36, 39)': 2938,
#    '(73, 64, 55)': 6771,
#    '(139, 125, 100)': 68,
#    '(192, 184, 173)': 368,
#    '(82, 98, 120)': 208,
#    '(137, 77, 48)': 22,
#    '(199, 160, 96)': 0}},
#  '1899_mm_dd_i_Темный_еловый_лес_3.jpg': {'path': '1899_mm_dd_i_Темный_еловый_лес_3.jpg',
#   'name_of_painting': 'Темный еловый лес 3',
#   'year': '1899',
#   'most_common_colors_ever': {'(35, 36, 39)': 1129,
#    '(73, 64, 55)': 2419,
#    '(139, 125, 100)': 1124,
#    '(192, 184, 173)': 0,
#    '(82, 98, 120)': 132,
#    '(137, 77, 48)': 306,
#    '(199, 160, 96)': 313}},
#  '1899_mm_dd_i_Трагедия.jpg': {'path': '1899_mm_dd_i_Трагедия.jpg',
#   'name_of_painting': 'Трагедия',
#   'year': '1899',
#   'most_common_colors_ever': {'(35, 36, 39)': 6323,
#    '(73, 64, 55)': 1297,
#    '(139, 125, 100)': 3,
#    '(192, 184, 173)': 0,
#    '(82, 98, 120)': 0,
#    '(137, 77, 48)': 935,
#    '(199, 160, 96)': 93}},
#  '1899_mm_dd_i_Тулла_Ларсен_1.jpg': {'path': '1899_mm_dd_i_Тулла_Ларсен_1.jpg',
#   'name_of_painting': 'Тулла Ларсен 1',
#   'year': '1899',
#   'most_common_colors_ever': {'(35, 36, 39)': 2594,
#    '(73, 64, 55)': 138,
#    '(139, 125, 100)': 167,
#    '(192, 184, 173)': 42,
#    '(82, 98, 120)': 941,
#    '(137, 77, 48)': 55,
#    '(199, 160, 96)': 683}},
#  '1899_mm_dd_i_Тулла_Ларсен_2.jpg': {'path': '1899_mm_dd_i_Тулла_Ларсен_2.jpg',
#   'name_of_painting': 'Тулла Ларсен 2',
#   'year': '1899',
#   'most_common_colors_ever': {'(35, 36, 39)': 5342,
#    '(73, 64, 55)': 7313,
#    '(139, 125, 100)': 15,
#    '(192, 184, 173)': 0,
#    '(82, 98, 120)': 0,
#    '(137, 77, 48)': 866,
#    '(199, 160, 96)': 0}},
#  '1900_mm_dd_i_Белая_ночь.jpg': {'path': '1900_mm_dd_i_Белая_ночь.jpg',
#   'name_of_painting': 'Белая ночь',
#   'year': '1900',
#   'most_common_colors_ever': {'(35, 36, 39)': 4645,
#    '(73, 64, 55)': 313,
#    '(139, 125, 100)': 9,
#    '(192, 184, 173)': 1,
#    '(82, 98, 120)': 1610,
#    '(137, 77, 48)': 0,
#    '(199, 160, 96)': 0}},
#  '1900_mm_dd_i_Вид_из_Нурстранна.jpg': {'path': '1900_mm_dd_i_Вид_из_Нурстранна.jpg',
#   'name_of_painting': 'Вид из Нурстранна',
#   'year': '1900',
#   'most_common_colors_ever': {'(35, 36, 39)': 6169,
#    '(73, 64, 55)': 1098,
#    '(139, 125, 100)': 70,
#    '(192, 184, 173)': 488,
#    '(82, 98, 120)': 94,
#    '(137, 77, 48)': 110,
#    '(199, 160, 96)': 11}},
#  '1900_mm_dd_i_Вид_из_Нурстранна_1.jpg': {'path': '1900_mm_dd_i_Вид_из_Нурстранна_1.jpg',
#   'name_of_painting': 'Вид из Нурстранна 1',
#   'year': '1900',
#   'most_common_colors_ever': {'(35, 36, 39)': 4466,
#    '(73, 64, 55)': 993,
#    '(139, 125, 100)': 204,
#    '(192, 184, 173)': 925,
#    '(82, 98, 120)': 647,
#    '(137, 77, 48)': 2,
#    '(199, 160, 96)': 0}},
#  '1900_mm_dd_i_Глаза_в_глаза.jpg': {'path': '1900_mm_dd_i_Глаза_в_глаза.jpg',
#   'name_of_painting': 'Глаза в глаза',
#   'year': '1900',
#   'most_common_colors_ever': {'(35, 36, 39)': 8329,
#    '(73, 64, 55)': 1449,
#    '(139, 125, 100)': 101,
#    '(192, 184, 173)': 68,
#    '(82, 98, 120)': 237,
#    '(137, 77, 48)': 42,
#    '(199, 160, 96)': 8}},
#  '1900_mm_dd_i_Голгофа.jpg': {'path': '1900_mm_dd_i_Голгофа.jpg',
#   'name_of_painting': 'Голгофа',
#   'year': '1900',
#   'most_common_colors_ever': {'(35, 36, 39)': 6490,
#    '(73, 64, 55)': 590,
#    '(139, 125, 100)': 162,
#    '(192, 184, 173)': 80,
#    '(82, 98, 120)': 298,
#    '(137, 77, 48)': 156,
#    '(199, 160, 96)': 83}},
#  '1900_mm_dd_i_Дымящий_поезд.jpg': {'path': '1900_mm_dd_i_Дымящий_поезд.jpg',
#   'name_of_painting': 'Дымящий поезд',
#   'year': '1900',
#   'most_common_colors_ever': {'(35, 36, 39)': 615,
#    '(73, 64, 55)': 920,
#    '(139, 125, 100)': 251,
#    '(192, 184, 173)': 199,
#    '(82, 98, 120)': 1231,
#    '(137, 77, 48)': 197,
#    '(199, 160, 96)': 4}},
#  '1900_mm_dd_i_Закат._Нурстранн.jpg': {'path': '1900_mm_dd_i_Закат._Нурстранн.jpg',
#   'name_of_painting': 'Закат. Нурстранн',
#   'year': '1900',
#   'most_common_colors_ever': {'(35, 36, 39)': 3944,
#    '(73, 64, 55)': 1392,
#    '(139, 125, 100)': 162,
#    '(192, 184, 173)': 3091,
#    '(82, 98, 120)': 70,
#    '(137, 77, 48)': 83,
#    '(199, 160, 96)': 200}},
#  '1900_mm_dd_i_Зима.jpg': {'path': '1900_mm_dd_i_Зима.jpg',
#   'name_of_painting': 'Зима',
#   'year': '1900',
#   'most_common_colors_ever': {'(35, 36, 39)': 1126,
#    '(73, 64, 55)': 753,
#    '(139, 125, 100)': 578,
#    '(192, 184, 173)': 5079,
#    '(82, 98, 120)': 372,
#    '(137, 77, 48)': 57,
#    '(199, 160, 96)': 0}},
#  '1900_mm_dd_i_Красное_и_белое.jpg': {'path': '1900_mm_dd_i_Красное_и_белое.jpg',
#   'name_of_painting': 'Красное и белое',
#   'year': '1900',
#   'most_common_colors_ever': {'(35, 36, 39)': 3102,
#    '(73, 64, 55)': 1843,
#    '(139, 125, 100)': 292,
#    '(192, 184, 173)': 289,
#    '(82, 98, 120)': 682,
#    '(137, 77, 48)': 613,
#    '(199, 160, 96)': 1}},
#  '1900_mm_dd_i_Красный_плющ.jpg': {'path': '1900_mm_dd_i_Красный_плющ.jpg',
#   'name_of_painting': 'Красный плющ',
#   'year': '1900',
#   'most_common_colors_ever': {'(35, 36, 39)': 1123,
#    '(73, 64, 55)': 1265,
#    '(139, 125, 100)': 511,
#    '(192, 184, 173)': 751,
#    '(82, 98, 120)': 29,
#    '(137, 77, 48)': 486,
#    '(199, 160, 96)': 62}},
#  '1900_mm_dd_i_Меланхолия.jpg': {'path': '1900_mm_dd_i_Меланхолия.jpg',
#   'name_of_painting': 'Меланхолия',
#   'year': '1900',
#   'most_common_colors_ever': {'(35, 36, 39)': 1302,
#    '(73, 64, 55)': 671,
#    '(139, 125, 100)': 519,
#    '(192, 184, 173)': 365,
#    '(82, 98, 120)': 69,
#    '(137, 77, 48)': 273,
#    '(199, 160, 96)': 344}},
#  '1900_mm_dd_i_Остров.jpg': {'path': '1900_mm_dd_i_Остров.jpg',
#   'name_of_painting': 'Остров',
#   'year': '1900',
#   'most_common_colors_ever': {'(35, 36, 39)': 5609,
#    '(73, 64, 55)': 1369,
#    '(139, 125, 100)': 486,
#    '(192, 184, 173)': 1180,
#    '(82, 98, 120)': 517,
#    '(137, 77, 48)': 10,
#    '(199, 160, 96)': 33}},
#  '1900_mm_dd_i_Парижский_бульвар.jpg': {'path': '1900_mm_dd_i_Парижский_бульвар.jpg',
#   'name_of_painting': 'Парижский бульвар',
#   'year': '1900',
#   'most_common_colors_ever': {'(35, 36, 39)': 988,
#    '(73, 64, 55)': 823,
#    '(139, 125, 100)': 225,
#    '(192, 184, 173)': 8,
#    '(82, 98, 120)': 2,
#    '(137, 77, 48)': 190,
#    '(199, 160, 96)': 361}},
#  '1900_mm_dd_i_Танец_жизни.jpg': {'path': '1900_mm_dd_i_Танец_жизни.jpg',
#   'name_of_painting': 'Танец жизни',
#   'year': '1900',
#   'most_common_colors_ever': {'(35, 36, 39)': 2583,
#    '(73, 64, 55)': 1036,
#    '(139, 125, 100)': 248,
#    '(192, 184, 173)': 288,
#    '(82, 98, 120)': 445,
#    '(137, 77, 48)': 313,
#    '(199, 160, 96)': 135}},
#  '1900_mm_dd_i_Танцы_на_пляже.jpg': {'path': '1900_mm_dd_i_Танцы_на_пляже.jpg',
#   'name_of_painting': 'Танцы на пляже',
#   'year': '1900',
#   'most_common_colors_ever': {'(35, 36, 39)': 5132,
#    '(73, 64, 55)': 2532,
#    '(139, 125, 100)': 533,
#    '(192, 184, 173)': 570,
#    '(82, 98, 120)': 380,
#    '(137, 77, 48)': 30,
#    '(199, 160, 96)': 27}},
#  '1901_mm_dd_i_Девочки_на_мосту_1.jpg': {'path': '1901_mm_dd_i_Девочки_на_мосту_1.jpg',
#   'name_of_painting': 'Девочки на мосту 1',
#   'year': '1901',
#   'most_common_colors_ever': {'(35, 36, 39)': 3751,
#    '(73, 64, 55)': 784,
#    '(139, 125, 100)': 2200,
#    '(192, 184, 173)': 366,
#    '(82, 98, 120)': 580,
#    '(137, 77, 48)': 186,
#    '(199, 160, 96)': 15}},
#  '1901_mm_dd_i_Девочки_на_мосту_2.jpg': {'path': '1901_mm_dd_i_Девочки_на_мосту_2.jpg',
#   'name_of_painting': 'Девочки на мосту 2',
#   'year': '1901',
#   'most_common_colors_ever': {'(35, 36, 39)': 4156,
#    '(73, 64, 55)': 1060,
#    '(139, 125, 100)': 2445,
#    '(192, 184, 173)': 513,
#    '(82, 98, 120)': 275,
#    '(137, 77, 48)': 711,
#    '(199, 160, 96)': 38}},
#  '1901_mm_dd_i_Зима_в_Нурстранне.jpg': {'path': '1901_mm_dd_i_Зима_в_Нурстранне.jpg',
#   'name_of_painting': 'Зима в Нурстранне',
#   'year': '1901',
#   'most_common_colors_ever': {'(35, 36, 39)': 3288,
#    '(73, 64, 55)': 1620,
#    '(139, 125, 100)': 1618,
#    '(192, 184, 173)': 165,
#    '(82, 98, 120)': 1070,
#    '(137, 77, 48)': 2,
#    '(199, 160, 96)': 0}},
#  '1901_mm_dd_i_Зимний_лес.jpg': {'path': '1901_mm_dd_i_Зимний_лес.jpg',
#   'name_of_painting': 'Зимний лес',
#   'year': '1901',
#   'most_common_colors_ever': {'(35, 36, 39)': 7372,
#    '(73, 64, 55)': 1750,
#    '(139, 125, 100)': 124,
#    '(192, 184, 173)': 1311,
#    '(82, 98, 120)': 569,
#    '(137, 77, 48)': 0,
#    '(199, 160, 96)': 0}},
#  '1901_mm_dd_i_Зимняя_ночь.jpg': {'path': '1901_mm_dd_i_Зимняя_ночь.jpg',
#   'name_of_painting': 'Зимняя ночь',
#   'year': '1901',
#   'most_common_colors_ever': {'(35, 36, 39)': 4894,
#    '(73, 64, 55)': 78,
#    '(139, 125, 100)': 4,
#    '(192, 184, 173)': 99,
#    '(82, 98, 120)': 534,
#    '(137, 77, 48)': 0,
#    '(199, 160, 96)': 0}},
#  '1901_mm_dd_i_Улица_в_Осгорстранне_1.jpg': {'path': '1901_mm_dd_i_Улица_в_Осгорстранне_1.jpg',
#   'name_of_painting': 'Улица в Осгорстранне 1',
#   'year': '1901',
#   'most_common_colors_ever': {'(35, 36, 39)': 1107,
#    '(73, 64, 55)': 816,
#    '(139, 125, 100)': 932,
#    '(192, 184, 173)': 447,
#    '(82, 98, 120)': 25,
#    '(137, 77, 48)': 420,
#    '(199, 160, 96)': 143}},
#  '1901_mm_dd_i_Улица_в_Осгорстранне_2.jpg': {'path': '1901_mm_dd_i_Улица_в_Осгорстранне_2.jpg',
#   'name_of_painting': 'Улица в Осгорстранне 2',
#   'year': '1901',
#   'most_common_colors_ever': {'(35, 36, 39)': 713,
#    '(73, 64, 55)': 360,
#    '(139, 125, 100)': 425,
#    '(192, 184, 173)': 1492,
#    '(82, 98, 120)': 24,
#    '(137, 77, 48)': 66,
#    '(199, 160, 96)': 354}},
#  '1901_mm_dd_Семейная_книга.jpg': {'path': '1901_mm_dd_Семейная_книга.jpg',
#   'name_of_painting': 'книга',
#   'year': '1901',
#   'most_common_colors_ever': {'(35, 36, 39)': 6029,
#    '(73, 64, 55)': 1072,
#    '(139, 125, 100)': 589,
#    '(192, 184, 173)': 1235,
#    '(82, 98, 120)': 84,
#    '(137, 77, 48)': 108,
#    '(199, 160, 96)': 17}},
#  '1902_mm_dd_i_В_саду.jpg': {'path': '1902_mm_dd_i_В_саду.jpg',
#   'name_of_painting': 'В саду',
#   'year': '1902',
#   'most_common_colors_ever': {'(35, 36, 39)': 361,
#    '(73, 64, 55)': 633,
#    '(139, 125, 100)': 702,
#    '(192, 184, 173)': 891,
#    '(82, 98, 120)': 243,
#    '(137, 77, 48)': 132,
#    '(199, 160, 96)': 698}},
#  '1902_mm_dd_i_Вампир_2.jpg': {'path': '1902_mm_dd_i_Вампир_2.jpg',
#   'name_of_painting': 'Вампир 2',
#   'year': '1902',
#   'most_common_colors_ever': {'(35, 36, 39)': 9077,
#    '(73, 64, 55)': 920,
#    '(139, 125, 100)': 251,
#    '(192, 184, 173)': 102,
#    '(82, 98, 120)': 57,
#    '(137, 77, 48)': 79,
#    '(199, 160, 96)': 489}},
#  '1902_mm_dd_i_Две_обнаженные_у_комода.jpg': {'path': '1902_mm_dd_i_Две_обнаженные_у_комода.jpg',
#   'name_of_painting': 'Две обнаженные у комода',
#   'year': '1902',
#   'most_common_colors_ever': {'(35, 36, 39)': 759,
#    '(73, 64, 55)': 469,
#    '(139, 125, 100)': 465,
#    '(192, 184, 173)': 308,
#    '(82, 98, 120)': 2,
#    '(137, 77, 48)': 2519,
#    '(199, 160, 96)': 775}},
#  '1902_mm_dd_i_Девочка_в_красном_клетчатом_платье_и_красной_шляпе.jpg': {'path': '1902_mm_dd_i_Девочка_в_красном_клетчатом_платье_и_красной_шляпе.jpg',
#   'name_of_painting': 'Девочка в красном клетчатом платье и красной шляпе',
#   'year': '1902',
#   'most_common_colors_ever': {'(35, 36, 39)': 2497,
#    '(73, 64, 55)': 1115,
#    '(139, 125, 100)': 129,
#    '(192, 184, 173)': 0,
#    '(82, 98, 120)': 6,
#    '(137, 77, 48)': 394,
#    '(199, 160, 96)': 537}},
#  '1902_mm_dd_i_Девочки_на_мосту.jpg': {'path': '1902_mm_dd_i_Девочки_на_мосту.jpg',
#   'name_of_painting': 'Девочки на мосту',
#   'year': '1902',
#   'most_common_colors_ever': {'(35, 36, 39)': 2756,
#    '(73, 64, 55)': 922,
#    '(139, 125, 100)': 256,
#    '(192, 184, 173)': 2311,
#    '(82, 98, 120)': 233,
#    '(137, 77, 48)': 271,
#    '(199, 160, 96)': 85}},
#  '1902_mm_dd_i_Девочки_на_мосту_1.jpg': {'path': '1902_mm_dd_i_Девочки_на_мосту_1.jpg',
#   'name_of_painting': 'Девочки на мосту 1',
#   'year': '1902',
#   'most_common_colors_ever': {'(35, 36, 39)': 2033,
#    '(73, 64, 55)': 1481,
#    '(139, 125, 100)': 609,
#    '(192, 184, 173)': 1163,
#    '(82, 98, 120)': 286,
#    '(137, 77, 48)': 202,
#    '(199, 160, 96)': 105}},
#  '1902_mm_dd_i_Дом_в_летнюю_ночь.jpg': {'path': '1902_mm_dd_i_Дом_в_летнюю_ночь.jpg',
#   'name_of_painting': 'Дом в летнюю ночь',
#   'year': '1902',
#   'most_common_colors_ever': {'(35, 36, 39)': 1697,
#    '(73, 64, 55)': 1169,
#    '(139, 125, 100)': 169,
#    '(192, 184, 173)': 13,
#    '(82, 98, 120)': 124,
#    '(137, 77, 48)': 286,
#    '(199, 160, 96)': 19}},
#  '1902_mm_dd_i_Женщины_на_мосту.jpg': {'path': '1902_mm_dd_i_Женщины_на_мосту.jpg',
#   'name_of_painting': 'Женщины на мосту',
#   'year': '1902',
#   'most_common_colors_ever': {'(35, 36, 39)': 1692,
#    '(73, 64, 55)': 1720,
#    '(139, 125, 100)': 419,
#    '(192, 184, 173)': 670,
#    '(82, 98, 120)': 90,
#    '(137, 77, 48)': 220,
#    '(199, 160, 96)': 642}},
#  '1902_mm_dd_i_Катафалк_на_Потсдамер-Платц.jpg': {'path': '1902_mm_dd_i_Катафалк_на_Потсдамер-Платц.jpg',
#   'name_of_painting': 'Катафалк на Потсдамер-Платц',
#   'year': '1902',
#   'most_common_colors_ever': {'(35, 36, 39)': 1358,
#    '(73, 64, 55)': 823,
#    '(139, 125, 100)': 695,
#    '(192, 184, 173)': 2780,
#    '(82, 98, 120)': 148,
#    '(137, 77, 48)': 67,
#    '(199, 160, 96)': 260}},
#  '1902_mm_dd_i_Катафалк_на_Потсдамер-Платц_2.jpg': {'path': '1902_mm_dd_i_Катафалк_на_Потсдамер-Платц_2.jpg',
#   'name_of_painting': 'Катафалк на Потсдамер-Платц 2',
#   'year': '1902',
#   'most_common_colors_ever': {'(35, 36, 39)': 2169,
#    '(73, 64, 55)': 1502,
#    '(139, 125, 100)': 1226,
#    '(192, 184, 173)': 914,
#    '(82, 98, 120)': 410,
#    '(137, 77, 48)': 57,
#    '(199, 160, 96)': 287}},
#  '1902_mm_dd_i_На_операционном_столе.jpg': {'path': '1902_mm_dd_i_На_операционном_столе.jpg',
#   'name_of_painting': 'На операционном столе',
#   'year': '1902',
#   'most_common_colors_ever': {'(35, 36, 39)': 1211,
#    '(73, 64, 55)': 1937,
#    '(139, 125, 100)': 2703,
#    '(192, 184, 173)': 164,
#    '(82, 98, 120)': 200,
#    '(137, 77, 48)': 497,
#    '(199, 160, 96)': 85}},
#  '1902_mm_dd_i_Обнажённая_с_длинными_рыжими_волосами.jpg': {'path': '1902_mm_dd_i_Обнажённая_с_длинными_рыжими_волосами.jpg',
#   'name_of_painting': 'Обнажённая с длинными рыжими волосами',
#   'year': '1902',
#   'most_common_colors_ever': {'(35, 36, 39)': 2198,
#    '(73, 64, 55)': 1579,
#    '(139, 125, 100)': 63,
#    '(192, 184, 173)': 1,
#    '(82, 98, 120)': 15,
#    '(137, 77, 48)': 1867,
#    '(199, 160, 96)': 58}},
#  '1902_mm_dd_i_Обнаженная.jpg': {'path': '1902_mm_dd_i_Обнаженная.jpg',
#   'name_of_painting': 'Обнаженная',
#   'year': '1902',
#   'most_common_colors_ever': {'(35, 36, 39)': 1194,
#    '(73, 64, 55)': 3274,
#    '(139, 125, 100)': 1373,
#    '(192, 184, 173)': 586,
#    '(82, 98, 120)': 78,
#    '(137, 77, 48)': 502,
#    '(199, 160, 96)': 345}},
#  '1902_mm_dd_i_Обнаженная_в_интерьере.jpg': {'path': '1902_mm_dd_i_Обнаженная_в_интерьере.jpg',
#   'name_of_painting': 'Обнаженная в интерьере',
#   'year': '1902',
#   'most_common_colors_ever': {'(35, 36, 39)': 1664,
#    '(73, 64, 55)': 1844,
#    '(139, 125, 100)': 998,
#    '(192, 184, 173)': 394,
#    '(82, 98, 120)': 101,
#    '(137, 77, 48)': 731,
#    '(199, 160, 96)': 406}},
#  '1902_mm_dd_i_Одежда_на_веревочке_в_Осгорстранне.jpg': {'path': '1902_mm_dd_i_Одежда_на_веревочке_в_Осгорстранне.jpg',
#   'name_of_painting': 'Одежда на веревочке в Осгорстранне',
#   'year': '1902',
#   'most_common_colors_ever': {'(35, 36, 39)': 282,
#    '(73, 64, 55)': 1256,
#    '(139, 125, 100)': 478,
#    '(192, 184, 173)': 1258,
#    '(82, 98, 120)': 201,
#    '(137, 77, 48)': 395,
#    '(199, 160, 96)': 42}},
#  '1902_mm_dd_i_Плодородие.jpg': {'path': '1902_mm_dd_i_Плодородие.jpg',
#   'name_of_painting': 'Плодородие',
#   'year': '1902',
#   'most_common_colors_ever': {'(35, 36, 39)': 2077,
#    '(73, 64, 55)': 2971,
#    '(139, 125, 100)': 370,
#    '(192, 184, 173)': 381,
#    '(82, 98, 120)': 254,
#    '(137, 77, 48)': 259,
#    '(199, 160, 96)': 10}},
#  '1902_mm_dd_i_Приёмные_матери_перед_окружным_судом.jpg': {'path': '1902_mm_dd_i_Приёмные_матери_перед_окружным_судом.jpg',
#   'name_of_painting': 'Приёмные матери перед окружным судом',
#   'year': '1902',
#   'most_common_colors_ever': {'(35, 36, 39)': 3188,
#    '(73, 64, 55)': 2412,
#    '(139, 125, 100)': 1487,
#    '(192, 184, 173)': 38,
#    '(82, 98, 120)': 27,
#    '(137, 77, 48)': 513,
#    '(199, 160, 96)': 682}},
#  '1902_mm_dd_i_Рыбак_на_жёлтом_фоне.jpg': {'path': '1902_mm_dd_i_Рыбак_на_жёлтом_фоне.jpg',
#   'name_of_painting': 'Рыбак на жёлтом фоне',
#   'year': '1902',
#   'most_common_colors_ever': {'(35, 36, 39)': 4101,
#    '(73, 64, 55)': 866,
#    '(139, 125, 100)': 83,
#    '(192, 184, 173)': 0,
#    '(82, 98, 120)': 4,
#    '(137, 77, 48)': 95,
#    '(199, 160, 96)': 275}},
#  '1902_mm_dd_i_Сад.jpg': {'path': '1902_mm_dd_i_Сад.jpg',
#   'name_of_painting': 'Сад',
#   'year': '1902',
#   'most_common_colors_ever': {'(35, 36, 39)': 6579,
#    '(73, 64, 55)': 2234,
#    '(139, 125, 100)': 379,
#    '(192, 184, 173)': 5,
#    '(82, 98, 120)': 304,
#    '(137, 77, 48)': 110,
#    '(199, 160, 96)': 0}},
#  '1902_mm_dd_i_Санаторий.jpg': {'path': '1902_mm_dd_i_Санаторий.jpg',
#   'name_of_painting': 'Санаторий',
#   'year': '1902',
#   'most_common_colors_ever': {'(35, 36, 39)': 6975,
#    '(73, 64, 55)': 2136,
#    '(139, 125, 100)': 137,
#    '(192, 184, 173)': 39,
#    '(82, 98, 120)': 20,
#    '(137, 77, 48)': 585,
#    '(199, 160, 96)': 66}},
#  '1902_mm_dd_i_Сидящая_обнаженная.jpg': {'path': '1902_mm_dd_i_Сидящая_обнаженная.jpg',
#   'name_of_painting': 'Сидящая обнаженная',
#   'year': '1902',
#   'most_common_colors_ever': {'(35, 36, 39)': 2457,
#    '(73, 64, 55)': 1947,
#    '(139, 125, 100)': 156,
#    '(192, 184, 173)': 96,
#    '(82, 98, 120)': 401,
#    '(137, 77, 48)': 668,
#    '(199, 160, 96)': 762}},
#  '1902_mm_dd_i_Сказочный_лес.jpg': {'path': '1902_mm_dd_i_Сказочный_лес.jpg',
#   'name_of_painting': 'Сказочный лес',
#   'year': '1902',
#   'most_common_colors_ever': {'(35, 36, 39)': 101,
#    '(73, 64, 55)': 650,
#    '(139, 125, 100)': 1237,
#    '(192, 184, 173)': 874,
#    '(82, 98, 120)': 240,
#    '(137, 77, 48)': 131,
#    '(199, 160, 96)': 1325}},
#  '1902_mm_dd_i_Старый_рыбак_со_своей_дочерью.jpg': {'path': '1902_mm_dd_i_Старый_рыбак_со_своей_дочерью.jpg',
#   'name_of_painting': 'Старый рыбак со своей дочерью',
#   'year': '1902',
#   'most_common_colors_ever': {'(35, 36, 39)': 3389,
#    '(73, 64, 55)': 1661,
#    '(139, 125, 100)': 172,
#    '(192, 184, 173)': 341,
#    '(82, 98, 120)': 12,
#    '(137, 77, 48)': 213,
#    '(199, 160, 96)': 425}},
#  '1902_mm_dd_i_Улица_в_Осгорстранне_с_женщиной_в_красном_платье.jpg': {'path': '1902_mm_dd_i_Улица_в_Осгорстранне_с_женщиной_в_красном_платье.jpg',
#   'name_of_painting': 'Улица в Осгорстранне с женщиной в красном платье',
#   'year': '1902',
#   'most_common_colors_ever': {'(35, 36, 39)': 334,
#    '(73, 64, 55)': 2270,
#    '(139, 125, 100)': 623,
#    '(192, 184, 173)': 155,
#    '(82, 98, 120)': 305,
#    '(137, 77, 48)': 444,
#    '(199, 160, 96)': 58}},
#  '1902_mm_dd_i_Утро._Обнаженная_у_окна.jpg': {'path': '1902_mm_dd_i_Утро._Обнаженная_у_окна.jpg',
#   'name_of_painting': 'Утро. Обнаженная у окна',
#   'year': '1902',
#   'most_common_colors_ever': {'(35, 36, 39)': 2590,
#    '(73, 64, 55)': 963,
#    '(139, 125, 100)': 268,
#    '(192, 184, 173)': 1075,
#    '(82, 98, 120)': 82,
#    '(137, 77, 48)': 792,
#    '(199, 160, 96)': 291}},
#  '1902_mm_dd_i_Яблоня.jpg': {'path': '1902_mm_dd_i_Яблоня.jpg',
#   'name_of_painting': 'Яблоня',
#   'year': '1902',
#   'most_common_colors_ever': {'(35, 36, 39)': 5763,
#    '(73, 64, 55)': 1320,
#    '(139, 125, 100)': 100,
#    '(192, 184, 173)': 81,
#    '(82, 98, 120)': 210,
#    '(137, 77, 48)': 117,
#    '(199, 160, 96)': 27}},
#  '1903_mm_dd_a_Автопортрет_в_Аду.jpg': {'path': '1903_mm_dd_a_Автопортрет_в_Аду.jpg',
#   'name_of_painting': 'Автопортрет в Аду',
#   'year': '1903',
#   'most_common_colors_ever': {'(35, 36, 39)': 4833,
#    '(73, 64, 55)': 1834,
#    '(139, 125, 100)': 35,
#    '(192, 184, 173)': 0,
#    '(82, 98, 120)': 0,
#    '(137, 77, 48)': 3130,
#    '(199, 160, 96)': 216}},
#  '1903_mm_dd_a_Автопортрет_на_операционном_столе.jpg': {'path': '1903_mm_dd_a_Автопортрет_на_операционном_столе.jpg',
#   'name_of_painting': 'Автопортрет на операционном столе',
#   'year': '1903',
#   'most_common_colors_ever': {'(35, 36, 39)': 233,
#    '(73, 64, 55)': 1051,
#    '(139, 125, 100)': 3151,
#    '(192, 184, 173)': 1812,
#    '(82, 98, 120)': 64,
#    '(137, 77, 48)': 378,
#    '(199, 160, 96)': 64}},
#  '1903_mm_dd_i_Автопортрет_в_аду.jpg': {'path': '1903_mm_dd_i_Автопортрет_в_аду.jpg',
#   'name_of_painting': 'Автопортрет в аду',
#   'year': '1903',
#   'most_common_colors_ever': {'(35, 36, 39)': 4857,
#    '(73, 64, 55)': 1769,
#    '(139, 125, 100)': 36,
#    '(192, 184, 173)': 0,
#    '(82, 98, 120)': 0,
#    '(137, 77, 48)': 3117,
#    '(199, 160, 96)': 195}},
#  '1903_mm_dd_i_Белая_ночь._Осгардстран.jpg': {'path': '1903_mm_dd_i_Белая_ночь._Осгардстран.jpg',
#   'name_of_painting': 'Белая ночь. Осгардстран',
#   'year': '1903',
#   'most_common_colors_ever': {'(35, 36, 39)': 3248,
#    '(73, 64, 55)': 1163,
#    '(139, 125, 100)': 293,
#    '(192, 184, 173)': 440,
#    '(82, 98, 120)': 136,
#    '(137, 77, 48)': 127,
#    '(199, 160, 96)': 763}},
#  '1903_mm_dd_i_Дамы_на_мосту.jpg': {'path': '1903_mm_dd_i_Дамы_на_мосту.jpg',
#   'name_of_painting': 'Дамы на мосту',
#   'year': '1903',
#   'most_common_colors_ever': {'(35, 36, 39)': 3024,
#    '(73, 64, 55)': 1376,
#    '(139, 125, 100)': 884,
#    '(192, 184, 173)': 1567,
#    '(82, 98, 120)': 171,
#    '(137, 77, 48)': 49,
#    '(199, 160, 96)': 98}},
#  '1903_mm_dd_i_Двое_детей_на_пути_в_сказочный_лес.jpg': {'path': '1903_mm_dd_i_Двое_детей_на_пути_в_сказочный_лес.jpg',
#   'name_of_painting': 'Двое детей на пути в сказочный лес',
#   'year': '1903',
#   'most_common_colors_ever': {'(35, 36, 39)': 470,
#    '(73, 64, 55)': 772,
#    '(139, 125, 100)': 353,
#    '(192, 184, 173)': 23,
#    '(82, 98, 120)': 457,
#    '(137, 77, 48)': 559,
#    '(199, 160, 96)': 367}},
#  '1903_mm_dd_i_Дети.jpg': {'path': '1903_mm_dd_i_Дети.jpg',
#   'name_of_painting': 'Дети',
#   'year': '1903',
#   'most_common_colors_ever': {'(35, 36, 39)': 1356,
#    '(73, 64, 55)': 980,
#    '(139, 125, 100)': 1095,
#    '(192, 184, 173)': 3069,
#    '(82, 98, 120)': 26,
#    '(137, 77, 48)': 248,
#    '(199, 160, 96)': 353}},
#  '1903_mm_dd_i_Ночь_святого_Ханса.jpg': {'path': '1903_mm_dd_i_Ночь_святого_Ханса.jpg',
#   'name_of_painting': 'Ночь святого Ханса',
#   'year': '1903',
#   'most_common_colors_ever': {'(35, 36, 39)': 1198,
#    '(73, 64, 55)': 1513,
#    '(139, 125, 100)': 1144,
#    '(192, 184, 173)': 1339,
#    '(82, 98, 120)': 15,
#    '(137, 77, 48)': 234,
#    '(199, 160, 96)': 346}},
#  '1903_mm_dd_i_Три_девушки_на_причале.jpg': {'path': '1903_mm_dd_i_Три_девушки_на_причале.jpg',
#   'name_of_painting': 'Три девушки на причале',
#   'year': '1903',
#   'most_common_colors_ever': {'(35, 36, 39)': 1281,
#    '(73, 64, 55)': 1065,
#    '(139, 125, 100)': 432,
#    '(192, 184, 173)': 1647,
#    '(82, 98, 120)': 24,
#    '(137, 77, 48)': 264,
#    '(199, 160, 96)': 768}},
#  '1903_mm_dd_i_Штормовой_пейзаж.jpg': {'path': '1903_mm_dd_i_Штормовой_пейзаж.jpg',
# ...
#    '(137, 77, 48)': 0,
#    '(199, 160, 96)': 0}},
#  '1913_mm_dd_i_Обнаженная.jpg': {'path': '1913_mm_dd_i_Обнаженная.jpg',
#   'name_of_painting': 'Обнаженная',
#   'year': '1913',
#   'most_common_colors_ever': {'(35, 36, 39)': 1696,
#    '(73, 64, 55)': 1387,
#    '(139, 125, 100)': 288,
#    '(192, 184, 173)': 783,
#    '(82, 98, 120)': 252,
#    '(137, 77, 48)': 577,
#    '(199, 160, 96)': 69}},
#  '1913_mm_dd_i_Солнце.jpg': {'path': '1913_mm_dd_i_Солнце.jpg',
#   'name_of_painting': 'Солнце',
#   'year': '1913',
#   'most_common_colors_ever': {'(35, 36, 39)': 66,
#    '(73, 64, 55)': 683,
#    '(139, 125, 100)': 870,
#    '(192, 184, 173)': 1117,
#    '(82, 98, 120)': 1209,
#    '(137, 77, 48)': 53,
#    '(199, 160, 96)': 337}},
#  '1915_mm_dd_a_Автопортрет1.jpg': {'path': '1915_mm_dd_a_Автопортрет1.jpg',
#   'name_of_painting': 'Автопортрет1',
#   'year': '1915',
#   'most_common_colors_ever': {'(35, 36, 39)': 370,
#    '(73, 64, 55)': 145,
#    '(139, 125, 100)': 82,
#    '(192, 184, 173)': 530,
#    '(82, 98, 120)': 2,
#    '(137, 77, 48)': 39,
#    '(199, 160, 96)': 208}},
#  '1915_mm_dd_a_Автопортрет_в_плаще_и_со_шляпой.jpg': {'path': '1915_mm_dd_a_Автопортрет_в_плаще_и_со_шляпой.jpg',
#   'name_of_painting': 'Автопортрет в плаще и со шляпой',
#   'year': '1915',
#   'most_common_colors_ever': {'(35, 36, 39)': 450,
#    '(73, 64, 55)': 236,
#    '(139, 125, 100)': 871,
#    '(192, 184, 173)': 702,
#    '(82, 98, 120)': 330,
#    '(137, 77, 48)': 109,
#    '(199, 160, 96)': 329}},
#  '1915_mm_dd_a_Автопортрет_с_шляпой_и_красным_галстуком.jpg': {'path': '1915_mm_dd_a_Автопортрет_с_шляпой_и_красным_галстуком.jpg',
#   'name_of_painting': 'Автопортрет с шляпой и красным галстуком',
#   'year': '1915',
#   'most_common_colors_ever': {'(35, 36, 39)': 3169,
#    '(73, 64, 55)': 511,
#    '(139, 125, 100)': 131,
#    '(192, 184, 173)': 804,
#    '(82, 98, 120)': 374,
#    '(137, 77, 48)': 69,
#    '(199, 160, 96)': 23}},
#  '1915_mm_dd_i_Дети_на_улице.jpg': {'path': '1915_mm_dd_i_Дети_на_улице.jpg',
#   'name_of_painting': 'Дети на улице',
#   'year': '1915',
#   'most_common_colors_ever': {'(35, 36, 39)': 752,
#    '(73, 64, 55)': 663,
#    '(139, 125, 100)': 564,
#    '(192, 184, 173)': 5262,
#    '(82, 98, 120)': 87,
#    '(137, 77, 48)': 134,
#    '(199, 160, 96)': 133}},
#  '1915_mm_dd_i_Рабочие_на_пути_домой.jpg': {'path': '1915_mm_dd_i_Рабочие_на_пути_домой.jpg',
#   'name_of_painting': 'Рабочие на пути домой',
#   'year': '1915',
#   'most_common_colors_ever': {'(35, 36, 39)': 2731,
#    '(73, 64, 55)': 2149,
#    '(139, 125, 100)': 1051,
#    '(192, 184, 173)': 860,
#    '(82, 98, 120)': 1346,
#    '(137, 77, 48)': 75,
#    '(199, 160, 96)': 44}},
#  '1916_mm_dd_a_Автопортрет_в_Бергене.jpg': {'path': '1916_mm_dd_a_Автопортрет_в_Бергене.jpg',
#   'name_of_painting': 'Автопортрет в Бергене',
#   'year': '1916',
#   'most_common_colors_ever': {'(35, 36, 39)': 295,
#    '(73, 64, 55)': 1976,
#    '(139, 125, 100)': 397,
#    '(192, 184, 173)': 3453,
#    '(82, 98, 120)': 277,
#    '(137, 77, 48)': 254,
#    '(199, 160, 96)': 85}},
#  '1916_mm_dd_i_Солнце.jpg': {'path': '1916_mm_dd_i_Солнце.jpg',
#   'name_of_painting': 'Солнце',
#   'year': '1916',
#   'most_common_colors_ever': {'(35, 36, 39)': 359,
#    '(73, 64, 55)': 584,
#    '(139, 125, 100)': 1773,
#    '(192, 184, 173)': 2112,
#    '(82, 98, 120)': 312,
#    '(137, 77, 48)': 109,
#    '(199, 160, 96)': 391}},
#  '1918_mm_dd_i_Адам_и_Ева.jpg': {'path': '1918_mm_dd_i_Адам_и_Ева.jpg',
#   'name_of_painting': 'Адам и Ева',
#   'year': '1918',
#   'most_common_colors_ever': {'(35, 36, 39)': 4584,
#    '(73, 64, 55)': 4963,
#    '(139, 125, 100)': 92,
#    '(192, 184, 173)': 0,
#    '(82, 98, 120)': 84,
#    '(137, 77, 48)': 785,
#    '(199, 160, 96)': 732}},
#  '1919_mm_dd_a_Автопортрет_(в_смятении).jpg': {'path': '1919_mm_dd_a_Автопортрет_(в_смятении).jpg',
#   'name_of_painting': 'Автопортрет (в смятении)',
#   'year': '1919',
#   'most_common_colors_ever': {'(35, 36, 39)': 762,
#    '(73, 64, 55)': 733,
#    '(139, 125, 100)': 317,
#    '(192, 184, 173)': 279,
#    '(82, 98, 120)': 53,
#    '(137, 77, 48)': 414,
#    '(199, 160, 96)': 171}},
#  '1919_mm_dd_a_Автопортрет_после_испанского_гриппа.jpg': {'path': '1919_mm_dd_a_Автопортрет_после_испанского_гриппа.jpg',
#   'name_of_painting': 'Автопортрет после испанского гриппа',
#   'year': '1919',
#   'most_common_colors_ever': {'(35, 36, 39)': 835,
#    '(73, 64, 55)': 1254,
#    '(139, 125, 100)': 918,
#    '(192, 184, 173)': 904,
#    '(82, 98, 120)': 260,
#    '(137, 77, 48)': 480,
#    '(199, 160, 96)': 530}},
#  '1919_mm_dd_a_Автопортрет_после_испанского_гриппа2.jpg': {'path': '1919_mm_dd_a_Автопортрет_после_испанского_гриппа2.jpg',
#   'name_of_painting': 'Автопортрет после испанского гриппа2',
#   'year': '1919',
#   'most_common_colors_ever': {'(35, 36, 39)': 2421,
#    '(73, 64, 55)': 1059,
#    '(139, 125, 100)': 529,
#    '(192, 184, 173)': 231,
#    '(82, 98, 120)': 31,
#    '(137, 77, 48)': 517,
#    '(199, 160, 96)': 1357}},
#  '1919_mm_dd_a_Автопортрет_после_испанского_гриппа3.jpg': {'path': '1919_mm_dd_a_Автопортрет_после_испанского_гриппа3.jpg',
#   'name_of_painting': 'Автопортрет после испанского гриппа3',
#   'year': '1919',
#   'most_common_colors_ever': {'(35, 36, 39)': 2890,
#    '(73, 64, 55)': 535,
#    '(139, 125, 100)': 264,
#    '(192, 184, 173)': 953,
#    '(82, 98, 120)': 295,
#    '(137, 77, 48)': 218,
#    '(199, 160, 96)': 219}},
#  '1919_mm_dd_i_Автопортрет_(в_смятении).jpg': {'path': '1919_mm_dd_i_Автопортрет_(в_смятении).jpg',
#   'name_of_painting': 'Автопортрет (в смятении)',
#   'year': '1919',
#   'most_common_colors_ever': {'(35, 36, 39)': 773,
#    '(73, 64, 55)': 737,
#    '(139, 125, 100)': 318,
#    '(192, 184, 173)': 280,
#    '(82, 98, 120)': 53,
#    '(137, 77, 48)': 415,
#    '(199, 160, 96)': 171}},
#  '1919_mm_dd_i_Автопортрет_после_испанки.jpg': {'path': '1919_mm_dd_i_Автопортрет_после_испанки.jpg',
#   'name_of_painting': 'Автопортрет после испанки',
#   'year': '1919',
#   'most_common_colors_ever': {'(35, 36, 39)': 4305,
#    '(73, 64, 55)': 717,
#    '(139, 125, 100)': 337,
#    '(192, 184, 173)': 1515,
#    '(82, 98, 120)': 9,
#    '(137, 77, 48)': 414,
#    '(199, 160, 96)': 44}},
#  '1919_mm_dd_i_Убийца_на_дороге.jpg': {'path': '1919_mm_dd_i_Убийца_на_дороге.jpg',
#   'name_of_painting': 'Убийца на дороге',
#   'year': '1919',
#   'most_common_colors_ever': {'(35, 36, 39)': 806,
#    '(73, 64, 55)': 502,
#    '(139, 125, 100)': 606,
#    '(192, 184, 173)': 361,
#    '(82, 98, 120)': 414,
#    '(137, 77, 48)': 332,
#    '(199, 160, 96)': 852}},
#  '1921_mm_dd_i_Художник_и_его_модель.jpg': {'path': '1921_mm_dd_i_Художник_и_его_модель.jpg',
#   'name_of_painting': 'Художник и его модель',
#   'year': '1921',
#   'most_common_colors_ever': {'(35, 36, 39)': 1748,
#    '(73, 64, 55)': 1305,
#    '(139, 125, 100)': 382,
#    '(192, 184, 173)': 587,
#    '(82, 98, 120)': 468,
#    '(137, 77, 48)': 686,
#    '(199, 160, 96)': 660}},
#  '1922_mm_dd_i_Звездная_ночь.jpg': {'path': '1922_mm_dd_i_Звездная_ночь.jpg',
#   'name_of_painting': 'Звездная ночь',
#   'year': '1922',
#   'most_common_colors_ever': {'(35, 36, 39)': 3068,
#    '(73, 64, 55)': 822,
#    '(139, 125, 100)': 111,
#    '(192, 184, 173)': 145,
#    '(82, 98, 120)': 986,
#    '(137, 77, 48)': 14,
#    '(199, 160, 96)': 20}},
#  '1923_mm_dd_a_Автопортрет.jpg': {'path': '1923_mm_dd_a_Автопортрет.jpg',
#   'name_of_painting': 'Автопортрет',
#   'year': '1923',
#   'most_common_colors_ever': {'(35, 36, 39)': 930,
#    '(73, 64, 55)': 467,
#    '(139, 125, 100)': 273,
#    '(192, 184, 173)': 1076,
#    '(82, 98, 120)': 906,
#    '(137, 77, 48)': 74,
#    '(199, 160, 96)': 43}},
#  '1924_mm_dd_a_Автопортрет._Ночной_странник.jpg': {'path': '1924_mm_dd_a_Автопортрет._Ночной_странник.jpg',
#   'name_of_painting': 'Автопортрет. Ночной странник',
#   'year': '1924',
#   'most_common_colors_ever': {'(35, 36, 39)': 3946,
#    '(73, 64, 55)': 4858,
#    '(139, 125, 100)': 503,
#    '(192, 184, 173)': 72,
#    '(82, 98, 120)': 224,
#    '(137, 77, 48)': 166,
#    '(199, 160, 96)': 412}},
#  '1924_mm_dd_i_Молодая_женщина_на_веранде.jpg': {'path': '1924_mm_dd_i_Молодая_женщина_на_веранде.jpg',
#   'name_of_painting': 'Молодая женщина на веранде',
#   'year': '1924',
#   'most_common_colors_ever': {'(35, 36, 39)': 178,
#    '(73, 64, 55)': 1460,
#    '(139, 125, 100)': 1510,
#    '(192, 184, 173)': 1772,
#    '(82, 98, 120)': 125,
#    '(137, 77, 48)': 1605,
#    '(199, 160, 96)': 70}},
#  '1925_mm_dd_i_Цыганская_свадьба.jpg': {'path': '1925_mm_dd_i_Цыганская_свадьба.jpg',
#   'name_of_painting': 'Цыганская свадьба',
#   'year': '1925',
#   'most_common_colors_ever': {'(35, 36, 39)': 2837,
#    '(73, 64, 55)': 623,
#    '(139, 125, 100)': 356,
#    '(192, 184, 173)': 567,
#    '(82, 98, 120)': 470,
#    '(137, 77, 48)': 54,
#    '(199, 160, 96)': 112}},
#  '1926_mm_dd_a_Автопортрет_в_Экели.jpg': {'path': '1926_mm_dd_a_Автопортрет_в_Экели.jpg',
#   'name_of_painting': 'Автопортрет в Экели',
#   'year': '1926',
#   'most_common_colors_ever': {'(35, 36, 39)': 1230,
#    '(73, 64, 55)': 1455,
#    '(139, 125, 100)': 243,
#    '(192, 184, 173)': 1265,
#    '(82, 98, 120)': 125,
#    '(137, 77, 48)': 39,
#    '(199, 160, 96)': 825}},
#  '1926_mm_dd_a_Автопортрет_за_свадебным_столом.jpg': {'path': '1926_mm_dd_a_Автопортрет_за_свадебным_столом.jpg',
#   'name_of_painting': 'Автопортрет за свадебным столом',
#   'year': '1926',
#   'most_common_colors_ever': {'(35, 36, 39)': 3999,
#    '(73, 64, 55)': 994,
#    '(139, 125, 100)': 259,
#    '(192, 184, 173)': 334,
#    '(82, 98, 120)': 542,
#    '(137, 77, 48)': 219,
#    '(199, 160, 96)': 226}},
#  '1926_mm_dd_a_Автопортрет_на_фоне_стены_дома.jpg': {'path': '1926_mm_dd_a_Автопортрет_на_фоне_стены_дома.jpg',
#   'name_of_painting': 'Автопортрет на фоне стены дома',
#   'year': '1926',
#   'most_common_colors_ever': {'(35, 36, 39)': 356,
#    '(73, 64, 55)': 1023,
#    '(139, 125, 100)': 1013,
#    '(192, 184, 173)': 553,
#    '(82, 98, 120)': 141,
#    '(137, 77, 48)': 349,
#    '(199, 160, 96)': 414}},
#  '1926_mm_dd_a_Автопортрет_с_руками_в_карманах.jpg': {'path': '1926_mm_dd_a_Автопортрет_с_руками_в_карманах.jpg',
#   'name_of_painting': 'Автопортрет с руками в карманах',
#   'year': '1926',
#   'most_common_colors_ever': {'(35, 36, 39)': 3460,
#    '(73, 64, 55)': 532,
#    '(139, 125, 100)': 97,
#    '(192, 184, 173)': 818,
#    '(82, 98, 120)': 1525,
#    '(137, 77, 48)': 104,
#    '(199, 160, 96)': 39}},
#  '1927_mm_dd_i_Dog.jpeg': {'path': '1927_mm_dd_i_Dog.jpeg',
#   'name_of_painting': 'Dog.jpeg',
#   'year': '1927',
#   'most_common_colors_ever': {'(35, 36, 39)': 2534,
#    '(73, 64, 55)': 3204,
#    '(139, 125, 100)': 924,
#    '(192, 184, 173)': 2,
#    '(82, 98, 120)': 0,
#    '(137, 77, 48)': 817,
#    '(199, 160, 96)': 306}},
#  '1927_mm_dd_i_Red House and Spruces.jpeg': {'path': '1927_mm_dd_i_Red House and Spruces.jpeg',
#   'name_of_painting': 'Red House and Spruces.jpeg',
#   'year': '1927',
#   'most_common_colors_ever': {'(35, 36, 39)': 72,
#    '(73, 64, 55)': 54,
#    '(139, 125, 100)': 142,
#    '(192, 184, 173)': 524,
#    '(82, 98, 120)': 366,
#    '(137, 77, 48)': 28,
#    '(199, 160, 96)': 101}},
#  '1928_mm_dd_i_Модель_на_кушетке.jpg': {'path': '1928_mm_dd_i_Модель_на_кушетке.jpg',
#   'name_of_painting': 'Модель на кушетке',
#   'year': '1928',
#   'most_common_colors_ever': {'(35, 36, 39)': 2352,
#    '(73, 64, 55)': 1679,
#    '(139, 125, 100)': 497,
#    '(192, 184, 173)': 1208,
#    '(82, 98, 120)': 725,
#    '(137, 77, 48)': 185,
#    '(199, 160, 96)': 54}},
#  '1929_mm_dd_i_Обнаженная_рядом_с_плетеным_креслом.jpg': {'path': '1929_mm_dd_i_Обнаженная_рядом_с_плетеным_креслом.jpg',
#   'name_of_painting': 'Обнаженная рядом с плетеным креслом',
#   'year': '1929',
#   'most_common_colors_ever': {'(35, 36, 39)': 1304,
#    '(73, 64, 55)': 864,
#    '(139, 125, 100)': 1190,
#    '(192, 184, 173)': 1070,
#    '(82, 98, 120)': 191,
#    '(137, 77, 48)': 823,
#    '(199, 160, 96)': 340}},
#  '1930_mm_dd_a_Автопортрет_во_время_болезни_глаз.jpg': {'path': '1930_mm_dd_a_Автопортрет_во_время_болезни_глаз.jpg',
#   'name_of_painting': 'Автопортрет во время болезни глаз',
#   'year': '1930',
#   'most_common_colors_ever': {'(35, 36, 39)': 3811,
#    '(73, 64, 55)': 1331,
#    '(139, 125, 100)': 502,
#    '(192, 184, 173)': 1025,
#    '(82, 98, 120)': 241,
#    '(137, 77, 48)': 419,
#    '(199, 160, 96)': 359}},
#  '1930_mm_dd_i_Голова_собаки.jpg': {'path': '1930_mm_dd_i_Голова_собаки.jpg',
#   'name_of_painting': 'Голова собаки',
#   'year': '1930',
#   'most_common_colors_ever': {'(35, 36, 39)': 2985,
#    '(73, 64, 55)': 2002,
#    '(139, 125, 100)': 529,
#    '(192, 184, 173)': 289,
#    '(82, 98, 120)': 7,
#    '(137, 77, 48)': 375,
#    '(199, 160, 96)': 338}},
#  '1935_mm_dd_i_Одинокие.jpg': {'path': '1935_mm_dd_i_Одинокие.jpg',
#   'name_of_painting': 'Одинокие',
#   'year': '1935',
#   'most_common_colors_ever': {'(35, 36, 39)': 735,
#    '(73, 64, 55)': 485,
#    '(139, 125, 100)': 292,
#    '(192, 184, 173)': 476,
#    '(82, 98, 120)': 57,
#    '(137, 77, 48)': 616,
#    '(199, 160, 96)': 90}},
#  '1938_mm_dd_a_Автопортрет_с_бутылками.jpg': {'path': '1938_mm_dd_a_Автопортрет_с_бутылками.jpg',
#   'name_of_painting': 'Автопортрет с бутылками',
#   'year': '1938',
#   'most_common_colors_ever': {'(35, 36, 39)': 1400,
#    '(73, 64, 55)': 411,
#    '(139, 125, 100)': 410,
#    '(192, 184, 173)': 1727,
#    '(82, 98, 120)': 338,
#    '(137, 77, 48)': 185,
#    '(199, 160, 96)': 301}},
#  '1940_mm_dd_a_Автопортрет_с_головой_трески.jpg': {'path': '1940_mm_dd_a_Автопортрет_с_головой_трески.jpg',
#   'name_of_painting': 'Автопортрет с головой трески',
#   'year': '1940',
#   'most_common_colors_ever': {'(35, 36, 39)': 3426,
#    '(73, 64, 55)': 863,
#    '(139, 125, 100)': 456,
#    '(192, 184, 173)': 238,
#    '(82, 98, 120)': 382,
#    '(137, 77, 48)': 241,
#    '(199, 160, 96)': 553}},
#  '1940_mm_dd_a_У_окна.jpg': {'path': '1940_mm_dd_a_У_окна.jpg',
#   'name_of_painting': 'У окна',
#   'year': '1940',
#   'most_common_colors_ever': {'(35, 36, 39)': 1530,
#    '(73, 64, 55)': 1123,
#    '(139, 125, 100)': 791,
#    '(192, 184, 173)': 877,
#    '(82, 98, 120)': 9,
#    '(137, 77, 48)': 196,
#    '(199, 160, 96)': 65}},
#  '1940_mm_dd_i_Женщины_на_мосту.jpg': {'path': '1940_mm_dd_i_Женщины_на_мосту.jpg',
#   'name_of_painting': 'Женщины на мосту',
#   'year': '1940',
#   'most_common_colors_ever': {'(35, 36, 39)': 578,
#    '(73, 64, 55)': 392,
#    '(139, 125, 100)': 243,
#    '(192, 184, 173)': 214,
#    '(82, 98, 120)': 152,
#    '(137, 77, 48)': 410,
#    '(199, 160, 96)': 393}},
#  '1942_mm_dd_a_Автопортрет_в_саду_Экели.jpg': {'path': '1942_mm_dd_a_Автопортрет_в_саду_Экели.jpg',
#   'name_of_painting': 'Автопортрет в саду Экели',
#   'year': '1942',
#   'most_common_colors_ever': {'(35, 36, 39)': 1,
#    '(73, 64, 55)': 1977,
#    '(139, 125, 100)': 3772,
#    '(192, 184, 173)': 481,
#    '(82, 98, 120)': 17,
#    '(137, 77, 48)': 306,
#    '(199, 160, 96)': 250}},
#  '1943_mm_dd_a_Автопортрет_с_пастельной_палкой_2.jpg': {'path': '1943_mm_dd_a_Автопортрет_с_пастельной_палкой_2.jpg',
#   'name_of_painting': 'Автопортрет с пастельной палкой 2',
#   'year': '1943',
#   'most_common_colors_ever': {'(35, 36, 39)': 2040,
#    '(73, 64, 55)': 1844,
#    '(139, 125, 100)': 588,
#    '(192, 184, 173)': 549,
#    '(82, 98, 120)': 312,
#    '(137, 77, 48)': 170,
#    '(199, 160, 96)': 507}},
#  '1943_mm_dd_a_Между_часами_и_кроватью._Автопортрет.jpg': {'path': '1943_mm_dd_a_Между_часами_и_кроватью._Автопортрет.jpg',
#   'name_of_painting': 'Между часами и кроватью. Автопортрет',
#   'year': '1943',
#   'most_common_colors_ever': {'(35, 36, 39)': 2929,
#    '(73, 64, 55)': 1881,
#    '(139, 125, 100)': 656,
#    '(192, 184, 173)': 1045,
#    '(82, 98, 120)': 209,
#    '(137, 77, 48)': 359,
#    '(199, 160, 96)': 247}},
#  '1943_mm_dd_i_Автопортрет_между_часами_и_кроватью.jpg': {'path': '1943_mm_dd_i_Автопортрет_между_часами_и_кроватью.jpg',
#   'name_of_painting': 'Автопортрет между часами и кроватью',
#   'year': '1943',
#   'most_common_colors_ever': {'(35, 36, 39)': 716,
#    '(73, 64, 55)': 2051,
#    '(139, 125, 100)': 935,
#    '(192, 184, 173)': 94,
#    '(82, 98, 120)': 318,
#    '(137, 77, 48)': 225,
#    '(199, 160, 96)': 88}},
#  '1944_mm_dd_a_Автопортрет_в_полосатом_свитере.jpg': {'path': '1944_mm_dd_a_Автопортрет_в_полосатом_свитере.jpg',
#   'name_of_painting': 'Автопортрет в полосатом свитере',
#   'year': '1944',
#   'most_common_colors_ever': {'(35, 36, 39)': 1313,
#    '(73, 64, 55)': 652,
#    '(139, 125, 100)': 419,
#    '(192, 184, 173)': 791,
#    '(82, 98, 120)': 125,
#    '(137, 77, 48)': 329,
#    '(199, 160, 96)': 271}}}

# %%
for i in files: 
    print(' '.join((i.split('_')[4:])).replace('.jpg', ''))
# Out:
# Автопортрет
# Автопортрет в 19 лет
# Девушка
# Больная девочка
# Автопортрет
# Автопортрет
# Летняя ночь (Ингер на берегу)
# Весна
# Ночь в Ницце
# Улица Лафайет
# Автопортрет под женской маской
# Вечер на улице Карла Иоанна
# Лунный свет на берегу
# Меланхолия
# Портрет Ингер Мунк
# Тайна летней ночи
#
# Буря
# Голос
# Крик
# Лунный свет
# Меланхолия
# Руки
# Смерть в комнате больного
# Мадонна
# Пепел
# Созревание
# Тревога
# Три стадии женщины (Сфинкс)
# Автопортрет с зажженной сигаретой
# Автопортрет со скелетом руки
# Автопортрет с зажжённой сигаретой
# Вампир
# Запах смерти
# Крик 1
# Лунный свет
# Мадонна
# Следующий день
# У смертного одра
# Автопортрет со скелетом руки
# Голос (Летняя ночь)
# Девушка на берегу
# Расставание
# Мать и дочь
# Поцелуй
# Поцелуй
# Вынос гроба
# Две женщины. Символический этюд
# Женщина у фьорда в Осгорстранне
# Красный дикий виноград
# Мужчина и женщина
# Обнаженная в профиль справа
# Плодородие
# Пляж
# Радуга
# Ревность в купалье
# Сидящая обнаженная на пляже
# Дом Мунка в Осгорстранне
# Дом и мастерская Мунка в Осгорстранне
# Дом с красным виноградом
# Дом с красным диким виноградом
# Зима в лесу. Нурстранн
# Летняя ночь в Студентерлюннене
# Метрвая мать и ребенок
# Обмен веществ
# Осе и Харальд Нёррегор
# Плодородие
# Портрет Осе Неррегор
# Сидящая обнажённая женщина и три мужские головы
# Смерть и ребенок
# Танец жизни
# Темный еловый лес 1
# Темный еловый лес 2
# Темный еловый лес 3
# Трагедия
# Тулла Ларсен 1
# Тулла Ларсен 2
# Белая ночь
# Вид из Нурстранна
# Вид из Нурстранна 1
# Глаза в глаза
# Голгофа
# Дымящий поезд
# Закат. Нурстранн
# Зима
# Красное и белое
# Красный плющ
# Меланхолия
# Остров
# Парижский бульвар
# Танец жизни
# Танцы на пляже
# Девочки на мосту 1
# Девочки на мосту 2
# Зима в Нурстранне
# Зимний лес
# Зимняя ночь
# Улица в Осгорстранне 1
# Улица в Осгорстранне 2
# книга
# В саду
# Вампир 2
# Две обнаженные у комода
# Девочка в красном клетчатом платье и красной шляпе
# Девочки на мосту
# Девочки на мосту 1
# Дом в летнюю ночь
# Женщины на мосту
# Катафалк на Потсдамер-Платц
# Катафалк на Потсдамер-Платц 2
# На операционном столе
# Обнажённая с длинными рыжими волосами
# Обнаженная
# Обнаженная в интерьере
# Одежда на веревочке в Осгорстранне
# Плодородие
# Приёмные матери перед окружным судом
# Рыбак на жёлтом фоне
# Сад
# Санаторий
# Сидящая обнаженная
# Сказочный лес
# Старый рыбак со своей дочерью
# Улица в Осгорстранне с женщиной в красном платье
# Утро. Обнаженная у окна
# Яблоня
# Автопортрет в Аду
# Автопортрет на операционном столе
# Автопортрет в аду
# Белая ночь. Осгардстран
# Дамы на мосту
# Двое детей на пути в сказочный лес
# Дети
# Ночь святого Ханса
# Три девушки на причале
# Штормовой пейзаж
# Автопортрт
# Автопортрет с кистями
# Летний день
# Летняя ночь в Арсгардстранде
# Летняя ночь на пляже
# Мадонна
# Пейзаж с красным домом
# Рождество в публичном доме
# Сын
# Четыре этапа жизни
# Автопортерт
# Автопортрет на зелёном фоне
# Автопортрет с Тулла Ларсен
# Голова к голове
# Два человека. Одинокие
# Дом у фьорда
# Наследие
# Под звездами
# Автопортрет на красном фоне
# Автопортрет с бутылкой вина
# Первый снег
# Сельская улица
# Убийца
# Фридрих Ницше
# Автопортрет
# Больная девочка
# Пара на побережье
# Публичный дом. Для милой Мадель
# Смерть Марата
# Автопортрет на фоне голубого неба
# Автопортрет в больнице профессора Якобсона
# Медсёстры с простынёй.jpeg
# Крик
# Убийца
# Автопортрет с рукой у щеки
# Меланхолия
# Зима, Крагеро.jpeg
# Автопортрет
# Обнаженная
# Солнце
# Автопортрет1
# Автопортрет в плаще и со шляпой
# Автопортрет с шляпой и красным галстуком
# Дети на улице
# Рабочие на пути домой
# Автопортрет в Бергене
# Солнце
# Адам и Ева
# Автопортрет (в смятении)
# Автопортрет после испанского гриппа
# Автопортрет после испанского гриппа2
# Автопортрет после испанского гриппа3
# Автопортрет (в смятении)
# Автопортрет после испанки
# Убийца на дороге
# Художник и его модель
# Звездная ночь
# Автопортрет
# Автопортрет. Ночной странник
# Молодая женщина на веранде
# Цыганская свадьба
# Автопортрет в Экели
# Автопортрет за свадебным столом
# Автопортрет на фоне стены дома
# Автопортрет с руками в карманах
# Dog.jpeg
# Red House and Spruces.jpeg
# Модель на кушетке
# Обнаженная рядом с плетеным креслом
# Автопортрет во время болезни глаз
# Голова собаки
# Одинокие
# Автопортрет с бутылками
# Автопортрет с головой трески
# У окна
# Женщины на мосту
# Автопортрет в саду Экели
# Автопортрет с пастельной палкой 2
# Между часами и кроватью. Автопортрет
# Автопортрет между часами и кроватью
# Автопортрет в полосатом свитере

# %%
for i in info_dict:
    info

# %% [markdown]
# #### BayesianGaussianMixture:

# %%
results_BGM, years, files = analyze_most_popular_ever_colors(folder_path, np.array(most_common_colors_gaussbayes))

# %%
plot_bar_distribution(results_BGM, years, model_name='BayesianGaussianMixture')

# %%
df_BGM = pd.DataFrame.from_dict(results_BGM, orient='index', columns=years)
df_BGM = df_BGM.T
df_BGM = df_BGM.reset_index().rename(columns={'index': 'year'})
df_BGM = df_BGM.groupby('year', as_index=False).sum()
df_BGM.head()
# Out:
#    year  (126, 124, 113)  (51, 50, 49)  (125, 78, 53)  (199, 164, 114)  \
# 0  1882              471         11074            229             1465
# 1  1883              814           321           1403             1988
# 2  1885              577          6982            126              103
# 3  1886              307          5684            612              469
# 4  1888              333          2897           1588             1141
#
#    (201, 195, 184)  (21, 22, 24)  (55, 73, 93)
# 0              303         11192          1388
# 1              492           135            17
# 2              561          2532           481
# 3              154          4721           477
# 4               20          1710            20

# %%
len(df_BGM)
# Out:
# 49

# %% [markdown]
# #### KMeans (без перевода в LAB):

# %%
results_gb, years, files = analyze_most_popular_ever_colors(folder_path, np.array(most_common_colors_nolab))

# %%
plot_bar_distribution(results_gb, years, model_name='KMeans (RGB)')

# %% [markdown]
# ### Смотрим отдельно основные цвета

# %%
def is_color_in_range(lab_pixel, lower_bound, upper_bound):
    return np.all((lab_pixel >= lower_bound) & (lab_pixel <= upper_bound))

# %%
def count_pixels_in_color_range(image_path, lower_bound, upper_bound):
    img = cv2.imread(image_path)
    
    img = cv2.resize(img, (128, 128)) 
    img_lab = cv2.cvtColor(img, cv2.COLOR_BGR2LAB)
    lab_array = img_lab.reshape(-1, 3)
    
    mask = np.apply_along_axis(is_color_in_range, 1, lab_array, lower_bound, upper_bound)
    total_pixels = lab_array.shape[0]
    
    color_pixel_count = np.sum(mask)
    return color_pixel_count, total_pixels

# %%
def analyze_images_in_range(folder_path, lower_bound, upper_bound):
    results = {}
    total_pixels_per_year = {}
    
    for filename in sorted(os.listdir(folder_path)):
        if filename.lower().endswith(('.png', '.jpg', '.jpeg')):
            image_path = os.path.join(folder_path, filename)
            
            year = extract_year_from_filename(filename)
            if year is None:
                continue
            
            color_count, total_pixels = count_pixels_in_color_range(image_path, lower_bound, upper_bound)
            
            if year in results:
                results[year] += color_count
                total_pixels_per_year[year] += total_pixels
            else:
                results[year] = color_count
                total_pixels_per_year[year] = total_pixels
    
    years = np.array(list(results.keys()))
    normalized_counts = np.array([results[year] for year in years]) # / total_pixels_per_year[year] for year in years])
    
    sorted_indices = np.argsort(years)
    years = years[sorted_indices]
    normalized_counts = normalized_counts[sorted_indices]
    
    return normalized_counts, years

# %%
def plot_color_distribution(results, years, color_name, color_hex):
    sns.set_theme(style="white")
    plt.rcParams['font.family'] = 'serif'
    plt.rcParams['font.serif'] = ['Times New Roman']
    
    plt.figure(figsize=(15, 10))
    plt.bar(range(len(years)), results, color=color_hex, label=f'{color_name} диапазон')
    plt.title(f'Распределение цвета ({color_name}) по годам', fontdict={'fontsize': 16, 'fontweight': 'bold'})
    plt.xlabel('Год', fontdict={'fontsize': 12})
    plt.ylabel('Доля пикселей в изображениях', fontdict={'fontsize': 12})
    plt.xticks(ticks=range(len(years)), labels=years, rotation=45)
    # plt.legend(loc='upper left')
    plt.xlim(-0.5, len(years) - 0.5)
    plt.show()

# %%
def get_lab_color_range(lab_center, tolerance):
    lower_bound = np.clip(lab_center - tolerance, [0, -128, -128], [100, 127, 127])
    upper_bound = np.clip(lab_center + tolerance, [0, -128, -128], [100, 127, 127])
    return lower_bound, upper_bound

# %%
def analyze_images_by_color_mean(folder_path, color):
    results = {}
    total_pixels_per_year = {}
    for filename in sorted(os.listdir(folder_path)):
        if filename.lower().endswith(('.png', '.jpg', '.jpeg')):
            image_path = os.path.join(folder_path, filename)
            
            year = extract_year_from_filename(filename)
            im = cv2.imread(image_path, cv2.IMREAD_COLOR)
            im = cv2.resize(im, (128, 128))
            if color == 'red':
                im = im[:, :, 0]
            elif color == 'green':
                im = im[:, :,1]
            elif color == 'blue':
                im = im[:, :, 2]
            elif color == 'yellow':
                im = im[:, :, 0].astype(float) / 2 + im[:, :, 1].astype(float) / 2
            color_count = im.mean() / 256.

            if year is None:
                continue

            if year in results:
                results[year].append(color_count)
            else:
                results[year] = [color_count]

    for year in results:
        results[year] = np.mean(results[year])

    years = np.array(list(results.keys()))
    normalized_counts = np.array(list(results.values()))
    sorted_indices = np.argsort(years)
    years = years[sorted_indices]
    normalized_counts = normalized_counts[sorted_indices]
    

    return normalized_counts, years

# %% [markdown]
# #### Красный:

# %%
results, years = analyze_images_by_color_mean(folder_path, color='red')
results
# Out:
# libpng warning: iCCP: known incorrect sRGB profile
# array([0.23879981, 0.36393595, 0.35134345, 0.29042878, 0.31355548,
#        0.26466711, 0.43265452, 0.17107189, 0.29417431, 0.35812298,
#        0.3603436 , 0.26469553, 0.46046205, 0.27991406, 0.32788089,
#        0.28227377, 0.31905403, 0.23304554, 0.38816461, 0.33263   ,
#        0.3672787 , 0.44956183, 0.41062617, 0.44150949, 0.21828222,
#        0.41369367])

# %%
color_hex = '#{:02x}{:02x}{:02x}'.format(152, 79, 50)
plot_color_distribution(results, years, color_name="красный", color_hex=color_hex)

# %% [markdown]
# #### Зеленый:

# %%
results, years = analyze_images_by_color_mean(folder_path, color='green')
# Out:
# libpng warning: iCCP: known incorrect sRGB profile

# %%
color_hex = '#{:02x}{:02x}{:02x}'.format(145, 130, 104)
plot_color_distribution(results, years, color_name="зеленый", color_hex=color_hex)

# %% [markdown]
# #### Синий:

# %%
results, years = analyze_images_by_color_mean(folder_path, color='blue')
# Out:
# libpng warning: iCCP: known incorrect sRGB profile

# %%
color_hex = '#{:02x}{:02x}{:02x}'.format(102, 118, 146)
plot_color_distribution(results, years, color_name="синий", color_hex=color_hex)

# %% [markdown]
# #### Желтый:

# %%
results, years = analyze_images_by_color_mean(folder_path, color='yellow')
# Out:
# libpng warning: iCCP: known incorrect sRGB profile

# %%
color_hex = '#{:02x}{:02x}{:02x}'.format(198, 159, 82)
plot_color_distribution(results, years, color_name="желтый", color_hex=color_hex)

# %% [markdown]
# ### Смотрим 7 самых часто используемых цветов за каждый год

# %%
def rgb_to_lab(rgb_pixels):
    rgb_pixels = rgb_pixels / 255.0
    lab_pixels = scolor.rgb2lab(rgb_pixels.reshape(-1, 1, 3)).reshape(-1, 3)
    return lab_pixels

def lab_to_rgb(lab_color):
    lab_color = np.array(lab_color).reshape(1, 1, 3)
    rgb_color = scolor.lab2rgb(lab_color).reshape(3) * 255
    rgb_color = np.clip(rgb_color, 0, 255).astype(int)
    return tuple(rgb_color)

# %%
def get_most_common_colors(image_path, classifier, num_colors=7, resize_dim=(128, 128), rounding=10):
# def get_most_common_colors(image_path, classifier, num_colors=7, resize_dim=(50, 50), rounding=10):
    image = Image.open(image_path).convert('RGB')
    image = image.resize(resize_dim)
    pixels = np.array(image).reshape(-1, 3)
    pixels = rgb_to_lab(pixels)

    if classifier == 'Counter':
        pixels = (pixels // rounding) * rounding
        color_counter = Counter(map(tuple, pixels))  # Преобразуем в кортежи
        most_common = color_counter.most_common(num_colors)
    
    elif classifier == 'KMeans':
        kmeans = KMeans(n_clusters=num_colors, random_state=42)
        kmeans.fit(pixels)
        labels = kmeans.labels_
        cluster_centers = kmeans.cluster_centers_
        
        color_counter = Counter(labels)
        most_common1 = color_counter.most_common(num_colors)
        
        most_common = []
        for cluster_idx, count in most_common1:
            lab_color = cluster_centers[cluster_idx]
            rgb_color = lab_to_rgb(lab_color)
            # most_common.append((rgb_color, count))
            # most_common.append((tuple(rgb_color.astype(int)), count))
            most_common.append((rgb_color, count))
            

    elif classifier == 'GM':
        gmm = GaussianMixture(n_components=num_colors, random_state=42)
        gmm.fit(pixels)
        labels = gmm.predict(pixels)
        cluster_centers = gmm.means_

        # Подсчет количества пикселей в каждом кластере
        color_counter = Counter(labels)
        most_common_labels = color_counter.most_common(num_colors)

        most_common = []
        for cluster_idx, count in most_common_labels:
            lab_color = cluster_centers[cluster_idx]
            rgb_color = scolor.lab2rgb(lab_color.reshape(1, 1, 3)).reshape(3) * 255  # LAB → RGB
            most_common.append((tuple(rgb_color.astype(int)), count))  # Преобразуем в кортеж
            
    elif classifier == 'GMM':
        gmm = BayesianGaussianMixture(n_components=num_colors, random_state=42)
        gmm.fit(pixels)
        labels = gmm.predict(pixels)
        cluster_centers = gmm.means_
        
        color_counter = Counter(labels)
        most_common1 = color_counter.most_common(num_colors)
        
        most_common = []
        for cluster_idx, count in most_common1:
            lab_color = cluster_centers[cluster_idx]
            rgb_color = lab_to_rgb(lab_color)
            most_common.append((rgb_color, count))

    return most_common  # Список (цвет, количество пикселей)

# %%
def get_colors_by_year(images_folder, classifier):
    
    colors_by_year = {}
    
    for file in os.listdir(images_folder):
        if file.endswith('.jpeg') or file.endswith('.jpg') or file.endswith('.png'):
            try:
                year = file.split('_')[0]
                year = int(year)
            except ValueError:
                continue
            
            image_path = os.path.join(images_folder, file)
            common_colors = get_most_common_colors(image_path, classifier)
            
            if year not in colors_by_year:
                colors_by_year[year] = []
            
            # add color codes and pixel counts
            for color, count in common_colors:
                colors_by_year[year].append((color, count))
    
    # top-7 by each year
    top_colors_by_year = {}
    for year, colors in colors_by_year.items():
        if classifier == 'KMeans':
            # color_counter = Counter({tuple(color): count for color, count in colors.items()})
            color_counter = Counter(dict(colors)) 
        else:
            color_counter = Counter(dict(colors)) # count the number of pixels for each color
        top_colors = color_counter.most_common(7)
        top_colors_by_year[year] = {color: count for color, count in top_colors}
    
    return top_colors_by_year

# def get_colors_by_year(images_folder, classifier):
    
#     colors_by_year = {}
    
#     for file in os.listdir(images_folder):
#         if file.endswith('.jpeg') or file.endswith('.jpg') or file.endswith('.png'):
#             # try:
#             #     year = file.split('_')[0]
#             #     year = int(year)
#             # except ValueError:
#             #     continue
#             year = file
            
#             image_path = os.path.join(images_folder, file)
#             common_colors = get_most_common_colors(image_path, classifier)
            
#             if year not in colors_by_year:
#                 colors_by_year[year] = []
            
#             # add color codes and pixel counts
#             for color, count in common_colors:
#                 colors_by_year[year].append((color, count))
    
#     # top-7 by each year
#     top_colors_by_year = {}
#     for year, colors in colors_by_year.items():
#         if classifier == 'KMeans':
#             # color_counter = Counter({tuple(color): count for color, count in colors.items()})
#             color_counter = Counter(dict(colors)) 
#         else:
#             color_counter = Counter(dict(colors)) # count the number of pixels for each color
#         top_colors = color_counter.most_common(7)
#         top_colors_by_year[year] = {str(color): count for color, count in top_colors}
    
#     return top_colors_by_year

# %%
def sort_colors_by_luminance(colors):
    # Calculate luminance (L channel) for each color in LAB space and sort by it
    lab_colors = np.array(colors)
    luminance = lab_colors[:, 0]  # L channel in LAB space
    sorted_indices = np.argsort(luminance)  # Sort based on luminance (L channel)
    return np.array(colors)[sorted_indices]

def calculate_brightness(lab_color):
    return lab_color[0]

# %%
def plot_color_distribution(colors_by_year, how, classifier):
    years = [year for year in sorted(colors_by_year.keys()) if colors_by_year[year]] # filter the years for which there is data
    
    # all colors
    all_colors = set()
    for color_dict in colors_by_year.values():
        all_colors.update(color_dict.keys())
    all_colors = list(all_colors)
    
    data = {color: [] for color in all_colors}
    
    # Normalize data on the Y axis (0 to 1) for each year
    for year in years:
        year_data = colors_by_year.get(year, {})
        total_pixels = sum(year_data.values())  # sum of all pixels for one year
        if total_pixels == 0: 
            total_pixels = 1
        for color in all_colors:
            count = year_data.get(color, 0)
            normalized_count = count / total_pixels  # normalizing
            data[color].append(normalized_count)
        
    if how == 'sorted':
        # if classifier == 'GM' or classifier == 'KMeans':
        if classifier in {'GM', 'KMeans', 'GMM'}:
            all_colors = sorted(all_colors, key=lambda color: calculate_brightness(rgb_to_lab(np.array([color]))[0]), reverse=False)
        # sorted_colors = sorted(all_colors, key=lambda color: calculate_brightness(rgb_to_lab(np.array([color]))[0]), reverse=False)
        else:
            all_colors = sort_colors_by_luminance(list(all_colors))
    
    bottom = np.zeros(len(years))
    
    plt.rcParams['font.family'] = 'serif'
    plt.rcParams['font.serif'] = ['Times New Roman']

    plt.figure(figsize=(15, 8))
    
    for color in all_colors:
        # Converting from LAB to RGB for display on a graph
        if classifier == 'Counter':
            lab_color = np.array(color).reshape(1, 1, 3)
            rgb_color = scolor.lab2rgb(lab_color).reshape(3) 
            rgb_color = np.clip(rgb_color, 0, 1)
        
        if how == 'not_sorted':
            if classifier == 'GM':
                plt.bar(range(len(years)), data[color], bottom=bottom, color=np.array(color)/255.0, label=str(color))
                bottom += np.array(data[color])
            elif classifier == 'KMeans':
                plt.bar(range(len(years)), data[color], bottom=bottom, color=np.array(color)/255.0, label=str(color))
                bottom += np.array(data[color])
            elif classifier == 'GMM':
                plt.bar(range(len(years)), data[color], bottom=bottom, color=np.array(color)/255.0, label=str(color))
                bottom += np.array(data[color])
            else:
                plt.bar(range(len(years)), data[color], bottom=bottom, color=rgb_color, label=str(color))
                bottom += np.array(data[color])
    
        elif how == 'sorted':
            if classifier == 'GM':
                # plt.bar(range(len(years)), data[color], bottom=bottom, color=np.array(color)/255.0, label=str(color))
                color_tuple = tuple(color) 
                plt.bar(range(len(years)), data[color_tuple], bottom=bottom, color=np.array(color)/255.0, label=str(color))
                bottom += np.array(data[color_tuple])
            elif classifier == 'KMeans':
                plt.bar(range(len(years)), data[color], bottom=bottom, color=np.array(color)/255.0, label=str(color))
                bottom += np.array(data[color])
            elif classifier == 'GMM':
                plt.bar(range(len(years)), data[color], bottom=bottom, color=np.array(color)/255.0, label=str(color))
                bottom += np.array(data[color])
            else:
                plt.bar(range(len(years)), data[tuple(color)], bottom=bottom, color=rgb_color, label=str(color))
                bottom += np.array(data[tuple(color)])
    
    plt.xlabel('Год', fontdict={'fontsize': 12})
    plt.ylabel('Нормализованное количество пикселей', fontdict={'fontsize': 12})
    plt.title('Частота использования топ-7 цветов на картинах по годам', fontdict={'fontsize': 16, 'fontweight': 'bold'})
    plt.xticks(ticks=range(len(years)), labels=years, rotation=45)
    plt.show()

# %% [markdown]
# #### Counter:

# %%
colors_by_year = get_colors_by_year(folder_path, classifier='Counter')

# %%
# pprint(colors_by_year)

# %%
rows = []
for year, colors in colors_by_year.items():
    for (r, g, b), count in colors.items():
        rows.append((year, r, g, b, count))

df = pd.DataFrame(rows, columns=['year', 'R', 'G', 'B', 'Count'])

# %%
df
# Out:
#      year     R     G     B  Count
# 0    1938  70.0 -10.0   0.0   1429
# 1    1938  80.0 -10.0   0.0    695
# 2    1938  60.0 -10.0   0.0    497
# 3    1938   0.0   0.0 -10.0    423
# 4    1938  10.0   0.0 -10.0    397
# ..    ...   ...   ...   ...    ...
# 338  1910  60.0   0.0  30.0    805
# 339  1910  70.0 -10.0   0.0    753
# 340  1910  60.0   0.0  20.0    687
# 341  1910  20.0 -10.0 -10.0    659
# 342  1910  50.0   0.0  20.0    644
#
# [343 rows x 5 columns]

# %%
plot_color_distribution(colors_by_year, how='not_sorted', classifier='Counter')

# %% [markdown]
# Отсортировано по яркости:

# %%
plot_color_distribution(colors_by_year, how='sorted', classifier='Counter')

# %% [markdown]
# #### GaussianMixture:

# %%
info_dict
# Out:
# {'1882_mm_dd_a_Автопортрет.jpg': {'path': '1882_mm_dd_a_Автопортрет.jpg',
#   'name_of_painting': 'Автопортрет',
#   'year': '1882',
#   'most_common_colors_ever': {'(35, 36, 39)': 4381,
#    '(73, 64, 55)': 2151,
#    '(139, 125, 100)': 429,
#    '(192, 184, 173)': 61,
#    '(82, 98, 120)': 13,
#    '(137, 77, 48)': 0,
#    '(199, 160, 96)': 259}},
#  '1882_mm_dd_a_Автопортрет_в_19_лет.jpg': {'path': '1882_mm_dd_a_Автопортрет_в_19_лет.jpg',
#   'name_of_painting': 'Автопортрет в 19 лет',
#   'year': '1882',
#   'most_common_colors_ever': {'(35, 36, 39)': 5159,
#    '(73, 64, 55)': 1873,
#    '(139, 125, 100)': 415,
#    '(192, 184, 173)': 169,
#    '(82, 98, 120)': 0,
#    '(137, 77, 48)': 36,
#    '(199, 160, 96)': 12}},
#  '1883_mm_dd_i_Девушка.jpg': {'path': '1883_mm_dd_i_Девушка.jpg',
#   'name_of_painting': 'Девушка',
#   'year': '1883',
#   'most_common_colors_ever': {'(35, 36, 39)': 242,
#    '(73, 64, 55)': 786,
#    '(139, 125, 100)': 2828,
#    '(192, 184, 173)': 410,
#    '(82, 98, 120)': 1,
#    '(137, 77, 48)': 555,
#    '(199, 160, 96)': 403}},
#  '1885_mm_dd_i_Больная_девочка.jpg': {'path': '1885_mm_dd_i_Больная_девочка.jpg',
#   'name_of_painting': 'Больная девочка',
#   'year': '1885',
#   'most_common_colors_ever': {'(35, 36, 39)': 6573,
#    '(73, 64, 55)': 3510,
#    '(139, 125, 100)': 365,
#    '(192, 184, 173)': 630,
#    '(82, 98, 120)': 106,
#    '(137, 77, 48)': 69,
#    '(199, 160, 96)': 48}},
#  '1886_mm_dd_a_Автопортрет.jpg': {'path': '1886_mm_dd_a_Автопортрет.jpg',
#   'name_of_painting': 'Автопортрет',
#   'year': '1886',
#   'most_common_colors_ever': {'(35, 36, 39)': 5856,
#    '(73, 64, 55)': 2217,
#    '(139, 125, 100)': 830,
#    '(192, 184, 173)': 376,
#    '(82, 98, 120)': 37,
#    '(137, 77, 48)': 330,
#    '(199, 160, 96)': 120}},
#  '1888_mm_dd_a_Автопортрет.jpg': {'path': '1888_mm_dd_a_Автопортрет.jpg',
#   'name_of_painting': 'Автопортрет',
#   'year': '1888',
#   'most_common_colors_ever': {'(35, 36, 39)': 2551,
#    '(73, 64, 55)': 2783,
#    '(139, 125, 100)': 870,
#    '(192, 184, 173)': 21,
#    '(82, 98, 120)': 10,
#    '(137, 77, 48)': 945,
#    '(199, 160, 96)': 1302}},
#  '1889_mm_dd_i_Летняя_ночь_(Ингер_на_берегу).jpg': {'path': '1889_mm_dd_i_Летняя_ночь_(Ингер_на_берегу).jpg',
#   'name_of_painting': 'Летняя ночь (Ингер на берегу)',
#   'year': '1889',
#   'most_common_colors_ever': {'(35, 36, 39)': 1476,
#    '(73, 64, 55)': 1034,
#    '(139, 125, 100)': 882,
#    '(192, 184, 173)': 408,
#    '(82, 98, 120)': 74,
#    '(137, 77, 48)': 6,
#    '(199, 160, 96)': 131}},
#  '1889_mm_xx_i_Весна.jpg': {'path': '1889_mm_xx_i_Весна.jpg',
#   'name_of_painting': 'Весна',
#   'year': '1889',
#   'most_common_colors_ever': {'(35, 36, 39)': 1946,
#    '(73, 64, 55)': 1650,
#    '(139, 125, 100)': 1863,
#    '(192, 184, 173)': 1266,
#    '(82, 98, 120)': 21,
#    '(137, 77, 48)': 176,
#    '(199, 160, 96)': 69}},
#  '1891_mm_dd_i_Ночь_в_Ницце.jpg': {'path': '1891_mm_dd_i_Ночь_в_Ницце.jpg',
#   'name_of_painting': 'Ночь в Ницце',
#   'year': '1891',
#   'most_common_colors_ever': {'(35, 36, 39)': 1183,
#    '(73, 64, 55)': 834,
#    '(139, 125, 100)': 689,
#    '(192, 184, 173)': 6,
#    '(82, 98, 120)': 1567,
#    '(137, 77, 48)': 2,
#    '(199, 160, 96)': 11}},
#  '1891_mm_dd_i_Улица_Лафайет.jpg': {'path': '1891_mm_dd_i_Улица_Лафайет.jpg',
#   'name_of_painting': 'Улица Лафайет',
#   'year': '1891',
#   'most_common_colors_ever': {'(35, 36, 39)': 527,
#    '(73, 64, 55)': 563,
#    '(139, 125, 100)': 839,
#    '(192, 184, 173)': 2065,
#    '(82, 98, 120)': 173,
#    '(137, 77, 48)': 81,
#    '(199, 160, 96)': 413}},
#  '1892_mm_dd_a_Автопортрет_под_женской_маской.jpg': {'path': '1892_mm_dd_a_Автопортрет_под_женской_маской.jpg',
#   'name_of_painting': 'Автопортрет под женской маской',
#   'year': '1892',
#   'most_common_colors_ever': {'(35, 36, 39)': 3311,
#    '(73, 64, 55)': 3473,
#    '(139, 125, 100)': 75,
#    '(192, 184, 173)': 73,
#    '(82, 98, 120)': 0,
#    '(137, 77, 48)': 2823,
#    '(199, 160, 96)': 89}},
#  '1892_mm_dd_i_Вечер_на_улице_Карла_Иоанна.jpg': {'path': '1892_mm_dd_i_Вечер_на_улице_Карла_Иоанна.jpg',
#   'name_of_painting': 'Вечер на улице Карла Иоанна',
#   'year': '1892',
#   'most_common_colors_ever': {'(35, 36, 39)': 3387,
#    '(73, 64, 55)': 2082,
#    '(139, 125, 100)': 583,
#    '(192, 184, 173)': 15,
#    '(82, 98, 120)': 757,
#    '(137, 77, 48)': 834,
#    '(199, 160, 96)': 202}},
#  '1892_mm_dd_i_Лунный_свет_на_берегу.jpg': {'path': '1892_mm_dd_i_Лунный_свет_на_берегу.jpg',
#   'name_of_painting': 'Лунный свет на берегу',
#   'year': '1892',
#   'most_common_colors_ever': {'(35, 36, 39)': 2952,
#    '(73, 64, 55)': 1892,
#    '(139, 125, 100)': 786,
#    '(192, 184, 173)': 487,
#    '(82, 98, 120)': 148,
#    '(137, 77, 48)': 0,
#    '(199, 160, 96)': 368}},
#  '1892_mm_dd_i_Меланхолия.jpg': {'path': '1892_mm_dd_i_Меланхолия.jpg',
#   'name_of_painting': 'Меланхолия',
#   'year': '1892',
#   'most_common_colors_ever': {'(35, 36, 39)': 1042,
#    '(73, 64, 55)': 507,
#    '(139, 125, 100)': 2120,
#    '(192, 184, 173)': 393,
#    '(82, 98, 120)': 467,
#    '(137, 77, 48)': 22,
#    '(199, 160, 96)': 33}},
#  '1892_mm_dd_i_Портрет_Ингер_Мунк.jpg': {'path': '1892_mm_dd_i_Портрет_Ингер_Мунк.jpg',
#   'name_of_painting': 'Портрет Ингер Мунк',
#   'year': '1892',
#   'most_common_colors_ever': {'(35, 36, 39)': 1199,
#    '(73, 64, 55)': 158,
#    '(139, 125, 100)': 174,
#    '(192, 184, 173)': 8,
#    '(82, 98, 120)': 0,
#    '(137, 77, 48)': 187,
#    '(199, 160, 96)': 85}},
#  '1892_mm_dd_i_Тайна_летней_ночи.jpg': {'path': '1892_mm_dd_i_Тайна_летней_ночи.jpg',
#   'name_of_painting': 'Тайна летней ночи',
#   'year': '1892',
#   'most_common_colors_ever': {'(35, 36, 39)': 1009,
#    '(73, 64, 55)': 1148,
#    '(139, 125, 100)': 1234,
#    '(192, 184, 173)': 228,
#    '(82, 98, 120)': 3035,
#    '(137, 77, 48)': 13,
#    '(199, 160, 96)': 531}},
#  '1892_mm_dd_Отчаяние.jpg': {'path': '1892_mm_dd_Отчаяние.jpg',
#   'name_of_painting': '',
#   'year': '1892',
#   'most_common_colors_ever': {'(35, 36, 39)': 4915,
#    '(73, 64, 55)': 846,
#    '(139, 125, 100)': 130,
#    '(192, 184, 173)': 110,
#    '(82, 98, 120)': 1294,
#    '(137, 77, 48)': 25,
#    '(199, 160, 96)': 219}},
#  '1893_mm_dd_i_Буря.jpg': {'path': '1893_mm_dd_i_Буря.jpg',
#   'name_of_painting': 'Буря',
#   'year': '1893',
#   'most_common_colors_ever': {'(35, 36, 39)': 5392,
#    '(73, 64, 55)': 3810,
#    '(139, 125, 100)': 2252,
#    '(192, 184, 173)': 295,
#    '(82, 98, 120)': 1,
#    '(137, 77, 48)': 92,
#    '(199, 160, 96)': 105}},
#  '1893_mm_dd_i_Голос.jpg': {'path': '1893_mm_dd_i_Голос.jpg',
#   'name_of_painting': 'Голос',
#   'year': '1893',
#   'most_common_colors_ever': {'(35, 36, 39)': 978,
#    '(73, 64, 55)': 526,
#    '(139, 125, 100)': 251,
#    '(192, 184, 173)': 1565,
#    '(82, 98, 120)': 0,
#    '(137, 77, 48)': 439,
#    '(199, 160, 96)': 36}},
#  '1893_mm_dd_i_Крик.jpg': {'path': '1893_mm_dd_i_Крик.jpg',
#   'name_of_painting': 'Крик',
#   'year': '1893',
#   'most_common_colors_ever': {'(35, 36, 39)': 13,
#    '(73, 64, 55)': 2360,
#    '(139, 125, 100)': 2634,
#    '(192, 184, 173)': 0,
#    '(82, 98, 120)': 314,
#    '(137, 77, 48)': 706,
#    '(199, 160, 96)': 26}},
#  '1893_mm_dd_i_Лунный_свет.jpg': {'path': '1893_mm_dd_i_Лунный_свет.jpg',
#   'name_of_painting': 'Лунный свет',
#   'year': '1893',
#   'most_common_colors_ever': {'(35, 36, 39)': 1300,
#    '(73, 64, 55)': 913,
#    '(139, 125, 100)': 571,
#    '(192, 184, 173)': 969,
#    '(82, 98, 120)': 132,
#    '(137, 77, 48)': 295,
#    '(199, 160, 96)': 0}},
#  '1893_mm_dd_i_Меланхолия.jpg': {'path': '1893_mm_dd_i_Меланхолия.jpg',
#   'name_of_painting': 'Меланхолия',
#   'year': '1893',
#   'most_common_colors_ever': {'(35, 36, 39)': 213,
#    '(73, 64, 55)': 156,
#    '(139, 125, 100)': 206,
#    '(192, 184, 173)': 1127,
#    '(82, 98, 120)': 95,
#    '(137, 77, 48)': 41,
#    '(199, 160, 96)': 1}},
#  '1893_mm_dd_i_Руки.jpg': {'path': '1893_mm_dd_i_Руки.jpg',
#   'name_of_painting': 'Руки',
#   'year': '1893',
#   'most_common_colors_ever': {'(35, 36, 39)': 1002,
#    '(73, 64, 55)': 2040,
#    '(139, 125, 100)': 912,
#    '(192, 184, 173)': 92,
#    '(82, 98, 120)': 114,
#    '(137, 77, 48)': 1120,
#    '(199, 160, 96)': 1137}},
#  '1893_mm_dd_i_Смерть_в_комнате_больного.jpg': {'path': '1893_mm_dd_i_Смерть_в_комнате_больного.jpg',
#   'name_of_painting': 'Смерть в комнате больного',
#   'year': '1893',
#   'most_common_colors_ever': {'(35, 36, 39)': 1171,
#    '(73, 64, 55)': 1448,
#    '(139, 125, 100)': 570,
#    '(192, 184, 173)': 121,
#    '(82, 98, 120)': 830,
#    '(137, 77, 48)': 648,
#    '(199, 160, 96)': 81}},
#  '1894_mm_dd_i_Мадонна.jpg.jpg': {'path': '1894_mm_dd_i_Мадонна.jpg.jpg',
#   'name_of_painting': 'Мадонна',
#   'year': '1894',
#   'most_common_colors_ever': {'(35, 36, 39)': 1210,
#    '(73, 64, 55)': 2328,
#    '(139, 125, 100)': 86,
#    '(192, 184, 173)': 7,
#    '(82, 98, 120)': 1,
#    '(137, 77, 48)': 1750,
#    '(199, 160, 96)': 392}},
#  '1894_mm_dd_i_Пепел.jpg': {'path': '1894_mm_dd_i_Пепел.jpg',
#   'name_of_painting': 'Пепел',
#   'year': '1894',
#   'most_common_colors_ever': {'(35, 36, 39)': 211,
#    '(73, 64, 55)': 6003,
#    '(139, 125, 100)': 899,
#    '(192, 184, 173)': 454,
#    '(82, 98, 120)': 75,
#    '(137, 77, 48)': 806,
#    '(199, 160, 96)': 517}},
#  '1894_mm_dd_i_Созревание.jpg': {'path': '1894_mm_dd_i_Созревание.jpg',
#   'name_of_painting': 'Созревание',
#   'year': '1894',
#   'most_common_colors_ever': {'(35, 36, 39)': 4337,
#    '(73, 64, 55)': 4940,
#    '(139, 125, 100)': 943,
#    '(192, 184, 173)': 331,
#    '(82, 98, 120)': 16,
#    '(137, 77, 48)': 189,
#    '(199, 160, 96)': 42}},
#  '1894_mm_dd_i_Тревога.jpg': {'path': '1894_mm_dd_i_Тревога.jpg',
#   'name_of_painting': 'Тревога',
#   'year': '1894',
#   'most_common_colors_ever': {'(35, 36, 39)': 6739,
#    '(73, 64, 55)': 1842,
#    '(139, 125, 100)': 185,
#    '(192, 184, 173)': 1,
#    '(82, 98, 120)': 31,
#    '(137, 77, 48)': 319,
#    '(199, 160, 96)': 659}},
#  '1894_mm_dd_i_Три_стадии_женщины_(Сфинкс).jpg': {'path': '1894_mm_dd_i_Три_стадии_женщины_(Сфинкс).jpg',
#   'name_of_painting': 'Три стадии женщины (Сфинкс)',
#   'year': '1894',
#   'most_common_colors_ever': {'(35, 36, 39)': 6170,
#    '(73, 64, 55)': 3557,
#    '(139, 125, 100)': 576,
#    '(192, 184, 173)': 6,
#    '(82, 98, 120)': 0,
#    '(137, 77, 48)': 23,
#    '(199, 160, 96)': 490}},
#  '1895_mm_dd_a_Автопортрет_с_зажженной_сигаретой.jpg': {'path': '1895_mm_dd_a_Автопортрет_с_зажженной_сигаретой.jpg',
#   'name_of_painting': 'Автопортрет с зажженной сигаретой',
#   'year': '1895',
#   'most_common_colors_ever': {'(35, 36, 39)': 5239,
#    '(73, 64, 55)': 2199,
#    '(139, 125, 100)': 145,
#    '(192, 184, 173)': 82,
#    '(82, 98, 120)': 986,
#    '(137, 77, 48)': 4,
#    '(199, 160, 96)': 7}},
#  '1895_mm_dd_a_Автопортрет_со_скелетом_руки.jpg': {'path': '1895_mm_dd_a_Автопортрет_со_скелетом_руки.jpg',
#   'name_of_painting': 'Автопортрет со скелетом руки',
#   'year': '1895',
#   'most_common_colors_ever': {'(35, 36, 39)': 3,
#    '(73, 64, 55)': 7115,
#    '(139, 125, 100)': 2396,
#    '(192, 184, 173)': 435,
#    '(82, 98, 120)': 0,
#    '(137, 77, 48)': 0,
#    '(199, 160, 96)': 2}},
#  '1895_mm_dd_i_Автопортрет_с_зажжённой_сигаретой.jpg': {'path': '1895_mm_dd_i_Автопортрет_с_зажжённой_сигаретой.jpg',
#   'name_of_painting': 'Автопортрет с зажжённой сигаретой',
#   'year': '1895',
#   'most_common_colors_ever': {'(35, 36, 39)': 5342,
#    '(73, 64, 55)': 2169,
#    '(139, 125, 100)': 148,
#    '(192, 184, 173)': 80,
#    '(82, 98, 120)': 952,
#    '(137, 77, 48)': 4,
#    '(199, 160, 96)': 9}},
#  '1895_mm_dd_i_Вампир.jpg': {'path': '1895_mm_dd_i_Вампир.jpg',
#   'name_of_painting': 'Вампир',
#   'year': '1895',
#   'most_common_colors_ever': {'(35, 36, 39)': 5821,
#    '(73, 64, 55)': 2986,
#    '(139, 125, 100)': 14,
#    '(192, 184, 173)': 7,
#    '(82, 98, 120)': 2,
#    '(137, 77, 48)': 305,
#    '(199, 160, 96)': 1}},
#  '1895_mm_dd_i_Запах_смерти.jpg': {'path': '1895_mm_dd_i_Запах_смерти.jpg',
#   'name_of_painting': 'Запах смерти',
#   'year': '1895',
#   'most_common_colors_ever': {'(35, 36, 39)': 2064,
#    '(73, 64, 55)': 984,
#    '(139, 125, 100)': 305,
#    '(192, 184, 173)': 177,
#    '(82, 98, 120)': 199,
#    '(137, 77, 48)': 285,
#    '(199, 160, 96)': 51}},
#  '1895_mm_dd_i_Крик_1.jpg': {'path': '1895_mm_dd_i_Крик_1.jpg',
#   'name_of_painting': 'Крик 1',
#   'year': '1895',
#   'most_common_colors_ever': {'(35, 36, 39)': 51,
#    '(73, 64, 55)': 414,
#    '(139, 125, 100)': 815,
#    '(192, 184, 173)': 182,
#    '(82, 98, 120)': 1608,
#    '(137, 77, 48)': 25,
#    '(199, 160, 96)': 792}},
#  '1895_mm_dd_i_Лунный_свет.jpg': {'path': '1895_mm_dd_i_Лунный_свет.jpg',
#   'name_of_painting': 'Лунный свет',
#   'year': '1895',
#   'most_common_colors_ever': {'(35, 36, 39)': 3233,
#    '(73, 64, 55)': 669,
#    '(139, 125, 100)': 51,
#    '(192, 184, 173)': 84,
#    '(82, 98, 120)': 386,
#    '(137, 77, 48)': 78,
#    '(199, 160, 96)': 76}},
#  '1895_mm_dd_i_Мадонна.jpg': {'path': '1895_mm_dd_i_Мадонна.jpg',
#   'name_of_painting': 'Мадонна',
#   'year': '1895',
#   'most_common_colors_ever': {'(35, 36, 39)': 1594,
#    '(73, 64, 55)': 7307,
#    '(139, 125, 100)': 274,
#    '(192, 184, 173)': 1580,
#    '(82, 98, 120)': 105,
#    '(137, 77, 48)': 1029,
#    '(199, 160, 96)': 0}},
#  '1895_mm_dd_i_Следующий_день.jpg': {'path': '1895_mm_dd_i_Следующий_день.jpg',
#   'name_of_painting': 'Следующий день',
#   'year': '1895',
#   'most_common_colors_ever': {'(35, 36, 39)': 2694,
#    '(73, 64, 55)': 3215,
#    '(139, 125, 100)': 286,
#    '(192, 184, 173)': 686,
#    '(82, 98, 120)': 69,
#    '(137, 77, 48)': 1818,
#    '(199, 160, 96)': 250}},
#  '1895_mm_dd_i_У_смертного_одра.jpg': {'path': '1895_mm_dd_i_У_смертного_одра.jpg',
#   'name_of_painting': 'У смертного одра',
#   'year': '1895',
#   'most_common_colors_ever': {'(35, 36, 39)': 4422,
#    '(73, 64, 55)': 945,
#    '(139, 125, 100)': 619,
#    '(192, 184, 173)': 355,
#    '(82, 98, 120)': 7,
#    '(137, 77, 48)': 757,
#    '(199, 160, 96)': 23}},
#  '1896_mm_dd_a_Автопортрет_со_скелетом_руки.jpg': {'path': '1896_mm_dd_a_Автопортрет_со_скелетом_руки.jpg',
#   'name_of_painting': 'Автопортрет со скелетом руки',
#   'year': '1896',
#   'most_common_colors_ever': {'(35, 36, 39)': 1726,
#    '(73, 64, 55)': 473,
#    '(139, 125, 100)': 412,
#    '(192, 184, 173)': 354,
#    '(82, 98, 120)': 0,
#    '(137, 77, 48)': 0,
#    '(199, 160, 96)': 0}},
#  '1896_mm_dd_i_Голос_(Летняя_ночь).jpg': {'path': '1896_mm_dd_i_Голос_(Летняя_ночь).jpg',
#   'name_of_painting': 'Голос (Летняя ночь)',
#   'year': '1896',
#   'most_common_colors_ever': {'(35, 36, 39)': 2134,
#    '(73, 64, 55)': 1733,
#    '(139, 125, 100)': 172,
#    '(192, 184, 173)': 338,
#    '(82, 98, 120)': 657,
#    '(137, 77, 48)': 273,
#    '(199, 160, 96)': 38}},
#  '1896_mm_dd_i_Девушка_на_берегу.jpg': {'path': '1896_mm_dd_i_Девушка_на_берегу.jpg',
#   'name_of_painting': 'Девушка на берегу',
#   'year': '1896',
#   'most_common_colors_ever': {'(35, 36, 39)': 1659,
#    '(73, 64, 55)': 131,
#    '(139, 125, 100)': 134,
#    '(192, 184, 173)': 79,
#    '(82, 98, 120)': 3152,
#    '(137, 77, 48)': 123,
#    '(199, 160, 96)': 11}},
#  '1896_mm_dd_i_Расставание.jpg': {'path': '1896_mm_dd_i_Расставание.jpg',
#   'name_of_painting': 'Расставание',
#   'year': '1896',
#   'most_common_colors_ever': {'(35, 36, 39)': 2762,
#    '(73, 64, 55)': 1498,
#    '(139, 125, 100)': 641,
#    '(192, 184, 173)': 510,
#    '(82, 98, 120)': 139,
#    '(137, 77, 48)': 559,
#    '(199, 160, 96)': 279}},
#  '1897_mm_dd_i_Мать_и_дочь.jpg': {'path': '1897_mm_dd_i_Мать_и_дочь.jpg',
#   'name_of_painting': 'Мать и дочь',
#   'year': '1897',
#   'most_common_colors_ever': {'(35, 36, 39)': 708,
#    '(73, 64, 55)': 480,
#    '(139, 125, 100)': 86,
#    '(192, 184, 173)': 13,
#    '(82, 98, 120)': 32,
#    '(137, 77, 48)': 589,
#    '(199, 160, 96)': 29}},
#  '1897_mm_dd_i_Поцелуй.jpg': {'path': '1897_mm_dd_i_Поцелуй.jpg',
#   'name_of_painting': 'Поцелуй',
#   'year': '1897',
#   'most_common_colors_ever': {'(35, 36, 39)': 3531,
#    '(73, 64, 55)': 6310,
#    '(139, 125, 100)': 311,
#    '(192, 184, 173)': 256,
#    '(82, 98, 120)': 27,
#    '(137, 77, 48)': 15,
#    '(199, 160, 96)': 1}},
#  '1897_mm_dd_i_Поцелуй.jpg.jpg': {'path': '1897_mm_dd_i_Поцелуй.jpg.jpg',
#   'name_of_painting': 'Поцелуй',
#   'year': '1897',
#   'most_common_colors_ever': {'(35, 36, 39)': 2518,
#    '(73, 64, 55)': 162,
#    '(139, 125, 100)': 29,
#    '(192, 184, 173)': 19,
#    '(82, 98, 120)': 1097,
#    '(137, 77, 48)': 0,
#    '(199, 160, 96)': 3}},
#  '1898_mm_dd_i_Вынос_гроба.jpg': {'path': '1898_mm_dd_i_Вынос_гроба.jpg',
#   'name_of_painting': 'Вынос гроба',
#   'year': '1898',
#   'most_common_colors_ever': {'(35, 36, 39)': 186,
#    '(73, 64, 55)': 1865,
#    '(139, 125, 100)': 1014,
#    '(192, 184, 173)': 26,
#    '(82, 98, 120)': 194,
#    '(137, 77, 48)': 750,
#    '(199, 160, 96)': 280}},
#  '1898_mm_dd_i_Две_женщины._Символический_этюд.jpg': {'path': '1898_mm_dd_i_Две_женщины._Символический_этюд.jpg',
#   'name_of_painting': 'Две женщины. Символический этюд',
#   'year': '1898',
#   'most_common_colors_ever': {'(35, 36, 39)': 301,
#    '(73, 64, 55)': 813,
#    '(139, 125, 100)': 118,
#    '(192, 184, 173)': 0,
#    '(82, 98, 120)': 4,
#    '(137, 77, 48)': 2624,
#    '(199, 160, 96)': 277}},
#  '1898_mm_dd_i_Женщина_у_фьорда_в_Осгорстранне.jpg': {'path': '1898_mm_dd_i_Женщина_у_фьорда_в_Осгорстранне.jpg',
#   'name_of_painting': 'Женщина у фьорда в Осгорстранне',
#   'year': '1898',
#   'most_common_colors_ever': {'(35, 36, 39)': 1228,
#    '(73, 64, 55)': 1645,
#    '(139, 125, 100)': 773,
#    '(192, 184, 173)': 1311,
#    '(82, 98, 120)': 362,
#    '(137, 77, 48)': 86,
#    '(199, 160, 96)': 0}},
#  '1898_mm_dd_i_Красный_дикий_виноград.jpg': {'path': '1898_mm_dd_i_Красный_дикий_виноград.jpg',
#   'name_of_painting': 'Красный дикий виноград',
#   'year': '1898',
#   'most_common_colors_ever': {'(35, 36, 39)': 1372,
#    '(73, 64, 55)': 1549,
#    '(139, 125, 100)': 2885,
#    '(192, 184, 173)': 0,
#    '(82, 98, 120)': 1,
#    '(137, 77, 48)': 1312,
#    '(199, 160, 96)': 4}},
#  '1898_mm_dd_i_Мужчина_и_женщина.jpg': {'path': '1898_mm_dd_i_Мужчина_и_женщина.jpg',
#   'name_of_painting': 'Мужчина и женщина',
#   'year': '1898',
#   'most_common_colors_ever': {'(35, 36, 39)': 5537,
#    '(73, 64, 55)': 2141,
#    '(139, 125, 100)': 281,
#    '(192, 184, 173)': 2,
#    '(82, 98, 120)': 4,
#    '(137, 77, 48)': 419,
#    '(199, 160, 96)': 1407}},
#  '1898_mm_dd_i_Обнаженная_в_профиль_справа.jpg': {'path': '1898_mm_dd_i_Обнаженная_в_профиль_справа.jpg',
#   'name_of_painting': 'Обнаженная в профиль справа',
#   'year': '1898',
#   'most_common_colors_ever': {'(35, 36, 39)': 2416,
#    '(73, 64, 55)': 5263,
#    '(139, 125, 100)': 405,
#    '(192, 184, 173)': 377,
#    '(82, 98, 120)': 159,
#    '(137, 77, 48)': 211,
#    '(199, 160, 96)': 104}},
#  '1898_mm_dd_i_Плодородие.jpg': {'path': '1898_mm_dd_i_Плодородие.jpg',
#   'name_of_painting': 'Плодородие',
#   'year': '1898',
#   'most_common_colors_ever': {'(35, 36, 39)': 3463,
#    '(73, 64, 55)': 4011,
#    '(139, 125, 100)': 1170,
#    '(192, 184, 173)': 134,
#    '(82, 98, 120)': 40,
#    '(137, 77, 48)': 128,
#    '(199, 160, 96)': 54}},
#  '1898_mm_dd_i_Пляж.jpg': {'path': '1898_mm_dd_i_Пляж.jpg',
#   'name_of_painting': 'Пляж',
#   'year': '1898',
#   'most_common_colors_ever': {'(35, 36, 39)': 330,
#    '(73, 64, 55)': 2048,
#    '(139, 125, 100)': 3076,
#    '(192, 184, 173)': 0,
#    '(82, 98, 120)': 523,
#    '(137, 77, 48)': 320,
#    '(199, 160, 96)': 0}},
#  '1898_mm_dd_i_Радуга.jpg': {'path': '1898_mm_dd_i_Радуга.jpg',
#   'name_of_painting': 'Радуга',
#   'year': '1898',
#   'most_common_colors_ever': {'(35, 36, 39)': 2192,
#    '(73, 64, 55)': 3545,
#    '(139, 125, 100)': 228,
#    '(192, 184, 173)': 4,
#    '(82, 98, 120)': 177,
#    '(137, 77, 48)': 386,
#    '(199, 160, 96)': 7}},
#  '1898_mm_dd_i_Ревность_в_купалье.jpg': {'path': '1898_mm_dd_i_Ревность_в_купалье.jpg',
#   'name_of_painting': 'Ревность в купалье',
#   'year': '1898',
#   'most_common_colors_ever': {'(35, 36, 39)': 6,
#    '(73, 64, 55)': 980,
#    '(139, 125, 100)': 804,
#    '(192, 184, 173)': 98,
#    '(82, 98, 120)': 18,
#    '(137, 77, 48)': 1637,
#    '(199, 160, 96)': 1962}},
#  '1898_mm_dd_i_Сидящая_обнаженная_на_пляже.jpg': {'path': '1898_mm_dd_i_Сидящая_обнаженная_на_пляже.jpg',
#   'name_of_painting': 'Сидящая обнаженная на пляже',
#   'year': '1898',
#   'most_common_colors_ever': {'(35, 36, 39)': 4275,
#    '(73, 64, 55)': 500,
#    '(139, 125, 100)': 154,
#    '(192, 184, 173)': 18,
#    '(82, 98, 120)': 8,
#    '(137, 77, 48)': 1721,
#    '(199, 160, 96)': 39}},
#  '1899_mm_dd_i_Дом_Мунка_в_Осгорстранне.jpg': {'path': '1899_mm_dd_i_Дом_Мунка_в_Осгорстранне.jpg',
#   'name_of_painting': 'Дом Мунка в Осгорстранне',
#   'year': '1899',
#   'most_common_colors_ever': {'(35, 36, 39)': 12,
#    '(73, 64, 55)': 501,
#    '(139, 125, 100)': 330,
#    '(192, 184, 173)': 121,
#    '(82, 98, 120)': 210,
#    '(137, 77, 48)': 387,
#    '(199, 160, 96)': 1612}},
#  '1899_mm_dd_i_Дом_и_мастерская_Мунка_в_Осгорстранне.jpg': {'path': '1899_mm_dd_i_Дом_и_мастерская_Мунка_в_Осгорстранне.jpg',
#   'name_of_painting': 'Дом и мастерская Мунка в Осгорстранне',
#   'year': '1899',
#   'most_common_colors_ever': {'(35, 36, 39)': 940,
#    '(73, 64, 55)': 551,
#    '(139, 125, 100)': 189,
#    '(192, 184, 173)': 1482,
#    '(82, 98, 120)': 8,
#    '(137, 77, 48)': 820,
#    '(199, 160, 96)': 178}},
#  '1899_mm_dd_i_Дом_с_красным_виноградом.jpg': {'path': '1899_mm_dd_i_Дом_с_красным_виноградом.jpg',
#   'name_of_painting': 'Дом с красным виноградом',
#   'year': '1899',
#   'most_common_colors_ever': {'(35, 36, 39)': 1895,
#    '(73, 64, 55)': 1108,
#    '(139, 125, 100)': 942,
#    '(192, 184, 173)': 1375,
#    '(82, 98, 120)': 106,
#    '(137, 77, 48)': 633,
#    '(199, 160, 96)': 49}},
#  '1899_mm_dd_i_Дом_с_красным_диким_виноградом.jpg': {'path': '1899_mm_dd_i_Дом_с_красным_диким_виноградом.jpg',
#   'name_of_painting': 'Дом с красным диким виноградом',
#   'year': '1899',
#   'most_common_colors_ever': {'(35, 36, 39)': 300,
#    '(73, 64, 55)': 279,
#    '(139, 125, 100)': 199,
#    '(192, 184, 173)': 1187,
#    '(82, 98, 120)': 4,
#    '(137, 77, 48)': 396,
#    '(199, 160, 96)': 953}},
#  '1899_mm_dd_i_Зима_в_лесу._Нурстранн.jpg': {'path': '1899_mm_dd_i_Зима_в_лесу._Нурстранн.jpg',
#   'name_of_painting': 'Зима в лесу. Нурстранн',
#   'year': '1899',
#   'most_common_colors_ever': {'(35, 36, 39)': 852,
#    '(73, 64, 55)': 677,
#    '(139, 125, 100)': 590,
#    '(192, 184, 173)': 2116,
#    '(82, 98, 120)': 49,
#    '(137, 77, 48)': 29,
#    '(199, 160, 96)': 8}},
#  '1899_mm_dd_i_Летняя_ночь_в_Студентерлюннене.jpg': {'path': '1899_mm_dd_i_Летняя_ночь_в_Студентерлюннене.jpg',
#   'name_of_painting': 'Летняя ночь в Студентерлюннене',
#   'year': '1899',
#   'most_common_colors_ever': {'(35, 36, 39)': 732,
#    '(73, 64, 55)': 84,
#    '(139, 125, 100)': 17,
#    '(192, 184, 173)': 79,
#    '(82, 98, 120)': 184,
#    '(137, 77, 48)': 586,
#    '(199, 160, 96)': 43}},
#  '1899_mm_dd_i_Метрвая_мать_и_ребенок.jpg': {'path': '1899_mm_dd_i_Метрвая_мать_и_ребенок.jpg',
#   'name_of_painting': 'Метрвая мать и ребенок',
#   'year': '1899',
#   'most_common_colors_ever': {'(35, 36, 39)': 945,
#    '(73, 64, 55)': 3282,
#    '(139, 125, 100)': 709,
#    '(192, 184, 173)': 2,
#    '(82, 98, 120)': 1,
#    '(137, 77, 48)': 783,
#    '(199, 160, 96)': 719}},
#  '1899_mm_dd_i_Обмен_веществ.jpg': {'path': '1899_mm_dd_i_Обмен_веществ.jpg',
#   'name_of_painting': 'Обмен веществ',
#   'year': '1899',
#   'most_common_colors_ever': {'(35, 36, 39)': 4818,
#    '(73, 64, 55)': 2697,
#    '(139, 125, 100)': 81,
#    '(192, 184, 173)': 1,
#    '(82, 98, 120)': 11,
#    '(137, 77, 48)': 669,
#    '(199, 160, 96)': 379}},
#  '1899_mm_dd_i_Осе_и_Харальд_Нёррегор.jpg': {'path': '1899_mm_dd_i_Осе_и_Харальд_Нёррегор.jpg',
#   'name_of_painting': 'Осе и Харальд Нёррегор',
#   'year': '1899',
#   'most_common_colors_ever': {'(35, 36, 39)': 2909,
#    '(73, 64, 55)': 1606,
#    '(139, 125, 100)': 120,
#    '(192, 184, 173)': 24,
#    '(82, 98, 120)': 54,
#    '(137, 77, 48)': 1294,
#    '(199, 160, 96)': 182}},
#  '1899_mm_dd_i_Плодородие.jpg': {'path': '1899_mm_dd_i_Плодородие.jpg',
#   'name_of_painting': 'Плодородие',
#   'year': '1899',
#   'most_common_colors_ever': {'(35, 36, 39)': 3955,
#    '(73, 64, 55)': 2161,
#    '(139, 125, 100)': 276,
#    '(192, 184, 173)': 441,
#    '(82, 98, 120)': 115,
#    '(137, 77, 48)': 317,
#    '(199, 160, 96)': 9}},
#  '1899_mm_dd_i_Портрет_Осе_Неррегор.jpg': {'path': '1899_mm_dd_i_Портрет_Осе_Неррегор.jpg',
#   'name_of_painting': 'Портрет Осе Неррегор',
#   'year': '1899',
#   'most_common_colors_ever': {'(35, 36, 39)': 4006,
#    '(73, 64, 55)': 220,
#    '(139, 125, 100)': 44,
#    '(192, 184, 173)': 0,
#    '(82, 98, 120)': 0,
#    '(137, 77, 48)': 2283,
#    '(199, 160, 96)': 198}},
#  '1899_mm_dd_i_Сидящая_обнажённая_женщина_и_три_мужские_головы.jpg': {'path': '1899_mm_dd_i_Сидящая_обнажённая_женщина_и_три_мужские_головы.jpg',
#   'name_of_painting': 'Сидящая обнажённая женщина и три мужские головы',
#   'year': '1899',
#   'most_common_colors_ever': {'(35, 36, 39)': 7955,
#    '(73, 64, 55)': 4061,
#    '(139, 125, 100)': 61,
#    '(192, 184, 173)': 0,
#    '(82, 98, 120)': 16,
#    '(137, 77, 48)': 271,
#    '(199, 160, 96)': 2}},
#  '1899_mm_dd_i_Смерть_и_ребенок.jpg': {'path': '1899_mm_dd_i_Смерть_и_ребенок.jpg',
#   'name_of_painting': 'Смерть и ребенок',
#   'year': '1899',
#   'most_common_colors_ever': {'(35, 36, 39)': 603,
#    '(73, 64, 55)': 578,
#    '(139, 125, 100)': 1160,
#    '(192, 184, 173)': 59,
#    '(82, 98, 120)': 4,
#    '(137, 77, 48)': 228,
#    '(199, 160, 96)': 533}},
#  '1899_mm_dd_i_Танец_жизни.jpg': {'path': '1899_mm_dd_i_Танец_жизни.jpg',
#   'name_of_painting': 'Танец жизни',
#   'year': '1899',
#   'most_common_colors_ever': {'(35, 36, 39)': 2805,
#    '(73, 64, 55)': 904,
#    '(139, 125, 100)': 182,
#    '(192, 184, 173)': 1316,
#    '(82, 98, 120)': 801,
#    '(137, 77, 48)': 427,
#    '(199, 160, 96)': 90}},
#  '1899_mm_dd_i_Темный_еловый_лес_1.jpg': {'path': '1899_mm_dd_i_Темный_еловый_лес_1.jpg',
#   'name_of_painting': 'Темный еловый лес 1',
#   'year': '1899',
#   'most_common_colors_ever': {'(35, 36, 39)': 2857,
#    '(73, 64, 55)': 3091,
#    '(139, 125, 100)': 508,
#    '(192, 184, 173)': 3,
#    '(82, 98, 120)': 57,
#    '(137, 77, 48)': 121,
#    '(199, 160, 96)': 56}},
#  '1899_mm_dd_i_Темный_еловый_лес_2.jpg': {'path': '1899_mm_dd_i_Темный_еловый_лес_2.jpg',
#   'name_of_painting': 'Темный еловый лес 2',
#   'year': '1899',
#   'most_common_colors_ever': {'(35, 36, 39)': 2938,
#    '(73, 64, 55)': 6771,
#    '(139, 125, 100)': 68,
#    '(192, 184, 173)': 368,
#    '(82, 98, 120)': 208,
#    '(137, 77, 48)': 22,
#    '(199, 160, 96)': 0}},
#  '1899_mm_dd_i_Темный_еловый_лес_3.jpg': {'path': '1899_mm_dd_i_Темный_еловый_лес_3.jpg',
#   'name_of_painting': 'Темный еловый лес 3',
#   'year': '1899',
#   'most_common_colors_ever': {'(35, 36, 39)': 1129,
#    '(73, 64, 55)': 2419,
#    '(139, 125, 100)': 1124,
#    '(192, 184, 173)': 0,
#    '(82, 98, 120)': 132,
#    '(137, 77, 48)': 306,
#    '(199, 160, 96)': 313}},
#  '1899_mm_dd_i_Трагедия.jpg': {'path': '1899_mm_dd_i_Трагедия.jpg',
#   'name_of_painting': 'Трагедия',
#   'year': '1899',
#   'most_common_colors_ever': {'(35, 36, 39)': 6323,
#    '(73, 64, 55)': 1297,
#    '(139, 125, 100)': 3,
#    '(192, 184, 173)': 0,
#    '(82, 98, 120)': 0,
#    '(137, 77, 48)': 935,
#    '(199, 160, 96)': 93}},
#  '1899_mm_dd_i_Тулла_Ларсен_1.jpg': {'path': '1899_mm_dd_i_Тулла_Ларсен_1.jpg',
#   'name_of_painting': 'Тулла Ларсен 1',
#   'year': '1899',
#   'most_common_colors_ever': {'(35, 36, 39)': 2594,
#    '(73, 64, 55)': 138,
#    '(139, 125, 100)': 167,
#    '(192, 184, 173)': 42,
#    '(82, 98, 120)': 941,
#    '(137, 77, 48)': 55,
#    '(199, 160, 96)': 683}},
#  '1899_mm_dd_i_Тулла_Ларсен_2.jpg': {'path': '1899_mm_dd_i_Тулла_Ларсен_2.jpg',
#   'name_of_painting': 'Тулла Ларсен 2',
#   'year': '1899',
#   'most_common_colors_ever': {'(35, 36, 39)': 5342,
#    '(73, 64, 55)': 7313,
#    '(139, 125, 100)': 15,
#    '(192, 184, 173)': 0,
#    '(82, 98, 120)': 0,
#    '(137, 77, 48)': 866,
#    '(199, 160, 96)': 0}},
#  '1900_mm_dd_i_Белая_ночь.jpg': {'path': '1900_mm_dd_i_Белая_ночь.jpg',
#   'name_of_painting': 'Белая ночь',
#   'year': '1900',
#   'most_common_colors_ever': {'(35, 36, 39)': 4645,
#    '(73, 64, 55)': 313,
#    '(139, 125, 100)': 9,
#    '(192, 184, 173)': 1,
#    '(82, 98, 120)': 1610,
#    '(137, 77, 48)': 0,
#    '(199, 160, 96)': 0}},
#  '1900_mm_dd_i_Вид_из_Нурстранна.jpg': {'path': '1900_mm_dd_i_Вид_из_Нурстранна.jpg',
#   'name_of_painting': 'Вид из Нурстранна',
#   'year': '1900',
#   'most_common_colors_ever': {'(35, 36, 39)': 6169,
#    '(73, 64, 55)': 1098,
#    '(139, 125, 100)': 70,
#    '(192, 184, 173)': 488,
#    '(82, 98, 120)': 94,
#    '(137, 77, 48)': 110,
#    '(199, 160, 96)': 11}},
#  '1900_mm_dd_i_Вид_из_Нурстранна_1.jpg': {'path': '1900_mm_dd_i_Вид_из_Нурстранна_1.jpg',
#   'name_of_painting': 'Вид из Нурстранна 1',
#   'year': '1900',
#   'most_common_colors_ever': {'(35, 36, 39)': 4466,
#    '(73, 64, 55)': 993,
#    '(139, 125, 100)': 204,
#    '(192, 184, 173)': 925,
#    '(82, 98, 120)': 647,
#    '(137, 77, 48)': 2,
#    '(199, 160, 96)': 0}},
#  '1900_mm_dd_i_Глаза_в_глаза.jpg': {'path': '1900_mm_dd_i_Глаза_в_глаза.jpg',
#   'name_of_painting': 'Глаза в глаза',
#   'year': '1900',
#   'most_common_colors_ever': {'(35, 36, 39)': 8329,
#    '(73, 64, 55)': 1449,
#    '(139, 125, 100)': 101,
#    '(192, 184, 173)': 68,
#    '(82, 98, 120)': 237,
#    '(137, 77, 48)': 42,
#    '(199, 160, 96)': 8}},
#  '1900_mm_dd_i_Голгофа.jpg': {'path': '1900_mm_dd_i_Голгофа.jpg',
#   'name_of_painting': 'Голгофа',
#   'year': '1900',
#   'most_common_colors_ever': {'(35, 36, 39)': 6490,
#    '(73, 64, 55)': 590,
#    '(139, 125, 100)': 162,
#    '(192, 184, 173)': 80,
#    '(82, 98, 120)': 298,
#    '(137, 77, 48)': 156,
#    '(199, 160, 96)': 83}},
#  '1900_mm_dd_i_Дымящий_поезд.jpg': {'path': '1900_mm_dd_i_Дымящий_поезд.jpg',
#   'name_of_painting': 'Дымящий поезд',
#   'year': '1900',
#   'most_common_colors_ever': {'(35, 36, 39)': 615,
#    '(73, 64, 55)': 920,
#    '(139, 125, 100)': 251,
#    '(192, 184, 173)': 199,
#    '(82, 98, 120)': 1231,
#    '(137, 77, 48)': 197,
#    '(199, 160, 96)': 4}},
#  '1900_mm_dd_i_Закат._Нурстранн.jpg': {'path': '1900_mm_dd_i_Закат._Нурстранн.jpg',
#   'name_of_painting': 'Закат. Нурстранн',
#   'year': '1900',
#   'most_common_colors_ever': {'(35, 36, 39)': 3944,
#    '(73, 64, 55)': 1392,
#    '(139, 125, 100)': 162,
#    '(192, 184, 173)': 3091,
#    '(82, 98, 120)': 70,
#    '(137, 77, 48)': 83,
#    '(199, 160, 96)': 200}},
#  '1900_mm_dd_i_Зима.jpg': {'path': '1900_mm_dd_i_Зима.jpg',
#   'name_of_painting': 'Зима',
#   'year': '1900',
#   'most_common_colors_ever': {'(35, 36, 39)': 1126,
#    '(73, 64, 55)': 753,
#    '(139, 125, 100)': 578,
#    '(192, 184, 173)': 5079,
#    '(82, 98, 120)': 372,
#    '(137, 77, 48)': 57,
#    '(199, 160, 96)': 0}},
#  '1900_mm_dd_i_Красное_и_белое.jpg': {'path': '1900_mm_dd_i_Красное_и_белое.jpg',
#   'name_of_painting': 'Красное и белое',
#   'year': '1900',
#   'most_common_colors_ever': {'(35, 36, 39)': 3102,
#    '(73, 64, 55)': 1843,
#    '(139, 125, 100)': 292,
#    '(192, 184, 173)': 289,
#    '(82, 98, 120)': 682,
#    '(137, 77, 48)': 613,
#    '(199, 160, 96)': 1}},
#  '1900_mm_dd_i_Красный_плющ.jpg': {'path': '1900_mm_dd_i_Красный_плющ.jpg',
#   'name_of_painting': 'Красный плющ',
#   'year': '1900',
#   'most_common_colors_ever': {'(35, 36, 39)': 1123,
#    '(73, 64, 55)': 1265,
#    '(139, 125, 100)': 511,
#    '(192, 184, 173)': 751,
#    '(82, 98, 120)': 29,
#    '(137, 77, 48)': 486,
#    '(199, 160, 96)': 62}},
#  '1900_mm_dd_i_Меланхолия.jpg': {'path': '1900_mm_dd_i_Меланхолия.jpg',
#   'name_of_painting': 'Меланхолия',
#   'year': '1900',
#   'most_common_colors_ever': {'(35, 36, 39)': 1302,
#    '(73, 64, 55)': 671,
#    '(139, 125, 100)': 519,
#    '(192, 184, 173)': 365,
#    '(82, 98, 120)': 69,
#    '(137, 77, 48)': 273,
#    '(199, 160, 96)': 344}},
#  '1900_mm_dd_i_Остров.jpg': {'path': '1900_mm_dd_i_Остров.jpg',
#   'name_of_painting': 'Остров',
#   'year': '1900',
#   'most_common_colors_ever': {'(35, 36, 39)': 5609,
#    '(73, 64, 55)': 1369,
#    '(139, 125, 100)': 486,
#    '(192, 184, 173)': 1180,
#    '(82, 98, 120)': 517,
#    '(137, 77, 48)': 10,
#    '(199, 160, 96)': 33}},
#  '1900_mm_dd_i_Парижский_бульвар.jpg': {'path': '1900_mm_dd_i_Парижский_бульвар.jpg',
#   'name_of_painting': 'Парижский бульвар',
#   'year': '1900',
#   'most_common_colors_ever': {'(35, 36, 39)': 988,
#    '(73, 64, 55)': 823,
#    '(139, 125, 100)': 225,
#    '(192, 184, 173)': 8,
#    '(82, 98, 120)': 2,
#    '(137, 77, 48)': 190,
#    '(199, 160, 96)': 361}},
#  '1900_mm_dd_i_Танец_жизни.jpg': {'path': '1900_mm_dd_i_Танец_жизни.jpg',
#   'name_of_painting': 'Танец жизни',
#   'year': '1900',
#   'most_common_colors_ever': {'(35, 36, 39)': 2583,
#    '(73, 64, 55)': 1036,
#    '(139, 125, 100)': 248,
#    '(192, 184, 173)': 288,
#    '(82, 98, 120)': 445,
#    '(137, 77, 48)': 313,
#    '(199, 160, 96)': 135}},
#  '1900_mm_dd_i_Танцы_на_пляже.jpg': {'path': '1900_mm_dd_i_Танцы_на_пляже.jpg',
#   'name_of_painting': 'Танцы на пляже',
#   'year': '1900',
#   'most_common_colors_ever': {'(35, 36, 39)': 5132,
#    '(73, 64, 55)': 2532,
#    '(139, 125, 100)': 533,
#    '(192, 184, 173)': 570,
#    '(82, 98, 120)': 380,
#    '(137, 77, 48)': 30,
#    '(199, 160, 96)': 27}},
#  '1901_mm_dd_i_Девочки_на_мосту_1.jpg': {'path': '1901_mm_dd_i_Девочки_на_мосту_1.jpg',
#   'name_of_painting': 'Девочки на мосту 1',
#   'year': '1901',
#   'most_common_colors_ever': {'(35, 36, 39)': 3751,
#    '(73, 64, 55)': 784,
#    '(139, 125, 100)': 2200,
#    '(192, 184, 173)': 366,
#    '(82, 98, 120)': 580,
#    '(137, 77, 48)': 186,
#    '(199, 160, 96)': 15}},
#  '1901_mm_dd_i_Девочки_на_мосту_2.jpg': {'path': '1901_mm_dd_i_Девочки_на_мосту_2.jpg',
#   'name_of_painting': 'Девочки на мосту 2',
#   'year': '1901',
#   'most_common_colors_ever': {'(35, 36, 39)': 4156,
#    '(73, 64, 55)': 1060,
#    '(139, 125, 100)': 2445,
#    '(192, 184, 173)': 513,
#    '(82, 98, 120)': 275,
#    '(137, 77, 48)': 711,
#    '(199, 160, 96)': 38}},
#  '1901_mm_dd_i_Зима_в_Нурстранне.jpg': {'path': '1901_mm_dd_i_Зима_в_Нурстранне.jpg',
#   'name_of_painting': 'Зима в Нурстранне',
#   'year': '1901',
#   'most_common_colors_ever': {'(35, 36, 39)': 3288,
#    '(73, 64, 55)': 1620,
#    '(139, 125, 100)': 1618,
#    '(192, 184, 173)': 165,
#    '(82, 98, 120)': 1070,
#    '(137, 77, 48)': 2,
#    '(199, 160, 96)': 0}},
#  '1901_mm_dd_i_Зимний_лес.jpg': {'path': '1901_mm_dd_i_Зимний_лес.jpg',
#   'name_of_painting': 'Зимний лес',
#   'year': '1901',
#   'most_common_colors_ever': {'(35, 36, 39)': 7372,
#    '(73, 64, 55)': 1750,
#    '(139, 125, 100)': 124,
#    '(192, 184, 173)': 1311,
#    '(82, 98, 120)': 569,
#    '(137, 77, 48)': 0,
#    '(199, 160, 96)': 0}},
#  '1901_mm_dd_i_Зимняя_ночь.jpg': {'path': '1901_mm_dd_i_Зимняя_ночь.jpg',
#   'name_of_painting': 'Зимняя ночь',
#   'year': '1901',
#   'most_common_colors_ever': {'(35, 36, 39)': 4894,
#    '(73, 64, 55)': 78,
#    '(139, 125, 100)': 4,
#    '(192, 184, 173)': 99,
#    '(82, 98, 120)': 534,
#    '(137, 77, 48)': 0,
#    '(199, 160, 96)': 0}},
#  '1901_mm_dd_i_Улица_в_Осгорстранне_1.jpg': {'path': '1901_mm_dd_i_Улица_в_Осгорстранне_1.jpg',
#   'name_of_painting': 'Улица в Осгорстранне 1',
#   'year': '1901',
#   'most_common_colors_ever': {'(35, 36, 39)': 1107,
#    '(73, 64, 55)': 816,
#    '(139, 125, 100)': 932,
#    '(192, 184, 173)': 447,
#    '(82, 98, 120)': 25,
#    '(137, 77, 48)': 420,
#    '(199, 160, 96)': 143}},
#  '1901_mm_dd_i_Улица_в_Осгорстранне_2.jpg': {'path': '1901_mm_dd_i_Улица_в_Осгорстранне_2.jpg',
#   'name_of_painting': 'Улица в Осгорстранне 2',
#   'year': '1901',
#   'most_common_colors_ever': {'(35, 36, 39)': 713,
#    '(73, 64, 55)': 360,
#    '(139, 125, 100)': 425,
#    '(192, 184, 173)': 1492,
#    '(82, 98, 120)': 24,
#    '(137, 77, 48)': 66,
#    '(199, 160, 96)': 354}},
#  '1901_mm_dd_Семейная_книга.jpg': {'path': '1901_mm_dd_Семейная_книга.jpg',
#   'name_of_painting': 'книга',
#   'year': '1901',
#   'most_common_colors_ever': {'(35, 36, 39)': 6029,
#    '(73, 64, 55)': 1072,
#    '(139, 125, 100)': 589,
#    '(192, 184, 173)': 1235,
#    '(82, 98, 120)': 84,
#    '(137, 77, 48)': 108,
#    '(199, 160, 96)': 17}},
#  '1902_mm_dd_i_В_саду.jpg': {'path': '1902_mm_dd_i_В_саду.jpg',
#   'name_of_painting': 'В саду',
#   'year': '1902',
#   'most_common_colors_ever': {'(35, 36, 39)': 361,
#    '(73, 64, 55)': 633,
#    '(139, 125, 100)': 702,
#    '(192, 184, 173)': 891,
#    '(82, 98, 120)': 243,
#    '(137, 77, 48)': 132,
#    '(199, 160, 96)': 698}},
#  '1902_mm_dd_i_Вампир_2.jpg': {'path': '1902_mm_dd_i_Вампир_2.jpg',
#   'name_of_painting': 'Вампир 2',
#   'year': '1902',
#   'most_common_colors_ever': {'(35, 36, 39)': 9077,
#    '(73, 64, 55)': 920,
#    '(139, 125, 100)': 251,
#    '(192, 184, 173)': 102,
#    '(82, 98, 120)': 57,
#    '(137, 77, 48)': 79,
#    '(199, 160, 96)': 489}},
#  '1902_mm_dd_i_Две_обнаженные_у_комода.jpg': {'path': '1902_mm_dd_i_Две_обнаженные_у_комода.jpg',
#   'name_of_painting': 'Две обнаженные у комода',
#   'year': '1902',
#   'most_common_colors_ever': {'(35, 36, 39)': 759,
#    '(73, 64, 55)': 469,
#    '(139, 125, 100)': 465,
#    '(192, 184, 173)': 308,
#    '(82, 98, 120)': 2,
#    '(137, 77, 48)': 2519,
#    '(199, 160, 96)': 775}},
#  '1902_mm_dd_i_Девочка_в_красном_клетчатом_платье_и_красной_шляпе.jpg': {'path': '1902_mm_dd_i_Девочка_в_красном_клетчатом_платье_и_красной_шляпе.jpg',
#   'name_of_painting': 'Девочка в красном клетчатом платье и красной шляпе',
#   'year': '1902',
#   'most_common_colors_ever': {'(35, 36, 39)': 2497,
#    '(73, 64, 55)': 1115,
#    '(139, 125, 100)': 129,
#    '(192, 184, 173)': 0,
#    '(82, 98, 120)': 6,
#    '(137, 77, 48)': 394,
#    '(199, 160, 96)': 537}},
#  '1902_mm_dd_i_Девочки_на_мосту.jpg': {'path': '1902_mm_dd_i_Девочки_на_мосту.jpg',
#   'name_of_painting': 'Девочки на мосту',
#   'year': '1902',
#   'most_common_colors_ever': {'(35, 36, 39)': 2756,
#    '(73, 64, 55)': 922,
#    '(139, 125, 100)': 256,
#    '(192, 184, 173)': 2311,
#    '(82, 98, 120)': 233,
#    '(137, 77, 48)': 271,
#    '(199, 160, 96)': 85}},
#  '1902_mm_dd_i_Девочки_на_мосту_1.jpg': {'path': '1902_mm_dd_i_Девочки_на_мосту_1.jpg',
#   'name_of_painting': 'Девочки на мосту 1',
#   'year': '1902',
#   'most_common_colors_ever': {'(35, 36, 39)': 2033,
#    '(73, 64, 55)': 1481,
#    '(139, 125, 100)': 609,
#    '(192, 184, 173)': 1163,
#    '(82, 98, 120)': 286,
#    '(137, 77, 48)': 202,
#    '(199, 160, 96)': 105}},
#  '1902_mm_dd_i_Дом_в_летнюю_ночь.jpg': {'path': '1902_mm_dd_i_Дом_в_летнюю_ночь.jpg',
#   'name_of_painting': 'Дом в летнюю ночь',
#   'year': '1902',
#   'most_common_colors_ever': {'(35, 36, 39)': 1697,
#    '(73, 64, 55)': 1169,
#    '(139, 125, 100)': 169,
#    '(192, 184, 173)': 13,
#    '(82, 98, 120)': 124,
#    '(137, 77, 48)': 286,
#    '(199, 160, 96)': 19}},
#  '1902_mm_dd_i_Женщины_на_мосту.jpg': {'path': '1902_mm_dd_i_Женщины_на_мосту.jpg',
#   'name_of_painting': 'Женщины на мосту',
#   'year': '1902',
#   'most_common_colors_ever': {'(35, 36, 39)': 1692,
#    '(73, 64, 55)': 1720,
#    '(139, 125, 100)': 419,
#    '(192, 184, 173)': 670,
#    '(82, 98, 120)': 90,
#    '(137, 77, 48)': 220,
#    '(199, 160, 96)': 642}},
#  '1902_mm_dd_i_Катафалк_на_Потсдамер-Платц.jpg': {'path': '1902_mm_dd_i_Катафалк_на_Потсдамер-Платц.jpg',
#   'name_of_painting': 'Катафалк на Потсдамер-Платц',
#   'year': '1902',
#   'most_common_colors_ever': {'(35, 36, 39)': 1358,
#    '(73, 64, 55)': 823,
#    '(139, 125, 100)': 695,
#    '(192, 184, 173)': 2780,
#    '(82, 98, 120)': 148,
#    '(137, 77, 48)': 67,
#    '(199, 160, 96)': 260}},
#  '1902_mm_dd_i_Катафалк_на_Потсдамер-Платц_2.jpg': {'path': '1902_mm_dd_i_Катафалк_на_Потсдамер-Платц_2.jpg',
#   'name_of_painting': 'Катафалк на Потсдамер-Платц 2',
#   'year': '1902',
#   'most_common_colors_ever': {'(35, 36, 39)': 2169,
#    '(73, 64, 55)': 1502,
#    '(139, 125, 100)': 1226,
#    '(192, 184, 173)': 914,
#    '(82, 98, 120)': 410,
#    '(137, 77, 48)': 57,
#    '(199, 160, 96)': 287}},
#  '1902_mm_dd_i_На_операционном_столе.jpg': {'path': '1902_mm_dd_i_На_операционном_столе.jpg',
#   'name_of_painting': 'На операционном столе',
#   'year': '1902',
#   'most_common_colors_ever': {'(35, 36, 39)': 1211,
#    '(73, 64, 55)': 1937,
#    '(139, 125, 100)': 2703,
#    '(192, 184, 173)': 164,
#    '(82, 98, 120)': 200,
#    '(137, 77, 48)': 497,
#    '(199, 160, 96)': 85}},
#  '1902_mm_dd_i_Обнажённая_с_длинными_рыжими_волосами.jpg': {'path': '1902_mm_dd_i_Обнажённая_с_длинными_рыжими_волосами.jpg',
#   'name_of_painting': 'Обнажённая с длинными рыжими волосами',
#   'year': '1902',
#   'most_common_colors_ever': {'(35, 36, 39)': 2198,
#    '(73, 64, 55)': 1579,
#    '(139, 125, 100)': 63,
#    '(192, 184, 173)': 1,
#    '(82, 98, 120)': 15,
#    '(137, 77, 48)': 1867,
#    '(199, 160, 96)': 58}},
#  '1902_mm_dd_i_Обнаженная.jpg': {'path': '1902_mm_dd_i_Обнаженная.jpg',
#   'name_of_painting': 'Обнаженная',
#   'year': '1902',
#   'most_common_colors_ever': {'(35, 36, 39)': 1194,
#    '(73, 64, 55)': 3274,
#    '(139, 125, 100)': 1373,
#    '(192, 184, 173)': 586,
#    '(82, 98, 120)': 78,
#    '(137, 77, 48)': 502,
#    '(199, 160, 96)': 345}},
#  '1902_mm_dd_i_Обнаженная_в_интерьере.jpg': {'path': '1902_mm_dd_i_Обнаженная_в_интерьере.jpg',
#   'name_of_painting': 'Обнаженная в интерьере',
#   'year': '1902',
#   'most_common_colors_ever': {'(35, 36, 39)': 1664,
#    '(73, 64, 55)': 1844,
#    '(139, 125, 100)': 998,
#    '(192, 184, 173)': 394,
#    '(82, 98, 120)': 101,
#    '(137, 77, 48)': 731,
#    '(199, 160, 96)': 406}},
#  '1902_mm_dd_i_Одежда_на_веревочке_в_Осгорстранне.jpg': {'path': '1902_mm_dd_i_Одежда_на_веревочке_в_Осгорстранне.jpg',
#   'name_of_painting': 'Одежда на веревочке в Осгорстранне',
#   'year': '1902',
#   'most_common_colors_ever': {'(35, 36, 39)': 282,
#    '(73, 64, 55)': 1256,
#    '(139, 125, 100)': 478,
#    '(192, 184, 173)': 1258,
#    '(82, 98, 120)': 201,
#    '(137, 77, 48)': 395,
#    '(199, 160, 96)': 42}},
#  '1902_mm_dd_i_Плодородие.jpg': {'path': '1902_mm_dd_i_Плодородие.jpg',
#   'name_of_painting': 'Плодородие',
#   'year': '1902',
#   'most_common_colors_ever': {'(35, 36, 39)': 2077,
#    '(73, 64, 55)': 2971,
#    '(139, 125, 100)': 370,
#    '(192, 184, 173)': 381,
#    '(82, 98, 120)': 254,
#    '(137, 77, 48)': 259,
#    '(199, 160, 96)': 10}},
#  '1902_mm_dd_i_Приёмные_матери_перед_окружным_судом.jpg': {'path': '1902_mm_dd_i_Приёмные_матери_перед_окружным_судом.jpg',
#   'name_of_painting': 'Приёмные матери перед окружным судом',
#   'year': '1902',
#   'most_common_colors_ever': {'(35, 36, 39)': 3188,
#    '(73, 64, 55)': 2412,
#    '(139, 125, 100)': 1487,
#    '(192, 184, 173)': 38,
#    '(82, 98, 120)': 27,
#    '(137, 77, 48)': 513,
#    '(199, 160, 96)': 682}},
#  '1902_mm_dd_i_Рыбак_на_жёлтом_фоне.jpg': {'path': '1902_mm_dd_i_Рыбак_на_жёлтом_фоне.jpg',
#   'name_of_painting': 'Рыбак на жёлтом фоне',
#   'year': '1902',
#   'most_common_colors_ever': {'(35, 36, 39)': 4101,
#    '(73, 64, 55)': 866,
#    '(139, 125, 100)': 83,
#    '(192, 184, 173)': 0,
#    '(82, 98, 120)': 4,
#    '(137, 77, 48)': 95,
#    '(199, 160, 96)': 275}},
#  '1902_mm_dd_i_Сад.jpg': {'path': '1902_mm_dd_i_Сад.jpg',
#   'name_of_painting': 'Сад',
#   'year': '1902',
#   'most_common_colors_ever': {'(35, 36, 39)': 6579,
#    '(73, 64, 55)': 2234,
#    '(139, 125, 100)': 379,
#    '(192, 184, 173)': 5,
#    '(82, 98, 120)': 304,
#    '(137, 77, 48)': 110,
#    '(199, 160, 96)': 0}},
#  '1902_mm_dd_i_Санаторий.jpg': {'path': '1902_mm_dd_i_Санаторий.jpg',
#   'name_of_painting': 'Санаторий',
#   'year': '1902',
#   'most_common_colors_ever': {'(35, 36, 39)': 6975,
#    '(73, 64, 55)': 2136,
#    '(139, 125, 100)': 137,
#    '(192, 184, 173)': 39,
#    '(82, 98, 120)': 20,
#    '(137, 77, 48)': 585,
#    '(199, 160, 96)': 66}},
#  '1902_mm_dd_i_Сидящая_обнаженная.jpg': {'path': '1902_mm_dd_i_Сидящая_обнаженная.jpg',
#   'name_of_painting': 'Сидящая обнаженная',
#   'year': '1902',
#   'most_common_colors_ever': {'(35, 36, 39)': 2457,
#    '(73, 64, 55)': 1947,
#    '(139, 125, 100)': 156,
#    '(192, 184, 173)': 96,
#    '(82, 98, 120)': 401,
#    '(137, 77, 48)': 668,
#    '(199, 160, 96)': 762}},
#  '1902_mm_dd_i_Сказочный_лес.jpg': {'path': '1902_mm_dd_i_Сказочный_лес.jpg',
#   'name_of_painting': 'Сказочный лес',
#   'year': '1902',
#   'most_common_colors_ever': {'(35, 36, 39)': 101,
#    '(73, 64, 55)': 650,
#    '(139, 125, 100)': 1237,
#    '(192, 184, 173)': 874,
#    '(82, 98, 120)': 240,
#    '(137, 77, 48)': 131,
#    '(199, 160, 96)': 1325}},
#  '1902_mm_dd_i_Старый_рыбак_со_своей_дочерью.jpg': {'path': '1902_mm_dd_i_Старый_рыбак_со_своей_дочерью.jpg',
#   'name_of_painting': 'Старый рыбак со своей дочерью',
#   'year': '1902',
#   'most_common_colors_ever': {'(35, 36, 39)': 3389,
#    '(73, 64, 55)': 1661,
#    '(139, 125, 100)': 172,
#    '(192, 184, 173)': 341,
#    '(82, 98, 120)': 12,
#    '(137, 77, 48)': 213,
#    '(199, 160, 96)': 425}},
#  '1902_mm_dd_i_Улица_в_Осгорстранне_с_женщиной_в_красном_платье.jpg': {'path': '1902_mm_dd_i_Улица_в_Осгорстранне_с_женщиной_в_красном_платье.jpg',
#   'name_of_painting': 'Улица в Осгорстранне с женщиной в красном платье',
#   'year': '1902',
#   'most_common_colors_ever': {'(35, 36, 39)': 334,
#    '(73, 64, 55)': 2270,
#    '(139, 125, 100)': 623,
#    '(192, 184, 173)': 155,
#    '(82, 98, 120)': 305,
#    '(137, 77, 48)': 444,
#    '(199, 160, 96)': 58}},
#  '1902_mm_dd_i_Утро._Обнаженная_у_окна.jpg': {'path': '1902_mm_dd_i_Утро._Обнаженная_у_окна.jpg',
#   'name_of_painting': 'Утро. Обнаженная у окна',
#   'year': '1902',
#   'most_common_colors_ever': {'(35, 36, 39)': 2590,
#    '(73, 64, 55)': 963,
#    '(139, 125, 100)': 268,
#    '(192, 184, 173)': 1075,
#    '(82, 98, 120)': 82,
#    '(137, 77, 48)': 792,
#    '(199, 160, 96)': 291}},
#  '1902_mm_dd_i_Яблоня.jpg': {'path': '1902_mm_dd_i_Яблоня.jpg',
#   'name_of_painting': 'Яблоня',
#   'year': '1902',
#   'most_common_colors_ever': {'(35, 36, 39)': 5763,
#    '(73, 64, 55)': 1320,
#    '(139, 125, 100)': 100,
#    '(192, 184, 173)': 81,
#    '(82, 98, 120)': 210,
#    '(137, 77, 48)': 117,
#    '(199, 160, 96)': 27}},
#  '1903_mm_dd_a_Автопортрет_в_Аду.jpg': {'path': '1903_mm_dd_a_Автопортрет_в_Аду.jpg',
#   'name_of_painting': 'Автопортрет в Аду',
#   'year': '1903',
#   'most_common_colors_ever': {'(35, 36, 39)': 4833,
#    '(73, 64, 55)': 1834,
#    '(139, 125, 100)': 35,
#    '(192, 184, 173)': 0,
#    '(82, 98, 120)': 0,
#    '(137, 77, 48)': 3130,
#    '(199, 160, 96)': 216}},
#  '1903_mm_dd_a_Автопортрет_на_операционном_столе.jpg': {'path': '1903_mm_dd_a_Автопортрет_на_операционном_столе.jpg',
#   'name_of_painting': 'Автопортрет на операционном столе',
#   'year': '1903',
#   'most_common_colors_ever': {'(35, 36, 39)': 233,
#    '(73, 64, 55)': 1051,
#    '(139, 125, 100)': 3151,
#    '(192, 184, 173)': 1812,
#    '(82, 98, 120)': 64,
#    '(137, 77, 48)': 378,
#    '(199, 160, 96)': 64}},
#  '1903_mm_dd_i_Автопортрет_в_аду.jpg': {'path': '1903_mm_dd_i_Автопортрет_в_аду.jpg',
#   'name_of_painting': 'Автопортрет в аду',
#   'year': '1903',
#   'most_common_colors_ever': {'(35, 36, 39)': 4857,
#    '(73, 64, 55)': 1769,
#    '(139, 125, 100)': 36,
#    '(192, 184, 173)': 0,
#    '(82, 98, 120)': 0,
#    '(137, 77, 48)': 3117,
#    '(199, 160, 96)': 195}},
#  '1903_mm_dd_i_Белая_ночь._Осгардстран.jpg': {'path': '1903_mm_dd_i_Белая_ночь._Осгардстран.jpg',
#   'name_of_painting': 'Белая ночь. Осгардстран',
#   'year': '1903',
#   'most_common_colors_ever': {'(35, 36, 39)': 3248,
#    '(73, 64, 55)': 1163,
#    '(139, 125, 100)': 293,
#    '(192, 184, 173)': 440,
#    '(82, 98, 120)': 136,
#    '(137, 77, 48)': 127,
#    '(199, 160, 96)': 763}},
#  '1903_mm_dd_i_Дамы_на_мосту.jpg': {'path': '1903_mm_dd_i_Дамы_на_мосту.jpg',
#   'name_of_painting': 'Дамы на мосту',
#   'year': '1903',
#   'most_common_colors_ever': {'(35, 36, 39)': 3024,
#    '(73, 64, 55)': 1376,
#    '(139, 125, 100)': 884,
#    '(192, 184, 173)': 1567,
#    '(82, 98, 120)': 171,
#    '(137, 77, 48)': 49,
#    '(199, 160, 96)': 98}},
#  '1903_mm_dd_i_Двое_детей_на_пути_в_сказочный_лес.jpg': {'path': '1903_mm_dd_i_Двое_детей_на_пути_в_сказочный_лес.jpg',
#   'name_of_painting': 'Двое детей на пути в сказочный лес',
#   'year': '1903',
#   'most_common_colors_ever': {'(35, 36, 39)': 470,
#    '(73, 64, 55)': 772,
#    '(139, 125, 100)': 353,
#    '(192, 184, 173)': 23,
#    '(82, 98, 120)': 457,
#    '(137, 77, 48)': 559,
#    '(199, 160, 96)': 367}},
#  '1903_mm_dd_i_Дети.jpg': {'path': '1903_mm_dd_i_Дети.jpg',
#   'name_of_painting': 'Дети',
#   'year': '1903',
#   'most_common_colors_ever': {'(35, 36, 39)': 1356,
#    '(73, 64, 55)': 980,
#    '(139, 125, 100)': 1095,
#    '(192, 184, 173)': 3069,
#    '(82, 98, 120)': 26,
#    '(137, 77, 48)': 248,
#    '(199, 160, 96)': 353}},
#  '1903_mm_dd_i_Ночь_святого_Ханса.jpg': {'path': '1903_mm_dd_i_Ночь_святого_Ханса.jpg',
#   'name_of_painting': 'Ночь святого Ханса',
#   'year': '1903',
#   'most_common_colors_ever': {'(35, 36, 39)': 1198,
#    '(73, 64, 55)': 1513,
#    '(139, 125, 100)': 1144,
#    '(192, 184, 173)': 1339,
#    '(82, 98, 120)': 15,
#    '(137, 77, 48)': 234,
#    '(199, 160, 96)': 346}},
#  '1903_mm_dd_i_Три_девушки_на_причале.jpg': {'path': '1903_mm_dd_i_Три_девушки_на_причале.jpg',
#   'name_of_painting': 'Три девушки на причале',
#   'year': '1903',
#   'most_common_colors_ever': {'(35, 36, 39)': 1281,
#    '(73, 64, 55)': 1065,
#    '(139, 125, 100)': 432,
#    '(192, 184, 173)': 1647,
#    '(82, 98, 120)': 24,
#    '(137, 77, 48)': 264,
#    '(199, 160, 96)': 768}},
#  '1903_mm_dd_i_Штормовой_пейзаж.jpg': {'path': '1903_mm_dd_i_Штормовой_пейзаж.jpg',
# ...
#    '(137, 77, 48)': 0,
#    '(199, 160, 96)': 0}},
#  '1913_mm_dd_i_Обнаженная.jpg': {'path': '1913_mm_dd_i_Обнаженная.jpg',
#   'name_of_painting': 'Обнаженная',
#   'year': '1913',
#   'most_common_colors_ever': {'(35, 36, 39)': 1696,
#    '(73, 64, 55)': 1387,
#    '(139, 125, 100)': 288,
#    '(192, 184, 173)': 783,
#    '(82, 98, 120)': 252,
#    '(137, 77, 48)': 577,
#    '(199, 160, 96)': 69}},
#  '1913_mm_dd_i_Солнце.jpg': {'path': '1913_mm_dd_i_Солнце.jpg',
#   'name_of_painting': 'Солнце',
#   'year': '1913',
#   'most_common_colors_ever': {'(35, 36, 39)': 66,
#    '(73, 64, 55)': 683,
#    '(139, 125, 100)': 870,
#    '(192, 184, 173)': 1117,
#    '(82, 98, 120)': 1209,
#    '(137, 77, 48)': 53,
#    '(199, 160, 96)': 337}},
#  '1915_mm_dd_a_Автопортрет1.jpg': {'path': '1915_mm_dd_a_Автопортрет1.jpg',
#   'name_of_painting': 'Автопортрет1',
#   'year': '1915',
#   'most_common_colors_ever': {'(35, 36, 39)': 370,
#    '(73, 64, 55)': 145,
#    '(139, 125, 100)': 82,
#    '(192, 184, 173)': 530,
#    '(82, 98, 120)': 2,
#    '(137, 77, 48)': 39,
#    '(199, 160, 96)': 208}},
#  '1915_mm_dd_a_Автопортрет_в_плаще_и_со_шляпой.jpg': {'path': '1915_mm_dd_a_Автопортрет_в_плаще_и_со_шляпой.jpg',
#   'name_of_painting': 'Автопортрет в плаще и со шляпой',
#   'year': '1915',
#   'most_common_colors_ever': {'(35, 36, 39)': 450,
#    '(73, 64, 55)': 236,
#    '(139, 125, 100)': 871,
#    '(192, 184, 173)': 702,
#    '(82, 98, 120)': 330,
#    '(137, 77, 48)': 109,
#    '(199, 160, 96)': 329}},
#  '1915_mm_dd_a_Автопортрет_с_шляпой_и_красным_галстуком.jpg': {'path': '1915_mm_dd_a_Автопортрет_с_шляпой_и_красным_галстуком.jpg',
#   'name_of_painting': 'Автопортрет с шляпой и красным галстуком',
#   'year': '1915',
#   'most_common_colors_ever': {'(35, 36, 39)': 3169,
#    '(73, 64, 55)': 511,
#    '(139, 125, 100)': 131,
#    '(192, 184, 173)': 804,
#    '(82, 98, 120)': 374,
#    '(137, 77, 48)': 69,
#    '(199, 160, 96)': 23}},
#  '1915_mm_dd_i_Дети_на_улице.jpg': {'path': '1915_mm_dd_i_Дети_на_улице.jpg',
#   'name_of_painting': 'Дети на улице',
#   'year': '1915',
#   'most_common_colors_ever': {'(35, 36, 39)': 752,
#    '(73, 64, 55)': 663,
#    '(139, 125, 100)': 564,
#    '(192, 184, 173)': 5262,
#    '(82, 98, 120)': 87,
#    '(137, 77, 48)': 134,
#    '(199, 160, 96)': 133}},
#  '1915_mm_dd_i_Рабочие_на_пути_домой.jpg': {'path': '1915_mm_dd_i_Рабочие_на_пути_домой.jpg',
#   'name_of_painting': 'Рабочие на пути домой',
#   'year': '1915',
#   'most_common_colors_ever': {'(35, 36, 39)': 2731,
#    '(73, 64, 55)': 2149,
#    '(139, 125, 100)': 1051,
#    '(192, 184, 173)': 860,
#    '(82, 98, 120)': 1346,
#    '(137, 77, 48)': 75,
#    '(199, 160, 96)': 44}},
#  '1916_mm_dd_a_Автопортрет_в_Бергене.jpg': {'path': '1916_mm_dd_a_Автопортрет_в_Бергене.jpg',
#   'name_of_painting': 'Автопортрет в Бергене',
#   'year': '1916',
#   'most_common_colors_ever': {'(35, 36, 39)': 295,
#    '(73, 64, 55)': 1976,
#    '(139, 125, 100)': 397,
#    '(192, 184, 173)': 3453,
#    '(82, 98, 120)': 277,
#    '(137, 77, 48)': 254,
#    '(199, 160, 96)': 85}},
#  '1916_mm_dd_i_Солнце.jpg': {'path': '1916_mm_dd_i_Солнце.jpg',
#   'name_of_painting': 'Солнце',
#   'year': '1916',
#   'most_common_colors_ever': {'(35, 36, 39)': 359,
#    '(73, 64, 55)': 584,
#    '(139, 125, 100)': 1773,
#    '(192, 184, 173)': 2112,
#    '(82, 98, 120)': 312,
#    '(137, 77, 48)': 109,
#    '(199, 160, 96)': 391}},
#  '1918_mm_dd_i_Адам_и_Ева.jpg': {'path': '1918_mm_dd_i_Адам_и_Ева.jpg',
#   'name_of_painting': 'Адам и Ева',
#   'year': '1918',
#   'most_common_colors_ever': {'(35, 36, 39)': 4584,
#    '(73, 64, 55)': 4963,
#    '(139, 125, 100)': 92,
#    '(192, 184, 173)': 0,
#    '(82, 98, 120)': 84,
#    '(137, 77, 48)': 785,
#    '(199, 160, 96)': 732}},
#  '1919_mm_dd_a_Автопортрет_(в_смятении).jpg': {'path': '1919_mm_dd_a_Автопортрет_(в_смятении).jpg',
#   'name_of_painting': 'Автопортрет (в смятении)',
#   'year': '1919',
#   'most_common_colors_ever': {'(35, 36, 39)': 762,
#    '(73, 64, 55)': 733,
#    '(139, 125, 100)': 317,
#    '(192, 184, 173)': 279,
#    '(82, 98, 120)': 53,
#    '(137, 77, 48)': 414,
#    '(199, 160, 96)': 171}},
#  '1919_mm_dd_a_Автопортрет_после_испанского_гриппа.jpg': {'path': '1919_mm_dd_a_Автопортрет_после_испанского_гриппа.jpg',
#   'name_of_painting': 'Автопортрет после испанского гриппа',
#   'year': '1919',
#   'most_common_colors_ever': {'(35, 36, 39)': 835,
#    '(73, 64, 55)': 1254,
#    '(139, 125, 100)': 918,
#    '(192, 184, 173)': 904,
#    '(82, 98, 120)': 260,
#    '(137, 77, 48)': 480,
#    '(199, 160, 96)': 530}},
#  '1919_mm_dd_a_Автопортрет_после_испанского_гриппа2.jpg': {'path': '1919_mm_dd_a_Автопортрет_после_испанского_гриппа2.jpg',
#   'name_of_painting': 'Автопортрет после испанского гриппа2',
#   'year': '1919',
#   'most_common_colors_ever': {'(35, 36, 39)': 2421,
#    '(73, 64, 55)': 1059,
#    '(139, 125, 100)': 529,
#    '(192, 184, 173)': 231,
#    '(82, 98, 120)': 31,
#    '(137, 77, 48)': 517,
#    '(199, 160, 96)': 1357}},
#  '1919_mm_dd_a_Автопортрет_после_испанского_гриппа3.jpg': {'path': '1919_mm_dd_a_Автопортрет_после_испанского_гриппа3.jpg',
#   'name_of_painting': 'Автопортрет после испанского гриппа3',
#   'year': '1919',
#   'most_common_colors_ever': {'(35, 36, 39)': 2890,
#    '(73, 64, 55)': 535,
#    '(139, 125, 100)': 264,
#    '(192, 184, 173)': 953,
#    '(82, 98, 120)': 295,
#    '(137, 77, 48)': 218,
#    '(199, 160, 96)': 219}},
#  '1919_mm_dd_i_Автопортрет_(в_смятении).jpg': {'path': '1919_mm_dd_i_Автопортрет_(в_смятении).jpg',
#   'name_of_painting': 'Автопортрет (в смятении)',
#   'year': '1919',
#   'most_common_colors_ever': {'(35, 36, 39)': 773,
#    '(73, 64, 55)': 737,
#    '(139, 125, 100)': 318,
#    '(192, 184, 173)': 280,
#    '(82, 98, 120)': 53,
#    '(137, 77, 48)': 415,
#    '(199, 160, 96)': 171}},
#  '1919_mm_dd_i_Автопортрет_после_испанки.jpg': {'path': '1919_mm_dd_i_Автопортрет_после_испанки.jpg',
#   'name_of_painting': 'Автопортрет после испанки',
#   'year': '1919',
#   'most_common_colors_ever': {'(35, 36, 39)': 4305,
#    '(73, 64, 55)': 717,
#    '(139, 125, 100)': 337,
#    '(192, 184, 173)': 1515,
#    '(82, 98, 120)': 9,
#    '(137, 77, 48)': 414,
#    '(199, 160, 96)': 44}},
#  '1919_mm_dd_i_Убийца_на_дороге.jpg': {'path': '1919_mm_dd_i_Убийца_на_дороге.jpg',
#   'name_of_painting': 'Убийца на дороге',
#   'year': '1919',
#   'most_common_colors_ever': {'(35, 36, 39)': 806,
#    '(73, 64, 55)': 502,
#    '(139, 125, 100)': 606,
#    '(192, 184, 173)': 361,
#    '(82, 98, 120)': 414,
#    '(137, 77, 48)': 332,
#    '(199, 160, 96)': 852}},
#  '1921_mm_dd_i_Художник_и_его_модель.jpg': {'path': '1921_mm_dd_i_Художник_и_его_модель.jpg',
#   'name_of_painting': 'Художник и его модель',
#   'year': '1921',
#   'most_common_colors_ever': {'(35, 36, 39)': 1748,
#    '(73, 64, 55)': 1305,
#    '(139, 125, 100)': 382,
#    '(192, 184, 173)': 587,
#    '(82, 98, 120)': 468,
#    '(137, 77, 48)': 686,
#    '(199, 160, 96)': 660}},
#  '1922_mm_dd_i_Звездная_ночь.jpg': {'path': '1922_mm_dd_i_Звездная_ночь.jpg',
#   'name_of_painting': 'Звездная ночь',
#   'year': '1922',
#   'most_common_colors_ever': {'(35, 36, 39)': 3068,
#    '(73, 64, 55)': 822,
#    '(139, 125, 100)': 111,
#    '(192, 184, 173)': 145,
#    '(82, 98, 120)': 986,
#    '(137, 77, 48)': 14,
#    '(199, 160, 96)': 20}},
#  '1923_mm_dd_a_Автопортрет.jpg': {'path': '1923_mm_dd_a_Автопортрет.jpg',
#   'name_of_painting': 'Автопортрет',
#   'year': '1923',
#   'most_common_colors_ever': {'(35, 36, 39)': 930,
#    '(73, 64, 55)': 467,
#    '(139, 125, 100)': 273,
#    '(192, 184, 173)': 1076,
#    '(82, 98, 120)': 906,
#    '(137, 77, 48)': 74,
#    '(199, 160, 96)': 43}},
#  '1924_mm_dd_a_Автопортрет._Ночной_странник.jpg': {'path': '1924_mm_dd_a_Автопортрет._Ночной_странник.jpg',
#   'name_of_painting': 'Автопортрет. Ночной странник',
#   'year': '1924',
#   'most_common_colors_ever': {'(35, 36, 39)': 3946,
#    '(73, 64, 55)': 4858,
#    '(139, 125, 100)': 503,
#    '(192, 184, 173)': 72,
#    '(82, 98, 120)': 224,
#    '(137, 77, 48)': 166,
#    '(199, 160, 96)': 412}},
#  '1924_mm_dd_i_Молодая_женщина_на_веранде.jpg': {'path': '1924_mm_dd_i_Молодая_женщина_на_веранде.jpg',
#   'name_of_painting': 'Молодая женщина на веранде',
#   'year': '1924',
#   'most_common_colors_ever': {'(35, 36, 39)': 178,
#    '(73, 64, 55)': 1460,
#    '(139, 125, 100)': 1510,
#    '(192, 184, 173)': 1772,
#    '(82, 98, 120)': 125,
#    '(137, 77, 48)': 1605,
#    '(199, 160, 96)': 70}},
#  '1925_mm_dd_i_Цыганская_свадьба.jpg': {'path': '1925_mm_dd_i_Цыганская_свадьба.jpg',
#   'name_of_painting': 'Цыганская свадьба',
#   'year': '1925',
#   'most_common_colors_ever': {'(35, 36, 39)': 2837,
#    '(73, 64, 55)': 623,
#    '(139, 125, 100)': 356,
#    '(192, 184, 173)': 567,
#    '(82, 98, 120)': 470,
#    '(137, 77, 48)': 54,
#    '(199, 160, 96)': 112}},
#  '1926_mm_dd_a_Автопортрет_в_Экели.jpg': {'path': '1926_mm_dd_a_Автопортрет_в_Экели.jpg',
#   'name_of_painting': 'Автопортрет в Экели',
#   'year': '1926',
#   'most_common_colors_ever': {'(35, 36, 39)': 1230,
#    '(73, 64, 55)': 1455,
#    '(139, 125, 100)': 243,
#    '(192, 184, 173)': 1265,
#    '(82, 98, 120)': 125,
#    '(137, 77, 48)': 39,
#    '(199, 160, 96)': 825}},
#  '1926_mm_dd_a_Автопортрет_за_свадебным_столом.jpg': {'path': '1926_mm_dd_a_Автопортрет_за_свадебным_столом.jpg',
#   'name_of_painting': 'Автопортрет за свадебным столом',
#   'year': '1926',
#   'most_common_colors_ever': {'(35, 36, 39)': 3999,
#    '(73, 64, 55)': 994,
#    '(139, 125, 100)': 259,
#    '(192, 184, 173)': 334,
#    '(82, 98, 120)': 542,
#    '(137, 77, 48)': 219,
#    '(199, 160, 96)': 226}},
#  '1926_mm_dd_a_Автопортрет_на_фоне_стены_дома.jpg': {'path': '1926_mm_dd_a_Автопортрет_на_фоне_стены_дома.jpg',
#   'name_of_painting': 'Автопортрет на фоне стены дома',
#   'year': '1926',
#   'most_common_colors_ever': {'(35, 36, 39)': 356,
#    '(73, 64, 55)': 1023,
#    '(139, 125, 100)': 1013,
#    '(192, 184, 173)': 553,
#    '(82, 98, 120)': 141,
#    '(137, 77, 48)': 349,
#    '(199, 160, 96)': 414}},
#  '1926_mm_dd_a_Автопортрет_с_руками_в_карманах.jpg': {'path': '1926_mm_dd_a_Автопортрет_с_руками_в_карманах.jpg',
#   'name_of_painting': 'Автопортрет с руками в карманах',
#   'year': '1926',
#   'most_common_colors_ever': {'(35, 36, 39)': 3460,
#    '(73, 64, 55)': 532,
#    '(139, 125, 100)': 97,
#    '(192, 184, 173)': 818,
#    '(82, 98, 120)': 1525,
#    '(137, 77, 48)': 104,
#    '(199, 160, 96)': 39}},
#  '1927_mm_dd_i_Dog.jpeg': {'path': '1927_mm_dd_i_Dog.jpeg',
#   'name_of_painting': 'Dog.jpeg',
#   'year': '1927',
#   'most_common_colors_ever': {'(35, 36, 39)': 2534,
#    '(73, 64, 55)': 3204,
#    '(139, 125, 100)': 924,
#    '(192, 184, 173)': 2,
#    '(82, 98, 120)': 0,
#    '(137, 77, 48)': 817,
#    '(199, 160, 96)': 306}},
#  '1927_mm_dd_i_Red House and Spruces.jpeg': {'path': '1927_mm_dd_i_Red House and Spruces.jpeg',
#   'name_of_painting': 'Red House and Spruces.jpeg',
#   'year': '1927',
#   'most_common_colors_ever': {'(35, 36, 39)': 72,
#    '(73, 64, 55)': 54,
#    '(139, 125, 100)': 142,
#    '(192, 184, 173)': 524,
#    '(82, 98, 120)': 366,
#    '(137, 77, 48)': 28,
#    '(199, 160, 96)': 101}},
#  '1928_mm_dd_i_Модель_на_кушетке.jpg': {'path': '1928_mm_dd_i_Модель_на_кушетке.jpg',
#   'name_of_painting': 'Модель на кушетке',
#   'year': '1928',
#   'most_common_colors_ever': {'(35, 36, 39)': 2352,
#    '(73, 64, 55)': 1679,
#    '(139, 125, 100)': 497,
#    '(192, 184, 173)': 1208,
#    '(82, 98, 120)': 725,
#    '(137, 77, 48)': 185,
#    '(199, 160, 96)': 54}},
#  '1929_mm_dd_i_Обнаженная_рядом_с_плетеным_креслом.jpg': {'path': '1929_mm_dd_i_Обнаженная_рядом_с_плетеным_креслом.jpg',
#   'name_of_painting': 'Обнаженная рядом с плетеным креслом',
#   'year': '1929',
#   'most_common_colors_ever': {'(35, 36, 39)': 1304,
#    '(73, 64, 55)': 864,
#    '(139, 125, 100)': 1190,
#    '(192, 184, 173)': 1070,
#    '(82, 98, 120)': 191,
#    '(137, 77, 48)': 823,
#    '(199, 160, 96)': 340}},
#  '1930_mm_dd_a_Автопортрет_во_время_болезни_глаз.jpg': {'path': '1930_mm_dd_a_Автопортрет_во_время_болезни_глаз.jpg',
#   'name_of_painting': 'Автопортрет во время болезни глаз',
#   'year': '1930',
#   'most_common_colors_ever': {'(35, 36, 39)': 3811,
#    '(73, 64, 55)': 1331,
#    '(139, 125, 100)': 502,
#    '(192, 184, 173)': 1025,
#    '(82, 98, 120)': 241,
#    '(137, 77, 48)': 419,
#    '(199, 160, 96)': 359}},
#  '1930_mm_dd_i_Голова_собаки.jpg': {'path': '1930_mm_dd_i_Голова_собаки.jpg',
#   'name_of_painting': 'Голова собаки',
#   'year': '1930',
#   'most_common_colors_ever': {'(35, 36, 39)': 2985,
#    '(73, 64, 55)': 2002,
#    '(139, 125, 100)': 529,
#    '(192, 184, 173)': 289,
#    '(82, 98, 120)': 7,
#    '(137, 77, 48)': 375,
#    '(199, 160, 96)': 338}},
#  '1935_mm_dd_i_Одинокие.jpg': {'path': '1935_mm_dd_i_Одинокие.jpg',
#   'name_of_painting': 'Одинокие',
#   'year': '1935',
#   'most_common_colors_ever': {'(35, 36, 39)': 735,
#    '(73, 64, 55)': 485,
#    '(139, 125, 100)': 292,
#    '(192, 184, 173)': 476,
#    '(82, 98, 120)': 57,
#    '(137, 77, 48)': 616,
#    '(199, 160, 96)': 90}},
#  '1938_mm_dd_a_Автопортрет_с_бутылками.jpg': {'path': '1938_mm_dd_a_Автопортрет_с_бутылками.jpg',
#   'name_of_painting': 'Автопортрет с бутылками',
#   'year': '1938',
#   'most_common_colors_ever': {'(35, 36, 39)': 1400,
#    '(73, 64, 55)': 411,
#    '(139, 125, 100)': 410,
#    '(192, 184, 173)': 1727,
#    '(82, 98, 120)': 338,
#    '(137, 77, 48)': 185,
#    '(199, 160, 96)': 301}},
#  '1940_mm_dd_a_Автопортрет_с_головой_трески.jpg': {'path': '1940_mm_dd_a_Автопортрет_с_головой_трески.jpg',
#   'name_of_painting': 'Автопортрет с головой трески',
#   'year': '1940',
#   'most_common_colors_ever': {'(35, 36, 39)': 3426,
#    '(73, 64, 55)': 863,
#    '(139, 125, 100)': 456,
#    '(192, 184, 173)': 238,
#    '(82, 98, 120)': 382,
#    '(137, 77, 48)': 241,
#    '(199, 160, 96)': 553}},
#  '1940_mm_dd_a_У_окна.jpg': {'path': '1940_mm_dd_a_У_окна.jpg',
#   'name_of_painting': 'У окна',
#   'year': '1940',
#   'most_common_colors_ever': {'(35, 36, 39)': 1530,
#    '(73, 64, 55)': 1123,
#    '(139, 125, 100)': 791,
#    '(192, 184, 173)': 877,
#    '(82, 98, 120)': 9,
#    '(137, 77, 48)': 196,
#    '(199, 160, 96)': 65}},
#  '1940_mm_dd_i_Женщины_на_мосту.jpg': {'path': '1940_mm_dd_i_Женщины_на_мосту.jpg',
#   'name_of_painting': 'Женщины на мосту',
#   'year': '1940',
#   'most_common_colors_ever': {'(35, 36, 39)': 578,
#    '(73, 64, 55)': 392,
#    '(139, 125, 100)': 243,
#    '(192, 184, 173)': 214,
#    '(82, 98, 120)': 152,
#    '(137, 77, 48)': 410,
#    '(199, 160, 96)': 393}},
#  '1942_mm_dd_a_Автопортрет_в_саду_Экели.jpg': {'path': '1942_mm_dd_a_Автопортрет_в_саду_Экели.jpg',
#   'name_of_painting': 'Автопортрет в саду Экели',
#   'year': '1942',
#   'most_common_colors_ever': {'(35, 36, 39)': 1,
#    '(73, 64, 55)': 1977,
#    '(139, 125, 100)': 3772,
#    '(192, 184, 173)': 481,
#    '(82, 98, 120)': 17,
#    '(137, 77, 48)': 306,
#    '(199, 160, 96)': 250}},
#  '1943_mm_dd_a_Автопортрет_с_пастельной_палкой_2.jpg': {'path': '1943_mm_dd_a_Автопортрет_с_пастельной_палкой_2.jpg',
#   'name_of_painting': 'Автопортрет с пастельной палкой 2',
#   'year': '1943',
#   'most_common_colors_ever': {'(35, 36, 39)': 2040,
#    '(73, 64, 55)': 1844,
#    '(139, 125, 100)': 588,
#    '(192, 184, 173)': 549,
#    '(82, 98, 120)': 312,
#    '(137, 77, 48)': 170,
#    '(199, 160, 96)': 507}},
#  '1943_mm_dd_a_Между_часами_и_кроватью._Автопортрет.jpg': {'path': '1943_mm_dd_a_Между_часами_и_кроватью._Автопортрет.jpg',
#   'name_of_painting': 'Между часами и кроватью. Автопортрет',
#   'year': '1943',
#   'most_common_colors_ever': {'(35, 36, 39)': 2929,
#    '(73, 64, 55)': 1881,
#    '(139, 125, 100)': 656,
#    '(192, 184, 173)': 1045,
#    '(82, 98, 120)': 209,
#    '(137, 77, 48)': 359,
#    '(199, 160, 96)': 247}},
#  '1943_mm_dd_i_Автопортрет_между_часами_и_кроватью.jpg': {'path': '1943_mm_dd_i_Автопортрет_между_часами_и_кроватью.jpg',
#   'name_of_painting': 'Автопортрет между часами и кроватью',
#   'year': '1943',
#   'most_common_colors_ever': {'(35, 36, 39)': 716,
#    '(73, 64, 55)': 2051,
#    '(139, 125, 100)': 935,
#    '(192, 184, 173)': 94,
#    '(82, 98, 120)': 318,
#    '(137, 77, 48)': 225,
#    '(199, 160, 96)': 88}},
#  '1944_mm_dd_a_Автопортрет_в_полосатом_свитере.jpg': {'path': '1944_mm_dd_a_Автопортрет_в_полосатом_свитере.jpg',
#   'name_of_painting': 'Автопортрет в полосатом свитере',
#   'year': '1944',
#   'most_common_colors_ever': {'(35, 36, 39)': 1313,
#    '(73, 64, 55)': 652,
#    '(139, 125, 100)': 419,
#    '(192, 184, 173)': 791,
#    '(82, 98, 120)': 125,
#    '(137, 77, 48)': 329,
#    '(199, 160, 96)': 271}}}

# %%
colors_by_year_gm = get_colors_by_year(folder_path, classifier='GM')

# %%
for i in colors_by_year_gm:
    # print(colors_by_year_gm[i])
    # # print(info_dict[i])
    # # print(i.split('_')[0])
    if i.split('_')[0] != 'yyyy':
        info_dict[i]['most_common_colors'] = colors_by_year_gm[i]

# %%
info_dict
# Out:
# {'1882_mm_dd_a_Автопортрет.jpg': {'path': '1882_mm_dd_a_Автопортрет.jpg',
#   'name_of_painting': 'Автопортрет',
#   'year': '1882',
#   'most_common_colors_ever': {'(35, 36, 39)': 4381,
#    '(73, 64, 55)': 2151,
#    '(139, 125, 100)': 429,
#    '(192, 184, 173)': 61,
#    '(82, 98, 120)': 13,
#    '(137, 77, 48)': 0,
#    '(199, 160, 96)': 259},
#   'most_common_colors': {'(41, 56, 62)': 7310,
#    '(62, 67, 70)': 3525,
#    '(197, 163, 126)': 1913,
#    '(27, 37, 44)': 1590,
#    '(120, 100, 85)': 1476,
#    '(116, 110, 103)': 294,
#    '(220, 215, 204)': 276}},
#  '1882_mm_dd_a_Автопортрет_в_19_лет.jpg': {'path': '1882_mm_dd_a_Автопортрет_в_19_лет.jpg',
#   'name_of_painting': 'Автопортрет в 19 лет',
#   'year': '1882',
#   'most_common_colors_ever': {'(35, 36, 39)': 5159,
#    '(73, 64, 55)': 1873,
#    '(139, 125, 100)': 415,
#    '(192, 184, 173)': 169,
#    '(82, 98, 120)': 0,
#    '(137, 77, 48)': 36,
#    '(199, 160, 96)': 12},
#   'most_common_colors': {'(11, 9, 15)': 5343,
#    '(42, 35, 31)': 3746,
#    '(20, 18, 21)': 3099,
#    '(74, 64, 52)': 1858,
#    '(150, 135, 110)': 982,
#    '(218, 192, 162)': 809,
#    '(119, 94, 75)': 547}},
#  '1883_mm_dd_i_Девушка.jpg': {'path': '1883_mm_dd_i_Девушка.jpg',
#   'name_of_painting': 'Девушка',
#   'year': '1883',
#   'most_common_colors_ever': {'(35, 36, 39)': 242,
#    '(73, 64, 55)': 786,
#    '(139, 125, 100)': 2828,
#    '(192, 184, 173)': 410,
#    '(82, 98, 120)': 1,
#    '(137, 77, 48)': 555,
#    '(199, 160, 96)': 403},
#   'most_common_colors': {'(179, 148, 117)': 6231,
#    '(139, 103, 81)': 3954,
#    '(102, 76, 69)': 2198,
#    '(150, 128, 119)': 1623,
#    '(224, 212, 196)': 1206,
#    '(188, 141, 112)': 631,
#    '(57, 44, 46)': 541}},
#  '1885_mm_dd_i_Больная_девочка.jpg': {'path': '1885_mm_dd_i_Больная_девочка.jpg',
#   'name_of_painting': 'Больная девочка',
#   'year': '1885',
#   'most_common_colors_ever': {'(35, 36, 39)': 6573,
#    '(73, 64, 55)': 3510,
#    '(139, 125, 100)': 365,
#    '(192, 184, 173)': 630,
#    '(82, 98, 120)': 106,
#    '(137, 77, 48)': 69,
#    '(199, 160, 96)': 48},
#   'most_common_colors': {'(55, 62, 55)': 5640,
#    '(33, 43, 44)': 5280,
#    '(86, 91, 80)': 2387,
#    '(161, 166, 156)': 1119,
#    '(205, 204, 182)': 860,
#    '(162, 147, 118)': 613,
#    '(100, 76, 57)': 485}},
#  '1886_mm_dd_a_Автопортрет.jpg': {'path': '1886_mm_dd_a_Автопортрет.jpg',
#   'name_of_painting': 'Автопортрет',
#   'year': '1886',
#   'most_common_colors_ever': {'(35, 36, 39)': 5856,
#    '(73, 64, 55)': 2217,
#    '(139, 125, 100)': 830,
#    '(192, 184, 173)': 376,
#    '(82, 98, 120)': 37,
#    '(137, 77, 48)': 330,
#    '(199, 160, 96)': 120},
#   'most_common_colors': {'(43, 50, 52)': 4229,
#    '(53, 41, 36)': 3334,
#    '(26, 21, 19)': 3085,
#    '(121, 103, 82)': 2566,
#    '(181, 160, 128)': 1949,
#    '(129, 92, 65)': 755,
#    '(154, 169, 154)': 466}},
#  '1888_mm_dd_a_Автопортрет.jpg': {'path': '1888_mm_dd_a_Автопортрет.jpg',
#   'name_of_painting': 'Автопортрет',
#   'year': '1888',
#   'most_common_colors_ever': {'(35, 36, 39)': 2551,
#    '(73, 64, 55)': 2783,
#    '(139, 125, 100)': 870,
#    '(192, 184, 173)': 21,
#    '(82, 98, 120)': 10,
#    '(137, 77, 48)': 945,
#    '(199, 160, 96)': 1302},
#   'most_common_colors': {'(114, 97, 67)': 3417,
#    '(68, 63, 55)': 3248,
#    '(155, 119, 66)': 2572,
#    '(37, 35, 33)': 2289,
#    '(199, 153, 104)': 2073,
#    '(122, 82, 44)': 1654,
#    '(196, 153, 87)': 1131}},
#  '1889_mm_dd_i_Летняя_ночь_(Ингер_на_берегу).jpg': {'path': '1889_mm_dd_i_Летняя_ночь_(Ингер_на_берегу).jpg',
#   'name_of_painting': 'Летняя ночь (Ингер на берегу)',
#   'year': '1889',
#   'most_common_colors_ever': {'(35, 36, 39)': 1476,
#    '(73, 64, 55)': 1034,
#    '(139, 125, 100)': 882,
#    '(192, 184, 173)': 408,
#    '(82, 98, 120)': 74,
#    '(137, 77, 48)': 6,
#    '(199, 160, 96)': 131},
#   'most_common_colors': {'(152, 183, 158)': 3427,
#    '(70, 85, 69)': 3100,
#    '(29, 51, 49)': 2759,
#    '(114, 124, 88)': 2685,
#    '(206, 208, 161)': 2111,
#    '(116, 148, 128)': 1547,
#    '(155, 140, 80)': 755}},
#  '1889_mm_xx_i_Весна.jpg': {'path': '1889_mm_xx_i_Весна.jpg',
#   'name_of_painting': 'Весна',
#   'year': '1889',
#   'most_common_colors_ever': {'(35, 36, 39)': 1946,
#    '(73, 64, 55)': 1650,
#    '(139, 125, 100)': 1863,
#    '(192, 184, 173)': 1266,
#    '(82, 98, 120)': 21,
#    '(137, 77, 48)': 176,
#    '(199, 160, 96)': 69},
#   'most_common_colors': {'(81, 86, 73)': 4345,
#    '(33, 51, 53)': 2818,
#    '(117, 120, 95)': 2670,
#    '(174, 175, 151)': 2629,
#    '(157, 157, 123)': 1901,
#    '(139, 113, 81)': 1249,
#    '(218, 212, 171)': 772}},
#  '1891_mm_dd_i_Ночь_в_Ницце.jpg': {'path': '1891_mm_dd_i_Ночь_в_Ницце.jpg',
#   'name_of_painting': 'Ночь в Ницце',
#   'year': '1891',
#   'most_common_colors_ever': {'(35, 36, 39)': 1183,
#    '(73, 64, 55)': 834,
#    '(139, 125, 100)': 689,
#    '(192, 184, 173)': 6,
#    '(82, 98, 120)': 1567,
#    '(137, 77, 48)': 2,
#    '(199, 160, 96)': 11},
#   'most_common_colors': {'(86, 150, 145)': 3539,
#    '(107, 113, 109)': 3282,
#    '(51, 84, 92)': 2181,
#    '(93, 129, 125)': 1971,
#    '(156, 153, 131)': 1921,
#    '(81, 84, 85)': 1753,
#    '(43, 47, 51)': 1737}},
#  '1891_mm_dd_i_Улица_Лафайет.jpg': {'path': '1891_mm_dd_i_Улица_Лафайет.jpg',
#   'name_of_painting': 'Улица Лафайет',
#   'year': '1891',
#   'most_common_colors_ever': {'(35, 36, 39)': 527,
#    '(73, 64, 55)': 563,
#    '(139, 125, 100)': 839,
#    '(192, 184, 173)': 2065,
#    '(82, 98, 120)': 173,
#    '(137, 77, 48)': 81,
#    '(199, 160, 96)': 413},
#   'most_common_colors': {'(181, 177, 165)': 4144,
#    '(207, 187, 148)': 3546,
#    '(161, 133, 95)': 2180,
#    '(229, 224, 211)': 1804,
#    '(231, 211, 149)': 1714,
#    '(120, 119, 118)': 1586,
#    '(61, 61, 50)': 1410}},
#  '1892_mm_dd_a_Автопортрет_под_женской_маской.jpg': {'path': '1892_mm_dd_a_Автопортрет_под_женской_маской.jpg',
#   'name_of_painting': 'Автопортрет под женской маской',
#   'year': '1892',
#   'most_common_colors_ever': {'(35, 36, 39)': 3311,
#    '(73, 64, 55)': 3473,
#    '(139, 125, 100)': 75,
#    '(192, 184, 173)': 73,
#    '(82, 98, 120)': 0,
#    '(137, 77, 48)': 2823,
#    '(199, 160, 96)': 89},
#   'most_common_colors': {'(51, 40, 36)': 4583,
#    '(124, 68, 49)': 3431,
#    '(84, 63, 47)': 3003,
#    '(156, 61, 47)': 2224,
#    '(200, 106, 60)': 1470,
#    '(183, 132, 71)': 958,
#    '(215, 199, 186)': 715}},
#  '1892_mm_dd_i_Вечер_на_улице_Карла_Иоанна.jpg': {'path': '1892_mm_dd_i_Вечер_на_улице_Карла_Иоанна.jpg',
#   'name_of_painting': 'Вечер на улице Карла Иоанна',
#   'year': '1892',
#   'most_common_colors_ever': {'(35, 36, 39)': 3387,
#    '(73, 64, 55)': 2082,
#    '(139, 125, 100)': 583,
#    '(192, 184, 173)': 15,
#    '(82, 98, 120)': 757,
#    '(137, 77, 48)': 834,
#    '(199, 160, 96)': 202},
#   'most_common_colors': {'(70, 60, 67)': 3968,
#    '(108, 66, 57)': 2895,
#    '(26, 25, 29)': 2795,
#    '(162, 109, 90)': 2174,
#    '(120, 104, 118)': 1996,
#    '(84, 94, 147)': 1769,
#    '(211, 165, 119)': 787}},
#  '1892_mm_dd_i_Лунный_свет_на_берегу.jpg': {'path': '1892_mm_dd_i_Лунный_свет_на_берегу.jpg',
#   'name_of_painting': 'Лунный свет на берегу',
#   'year': '1892',
#   'most_common_colors_ever': {'(35, 36, 39)': 2952,
#    '(73, 64, 55)': 1892,
#    '(139, 125, 100)': 786,
#    '(192, 184, 173)': 487,
#    '(82, 98, 120)': 148,
#    '(137, 77, 48)': 0,
#    '(199, 160, 96)': 368},
#   'most_common_colors': {'(37, 55, 57)': 5745,
#    '(102, 94, 87)': 3188,
#    '(66, 69, 70)': 2362,
#    '(176, 135, 101)': 1883,
#    '(200, 182, 154)': 1232,
#    '(160, 156, 147)': 1096,
#    '(130, 144, 151)': 878}},
#  '1892_mm_dd_i_Меланхолия.jpg': {'path': '1892_mm_dd_i_Меланхолия.jpg',
#   'name_of_painting': 'Меланхолия',
#   'year': '1892',
#   'most_common_colors_ever': {'(35, 36, 39)': 1042,
#    '(73, 64, 55)': 507,
#    '(139, 125, 100)': 2120,
#    '(192, 184, 173)': 393,
#    '(82, 98, 120)': 467,
#    '(137, 77, 48)': 22,
#    '(199, 160, 96)': 33},
#   'most_common_colors': {'(128, 117, 108)': 5144,
#    '(3, 19, 15)': 2803,
#    '(135, 141, 143)': 2749,
#    '(39, 54, 49)': 2523,
#    '(171, 136, 112)': 1390,
#    '(172, 161, 147)': 1252,
#    '(99, 108, 112)': 523}},
#  '1892_mm_dd_i_Портрет_Ингер_Мунк.jpg': {'path': '1892_mm_dd_i_Портрет_Ингер_Мунк.jpg',
#   'name_of_painting': 'Портрет Ингер Мунк',
#   'year': '1892',
#   'most_common_colors_ever': {'(35, 36, 39)': 1199,
#    '(73, 64, 55)': 158,
#    '(139, 125, 100)': 174,
#    '(192, 184, 173)': 8,
#    '(82, 98, 120)': 0,
#    '(137, 77, 48)': 187,
#    '(199, 160, 96)': 85},
#   'most_common_colors': {'(204, 145, 133)': 4507,
#    '(173, 116, 115)': 3805,
#    '(201, 63, 32)': 2214,
#    '(9, 8, 16)': 2137,
#    '(36, 22, 28)': 1616,
#    '(127, 62, 50)': 1430,
#    '(215, 144, 115)': 675}},
#  '1892_mm_dd_i_Тайна_летней_ночи.jpg': {'path': '1892_mm_dd_i_Тайна_летней_ночи.jpg',
#   'name_of_painting': 'Тайна летней ночи',
#   'year': '1892',
#   'most_common_colors_ever': {'(35, 36, 39)': 1009,
#    '(73, 64, 55)': 1148,
#    '(139, 125, 100)': 1234,
#    '(192, 184, 173)': 228,
#    '(82, 98, 120)': 3035,
#    '(137, 77, 48)': 13,
#    '(199, 160, 96)': 531},
#   'most_common_colors': {'(92, 99, 120)': 3502,
#    '(118, 102, 82)': 3045,
#    '(56, 69, 83)': 3013,
#    '(135, 126, 131)': 2556,
#    '(203, 169, 135)': 1787,
#    '(52, 61, 56)': 1592,
#    '(174, 137, 117)': 889}},
#  '1892_mm_dd_Отчаяние.jpg': {'path': '1892_mm_dd_Отчаяние.jpg',
#   'name_of_painting': '',
#   'year': '1892',
#   'most_common_colors_ever': {'(35, 36, 39)': 4915,
#    '(73, 64, 55)': 846,
#    '(139, 125, 100)': 130,
#    '(192, 184, 173)': 110,
#    '(82, 98, 120)': 1294,
#    '(137, 77, 48)': 25,
#    '(199, 160, 96)': 219},
#   'most_common_colors': {'(28, 30, 31)': 5354,
#    '(69, 84, 97)': 3814,
#    '(215, 132, 96)': 1701,
#    '(136, 135, 140)': 1604,
#    '(74, 58, 52)': 1529,
#    '(214, 75, 39)': 1341,
#    '(230, 205, 166)': 1041}},
#  '1893_mm_dd_i_Буря.jpg': {'path': '1893_mm_dd_i_Буря.jpg',
#   'name_of_painting': 'Буря',
#   'year': '1893',
#   'most_common_colors_ever': {'(35, 36, 39)': 5392,
#    '(73, 64, 55)': 3810,
#    '(139, 125, 100)': 2252,
#    '(192, 184, 173)': 295,
#    '(82, 98, 120)': 1,
#    '(137, 77, 48)': 92,
#    '(199, 160, 96)': 105},
#   'most_common_colors': {'(33, 42, 35)': 4497,
#    '(61, 60, 44)': 3942,
#    '(94, 84, 59)': 2697,
#    '(133, 125, 105)': 2221,
#    '(142, 122, 87)': 1569,
#    '(174, 167, 148)': 984,
#    '(212, 191, 136)': 474}},
#  '1893_mm_dd_i_Голос.jpg': {'path': '1893_mm_dd_i_Голос.jpg',
#   'name_of_painting': 'Голос',
#   'year': '1893',
#   'most_common_colors_ever': {'(35, 36, 39)': 978,
#    '(73, 64, 55)': 526,
#    '(139, 125, 100)': 251,
#    '(192, 184, 173)': 1565,
#    '(82, 98, 120)': 0,
#    '(137, 77, 48)': 439,
#    '(199, 160, 96)': 36},
#   'most_common_colors': {'(35, 14, 13)': 5026,
#    '(188, 183, 167)': 3369,
#    '(71, 44, 36)': 2638,
#    '(140, 73, 47)': 1999,
#    '(181, 145, 130)': 1763,
#    '(238, 185, 139)': 1198,
#    '(243, 204, 104)': 391}},
#  '1893_mm_dd_i_Крик.jpg': {'path': '1893_mm_dd_i_Крик.jpg',
#   'name_of_painting': 'Крик',
#   'year': '1893',
#   'most_common_colors_ever': {'(35, 36, 39)': 13,
#    '(73, 64, 55)': 2360,
#    '(139, 125, 100)': 2634,
#    '(192, 184, 173)': 0,
#    '(82, 98, 120)': 314,
#    '(137, 77, 48)': 706,
#    '(199, 160, 96)': 26},
#   'most_common_colors': {'(78, 75, 79)': 3362,
#    '(98, 87, 80)': 3353,
#    '(125, 103, 84)': 3342,
#    '(158, 99, 75)': 2180,
#    '(147, 119, 87)': 1774,
#    '(164, 84, 59)': 1412,
#    '(170, 114, 68)': 961}},
#  '1893_mm_dd_i_Лунный_свет.jpg': {'path': '1893_mm_dd_i_Лунный_свет.jpg',
#   'name_of_painting': 'Лунный свет',
#   'year': '1893',
#   'most_common_colors_ever': {'(35, 36, 39)': 1300,
#    '(73, 64, 55)': 913,
#    '(139, 125, 100)': 571,
#    '(192, 184, 173)': 969,
#    '(82, 98, 120)': 132,
#    '(137, 77, 48)': 295,
#    '(199, 160, 96)': 0},
#   'most_common_colors': {'(9, 4, 5)': 5059,
#    '(24, 15, 17)': 2469,
#    '(101, 79, 62)': 2453,
#    '(162, 162, 155)': 2388,
#    '(87, 79, 80)': 1821,
#    '(211, 213, 199)': 1630,
#    '(110, 69, 42)': 564}},
#  '1893_mm_dd_i_Меланхолия.jpg': {'path': '1893_mm_dd_i_Меланхолия.jpg',
#   'name_of_painting': 'Меланхолия',
#   'year': '1893',
#   'most_common_colors_ever': {'(35, 36, 39)': 213,
#    '(73, 64, 55)': 156,
#    '(139, 125, 100)': 206,
#    '(192, 184, 173)': 1127,
#    '(82, 98, 120)': 95,
#    '(137, 77, 48)': 41,
#    '(199, 160, 96)': 1},
#   'most_common_colors': {'(166, 153, 177)': 4981,
#    '(194, 157, 149)': 3137,
#    '(117, 86, 97)': 2506,
#    '(10, 25, 91)': 1915,
#    '(15, 40, 60)': 1818,
#    '(241, 236, 219)': 1301,
#    '(68, 100, 82)': 726}},
#  '1893_mm_dd_i_Руки.jpg': {'path': '1893_mm_dd_i_Руки.jpg',
#   'name_of_painting': 'Руки',
#   'year': '1893',
#   'most_common_colors_ever': {'(35, 36, 39)': 1002,
#    '(73, 64, 55)': 2040,
#    '(139, 125, 100)': 912,
#    '(192, 184, 173)': 92,
#    '(82, 98, 120)': 114,
#    '(137, 77, 48)': 1120,
#    '(199, 160, 96)': 1137},
#   'most_common_colors': {'(162, 112, 77)': 3804,
#    '(68, 49, 47)': 3178,
#    '(115, 84, 80)': 2680,
#    '(190, 140, 91)': 2371,
#    '(66, 49, 77)': 1943,
#    '(141, 137, 115)': 1242,
#    '(121, 51, 46)': 1166}},
#  '1893_mm_dd_i_Смерть_в_комнате_больного.jpg': {'path': '1893_mm_dd_i_Смерть_в_комнате_больного.jpg',
#   'name_of_painting': 'Смерть в комнате больного',
#   'year': '1893',
#   'most_common_colors_ever': {'(35, 36, 39)': 1171,
#    '(73, 64, 55)': 1448,
#    '(139, 125, 100)': 570,
#    '(192, 184, 173)': 121,
#    '(82, 98, 120)': 830,
#    '(137, 77, 48)': 648,
#    '(199, 160, 96)': 81},
#   'most_common_colors': {'(228, 139, 70)': 3518,
#    '(47, 50, 61)': 2809,
#    '(119, 146, 115)': 2658,
#    '(75, 85, 96)': 2318,
#    '(100, 63, 57)': 2078,
#    '(151, 138, 119)': 1555,
#    '(183, 101, 58)': 1448}},
#  '1894_mm_dd_i_Мадонна.jpg.jpg': {'path': '1894_mm_dd_i_Мадонна.jpg.jpg',
#   'name_of_painting': 'Мадонна',
#   'year': '1894',
#   'most_common_colors_ever': {'(35, 36, 39)': 1210,
#    '(73, 64, 55)': 2328,
#    '(139, 125, 100)': 86,
#    '(192, 184, 173)': 7,
#    '(82, 98, 120)': 1,
#    '(137, 77, 48)': 1750,
#    '(199, 160, 96)': 392},
#   'most_common_colors': {'(97, 69, 51)': 4450,
#    '(147, 101, 54)': 4160,
#    '(59, 40, 31)': 2858,
#    '(223, 172, 98)': 1497,
#    '(249, 204, 100)': 1473,
#    '(21, 13, 10)': 1258,
#    '(154, 65, 19)': 688}},
#  '1894_mm_dd_i_Пепел.jpg': {'path': '1894_mm_dd_i_Пепел.jpg',
#   'name_of_painting': 'Пепел',
#   'year': '1894',
#   'most_common_colors_ever': {'(35, 36, 39)': 211,
#    '(73, 64, 55)': 6003,
#    '(139, 125, 100)': 899,
#    '(192, 184, 173)': 454,
#    '(82, 98, 120)': 75,
#    '(137, 77, 48)': 806,
#    '(199, 160, 96)': 517},
#   'most_common_colors': {'(66, 66, 63)': 4617,
#    '(95, 76, 60)': 3603,
#    '(90, 93, 77)': 2538,
#    '(141, 134, 107)': 1970,
#    '(143, 109, 71)': 1373,
#    '(185, 166, 105)': 1240,
#    '(201, 201, 168)': 1043}},
#  '1894_mm_dd_i_Созревание.jpg': {'path': '1894_mm_dd_i_Созревание.jpg',
#   'name_of_painting': 'Созревание',
#   'year': '1894',
#   'most_common_colors_ever': {'(35, 36, 39)': 4337,
#    '(73, 64, 55)': 4940,
#    '(139, 125, 100)': 943,
#    '(192, 184, 173)': 331,
#    '(82, 98, 120)': 16,
#    '(137, 77, 48)': 189,
#    '(199, 160, 96)': 42},
#   'most_common_colors': {'(63, 59, 50)': 3416,
#    '(90, 82, 61)': 3194,
#    '(56, 41, 34)': 2732,
#    '(39, 41, 43)': 2566,
#    '(144, 115, 84)': 2180,
#    '(113, 118, 105)': 1248,
#    '(173, 170, 147)': 1048}},
#  '1894_mm_dd_i_Тревога.jpg': {'path': '1894_mm_dd_i_Тревога.jpg',
#   'name_of_painting': 'Тревога',
#   'year': '1894',
#   'most_common_colors_ever': {'(35, 36, 39)': 6739,
#    '(73, 64, 55)': 1842,
#    '(139, 125, 100)': 185,
#    '(192, 184, 173)': 1,
#    '(82, 98, 120)': 31,
#    '(137, 77, 48)': 319,
#    '(199, 160, 96)': 659},
#   'most_common_colors': {'(41, 46, 42)': 5389,
#    '(21, 26, 31)': 2721,
#    '(160, 133, 90)': 2271,
#    '(181, 62, 43)': 1814,
#    '(81, 64, 48)': 1685,
#    '(210, 140, 65)': 1303,
#    '(186, 105, 65)': 1201}},
#  '1894_mm_dd_i_Три_стадии_женщины_(Сфинкс).jpg': {'path': '1894_mm_dd_i_Три_стадии_женщины_(Сфинкс).jpg',
#   'name_of_painting': 'Три стадии женщины (Сфинкс)',
#   'year': '1894',
#   'most_common_colors_ever': {'(35, 36, 39)': 6170,
#    '(73, 64, 55)': 3557,
#    '(139, 125, 100)': 576,
#    '(192, 184, 173)': 6,
#    '(82, 98, 120)': 0,
#    '(137, 77, 48)': 23,
#    '(199, 160, 96)': 490},
#   'most_common_colors': {'(38, 42, 49)': 4795,
#    '(91, 80, 75)': 3472,
#    '(49, 53, 54)': 2354,
#    '(166, 131, 101)': 1905,
#    '(62, 50, 52)': 1740,
#    '(182, 128, 90)': 1197,
#    '(230, 209, 166)': 921}},
#  '1895_mm_dd_a_Автопортрет_с_зажженной_сигаретой.jpg': {'path': '1895_mm_dd_a_Автопортрет_с_зажженной_сигаретой.jpg',
#   'name_of_painting': 'Автопортрет с зажженной сигаретой',
#   'year': '1895',
#   'most_common_colors_ever': {'(35, 36, 39)': 5239,
#    '(73, 64, 55)': 2199,
#    '(139, 125, 100)': 145,
#    '(192, 184, 173)': 82,
#    '(82, 98, 120)': 986,
#    '(137, 77, 48)': 4,
#    '(199, 160, 96)': 7},
#   'most_common_colors': {'(49, 46, 57)': 3751,
#    '(34, 33, 44)': 3435,
#    '(61, 72, 86)': 3177,
#    '(42, 55, 76)': 2299,
#    '(84, 92, 102)': 1417,
#    '(72, 67, 72)': 1385,
#    '(155, 137, 126)': 920}},
#  '1895_mm_dd_a_Автопортрет_со_скелетом_руки.jpg': {'path': '1895_mm_dd_a_Автопортрет_со_скелетом_руки.jpg',
#   'name_of_painting': 'Автопортрет со скелетом руки',
#   'year': '1895',
#   'most_common_colors_ever': {'(35, 36, 39)': 3,
#    '(73, 64, 55)': 7115,
#    '(139, 125, 100)': 2396,
#    '(192, 184, 173)': 435,
#    '(82, 98, 120)': 0,
#    '(137, 77, 48)': 0,
#    '(199, 160, 96)': 2},
#   'most_common_colors': {'(67, 61, 54)': 4500,
#    '(82, 74, 62)': 2677,
#    '(105, 94, 76)': 2467,
#    '(135, 119, 95)': 1947,
#    '(238, 225, 201)': 1690,
#    '(169, 148, 120)': 1561,
#    '(207, 188, 160)': 1542}},
#  '1895_mm_dd_i_Автопортрет_с_зажжённой_сигаретой.jpg': {'path': '1895_mm_dd_i_Автопортрет_с_зажжённой_сигаретой.jpg',
#   'name_of_painting': 'Автопортрет с зажжённой сигаретой',
#   'year': '1895',
#   'most_common_colors_ever': {'(35, 36, 39)': 5342,
#    '(73, 64, 55)': 2169,
#    '(139, 125, 100)': 148,
#    '(192, 184, 173)': 80,
#    '(82, 98, 120)': 952,
#    '(137, 77, 48)': 4,
#    '(199, 160, 96)': 9},
#   'most_common_colors': {'(34, 32, 42)': 3490,
#    '(66, 73, 86)': 3318,
#    '(45, 46, 59)': 3124,
#    '(46, 61, 81)': 2589,
#    '(60, 51, 58)': 1834,
#    '(86, 92, 100)': 1172,
#    '(158, 139, 126)': 857}},
#  '1895_mm_dd_i_Вампир.jpg': {'path': '1895_mm_dd_i_Вампир.jpg',
#   'name_of_painting': 'Вампир',
#   'year': '1895',
#   'most_common_colors_ever': {'(35, 36, 39)': 5821,
#    '(73, 64, 55)': 2986,
#    '(139, 125, 100)': 14,
#    '(192, 184, 173)': 7,
#    '(82, 98, 120)': 2,
#    '(137, 77, 48)': 305,
#    '(199, 160, 96)': 1},
#   'most_common_colors': {'(51, 31, 24)': 4541,
#    '(44, 35, 30)': 3950,
#    '(69, 52, 47)': 3248,
#    '(105, 46, 37)': 2172,
#    '(241, 205, 172)': 892,
#    '(172, 69, 52)': 881,
#    '(214, 132, 107)': 700}},
#  '1895_mm_dd_i_Запах_смерти.jpg': {'path': '1895_mm_dd_i_Запах_смерти.jpg',
#   'name_of_painting': 'Запах смерти',
#   'year': '1895',
#   'most_common_colors_ever': {'(35, 36, 39)': 2064,
#    '(73, 64, 55)': 984,
#    '(139, 125, 100)': 305,
#    '(192, 184, 173)': 177,
#    '(82, 98, 120)': 199,
#    '(137, 77, 48)': 285,
#    '(199, 160, 96)': 51},
#   'most_common_colors': {'(212, 122, 72)': 5529,
#    '(151, 98, 77)': 2527,
#    '(150, 158, 138)': 2161,
#    '(22, 23, 37)': 2161,
#    '(69, 48, 58)': 2004,
#    '(85, 120, 113)': 1676,
#    '(178, 95, 107)': 326}},
#  '1895_mm_dd_i_Крик_1.jpg': {'path': '1895_mm_dd_i_Крик_1.jpg',
#   'name_of_painting': 'Крик 1',
#   'year': '1895',
#   'most_common_colors_ever': {'(35, 36, 39)': 51,
#    '(73, 64, 55)': 414,
#    '(139, 125, 100)': 815,
#    '(192, 184, 173)': 182,
#    '(82, 98, 120)': 1608,
#    '(137, 77, 48)': 25,
#    '(199, 160, 96)': 792},
#   'most_common_colors': {'(75, 97, 139)': 3200,
#    '(126, 129, 143)': 3103,
#    '(81, 89, 89)': 2946,
#    '(193, 110, 72)': 2448,
#    '(180, 164, 136)': 2154,
#    '(147, 123, 106)': 1719,
#    '(203, 176, 104)': 814}},
#  '1895_mm_dd_i_Лунный_свет.jpg': {'path': '1895_mm_dd_i_Лунный_свет.jpg',
#   'name_of_painting': 'Лунный свет',
#   'year': '1895',
#   'most_common_colors_ever': {'(35, 36, 39)': 3233,
#    '(73, 64, 55)': 669,
#    '(139, 125, 100)': 51,
#    '(192, 184, 173)': 84,
#    '(82, 98, 120)': 386,
#    '(137, 77, 48)': 78,
#    '(199, 160, 96)': 76},
#   'most_common_colors': {'(29, 26, 22)': 4579,
#    '(41, 122, 169)': 3014,
#    '(60, 88, 109)': 2208,
#    '(61, 50, 35)': 2169,
#    '(234, 201, 170)': 1857,
#    '(104, 128, 165)': 1771,
#    '(179, 117, 78)': 786}},
#  '1895_mm_dd_i_Мадонна.jpg': {'path': '1895_mm_dd_i_Мадонна.jpg',
#   'name_of_painting': 'Мадонна',
#   'year': '1895',
#   'most_common_colors_ever': {'(35, 36, 39)': 1594,
#    '(73, 64, 55)': 7307,
#    '(139, 125, 100)': 274,
#    '(192, 184, 173)': 1580,
#    '(82, 98, 120)': 105,
#    '(137, 77, 48)': 1029,
#    '(199, 160, 96)': 0},
#   'most_common_colors': {'(58, 59, 57)': 5652,
#    '(131, 132, 120)': 2429,
#    '(63, 68, 68)': 1736,
#    '(152, 98, 68)': 1670,
#    '(242, 237, 230)': 1667,
#    '(105, 82, 65)': 1644,
#    '(204, 202, 178)': 1586}},
#  '1895_mm_dd_i_Следующий_день.jpg': {'path': '1895_mm_dd_i_Следующий_день.jpg',
#   'name_of_painting': 'Следующий день',
#   'year': '1895',
#   'most_common_colors_ever': {'(35, 36, 39)': 2694,
#    '(73, 64, 55)': 3215,
#    '(139, 125, 100)': 286,
#    '(192, 184, 173)': 686,
#    '(82, 98, 120)': 69,
#    '(137, 77, 48)': 1818,
#    '(199, 160, 96)': 250},
#   'most_common_colors': {'(67, 47, 44)': 3561,
#    '(96, 76, 76)': 3108,
#    '(110, 65, 55)': 2726,
#    '(130, 84, 61)': 2005,
#    '(182, 143, 121)': 1871,
#    '(32, 34, 41)': 1760,
#    '(209, 191, 184)': 1353}},
#  '1895_mm_dd_i_У_смертного_одра.jpg': {'path': '1895_mm_dd_i_У_смертного_одра.jpg',
#   'name_of_painting': 'У смертного одра',
#   'year': '1895',
#   'most_common_colors_ever': {'(35, 36, 39)': 4422,
#    '(73, 64, 55)': 945,
#    '(139, 125, 100)': 619,
#    '(192, 184, 173)': 355,
#    '(82, 98, 120)': 7,
#    '(137, 77, 48)': 757,
#    '(199, 160, 96)': 23},
#   'most_common_colors': {'(29, 29, 29)': 4527,
#    '(124, 50, 38)': 3470,
#    '(20, 13, 12)': 2305,
#    '(104, 48, 37)': 2007,
#    '(68, 54, 52)': 1582,
#    '(149, 127, 103)': 1419,
#    '(184, 169, 150)': 1074}},
#  '1896_mm_dd_a_Автопортрет_со_скелетом_руки.jpg': {'path': '1896_mm_dd_a_Автопортрет_со_скелетом_руки.jpg',
#   'name_of_painting': 'Автопортрет со скелетом руки',
#   'year': '1896',
#   'most_common_colors_ever': {'(35, 36, 39)': 1726,
#    '(73, 64, 55)': 473,
#    '(139, 125, 100)': 412,
#    '(192, 184, 173)': 354,
#    '(82, 98, 120)': 0,
#    '(137, 77, 48)': 0,
#    '(199, 160, 96)': 0},
#   'most_common_colors': {'(14, 14, 14)': 11253,
#    '(234, 218, 191)': 1610,
#    '(29, 28, 27)': 1005,
#    '(205, 191, 166)': 768,
#    '(113, 106, 93)': 679,
#    '(157, 147, 128)': 582,
#    '(71, 67, 60)': 487}},
#  '1896_mm_dd_i_Голос_(Летняя_ночь).jpg': {'path': '1896_mm_dd_i_Голос_(Летняя_ночь).jpg',
#   'name_of_painting': 'Голос (Летняя ночь)',
#   'year': '1896',
#   'most_common_colors_ever': {'(35, 36, 39)': 2134,
#    '(73, 64, 55)': 1733,
#    '(139, 125, 100)': 172,
#    '(192, 184, 173)': 338,
#    '(82, 98, 120)': 657,
#    '(137, 77, 48)': 273,
#    '(199, 160, 96)': 38},
#   'most_common_colors': {'(47, 54, 62)': 4301,
#    '(119, 135, 164)': 3379,
#    '(90, 52, 50)': 2803,
#    '(57, 76, 111)': 1696,
#    '(149, 125, 120)': 1592,
#    '(86, 138, 206)': 1407,
#    '(196, 195, 200)': 1206}},
#  '1896_mm_dd_i_Девушка_на_берегу.jpg': {'path': '1896_mm_dd_i_Девушка_на_берегу.jpg',
#   'name_of_painting': 'Девушка на берегу',
#   'year': '1896',
#   'most_common_colors_ever': {'(35, 36, 39)': 1659,
#    '(73, 64, 55)': 131,
#    '(139, 125, 100)': 134,
#    '(192, 184, 173)': 79,
#    '(82, 98, 120)': 3152,
#    '(137, 77, 48)': 123,
#    '(199, 160, 96)': 11},
#   'most_common_colors': {'(81, 106, 132)': 4461,
#    '(86, 134, 191)': 3088,
#    '(94, 155, 209)': 2753,
#    '(120, 132, 139)': 2254,
#    '(32, 39, 40)': 1806,
#    '(220, 221, 220)': 1678,
#    '(155, 110, 61)': 344}},
#  '1896_mm_dd_i_Расставание.jpg': {'path': '1896_mm_dd_i_Расставание.jpg',
#   'name_of_painting': 'Расставание',
#   'year': '1896',
#   'most_common_colors_ever': {'(35, 36, 39)': 2762,
#    '(73, 64, 55)': 1498,
#    '(139, 125, 100)': 641,
#    '(192, 184, 173)': 510,
#    '(82, 98, 120)': 139,
#    '(137, 77, 48)': 559,
#    '(199, 160, 96)': 279},
#   'most_common_colors': {'(76, 80, 66)': 3013,
#    '(133, 132, 139)': 2980,
#    '(33, 31, 28)': 2730,
#    '(220, 203, 153)': 2477,
#    '(124, 84, 43)': 2212,
#    '(155, 141, 107)': 1792,
#    '(198, 180, 145)': 1180}},
#  '1897_mm_dd_i_Мать_и_дочь.jpg': {'path': '1897_mm_dd_i_Мать_и_дочь.jpg',
#   'name_of_painting': 'Мать и дочь',
#   'year': '1897',
#   'most_common_colors_ever': {'(35, 36, 39)': 708,
#    '(73, 64, 55)': 480,
#    '(139, 125, 100)': 86,
#    '(192, 184, 173)': 13,
#    '(82, 98, 120)': 32,
#    '(137, 77, 48)': 589,
#    '(199, 160, 96)': 29},
#   'most_common_colors': {'(51, 32, 17)': 4242,
#    '(97, 68, 32)': 3536,
#    '(15, 7, 7)': 2437,
#    '(238, 210, 172)': 2325,
#    '(158, 126, 144)': 1845,
#    '(169, 119, 85)': 1034,
#    '(189, 95, 29)': 965}},
#  '1897_mm_dd_i_Поцелуй.jpg': {'path': '1897_mm_dd_i_Поцелуй.jpg',
#   'name_of_painting': 'Поцелуй',
#   'year': '1897',
#   'most_common_colors_ever': {'(35, 36, 39)': 3531,
#    '(73, 64, 55)': 6310,
#    '(139, 125, 100)': 311,
#    '(192, 184, 173)': 256,
#    '(82, 98, 120)': 27,
#    '(137, 77, 48)': 15,
#    '(199, 160, 96)': 1},
#   'most_common_colors': {'(59, 62, 66)': 7253,
#    '(44, 52, 56)': 4766,
#    '(168, 169, 181)': 1442,
#    '(77, 73, 73)': 1054,
#    '(134, 95, 82)': 849,
#    '(137, 129, 125)': 656,
#    '(234, 209, 191)': 364}},
#  '1897_mm_dd_i_Поцелуй.jpg.jpg': {'path': '1897_mm_dd_i_Поцелуй.jpg.jpg',
#   'name_of_painting': 'Поцелуй',
#   'year': '1897',
#   'most_common_colors_ever': {'(35, 36, 39)': 2518,
#    '(73, 64, 55)': 162,
#    '(139, 125, 100)': 29,
#    '(192, 184, 173)': 19,
#    '(82, 98, 120)': 1097,
#    '(137, 77, 48)': 0,
#    '(199, 160, 96)': 3},
#   'most_common_colors': {'(92, 134, 153)': 2959,
#    '(66, 113, 142)': 2372,
#    '(31, 52, 67)': 2346,
#    '(17, 24, 29)': 2303,
#    '(105, 138, 146)': 2245,
#    '(91, 110, 101)': 2209,
#    '(26, 58, 91)': 1950}},
#  '1898_mm_dd_i_Вынос_гроба.jpg': {'path': '1898_mm_dd_i_Вынос_гроба.jpg',
#   'name_of_painting': 'Вынос гроба',
#   'year': '1898',
#   'most_common_colors_ever': {'(35, 36, 39)': 186,
#    '(73, 64, 55)': 1865,
#    '(139, 125, 100)': 1014,
#    '(192, 184, 173)': 26,
#    '(82, 98, 120)': 194,
#    '(137, 77, 48)': 750,
#    '(199, 160, 96)': 280},
#   'most_common_colors': {'(93, 64, 65)': 3950,
#    '(169, 95, 59)': 2836,
#    '(221, 140, 51)': 2730,
#    '(172, 136, 106)': 2671,
#    '(126, 120, 129)': 2346,
#    '(60, 59, 90)': 1149,
#    '(218, 72, 36)': 702}},
#  '1898_mm_dd_i_Две_женщины._Символический_этюд.jpg': {'path': '1898_mm_dd_i_Две_женщины._Символический_этюд.jpg',
#   'name_of_painting': 'Две женщины. Символический этюд',
#   'year': '1898',
#   'most_common_colors_ever': {'(35, 36, 39)': 301,
#    '(73, 64, 55)': 813,
#    '(139, 125, 100)': 118,
#    '(192, 184, 173)': 0,
#    '(82, 98, 120)': 4,
#    '(137, 77, 48)': 2624,
#    '(199, 160, 96)': 277},
#   'most_common_colors': {'(186, 97, 49)': 3718,
#    '(102, 76, 42)': 3070,
#    '(222, 148, 74)': 2713,
#    '(153, 69, 50)': 2449,
#    '(110, 67, 59)': 2341,
#    '(180, 121, 88)': 1426,
#    '(51, 36, 86)': 667}},
#  '1898_mm_dd_i_Женщина_у_фьорда_в_Осгорстранне.jpg': {'path': '1898_mm_dd_i_Женщина_у_фьорда_в_Осгорстранне.jpg',
#   'name_of_painting': 'Женщина у фьорда в Осгорстранне',
#   'year': '1898',
#   'most_common_colors_ever': {'(35, 36, 39)': 1228,
#    '(73, 64, 55)': 1645,
#    '(139, 125, 100)': 773,
#    '(192, 184, 173)': 1311,
#    '(82, 98, 120)': 362,
#    '(137, 77, 48)': 86,
#    '(199, 160, 96)': 0},
#   'most_common_colors': {'(77, 59, 52)': 4255,
#    '(149, 143, 177)': 2416,
#    '(131, 120, 116)': 2362,
#    '(109, 111, 152)': 2203,
#    '(193, 184, 188)': 2157,
#    '(171, 168, 194)': 2104,
#    '(25, 18, 19)': 887}},
#  '1898_mm_dd_i_Красный_дикий_виноград.jpg': {'path': '1898_mm_dd_i_Красный_дикий_виноград.jpg',
#   'name_of_painting': 'Красный дикий виноград',
#   'year': '1898',
#   'most_common_colors_ever': {'(35, 36, 39)': 1372,
#    '(73, 64, 55)': 1549,
#    '(139, 125, 100)': 2885,
#    '(192, 184, 173)': 0,
#    '(82, 98, 120)': 1,
#    '(137, 77, 48)': 1312,
#    '(199, 160, 96)': 4},
#   'most_common_colors': {'(160, 140, 121)': 3383,
#    '(134, 96, 72)': 3125,
#    '(120, 105, 94)': 2914,
#    '(85, 68, 41)': 2249,
#    '(84, 48, 28)': 2168,
#    '(45, 29, 22)': 1406,
#    '(136, 52, 33)': 1139}},
#  '1898_mm_dd_i_Мужчина_и_женщина.jpg': {'path': '1898_mm_dd_i_Мужчина_и_женщина.jpg',
#   'name_of_painting': 'Мужчина и женщина',
#   'year': '1898',
#   'most_common_colors_ever': {'(35, 36, 39)': 5537,
#    '(73, 64, 55)': 2141,
#    '(139, 125, 100)': 281,
#    '(192, 184, 173)': 2,
#    '(82, 98, 120)': 4,
#    '(137, 77, 48)': 419,
#    '(199, 160, 96)': 1407},
#   'most_common_colors': {'(42, 41, 45)': 5533,
#    '(163, 126, 75)': 2301,
#    '(117, 95, 63)': 2240,
#    '(58, 56, 42)': 1936,
#    '(106, 107, 52)': 1922,
#    '(197, 166, 101)': 1526,
#    '(91, 39, 26)': 926}},
#  '1898_mm_dd_i_Обнаженная_в_профиль_справа.jpg': {'path': '1898_mm_dd_i_Обнаженная_в_профиль_справа.jpg',
#   'name_of_painting': 'Обнаженная в профиль справа',
#   'year': '1898',
#   'most_common_colors_ever': {'(35, 36, 39)': 2416,
#    '(73, 64, 55)': 5263,
#    '(139, 125, 100)': 405,
#    '(192, 184, 173)': 377,
#    '(82, 98, 120)': 159,
#    '(137, 77, 48)': 211,
#    '(199, 160, 96)': 104},
#   'most_common_colors': {'(49, 60, 63)': 5988,
#    '(95, 85, 68)': 3161,
#    '(62, 56, 58)': 2817,
#    '(60, 69, 77)': 1718,
#    '(192, 185, 146)': 1090,
#    '(161, 142, 91)': 1026,
#    '(100, 62, 59)': 584}},
#  '1898_mm_dd_i_Плодородие.jpg': {'path': '1898_mm_dd_i_Плодородие.jpg',
#   'name_of_painting': 'Плодородие',
#   'year': '1898',
#   'most_common_colors_ever': {'(35, 36, 39)': 3463,
#    '(73, 64, 55)': 4011,
#    '(139, 125, 100)': 1170,
#    '(192, 184, 173)': 134,
#    '(82, 98, 120)': 40,
#    '(137, 77, 48)': 128,
#    '(199, 160, 96)': 54},
#   'most_common_colors': {'(67, 67, 65)': 4435,
#    '(40, 44, 51)': 3637,
#    '(105, 108, 77)': 2550,
#    '(106, 91, 77)': 2349,
#    '(230, 210, 170)': 1618,
#    '(169, 151, 121)': 1199,
#    '(162, 95, 71)': 596}},
#  '1898_mm_dd_i_Пляж.jpg': {'path': '1898_mm_dd_i_Пляж.jpg',
#   'name_of_painting': 'Пляж',
#   'year': '1898',
#   'most_common_colors_ever': {'(35, 36, 39)': 330,
#    '(73, 64, 55)': 2048,
#    '(139, 125, 100)': 3076,
#    '(192, 184, 173)': 0,
#    '(82, 98, 120)': 523,
#    '(137, 77, 48)': 320,
#    '(199, 160, 96)': 0},
#   'most_common_colors': {'(134, 99, 84)': 3892,
#    '(104, 84, 78)': 3613,
#    '(110, 110, 102)': 3423,
#    '(145, 132, 118)': 1751,
#    '(62, 58, 57)': 1623,
#    '(83, 90, 85)': 1346,
#    '(132, 134, 138)': 736}},
#  '1898_mm_dd_i_Радуга.jpg': {'path': '1898_mm_dd_i_Радуга.jpg',
#   'name_of_painting': 'Радуга',
#   'year': '1898',
#   'most_common_colors_ever': {'(35, 36, 39)': 2192,
#    '(73, 64, 55)': 3545,
#    '(139, 125, 100)': 228,
#    '(192, 184, 173)': 4,
#    '(82, 98, 120)': 177,
#    '(137, 77, 48)': 386,
#    '(199, 160, 96)': 7},
#   'most_common_colors': {'(85, 59, 68)': 3747,
#    '(38, 62, 72)': 3491,
#    '(73, 61, 85)': 2267,
#    '(130, 85, 65)': 2227,
#    '(61, 67, 57)': 2206,
#    '(42, 34, 45)': 1748,
#    '(224, 167, 137)': 698}},
#  '1898_mm_dd_i_Ревность_в_купалье.jpg': {'path': '1898_mm_dd_i_Ревность_в_купалье.jpg',
#   'name_of_painting': 'Ревность в купалье',
#   'year': '1898',
#   'most_common_colors_ever': {'(35, 36, 39)': 6,
#    '(73, 64, 55)': 980,
#    '(139, 125, 100)': 804,
#    '(192, 184, 173)': 98,
#    '(82, 98, 120)': 18,
#    '(137, 77, 48)': 1637,
#    '(199, 160, 96)': 1962},
#   'most_common_colors': {'(175, 140, 75)': 4425,
#    '(156, 107, 68)': 4065,
#    '(111, 79, 65)': 2466,
#    '(122, 131, 106)': 2276,
#    '(180, 69, 45)': 1213,
#    '(72, 70, 74)': 998,
#    '(206, 186, 129)': 941}},
#  '1898_mm_dd_i_Сидящая_обнаженная_на_пляже.jpg': {'path': '1898_mm_dd_i_Сидящая_обнаженная_на_пляже.jpg',
#   'name_of_painting': 'Сидящая обнаженная на пляже',
#   'year': '1898',
#   'most_common_colors_ever': {'(35, 36, 39)': 4275,
#    '(73, 64, 55)': 500,
#    '(139, 125, 100)': 154,
#    '(192, 184, 173)': 18,
#    '(82, 98, 120)': 8,
#    '(137, 77, 48)': 1721,
#    '(199, 160, 96)': 39},
#   'most_common_colors': {'(111, 67, 33)': 4981,
#    '(56, 35, 29)': 3989,
#    '(30, 25, 22)': 2702,
#    '(148, 109, 43)': 2058,
#    '(145, 118, 93)': 1204,
#    '(97, 59, 38)': 730,
#    '(134, 56, 20)': 720}},
#  '1899_mm_dd_i_Дом_Мунка_в_Осгорстранне.jpg': {'path': '1899_mm_dd_i_Дом_Мунка_в_Осгорстранне.jpg',
#   'name_of_painting': 'Дом Мунка в Осгорстранне',
#   'year': '1899',
#   'most_common_colors_ever': {'(35, 36, 39)': 12,
#    '(73, 64, 55)': 501,
#    '(139, 125, 100)': 330,
#    '(192, 184, 173)': 121,
#    '(82, 98, 120)': 210,
#    '(137, 77, 48)': 387,
#    '(199, 160, 96)': 1612},
#   'most_common_colors': {'(141, 98, 84)': 3896,
#    '(199, 174, 75)': 2728,
#    '(201, 160, 112)': 2605,
#    '(80, 115, 214)': 2270,
#    '(75, 84, 116)': 1827,
#    '(132, 132, 45)': 1754,
#    '(215, 123, 43)': 1304}},
#  '1899_mm_dd_i_Дом_и_мастерская_Мунка_в_Осгорстранне.jpg': {'path': '1899_mm_dd_i_Дом_и_мастерская_Мунка_в_Осгорстранне.jpg',
#   'name_of_painting': 'Дом и мастерская Мунка в Осгорстранне',
#   'year': '1899',
#   'most_common_colors_ever': {'(35, 36, 39)': 940,
#    '(73, 64, 55)': 551,
#    '(139, 125, 100)': 189,
#    '(192, 184, 173)': 1482,
#    '(82, 98, 120)': 8,
#    '(137, 77, 48)': 820,
#    '(199, 160, 96)': 178},
#   'most_common_colors': {'(168, 162, 169)': 4290,
#    '(141, 108, 48)': 4257,
#    '(172, 118, 61)': 2425,
#    '(148, 140, 161)': 1642,
#    '(85, 36, 29)': 1464,
#    '(56, 56, 38)': 1380,
#    '(136, 109, 92)': 926}},
#  '1899_mm_dd_i_Дом_с_красным_виноградом.jpg': {'path': '1899_mm_dd_i_Дом_с_красным_виноградом.jpg',
#   'name_of_painting': 'Дом с красным виноградом',
#   'year': '1899',
#   'most_common_colors_ever': {'(35, 36, 39)': 1895,
#    '(73, 64, 55)': 1108,
#    '(139, 125, 100)': 942,
#    '(192, 184, 173)': 1375,
#    '(82, 98, 120)': 106,
#    '(137, 77, 48)': 633,
#    '(199, 160, 96)': 49},
#   'most_common_colors': {'(210, 203, 190)': 3116,
#    '(88, 78, 67)': 3025,
#    '(169, 155, 134)': 2761,
#    '(29, 44, 42)': 2366,
#    '(155, 109, 78)': 2127,
#    '(70, 91, 59)': 1645,
#    '(105, 105, 30)': 1344}},
#  '1899_mm_dd_i_Дом_с_красным_диким_виноградом.jpg': {'path': '1899_mm_dd_i_Дом_с_красным_диким_виноградом.jpg',
#   'name_of_painting': 'Дом с красным диким виноградом',
#   'year': '1899',
#   'most_common_colors_ever': {'(35, 36, 39)': 300,
#    '(73, 64, 55)': 279,
#    '(139, 125, 100)': 199,
#    '(192, 184, 173)': 1187,
#    '(82, 98, 120)': 4,
#    '(137, 77, 48)': 396,
#    '(199, 160, 96)': 953},
#   'most_common_colors': {'(180, 157, 152)': 4245,
#    '(154, 93, 65)': 3340,
#    '(190, 152, 121)': 2826,
#    '(120, 103, 38)': 2242,
#    '(202, 143, 51)': 1615,
#    '(54, 35, 30)': 1096,
#    '(165, 28, 6)': 1020}},
#  '1899_mm_dd_i_Зима_в_лесу._Нурстранн.jpg': {'path': '1899_mm_dd_i_Зима_в_лесу._Нурстранн.jpg',
#   'name_of_painting': 'Зима в лесу. Нурстранн',
#   'year': '1899',
#   'most_common_colors_ever': {'(35, 36, 39)': 852,
#    '(73, 64, 55)': 677,
#    '(139, 125, 100)': 590,
#    '(192, 184, 173)': 2116,
#    '(82, 98, 120)': 49,
#    '(137, 77, 48)': 29,
#    '(199, 160, 96)': 8},
#   'most_common_colors': {'(221, 215, 198)': 4496,
#    '(11, 8, 5)': 2994,
#    '(196, 191, 179)': 2309,
#    '(150, 141, 134)': 2141,
#    '(33, 25, 16)': 1945,
#    '(74, 64, 42)': 1854,
#    '(141, 128, 103)': 645}},
#  '1899_mm_dd_i_Летняя_ночь_в_Студентерлюннене.jpg': {'path': '1899_mm_dd_i_Летняя_ночь_в_Студентерлюннене.jpg',
#   'name_of_painting': 'Летняя ночь в Студентерлюннене',
#   'year': '1899',
#   'most_common_colors_ever': {'(35, 36, 39)': 732,
#    '(73, 64, 55)': 84,
#    '(139, 125, 100)': 17,
#    '(192, 184, 173)': 79,
#    '(82, 98, 120)': 184,
#    '(137, 77, 48)': 586,
#    '(199, 160, 96)': 43},
#   'most_common_colors': {'(27, 46, 24)': 3569,
#    '(134, 86, 35)': 2399,
#    '(108, 116, 158)': 2326,
#    '(0, 1, 1)': 2100,
#    '(6, 14, 10)': 2072,
#    '(77, 90, 178)': 2013,
#    '(90, 104, 91)': 1905}},
#  '1899_mm_dd_i_Метрвая_мать_и_ребенок.jpg': {'path': '1899_mm_dd_i_Метрвая_мать_и_ребенок.jpg',
#   'name_of_painting': 'Метрвая мать и ребенок',
#   'year': '1899',
#   'most_common_colors_ever': {'(35, 36, 39)': 945,
#    '(73, 64, 55)': 3282,
#    '(139, 125, 100)': 709,
#    '(192, 184, 173)': 2,
#    '(82, 98, 120)': 1,
#    '(137, 77, 48)': 783,
#    '(199, 160, 96)': 719},
#   'most_common_colors': {'(71, 70, 54)': 3945,
#    '(199, 97, 38)': 2519,
#    '(128, 82, 44)': 2493,
#    '(223, 156, 54)': 2396,
#    '(131, 117, 79)': 1905,
#    '(77, 70, 46)': 1674,
#    '(204, 178, 92)': 1452}},
#  '1899_mm_dd_i_Обмен_веществ.jpg': {'path': '1899_mm_dd_i_Обмен_веществ.jpg',
#   'name_of_painting': 'Обмен веществ',
#   'year': '1899',
#   'most_common_colors_ever': {'(35, 36, 39)': 4818,
#    '(73, 64, 55)': 2697,
#    '(139, 125, 100)': 81,
#    '(192, 184, 173)': 1,
#    '(82, 98, 120)': 11,
#    '(137, 77, 48)': 669,
#    '(199, 160, 96)': 379},
#   'most_common_colors': {'(33, 41, 43)': 3763,
#    '(75, 50, 28)': 3060,
#    '(117, 84, 52)': 3029,
#    '(48, 38, 31)': 2667,
#    '(77, 74, 67)': 1491,
#    '(190, 137, 88)': 1206,
#    '(31, 60, 69)': 1168}},
#  '1899_mm_dd_i_Осе_и_Харальд_Нёррегор.jpg': {'path': '1899_mm_dd_i_Осе_и_Харальд_Нёррегор.jpg',
#   'name_of_painting': 'Осе и Харальд Нёррегор',
#   'year': '1899',
#   'most_common_colors_ever': {'(35, 36, 39)': 2909,
#    '(73, 64, 55)': 1606,
#    '(139, 125, 100)': 120,
#    '(192, 184, 173)': 24,
#    '(82, 98, 120)': 54,
#    '(137, 77, 48)': 1294,
#    '(199, 160, 96)': 182},
#   'most_common_colors': {'(76, 53, 29)': 3301,
#    '(99, 55, 36)': 2982,
#    '(70, 41, 41)': 2866,
#    '(187, 119, 77)': 2362,
#    '(30, 25, 37)': 2155,
#    '(120, 79, 50)': 2058,
#    '(144, 139, 150)': 660}},
#  '1899_mm_dd_i_Плодородие.jpg': {'path': '1899_mm_dd_i_Плодородие.jpg',
#   'name_of_painting': 'Плодородие',
#   'year': '1899',
#   'most_common_colors_ever': {'(35, 36, 39)': 3955,
#    '(73, 64, 55)': 2161,
#    '(139, 125, 100)': 276,
#    '(192, 184, 173)': 441,
#    '(82, 98, 120)': 115,
#    '(137, 77, 48)': 317,
#    '(199, 160, 96)': 9},
#   'most_common_colors': {'(40, 47, 41)': 4205,
#    '(79, 86, 62)': 3117,
#    '(98, 117, 53)': 2601,
#    '(54, 35, 31)': 2141,
#    '(150, 117, 91)': 1742,
#    '(213, 212, 203)': 1575,
#    '(50, 57, 78)': 1003}},
#  '1899_mm_dd_i_Портрет_Осе_Неррегор.jpg': {'path': '1899_mm_dd_i_Портрет_Осе_Неррегор.jpg',
#   'name_of_painting': 'Портрет Осе Неррегор',
#   'year': '1899',
#   'most_common_colors_ever': {'(35, 36, 39)': 4006,
#    '(73, 64, 55)': 220,
#    '(139, 125, 100)': 44,
#    '(192, 184, 173)': 0,
#    '(82, 98, 120)': 0,
#    '(137, 77, 48)': 2283,
#    '(199, 160, 96)': 198},
#   'most_common_colors': {'(108, 62, 27)': 3994,
#    '(123, 75, 31)': 2428,
#    '(42, 31, 28)': 2403,
#    '(123, 66, 21)': 2223,
#    '(20, 19, 25)': 2169,
#    '(94, 50, 25)': 1990,
#    '(170, 136, 91)': 1177}},
#  '1899_mm_dd_i_Сидящая_обнажённая_женщина_и_три_мужские_головы.jpg': {'path': '1899_mm_dd_i_Сидящая_обнажённая_женщина_и_три_мужские_головы.jpg',
#   'name_of_painting': 'Сидящая обнажённая женщина и три мужские головы',
#   'year': '1899',
#   'most_common_colors_ever': {'(35, 36, 39)': 7955,
#    '(73, 64, 55)': 4061,
#    '(139, 125, 100)': 61,
#    '(192, 184, 173)': 0,
#    '(82, 98, 120)': 16,
#    '(137, 77, 48)': 271,
#    '(199, 160, 96)': 2},
#   'most_common_colors': {'(39, 40, 42)': 5595,
#    '(55, 48, 43)': 5451,
#    '(101, 90, 61)': 1806,
#    '(82, 43, 42)': 1158,
#    '(65, 71, 61)': 988,
#    '(131, 106, 54)': 961,
#    '(157, 87, 33)': 425}},
#  '1899_mm_dd_i_Смерть_и_ребенок.jpg': {'path': '1899_mm_dd_i_Смерть_и_ребенок.jpg',
#   'name_of_painting': 'Смерть и ребенок',
#   'year': '1899',
#   'most_common_colors_ever': {'(35, 36, 39)': 603,
#    '(73, 64, 55)': 578,
#    '(139, 125, 100)': 1160,
#    '(192, 184, 173)': 59,
#    '(82, 98, 120)': 4,
#    '(137, 77, 48)': 228,
#    '(199, 160, 96)': 533},
#   'most_common_colors': {'(141, 145, 91)': 4439,
#    '(201, 191, 123)': 3047,
#    '(103, 110, 75)': 2506,
#    '(63, 58, 33)': 1784,
#    '(186, 99, 24)': 1728,
#    '(141, 81, 21)': 1623,
#    '(193, 140, 54)': 1257}},
#  '1899_mm_dd_i_Танец_жизни.jpg': {'path': '1899_mm_dd_i_Танец_жизни.jpg',
#   'name_of_painting': 'Танец жизни',
#   'year': '1899',
#   'most_common_colors_ever': {'(35, 36, 39)': 2805,
#    '(73, 64, 55)': 904,
#    '(139, 125, 100)': 182,
#    '(192, 184, 173)': 1316,
#    '(82, 98, 120)': 801,
#    '(137, 77, 48)': 427,
#    '(199, 160, 96)': 90},
#   'most_common_colors': {'(31, 65, 36)': 3399,
#    '(87, 84, 99)': 2892,
#    '(31, 25, 26)': 2447,
#    '(200, 184, 162)': 2204,
#    '(142, 102, 76)': 2191,
#    '(59, 56, 44)': 1952,
#    '(149, 47, 33)': 1299}},
#  '1899_mm_dd_i_Темный_еловый_лес_1.jpg': {'path': '1899_mm_dd_i_Темный_еловый_лес_1.jpg',
#   'name_of_painting': 'Темный еловый лес 1',
#   'year': '1899',
#   'most_common_colors_ever': {'(35, 36, 39)': 2857,
#    '(73, 64, 55)': 3091,
#    '(139, 125, 100)': 508,
#    '(192, 184, 173)': 3,
#    '(82, 98, 120)': 57,
#    '(137, 77, 48)': 121,
#    '(199, 160, 96)': 56},
#   'most_common_colors': {'(51, 50, 65)': 3911,
#    '(76, 73, 67)': 3317,
#    '(46, 90, 201)': 2354,
#    '(114, 105, 68)': 2259,
#    '(48, 38, 35)': 2101,
#    '(32, 57, 133)': 1723,
#    '(169, 145, 88)': 719}},
#  '1899_mm_dd_i_Темный_еловый_лес_2.jpg': {'path': '1899_mm_dd_i_Темный_еловый_лес_2.jpg',
#   'name_of_painting': 'Темный еловый лес 2',
#   'year': '1899',
#   'most_common_colors_ever': {'(35, 36, 39)': 2938,
#    '(73, 64, 55)': 6771,
#    '(139, 125, 100)': 68,
#    '(192, 184, 173)': 368,
#    '(82, 98, 120)': 208,
#    '(137, 77, 48)': 22,
#    '(199, 160, 96)': 0},
#   'most_common_colors': {'(49, 67, 110)': 4083,
#    '(56, 58, 49)': 3816,
#    '(56, 57, 55)': 3584,
#    '(94, 81, 65)': 1590,
#    '(87, 92, 55)': 1501,
#    '(52, 55, 65)': 1300,
#    '(190, 187, 177)': 510}},
#  '1899_mm_dd_i_Темный_еловый_лес_3.jpg': {'path': '1899_mm_dd_i_Темный_еловый_лес_3.jpg',
#   'name_of_painting': 'Темный еловый лес 3',
#   'year': '1899',
#   'most_common_colors_ever': {'(35, 36, 39)': 1129,
#    '(73, 64, 55)': 2419,
#    '(139, 125, 100)': 1124,
#    '(192, 184, 173)': 0,
#    '(82, 98, 120)': 132,
#    '(137, 77, 48)': 306,
#    '(199, 160, 96)': 313},
#   'most_common_colors': {'(118, 104, 75)': 3884,
#    '(60, 57, 44)': 3410,
#    '(117, 149, 236)': 2803,
#    '(189, 157, 63)': 2495,
#    '(153, 107, 65)': 1482,
#    '(128, 103, 92)': 1380,
#    '(103, 111, 160)': 930}},
#  '1899_mm_dd_i_Трагедия.jpg': {'path': '1899_mm_dd_i_Трагедия.jpg',
#   'name_of_painting': 'Трагедия',
#   'year': '1899',
#   'most_common_colors_ever': {'(35, 36, 39)': 6323,
#    '(73, 64, 55)': 1297,
#    '(139, 125, 100)': 3,
#    '(192, 184, 173)': 0,
#    '(82, 98, 120)': 0,
#    '(137, 77, 48)': 935,
#    '(199, 160, 96)': 93},
#   'most_common_colors': {'(30, 32, 30)': 3387,
#    '(108, 78, 41)': 3301,
#    '(17, 19, 22)': 3001,
#    '(79, 76, 43)': 2472,
#    '(208, 125, 55)': 1960,
#    '(232, 191, 98)': 1170,
#    '(155, 73, 39)': 1093}},
#  '1899_mm_dd_i_Тулла_Ларсен_1.jpg': {'path': '1899_mm_dd_i_Тулла_Ларсен_1.jpg',
#   'name_of_painting': 'Тулла Ларсен 1',
#   'year': '1899',
#   'most_common_colors_ever': {'(35, 36, 39)': 2594,
#    '(73, 64, 55)': 138,
#    '(139, 125, 100)': 167,
#    '(192, 184, 173)': 42,
#    '(82, 98, 120)': 941,
#    '(137, 77, 48)': 55,
#    '(199, 160, 96)': 683},
#   'most_common_colors': {'(23, 44, 53)': 2961,
#    '(45, 70, 85)': 2820,
#    '(228, 178, 118)': 2808,
#    '(105, 108, 111)': 2482,
#    '(25, 62, 55)': 2460,
#    '(204, 141, 85)': 1481,
#    '(52, 95, 97)': 1372}},
#  '1899_mm_dd_i_Тулла_Ларсен_2.jpg': {'path': '1899_mm_dd_i_Тулла_Ларсен_2.jpg',
#   'name_of_painting': 'Тулла Ларсен 2',
#   'year': '1899',
#   'most_common_colors_ever': {'(35, 36, 39)': 5342,
#    '(73, 64, 55)': 7313,
#    '(139, 125, 100)': 15,
#    '(192, 184, 173)': 0,
#    '(82, 98, 120)': 0,
#    '(137, 77, 48)': 866,
#    '(199, 160, 96)': 0},
#   'most_common_colors': {'(55, 42, 45)': 4260,
#    '(49, 52, 53)': 3022,
#    '(69, 53, 50)': 2881,
#    '(117, 80, 59)': 2268,
#    '(68, 73, 69)': 1667,
#    '(29, 27, 32)': 1181,
#    '(84, 65, 57)': 1105}},
#  '1900_mm_dd_i_Белая_ночь.jpg': {'path': '1900_mm_dd_i_Белая_ночь.jpg',
#   'name_of_painting': 'Белая ночь',
#   'year': '1900',
#   'most_common_colors_ever': {'(35, 36, 39)': 4645,
#    '(73, 64, 55)': 313,
#    '(139, 125, 100)': 9,
#    '(192, 184, 173)': 1,
#    '(82, 98, 120)': 1610,
#    '(137, 77, 48)': 0,
#    '(199, 160, 96)': 0},
#   'most_common_colors': {'(25, 30, 34)': 3076,
#    '(35, 52, 59)': 2999,
#    '(84, 115, 123)': 2965,
#    '(63, 118, 138)': 2282,
#    '(110, 146, 157)': 2141,
#    '(50, 71, 73)': 1694,
#    '(58, 119, 122)': 1227}},
#  '1900_mm_dd_i_Вид_из_Нурстранна.jpg': {'path': '1900_mm_dd_i_Вид_из_Нурстранна.jpg',
#   'name_of_painting': 'Вид из Нурстранна',
#   'year': '1900',
#   'most_common_colors_ever': {'(35, 36, 39)': 6169,
#    '(73, 64, 55)': 1098,
#    '(139, 125, 100)': 70,
#    '(192, 184, 173)': 488,
#    '(82, 98, 120)': 94,
#    '(137, 77, 48)': 110,
#    '(199, 160, 96)': 11},
#   'most_common_colors': {'(31, 32, 32)': 5307,
#    '(157, 157, 175)': 4573,
#    '(72, 62, 70)': 1681,
#    '(60, 52, 37)': 1612,
#    '(158, 134, 33)': 1576,
#    '(198, 205, 214)': 1108,
#    '(132, 110, 66)': 527}},
#  '1900_mm_dd_i_Вид_из_Нурстранна_1.jpg': {'path': '1900_mm_dd_i_Вид_из_Нурстранна_1.jpg',
#   'name_of_painting': 'Вид из Нурстранна 1',
#   'year': '1900',
#   'most_common_colors_ever': {'(35, 36, 39)': 4466,
#    '(73, 64, 55)': 993,
#    '(139, 125, 100)': 204,
#    '(192, 184, 173)': 925,
#    '(82, 98, 120)': 647,
#    '(137, 77, 48)': 2,
#    '(199, 160, 96)': 0},
#   'most_common_colors': {'(38, 33, 41)': 4998,
#    '(52, 80, 88)': 2868,
#    '(112, 99, 105)': 2702,
#    '(35, 67, 85)': 2012,
#    '(209, 190, 179)': 1402,
#    '(78, 77, 68)': 1261,
#    '(63, 137, 108)': 1141}},
#  '1900_mm_dd_i_Глаза_в_глаза.jpg': {'path': '1900_mm_dd_i_Глаза_в_глаза.jpg',
#   'name_of_painting': 'Глаза в глаза',
#   'year': '1900',
#   'most_common_colors_ever': {'(35, 36, 39)': 8329,
#    '(73, 64, 55)': 1449,
#    '(139, 125, 100)': 101,
#    '(192, 184, 173)': 68,
#    '(82, 98, 120)': 237,
#    '(137, 77, 48)': 42,
#    '(199, 160, 96)': 8},
#   'most_common_colors': {'(24, 39, 46)': 5141,
#    '(36, 49, 52)': 4395,
#    '(77, 68, 62)': 1939,
#    '(47, 72, 65)': 1781,
#    '(70, 93, 87)': 1638,
#    '(161, 147, 133)': 839,
#    '(115, 155, 143)': 651}},
#  '1900_mm_dd_i_Голгофа.jpg': {'path': '1900_mm_dd_i_Голгофа.jpg',
#   'name_of_painting': 'Голгофа',
#   'year': '1900',
#   'most_common_colors_ever': {'(35, 36, 39)': 6490,
#    '(73, 64, 55)': 590,
#    '(139, 125, 100)': 162,
#    '(192, 184, 173)': 80,
#    '(82, 98, 120)': 298,
#    '(137, 77, 48)': 156,
#    '(199, 160, 96)': 83},
#   'most_common_colors': {'(35, 39, 56)': 5468,
#    '(19, 19, 30)': 4294,
#    '(68, 68, 85)': 2080,
#    '(45, 54, 109)': 1377,
#    '(169, 166, 132)': 1180,
#    '(150, 121, 70)': 1168,
#    '(78, 40, 42)': 817}},
#  '1900_mm_dd_i_Дымящий_поезд.jpg': {'path': '1900_mm_dd_i_Дымящий_поезд.jpg',
#   'name_of_painting': 'Дымящий поезд',
#   'year': '1900',
#   'most_common_colors_ever': {'(35, 36, 39)': 615,
#    '(73, 64, 55)': 920,
#    '(139, 125, 100)': 251,
#    '(192, 184, 173)': 199,
#    '(82, 98, 120)': 1231,
#    '(137, 77, 48)': 197,
#    '(199, 160, 96)': 4},
#   'most_common_colors': {'(166, 152, 145)': 4018,
#    '(36, 64, 60)': 3291,
#    '(126, 130, 142)': 2416,
#    '(91, 107, 125)': 2096,
#    '(93, 75, 70)': 1968,
#    '(80, 99, 76)': 1381,
#    '(46, 60, 75)': 1214}},
#  '1900_mm_dd_i_Закат._Нурстранн.jpg': {'path': '1900_mm_dd_i_Закат._Нурстранн.jpg',
#   'name_of_painting': 'Закат. Нурстранн',
#   'year': '1900',
#   'most_common_colors_ever': {'(35, 36, 39)': 3944,
#    '(73, 64, 55)': 1392,
#    '(139, 125, 100)': 162,
#    '(192, 184, 173)': 3091,
#    '(82, 98, 120)': 70,
#    '(137, 77, 48)': 83,
#    '(199, 160, 96)': 200},
#   'most_common_colors': {'(40, 32, 31)': 4647,
#    '(189, 170, 158)': 4152,
#    '(82, 43, 33)': 1994,
#    '(56, 59, 39)': 1828,
#    '(120, 105, 118)': 1429,
#    '(210, 197, 155)': 1219,
#    '(186, 154, 110)': 1115}},
#  '1900_mm_dd_i_Зима.jpg': {'path': '1900_mm_dd_i_Зима.jpg',
#   'name_of_painting': 'Зима',
#   'year': '1900',
#   'most_common_colors_ever': {'(35, 36, 39)': 1126,
#    '(73, 64, 55)': 753,
#    '(139, 125, 100)': 578,
#    '(192, 184, 173)': 5079,
#    '(82, 98, 120)': 372,
#    '(137, 77, 48)': 57,
#    '(199, 160, 96)': 0},
#   'most_common_colors': {'(202, 199, 188)': 6149,
#    '(160, 160, 138)': 2887,
#    '(175, 175, 167)': 2115,
#    '(108, 118, 119)': 1913,
#    '(37, 44, 46)': 1574,
#    '(89, 74, 56)': 1127,
#    '(39, 60, 102)': 619}},
#  '1900_mm_dd_i_Красное_и_белое.jpg': {'path': '1900_mm_dd_i_Красное_и_белое.jpg',
#   'name_of_painting': 'Красное и белое',
#   'year': '1900',
#   'most_common_colors_ever': {'(35, 36, 39)': 3102,
#    '(73, 64, 55)': 1843,
#    '(139, 125, 100)': 292,
#    '(192, 184, 173)': 289,
#    '(82, 98, 120)': 682,
#    '(137, 77, 48)': 613,
#    '(199, 160, 96)': 1},
#   'most_common_colors': {'(102, 103, 114)': 3037,
#    '(47, 47, 49)': 2911,
#    '(177, 76, 53)': 2476,
#    '(152, 167, 180)': 2434,
#    '(98, 70, 63)': 2332,
#    '(40, 59, 59)': 2229,
#    '(179, 137, 117)': 965}},
# ...
#    '(192, 184, 173)': 1515,
#    '(82, 98, 120)': 9,
#    '(137, 77, 48)': 414,
#    '(199, 160, 96)': 44},
#   'most_common_colors': {'(24, 36, 28)': 4057,
#    '(36, 51, 44)': 3191,
#    '(167, 181, 157)': 3099,
#    '(92, 104, 79)': 1982,
#    '(108, 72, 36)': 1826,
#    '(198, 205, 191)': 1436,
#    '(172, 144, 107)': 793}},
#  '1919_mm_dd_i_Убийца_на_дороге.jpg': {'path': '1919_mm_dd_i_Убийца_на_дороге.jpg',
#   'name_of_painting': 'Убийца на дороге',
#   'year': '1919',
#   'most_common_colors_ever': {'(35, 36, 39)': 806,
#    '(73, 64, 55)': 502,
#    '(139, 125, 100)': 606,
#    '(192, 184, 173)': 361,
#    '(82, 98, 120)': 414,
#    '(137, 77, 48)': 332,
#    '(199, 160, 96)': 852},
#   'most_common_colors': {'(102, 58, 41)': 2844,
#    '(130, 158, 181)': 2835,
#    '(147, 125, 100)': 2794,
#    '(66, 73, 94)': 2601,
#    '(209, 155, 116)': 2518,
#    '(15, 4, 9)': 1448,
#    '(200, 214, 216)': 1344}},
#  '1921_mm_dd_i_Художник_и_его_модель.jpg': {'path': '1921_mm_dd_i_Художник_и_его_модель.jpg',
#   'name_of_painting': 'Художник и его модель',
#   'year': '1921',
#   'most_common_colors_ever': {'(35, 36, 39)': 1748,
#    '(73, 64, 55)': 1305,
#    '(139, 125, 100)': 382,
#    '(192, 184, 173)': 587,
#    '(82, 98, 120)': 468,
#    '(137, 77, 48)': 686,
#    '(199, 160, 96)': 660},
#   'most_common_colors': {'(131, 81, 51)': 3442,
#    '(79, 89, 110)': 2428,
#    '(39, 41, 40)': 2384,
#    '(118, 114, 87)': 2355,
#    '(210, 194, 168)': 2281,
#    '(219, 172, 110)': 1748,
#    '(217, 139, 73)': 1746}},
#  '1922_mm_dd_i_Звездная_ночь.jpg': {'path': '1922_mm_dd_i_Звездная_ночь.jpg',
#   'name_of_painting': 'Звездная ночь',
#   'year': '1922',
#   'most_common_colors_ever': {'(35, 36, 39)': 3068,
#    '(73, 64, 55)': 822,
#    '(139, 125, 100)': 111,
#    '(192, 184, 173)': 145,
#    '(82, 98, 120)': 986,
#    '(137, 77, 48)': 14,
#    '(199, 160, 96)': 20},
#   'most_common_colors': {'(52, 63, 102)': 3334,
#    '(33, 30, 39)': 3103,
#    '(192, 200, 220)': 2681,
#    '(105, 128, 129)': 2528,
#    '(130, 142, 175)': 2446,
#    '(72, 68, 73)': 1821,
#    '(151, 144, 130)': 471}},
#  '1923_mm_dd_a_Автопортрет.jpg': {'path': '1923_mm_dd_a_Автопортрет.jpg',
#   'name_of_painting': 'Автопортрет',
#   'year': '1923',
#   'most_common_colors_ever': {'(35, 36, 39)': 930,
#    '(73, 64, 55)': 467,
#    '(139, 125, 100)': 273,
#    '(192, 184, 173)': 1076,
#    '(82, 98, 120)': 906,
#    '(137, 77, 48)': 74,
#    '(199, 160, 96)': 43},
#   'most_common_colors': {'(173, 186, 193)': 4168,
#    '(119, 130, 134)': 2994,
#    '(55, 68, 99)': 2579,
#    '(206, 211, 187)': 2327,
#    '(149, 120, 100)': 1756,
#    '(50, 53, 50)': 1536,
#    '(254, 254, 254)': 1024}},
#  '1924_mm_dd_a_Автопортрет._Ночной_странник.jpg': {'path': '1924_mm_dd_a_Автопортрет._Ночной_странник.jpg',
#   'name_of_painting': 'Автопортрет. Ночной странник',
#   'year': '1924',
#   'most_common_colors_ever': {'(35, 36, 39)': 3946,
#    '(73, 64, 55)': 4858,
#    '(139, 125, 100)': 503,
#    '(192, 184, 173)': 72,
#    '(82, 98, 120)': 224,
#    '(137, 77, 48)': 166,
#    '(199, 160, 96)': 412},
#   'most_common_colors': {'(48, 38, 45)': 4379,
#    '(68, 58, 65)': 3862,
#    '(88, 72, 68)': 2417,
#    '(180, 153, 113)': 1831,
#    '(128, 127, 125)': 1827,
#    '(67, 64, 102)': 1184,
#    '(142, 96, 76)': 884}},
#  '1924_mm_dd_i_Молодая_женщина_на_веранде.jpg': {'path': '1924_mm_dd_i_Молодая_женщина_на_веранде.jpg',
#   'name_of_painting': 'Молодая женщина на веранде',
#   'year': '1924',
#   'most_common_colors_ever': {'(35, 36, 39)': 178,
#    '(73, 64, 55)': 1460,
#    '(139, 125, 100)': 1510,
#    '(192, 184, 173)': 1772,
#    '(82, 98, 120)': 125,
#    '(137, 77, 48)': 1605,
#    '(199, 160, 96)': 70},
#   'most_common_colors': {'(149, 139, 133)': 4684,
#    '(85, 85, 80)': 2617,
#    '(175, 169, 164)': 2597,
#    '(129, 106, 87)': 2036,
#    '(99, 105, 94)': 1941,
#    '(143, 92, 38)': 1355,
#    '(118, 60, 44)': 1154}},
#  '1925_mm_dd_i_Цыганская_свадьба.jpg': {'path': '1925_mm_dd_i_Цыганская_свадьба.jpg',
#   'name_of_painting': 'Цыганская свадьба',
#   'year': '1925',
#   'most_common_colors_ever': {'(35, 36, 39)': 2837,
#    '(73, 64, 55)': 623,
#    '(139, 125, 100)': 356,
#    '(192, 184, 173)': 567,
#    '(82, 98, 120)': 470,
#    '(137, 77, 48)': 54,
#    '(199, 160, 96)': 112},
#   'most_common_colors': {'(133, 157, 156)': 3824,
#    '(49, 64, 62)': 2956,
#    '(27, 42, 51)': 2563,
#    '(217, 221, 215)': 2509,
#    '(114, 110, 78)': 2288,
#    '(197, 186, 149)': 1367,
#    '(78, 97, 123)': 877}},
#  '1926_mm_dd_a_Автопортрет_в_Экели.jpg': {'path': '1926_mm_dd_a_Автопортрет_в_Экели.jpg',
#   'name_of_painting': 'Автопортрет в Экели',
#   'year': '1926',
#   'most_common_colors_ever': {'(35, 36, 39)': 1230,
#    '(73, 64, 55)': 1455,
#    '(139, 125, 100)': 243,
#    '(192, 184, 173)': 1265,
#    '(82, 98, 120)': 125,
#    '(137, 77, 48)': 39,
#    '(199, 160, 96)': 825},
#   'most_common_colors': {'(216, 216, 222)': 3611,
#    '(180, 180, 187)': 2919,
#    '(204, 182, 128)': 2824,
#    '(194, 152, 133)': 2498,
#    '(66, 63, 55)': 1701,
#    '(119, 108, 109)': 1608,
#    '(35, 31, 28)': 1223}},
#  '1926_mm_dd_a_Автопортрет_за_свадебным_столом.jpg': {'path': '1926_mm_dd_a_Автопортрет_за_свадебным_столом.jpg',
#   'name_of_painting': 'Автопортрет за свадебным столом',
#   'year': '1926',
#   'most_common_colors_ever': {'(35, 36, 39)': 3999,
#    '(73, 64, 55)': 994,
#    '(139, 125, 100)': 259,
#    '(192, 184, 173)': 334,
#    '(82, 98, 120)': 542,
#    '(137, 77, 48)': 219,
#    '(199, 160, 96)': 226},
#   'most_common_colors': {'(18, 19, 21)': 4621,
#    '(53, 55, 58)': 3590,
#    '(115, 123, 127)': 2735,
#    '(192, 192, 151)': 2357,
#    '(88, 51, 38)': 1313,
#    '(232, 220, 130)': 964,
#    '(174, 150, 92)': 804}},
#  '1926_mm_dd_a_Автопортрет_на_фоне_стены_дома.jpg': {'path': '1926_mm_dd_a_Автопортрет_на_фоне_стены_дома.jpg',
#   'name_of_painting': 'Автопортрет на фоне стены дома',
#   'year': '1926',
#   'most_common_colors_ever': {'(35, 36, 39)': 356,
#    '(73, 64, 55)': 1023,
#    '(139, 125, 100)': 1013,
#    '(192, 184, 173)': 553,
#    '(82, 98, 120)': 141,
#    '(137, 77, 48)': 349,
#    '(199, 160, 96)': 414},
#   'most_common_colors': {'(122, 87, 77)': 3452,
#    '(177, 162, 139)': 2921,
#    '(108, 126, 86)': 2415,
#    '(70, 64, 74)': 2274,
#    '(45, 81, 64)': 1935,
#    '(190, 163, 89)': 1920,
#    '(16, 67, 107)': 1467}},
#  '1926_mm_dd_a_Автопортрет_с_руками_в_карманах.jpg': {'path': '1926_mm_dd_a_Автопортрет_с_руками_в_карманах.jpg',
#   'name_of_painting': 'Автопортрет с руками в карманах',
#   'year': '1926',
#   'most_common_colors_ever': {'(35, 36, 39)': 3460,
#    '(73, 64, 55)': 532,
#    '(139, 125, 100)': 97,
#    '(192, 184, 173)': 818,
#    '(82, 98, 120)': 1525,
#    '(137, 77, 48)': 104,
#    '(199, 160, 96)': 39},
#   'most_common_colors': {'(52, 68, 86)': 4725,
#    '(33, 39, 49)': 4243,
#    '(221, 203, 187)': 2122,
#    '(85, 104, 119)': 1951,
#    '(164, 169, 180)': 1437,
#    '(140, 104, 83)': 1240,
#    '(255, 254, 254)': 666}},
#  '1927_mm_dd_i_Dog.jpeg': {'path': '1927_mm_dd_i_Dog.jpeg',
#   'name_of_painting': 'Dog.jpeg',
#   'year': '1927',
#   'most_common_colors_ever': {'(35, 36, 39)': 2534,
#    '(73, 64, 55)': 3204,
#    '(139, 125, 100)': 924,
#    '(192, 184, 173)': 2,
#    '(82, 98, 120)': 0,
#    '(137, 77, 48)': 817,
#    '(199, 160, 96)': 306},
#   'most_common_colors': {'(111, 96, 59)': 3358,
#    '(62, 63, 41)': 2622,
#    '(36, 41, 31)': 2578,
#    '(165, 130, 67)': 2262,
#    '(90, 68, 40)': 2075,
#    '(144, 104, 57)': 1759,
#    '(153, 136, 94)': 1730}},
#  '1927_mm_dd_i_Red House and Spruces.jpeg': {'path': '1927_mm_dd_i_Red House and Spruces.jpeg',
#   'name_of_painting': 'Red House and Spruces.jpeg',
#   'year': '1927',
#   'most_common_colors_ever': {'(35, 36, 39)': 72,
#    '(73, 64, 55)': 54,
#    '(139, 125, 100)': 142,
#    '(192, 184, 173)': 524,
#    '(82, 98, 120)': 366,
#    '(137, 77, 48)': 28,
#    '(199, 160, 96)': 101},
#   'most_common_colors': {'(129, 165, 168)': 3916,
#    '(106, 143, 158)': 3475,
#    '(155, 170, 169)': 2525,
#    '(24, 91, 129)': 2179,
#    '(56, 110, 139)': 1988,
#    '(163, 133, 97)': 1280,
#    '(21, 65, 93)': 1021}},
#  '1928_mm_dd_i_Модель_на_кушетке.jpg': {'path': '1928_mm_dd_i_Модель_на_кушетке.jpg',
#   'name_of_painting': 'Модель на кушетке',
#   'year': '1928',
#   'most_common_colors_ever': {'(35, 36, 39)': 2352,
#    '(73, 64, 55)': 1679,
#    '(139, 125, 100)': 497,
#    '(192, 184, 173)': 1208,
#    '(82, 98, 120)': 725,
#    '(137, 77, 48)': 185,
#    '(199, 160, 96)': 54},
#   'most_common_colors': {'(166, 151, 141)': 5207,
#    '(100, 110, 122)': 2846,
#    '(69, 42, 39)': 2205,
#    '(57, 64, 55)': 2003,
#    '(223, 212, 207)': 1726,
#    '(32, 42, 41)': 1683,
#    '(175, 95, 59)': 714}},
#  '1929_mm_dd_i_Обнаженная_рядом_с_плетеным_креслом.jpg': {'path': '1929_mm_dd_i_Обнаженная_рядом_с_плетеным_креслом.jpg',
#   'name_of_painting': 'Обнаженная рядом с плетеным креслом',
#   'year': '1929',
#   'most_common_colors_ever': {'(35, 36, 39)': 1304,
#    '(73, 64, 55)': 864,
#    '(139, 125, 100)': 1190,
#    '(192, 184, 173)': 1070,
#    '(82, 98, 120)': 191,
#    '(137, 77, 48)': 823,
#    '(199, 160, 96)': 340},
#   'most_common_colors': {'(167, 143, 119)': 4256,
#    '(200, 194, 194)': 2935,
#    '(133, 73, 54)': 2872,
#    '(108, 115, 92)': 2154,
#    '(41, 36, 38)': 1613,
#    '(65, 69, 94)': 1323,
#    '(186, 128, 60)': 1231}},
#  '1930_mm_dd_a_Автопортрет_во_время_болезни_глаз.jpg': {'path': '1930_mm_dd_a_Автопортрет_во_время_болезни_глаз.jpg',
#   'name_of_painting': 'Автопортрет во время болезни глаз',
#   'year': '1930',
#   'most_common_colors_ever': {'(35, 36, 39)': 3811,
#    '(73, 64, 55)': 1331,
#    '(139, 125, 100)': 502,
#    '(192, 184, 173)': 1025,
#    '(82, 98, 120)': 241,
#    '(137, 77, 48)': 419,
#    '(199, 160, 96)': 359},
#   'most_common_colors': {'(146, 127, 105)': 4342,
#    '(35, 31, 35)': 3556,
#    '(91, 56, 47)': 2438,
#    '(214, 186, 162)': 2054,
#    '(52, 59, 71)': 1874,
#    '(192, 193, 199)': 1496,
#    '(173, 91, 59)': 624}},
#  '1930_mm_dd_i_Голова_собаки.jpg': {'path': '1930_mm_dd_i_Голова_собаки.jpg',
#   'name_of_painting': 'Голова собаки',
#   'year': '1930',
#   'most_common_colors_ever': {'(35, 36, 39)': 2985,
#    '(73, 64, 55)': 2002,
#    '(139, 125, 100)': 529,
#    '(192, 184, 173)': 289,
#    '(82, 98, 120)': 7,
#    '(137, 77, 48)': 375,
#    '(199, 160, 96)': 338},
#   'most_common_colors': {'(62, 69, 48)': 5259,
#    '(116, 121, 91)': 2563,
#    '(33, 35, 24)': 2380,
#    '(144, 79, 36)': 1917,
#    '(185, 140, 79)': 1588,
#    '(215, 208, 178)': 1347,
#    '(95, 115, 56)': 1330}},
#  '1935_mm_dd_i_Одинокие.jpg': {'path': '1935_mm_dd_i_Одинокие.jpg',
#   'name_of_painting': 'Одинокие',
#   'year': '1935',
#   'most_common_colors_ever': {'(35, 36, 39)': 735,
#    '(73, 64, 55)': 485,
#    '(139, 125, 100)': 292,
#    '(192, 184, 173)': 476,
#    '(82, 98, 120)': 57,
#    '(137, 77, 48)': 616,
#    '(199, 160, 96)': 90},
#   'most_common_colors': {'(171, 168, 202)': 4957,
#    '(69, 36, 34)': 2914,
#    '(148, 117, 104)': 2065,
#    '(202, 162, 132)': 1981,
#    '(156, 82, 62)': 1883,
#    '(225, 217, 203)': 1372,
#    '(68, 72, 113)': 1212}},
#  '1938_mm_dd_a_Автопортрет_с_бутылками.jpg': {'path': '1938_mm_dd_a_Автопортрет_с_бутылками.jpg',
#   'name_of_painting': 'Автопортрет с бутылками',
#   'year': '1938',
#   'most_common_colors_ever': {'(35, 36, 39)': 1400,
#    '(73, 64, 55)': 411,
#    '(139, 125, 100)': 410,
#    '(192, 184, 173)': 1727,
#    '(82, 98, 120)': 338,
#    '(137, 77, 48)': 185,
#    '(199, 160, 96)': 301},
#   'most_common_colors': {'(181, 189, 177)': 4582,
#    '(146, 140, 132)': 2878,
#    '(34, 33, 61)': 2327,
#    '(194, 141, 91)': 1723,
#    '(80, 103, 103)': 1676,
#    '(103, 56, 52)': 1650,
#    '(227, 202, 112)': 1548}},
#  '1940_mm_dd_a_Автопортрет_с_головой_трески.jpg': {'path': '1940_mm_dd_a_Автопортрет_с_головой_трески.jpg',
#   'name_of_painting': 'Автопортрет с головой трески',
#   'year': '1940',
#   'most_common_colors_ever': {'(35, 36, 39)': 3426,
#    '(73, 64, 55)': 863,
#    '(139, 125, 100)': 456,
#    '(192, 184, 173)': 238,
#    '(82, 98, 120)': 382,
#    '(137, 77, 48)': 241,
#    '(199, 160, 96)': 553},
#   'most_common_colors': {'(124, 147, 130)': 4009,
#    '(32, 38, 33)': 3734,
#    '(147, 149, 123)': 2743,
#    '(65, 78, 64)': 2619,
#    '(203, 164, 111)': 1489,
#    '(152, 95, 47)': 1139,
#    '(88, 97, 115)': 651}},
#  '1940_mm_dd_a_У_окна.jpg': {'path': '1940_mm_dd_a_У_окна.jpg',
#   'name_of_painting': 'У окна',
#   'year': '1940',
#   'most_common_colors_ever': {'(35, 36, 39)': 1530,
#    '(73, 64, 55)': 1123,
#    '(139, 125, 100)': 791,
#    '(192, 184, 173)': 877,
#    '(82, 98, 120)': 9,
#    '(137, 77, 48)': 196,
#    '(199, 160, 96)': 65},
#   'most_common_colors': {'(172, 172, 158)': 4507,
#    '(32, 26, 18)': 2846,
#    '(80, 72, 51)': 2580,
#    '(6, 7, 5)': 2003,
#    '(238, 229, 214)': 1796,
#    '(153, 100, 66)': 1436,
#    '(215, 92, 48)': 1216}},
#  '1940_mm_dd_i_Женщины_на_мосту.jpg': {'path': '1940_mm_dd_i_Женщины_на_мосту.jpg',
#   'name_of_painting': 'Женщины на мосту',
#   'year': '1940',
#   'most_common_colors_ever': {'(35, 36, 39)': 578,
#    '(73, 64, 55)': 392,
#    '(139, 125, 100)': 243,
#    '(192, 184, 173)': 214,
#    '(82, 98, 120)': 152,
#    '(137, 77, 48)': 410,
#    '(199, 160, 96)': 393},
#   'most_common_colors': {'(121, 99, 87)': 5358,
#    '(236, 226, 212)': 2294,
#    '(166, 76, 37)': 2129,
#    '(135, 175, 173)': 1884,
#    '(214, 142, 76)': 1745,
#    '(36, 74, 50)': 1605,
#    '(226, 187, 90)': 1369}},
#  '1942_mm_dd_a_Автопортрет_в_саду_Экели.jpg': {'path': '1942_mm_dd_a_Автопортрет_в_саду_Экели.jpg',
#   'name_of_painting': 'Автопортрет в саду Экели',
#   'year': '1942',
#   'most_common_colors_ever': {'(35, 36, 39)': 1,
#    '(73, 64, 55)': 1977,
#    '(139, 125, 100)': 3772,
#    '(192, 184, 173)': 481,
#    '(82, 98, 120)': 17,
#    '(137, 77, 48)': 306,
#    '(199, 160, 96)': 250},
#   'most_common_colors': {'(151, 137, 110)': 3081,
#    '(114, 96, 83)': 2925,
#    '(155, 127, 114)': 2919,
#    '(79, 70, 65)': 2482,
#    '(178, 170, 141)': 2088,
#    '(145, 96, 78)': 2010,
#    '(175, 164, 98)': 879}},
#  '1943_mm_dd_a_Автопортрет_с_пастельной_палкой_2.jpg': {'path': '1943_mm_dd_a_Автопортрет_с_пастельной_палкой_2.jpg',
#   'name_of_painting': 'Автопортрет с пастельной палкой 2',
#   'year': '1943',
#   'most_common_colors_ever': {'(35, 36, 39)': 2040,
#    '(73, 64, 55)': 1844,
#    '(139, 125, 100)': 588,
#    '(192, 184, 173)': 549,
#    '(82, 98, 120)': 312,
#    '(137, 77, 48)': 170,
#    '(199, 160, 96)': 507},
#   'most_common_colors': {'(74, 63, 61)': 3434,
#    '(220, 160, 108)': 3154,
#    '(138, 144, 144)': 2813,
#    '(151, 122, 99)': 2151,
#    '(38, 36, 43)': 2064,
#    '(242, 170, 93)': 1754,
#    '(225, 215, 182)': 1014}},
#  '1943_mm_dd_a_Между_часами_и_кроватью._Автопортрет.jpg': {'path': '1943_mm_dd_a_Между_часами_и_кроватью._Автопортрет.jpg',
#   'name_of_painting': 'Между часами и кроватью. Автопортрет',
#   'year': '1943',
#   'most_common_colors_ever': {'(35, 36, 39)': 2929,
#    '(73, 64, 55)': 1881,
#    '(139, 125, 100)': 656,
#    '(192, 184, 173)': 1045,
#    '(82, 98, 120)': 209,
#    '(137, 77, 48)': 359,
#    '(199, 160, 96)': 247},
#   'most_common_colors': {'(84, 67, 55)': 3911,
#    '(125, 125, 122)': 3897,
#    '(30, 29, 31)': 2599,
#    '(179, 158, 133)': 2031,
#    '(219, 213, 214)': 1759,
#    '(188, 117, 102)': 1124,
#    '(216, 163, 73)': 1063}},
#  '1943_mm_dd_i_Автопортрет_между_часами_и_кроватью.jpg': {'path': '1943_mm_dd_i_Автопортрет_между_часами_и_кроватью.jpg',
#   'name_of_painting': 'Автопортрет между часами и кроватью',
#   'year': '1943',
#   'most_common_colors_ever': {'(35, 36, 39)': 716,
#    '(73, 64, 55)': 2051,
#    '(139, 125, 100)': 935,
#    '(192, 184, 173)': 94,
#    '(82, 98, 120)': 318,
#    '(137, 77, 48)': 225,
#    '(199, 160, 96)': 88},
#   'most_common_colors': {'(115, 129, 98)': 4101,
#    '(100, 84, 60)': 2863,
#    '(59, 103, 97)': 2417,
#    '(53, 58, 52)': 2354,
#    '(154, 159, 139)': 2242,
#    '(164, 120, 96)': 1389,
#    '(157, 146, 68)': 1018}},
#  '1944_mm_dd_a_Автопортрет_в_полосатом_свитере.jpg': {'path': '1944_mm_dd_a_Автопортрет_в_полосатом_свитере.jpg',
#   'name_of_painting': 'Автопортрет в полосатом свитере',
#   'year': '1944',
#   'most_common_colors_ever': {'(35, 36, 39)': 1313,
#    '(73, 64, 55)': 652,
#    '(139, 125, 100)': 419,
#    '(192, 184, 173)': 791,
#    '(82, 98, 120)': 125,
#    '(137, 77, 48)': 329,
#    '(199, 160, 96)': 271},
#   'most_common_colors': {'(115, 126, 89)': 3607,
#    '(203, 181, 63)': 3102,
#    '(52, 64, 56)': 3094,
#    '(137, 129, 40)': 2909,
#    '(187, 182, 142)': 1450,
#    '(157, 101, 58)': 1322,
#    '(19, 20, 14)': 900}}}

# %%
# info_dict

# %%
import json

with open("colors_data.json", "w", encoding="utf-8") as f:
    json.dump(info_dict, f, default=str, ensure_ascii=False, indent=4)

# %%
plot_color_distribution(colors_by_year_gm, how='not_sorted', classifier='GM')

# %% [markdown]
# Отсортировано по яркости:

# %%
plot_color_distribution(colors_by_year_gm, how='sorted', classifier='GM')

# %%
# colors_by_year_gm

# %%
rows = []
for year, colors in colors_by_year_gm.items():
    color_list = list(colors.items())[:7]  # Оставляем только 7 цветов
    row = [year]
    for i, ((r, g, b), count) in enumerate(color_list):
        row.extend([r, g, b, count])  # Добавляем R, G, B и Count
    rows.append(row)
    
columns = ['year']
for i in range(1, 8):  # 7 цветов
    columns.extend([f'R{i}', f'G{i}', f'B{i}', f'Count{i}'])

# Создаем DataFrame
df = pd.DataFrame(rows, columns=columns)
df.head()
# Out:
#    year   R1   G1   B1  Count1   R2   G2   B2  Count2   R3  ...   B5  Count5  \
# 0  1938  181  189  177    4582  146  140  132    2878   34  ...  103    1676
# 1  1895   58   59   57    5652  212  122   72    5529   29  ...   29    4527
# 2  1902   18   26   34    5729   34   34   37    5106  183  ...   53    4566
# 3  1893    9    4    5    5059   35   14   13    5026  166  ...   44    3942
# 4  1888  114   97   67    3417   68   63   55    3248  155  ...  104    2073
#
#     R6   G6  B6  Count6   R7   G7   B7  Count7
# 0  103   56  52    1650  227  202  112    1548
# 1   67   61  54    4500   44   35   30    3950
# 2   27   35  41    4545  213  192  185    4505
# 3  162  112  77    3804  228  139   70    3518
# 4  122   82  44    1654  196  153   87    1131
#
# [5 rows x 29 columns]

# %%
# df_GM

# %%
df_GM = pd.merge(df_GM, df, on='year', how='inner')
df_GM.head()
# Out:
#    year  (35, 36, 39)  (73, 64, 55)  (139, 125, 100)  (192, 184, 173)  \
# 0  1882          9540          4024              844              230
# 1  1883           242           786             2828              410
# 2  1885          6573          3510              365              630
# 3  1886          5856          2217              830              376
# 4  1888          2551          2783              870               21
#
#    (82, 98, 120)  (137, 77, 48)  (199, 160, 96)   R1   G1  ...   B5  Count5  \
# 0             13             36             271   41   56  ...   21    3099
# 1              1            555             403  179  148  ...  196    1206
# 2            106             69              48   55   62  ...  182     860
# 3             37            330             120   43   50  ...  128    1949
# 4             10            945            1302  114   97  ...  104    2073
#
#     R6   G6   B6  Count6   R7   G7   B7  Count7
# 0  197  163  126    1913   74   64   52    1858
# 1  188  141  112     631   57   44   46     541
# 2  162  147  118     613  100   76   57     485
# 3  129   92   65     755  154  169  154     466
# 4  122   82   44    1654  196  153   87    1131
#
# [5 rows x 36 columns]

# %%
df_counts['year'] = df_counts['year'].astype(int)

# %%
df_GM = pd.merge(df_GM, df_counts, on='year', how='inner')

# %%
df_GM.head()
# Out:
#    year  (35, 36, 39)  (73, 64, 55)  (139, 125, 100)  (192, 184, 173)  \
# 0  1882          9540          4024              844              230
# 1  1883           242           786             2828              410
# 2  1885          6573          3510              365              630
# 3  1886          5856          2217              830              376
# 4  1888          2551          2783              870               21
#
#    (82, 98, 120)  (137, 77, 48)  (199, 160, 96)   R1   G1  ...  Count5   R6  \
# 0             13             36             271   41   56  ...    3099  197
# 1              1            555             403  179  148  ...    1206  188
# 2            106             69              48   55   62  ...     860  162
# 3             37            330             120   43   50  ...    1949  129
# 4             10            945            1302  114   97  ...    2073  122
#
#     G6   B6  Count6   R7   G7   B7  Count7  count
# 0  163  126    1913   74   64   52    1858      2
# 1  141  112     631   57   44   46     541      1
# 2  147  118     613  100   76   57     485      1
# 3   92   65     755  154  169  154     466      1
# 4   82   44    1654  196  153   87    1131      1
#
# [5 rows x 37 columns]

# %%
df_GM.to_csv('data_GM.csv', index=False)

# %% [markdown]
# #### KMeans:

# %%
colors_by_year_km = get_colors_by_year(folder_path, classifier='KMeans')

# %%
plot_color_distribution(colors_by_year_km, how='not_sorted', classifier='KMeans')

# %% [markdown]
# Отсортировано по яркости:

# %%
plot_color_distribution(colors_by_year_km, how='sorted', classifier='KMeans')

# %%
# colors_by_year_km

# %%
rows = []
for year, colors in colors_by_year_km.items():
    color_list = list(colors.items())[:7]  # Оставляем только 7 цветов
    row = [year]
    for i, ((r, g, b), count) in enumerate(color_list):
        row.extend([r, g, b, count])  # Добавляем R, G, B и Count
    rows.append(row)
    
columns = ['year']
for i in range(1, 8):  # 7 цветов
    columns.extend([f'R{i}', f'G{i}', f'B{i}', f'Count{i}'])

# Создаем DataFrame
df = pd.DataFrame(rows, columns=columns)
df.head()
# Out:
#    year   R1   G1   B1  Count1   R2   G2   B2  Count2   R3  ...   B5  Count5  \
# 0  1938  201  200  183    4054  146  149  141    3406   39  ...   97    1589
# 1  1895   59   61   58    7344   43   33   27    6505  212  ...   54    4498
# 2  1902   37   36   39    7135   18   24   31    6956   23  ...  171    4754
# 3  1893   15    8   10    7569   34   15   15    5083   33  ...   70    4076
# 4  1888   38   35   32    3126   76   68   57    2851  160  ...   41    2011
#
#     R6   G6   B6  Count6   R7   G7   B7  Count7
# 0  190  117   76    1460   99   56   54    1285
# 1   21   18   17    4462   49  119  166    4163
# 2  209  176  149    4731   22   32   38    4686
# 3  157  144  171    4014   63   61   45    3435
# 4  205  168  119    1766  202  151   80    1181
#
# [5 rows x 29 columns]

# %%
df_KMeans = pd.merge(df_KMeans, df, on='year', how='inner')
df_KMeans.head()
# Out:
#    year  (36, 35, 39)  (76, 70, 60)  (197, 189, 178)  (135, 123, 95)  \
# 0  1882          9503          3978              269             802
# 1  1883           252           884              463            2527
# 2  1885          6388          3420              602             407
# 3  1886          5862          1731              254             948
# 4  1888          2627          2598               22             990
#
#    (100, 117, 145)  (153, 80, 50)  (198, 159, 84)   R1   G1  ...   B5  Count5  \
# 0                0              5               7   44   58  ...   26    2584
# 1                0            189              68  165  129  ...  117    2070
# 2               22             49              29   33   42  ...  159     769
# 3               10            126              30   30   25  ...   70    1572
# 4                1            502            1049   38   35  ...   41    2011
#
#     R6   G6   B6  Count6   R7   G7   B7  Count7
# 0   49   42   35    2105  201  166  129    1593
# 1  224  210  194    1390   57   43   45     662
# 2  155  145  114     692  135   96   64     345
# 3  175  173  153    1112  103   93   78    1067
# 4  205  168  119    1766  202  151   80    1181
#
# [5 rows x 36 columns]

# %%
df_counts['year'] = df_counts['year'].astype(int)
df_KMeans = pd.merge(df_KMeans, df_counts, on='year', how='inner')

# %%
df_KMeans.head()
# Out:
#    year  (36, 35, 39)  (76, 70, 60)  (197, 189, 178)  (135, 123, 95)  \
# 0  1882          9503          3978              269             802
# 1  1883           252           884              463            2527
# 2  1885          6388          3420              602             407
# 3  1886          5862          1731              254             948
# 4  1888          2627          2598               22             990
#
#    (100, 117, 145)  (153, 80, 50)  (198, 159, 84)   R1   G1  ...  Count5   R6  \
# 0                0              5               7   44   58  ...    2584   49
# 1                0            189              68  165  129  ...    2070  224
# 2               22             49              29   33   42  ...     769  155
# 3               10            126              30   30   25  ...    1572  175
# 4                1            502            1049   38   35  ...    2011  205
#
#     G6   B6  Count6   R7   G7   B7  Count7  count
# 0   42   35    2105  201  166  129    1593      2
# 1  210  194    1390   57   43   45     662      1
# 2  145  114     692  135   96   64     345      1
# 3  173  153    1112  103   93   78    1067      1
# 4  168  119    1766  202  151   80    1181      1
#
# [5 rows x 37 columns]

# %%
df_KMeans.to_csv('data_KMeans.csv', index=False)

# %% [markdown]
# #### BayesianGaussianMixture:

# %%
colors_by_year_bgm = get_colors_by_year(folder_path, classifier='GMM')
# Out:
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/mixture/_base.py:269: ConvergenceWarning: Best performing initialization did not converge. Try different init parameters, or increase max_iter, tol, or check for degenerate data.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/mixture/_base.py:269: ConvergenceWarning: Best performing initialization did not converge. Try different init parameters, or increase max_iter, tol, or check for degenerate data.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/mixture/_base.py:269: ConvergenceWarning: Best performing initialization did not converge. Try different init parameters, or increase max_iter, tol, or check for degenerate data.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/mixture/_base.py:269: ConvergenceWarning: Best performing initialization did not converge. Try different init parameters, or increase max_iter, tol, or check for degenerate data.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/mixture/_base.py:269: ConvergenceWarning: Best performing initialization did not converge. Try different init parameters, or increase max_iter, tol, or check for degenerate data.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/mixture/_base.py:269: ConvergenceWarning: Best performing initialization did not converge. Try different init parameters, or increase max_iter, tol, or check for degenerate data.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/mixture/_base.py:269: ConvergenceWarning: Best performing initialization did not converge. Try different init parameters, or increase max_iter, tol, or check for degenerate data.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/mixture/_base.py:269: ConvergenceWarning: Best performing initialization did not converge. Try different init parameters, or increase max_iter, tol, or check for degenerate data.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/mixture/_base.py:269: ConvergenceWarning: Best performing initialization did not converge. Try different init parameters, or increase max_iter, tol, or check for degenerate data.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/mixture/_base.py:269: ConvergenceWarning: Best performing initialization did not converge. Try different init parameters, or increase max_iter, tol, or check for degenerate data.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/mixture/_base.py:269: ConvergenceWarning: Best performing initialization did not converge. Try different init parameters, or increase max_iter, tol, or check for degenerate data.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/mixture/_base.py:269: ConvergenceWarning: Best performing initialization did not converge. Try different init parameters, or increase max_iter, tol, or check for degenerate data.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/mixture/_base.py:269: ConvergenceWarning: Best performing initialization did not converge. Try different init parameters, or increase max_iter, tol, or check for degenerate data.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/mixture/_base.py:269: ConvergenceWarning: Best performing initialization did not converge. Try different init parameters, or increase max_iter, tol, or check for degenerate data.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/mixture/_base.py:269: ConvergenceWarning: Best performing initialization did not converge. Try different init parameters, or increase max_iter, tol, or check for degenerate data.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/mixture/_base.py:269: ConvergenceWarning: Best performing initialization did not converge. Try different init parameters, or increase max_iter, tol, or check for degenerate data.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/mixture/_base.py:269: ConvergenceWarning: Best performing initialization did not converge. Try different init parameters, or increase max_iter, tol, or check for degenerate data.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/mixture/_base.py:269: ConvergenceWarning: Best performing initialization did not converge. Try different init parameters, or increase max_iter, tol, or check for degenerate data.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/mixture/_base.py:269: ConvergenceWarning: Best performing initialization did not converge. Try different init parameters, or increase max_iter, tol, or check for degenerate data.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/mixture/_base.py:269: ConvergenceWarning: Best performing initialization did not converge. Try different init parameters, or increase max_iter, tol, or check for degenerate data.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/mixture/_base.py:269: ConvergenceWarning: Best performing initialization did not converge. Try different init parameters, or increase max_iter, tol, or check for degenerate data.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/mixture/_base.py:269: ConvergenceWarning: Best performing initialization did not converge. Try different init parameters, or increase max_iter, tol, or check for degenerate data.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/mixture/_base.py:269: ConvergenceWarning: Best performing initialization did not converge. Try different init parameters, or increase max_iter, tol, or check for degenerate data.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/mixture/_base.py:269: ConvergenceWarning: Best performing initialization did not converge. Try different init parameters, or increase max_iter, tol, or check for degenerate data.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/mixture/_base.py:269: ConvergenceWarning: Best performing initialization did not converge. Try different init parameters, or increase max_iter, tol, or check for degenerate data.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/mixture/_base.py:269: ConvergenceWarning: Best performing initialization did not converge. Try different init parameters, or increase max_iter, tol, or check for degenerate data.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/mixture/_base.py:269: ConvergenceWarning: Best performing initialization did not converge. Try different init parameters, or increase max_iter, tol, or check for degenerate data.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/mixture/_base.py:269: ConvergenceWarning: Best performing initialization did not converge. Try different init parameters, or increase max_iter, tol, or check for degenerate data.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/mixture/_base.py:269: ConvergenceWarning: Best performing initialization did not converge. Try different init parameters, or increase max_iter, tol, or check for degenerate data.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/mixture/_base.py:269: ConvergenceWarning: Best performing initialization did not converge. Try different init parameters, or increase max_iter, tol, or check for degenerate data.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/mixture/_base.py:269: ConvergenceWarning: Best performing initialization did not converge. Try different init parameters, or increase max_iter, tol, or check for degenerate data.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/mixture/_base.py:269: ConvergenceWarning: Best performing initialization did not converge. Try different init parameters, or increase max_iter, tol, or check for degenerate data.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/mixture/_base.py:269: ConvergenceWarning: Best performing initialization did not converge. Try different init parameters, or increase max_iter, tol, or check for degenerate data.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/mixture/_base.py:269: ConvergenceWarning: Best performing initialization did not converge. Try different init parameters, or increase max_iter, tol, or check for degenerate data.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/mixture/_base.py:269: ConvergenceWarning: Best performing initialization did not converge. Try different init parameters, or increase max_iter, tol, or check for degenerate data.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/mixture/_base.py:269: ConvergenceWarning: Best performing initialization did not converge. Try different init parameters, or increase max_iter, tol, or check for degenerate data.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/mixture/_base.py:269: ConvergenceWarning: Best performing initialization did not converge. Try different init parameters, or increase max_iter, tol, or check for degenerate data.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/mixture/_base.py:269: ConvergenceWarning: Best performing initialization did not converge. Try different init parameters, or increase max_iter, tol, or check for degenerate data.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/mixture/_base.py:269: ConvergenceWarning: Best performing initialization did not converge. Try different init parameters, or increase max_iter, tol, or check for degenerate data.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/mixture/_base.py:269: ConvergenceWarning: Best performing initialization did not converge. Try different init parameters, or increase max_iter, tol, or check for degenerate data.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/mixture/_base.py:269: ConvergenceWarning: Best performing initialization did not converge. Try different init parameters, or increase max_iter, tol, or check for degenerate data.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/mixture/_base.py:269: ConvergenceWarning: Best performing initialization did not converge. Try different init parameters, or increase max_iter, tol, or check for degenerate data.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/mixture/_base.py:269: ConvergenceWarning: Best performing initialization did not converge. Try different init parameters, or increase max_iter, tol, or check for degenerate data.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/mixture/_base.py:269: ConvergenceWarning: Best performing initialization did not converge. Try different init parameters, or increase max_iter, tol, or check for degenerate data.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/mixture/_base.py:269: ConvergenceWarning: Best performing initialization did not converge. Try different init parameters, or increase max_iter, tol, or check for degenerate data.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/mixture/_base.py:269: ConvergenceWarning: Best performing initialization did not converge. Try different init parameters, or increase max_iter, tol, or check for degenerate data.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/mixture/_base.py:269: ConvergenceWarning: Best performing initialization did not converge. Try different init parameters, or increase max_iter, tol, or check for degenerate data.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/mixture/_base.py:269: ConvergenceWarning: Best performing initialization did not converge. Try different init parameters, or increase max_iter, tol, or check for degenerate data.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/mixture/_base.py:269: ConvergenceWarning: Best performing initialization did not converge. Try different init parameters, or increase max_iter, tol, or check for degenerate data.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/mixture/_base.py:269: ConvergenceWarning: Best performing initialization did not converge. Try different init parameters, or increase max_iter, tol, or check for degenerate data.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/mixture/_base.py:269: ConvergenceWarning: Best performing initialization did not converge. Try different init parameters, or increase max_iter, tol, or check for degenerate data.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/mixture/_base.py:269: ConvergenceWarning: Best performing initialization did not converge. Try different init parameters, or increase max_iter, tol, or check for degenerate data.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/mixture/_base.py:269: ConvergenceWarning: Best performing initialization did not converge. Try different init parameters, or increase max_iter, tol, or check for degenerate data.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/mixture/_base.py:269: ConvergenceWarning: Best performing initialization did not converge. Try different init parameters, or increase max_iter, tol, or check for degenerate data.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/mixture/_base.py:269: ConvergenceWarning: Best performing initialization did not converge. Try different init parameters, or increase max_iter, tol, or check for degenerate data.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/mixture/_base.py:269: ConvergenceWarning: Best performing initialization did not converge. Try different init parameters, or increase max_iter, tol, or check for degenerate data.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/mixture/_base.py:269: ConvergenceWarning: Best performing initialization did not converge. Try different init parameters, or increase max_iter, tol, or check for degenerate data.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/mixture/_base.py:269: ConvergenceWarning: Best performing initialization did not converge. Try different init parameters, or increase max_iter, tol, or check for degenerate data.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/mixture/_base.py:269: ConvergenceWarning: Best performing initialization did not converge. Try different init parameters, or increase max_iter, tol, or check for degenerate data.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/mixture/_base.py:269: ConvergenceWarning: Best performing initialization did not converge. Try different init parameters, or increase max_iter, tol, or check for degenerate data.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/mixture/_base.py:269: ConvergenceWarning: Best performing initialization did not converge. Try different init parameters, or increase max_iter, tol, or check for degenerate data.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/mixture/_base.py:269: ConvergenceWarning: Best performing initialization did not converge. Try different init parameters, or increase max_iter, tol, or check for degenerate data.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/mixture/_base.py:269: ConvergenceWarning: Best performing initialization did not converge. Try different init parameters, or increase max_iter, tol, or check for degenerate data.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/mixture/_base.py:269: ConvergenceWarning: Best performing initialization did not converge. Try different init parameters, or increase max_iter, tol, or check for degenerate data.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/mixture/_base.py:269: ConvergenceWarning: Best performing initialization did not converge. Try different init parameters, or increase max_iter, tol, or check for degenerate data.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/mixture/_base.py:269: ConvergenceWarning: Best performing initialization did not converge. Try different init parameters, or increase max_iter, tol, or check for degenerate data.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/mixture/_base.py:269: ConvergenceWarning: Best performing initialization did not converge. Try different init parameters, or increase max_iter, tol, or check for degenerate data.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/mixture/_base.py:269: ConvergenceWarning: Best performing initialization did not converge. Try different init parameters, or increase max_iter, tol, or check for degenerate data.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/mixture/_base.py:269: ConvergenceWarning: Best performing initialization did not converge. Try different init parameters, or increase max_iter, tol, or check for degenerate data.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/mixture/_base.py:269: ConvergenceWarning: Best performing initialization did not converge. Try different init parameters, or increase max_iter, tol, or check for degenerate data.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/mixture/_base.py:269: ConvergenceWarning: Best performing initialization did not converge. Try different init parameters, or increase max_iter, tol, or check for degenerate data.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/mixture/_base.py:269: ConvergenceWarning: Best performing initialization did not converge. Try different init parameters, or increase max_iter, tol, or check for degenerate data.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/mixture/_base.py:269: ConvergenceWarning: Best performing initialization did not converge. Try different init parameters, or increase max_iter, tol, or check for degenerate data.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/mixture/_base.py:269: ConvergenceWarning: Best performing initialization did not converge. Try different init parameters, or increase max_iter, tol, or check for degenerate data.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/mixture/_base.py:269: ConvergenceWarning: Best performing initialization did not converge. Try different init parameters, or increase max_iter, tol, or check for degenerate data.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/mixture/_base.py:269: ConvergenceWarning: Best performing initialization did not converge. Try different init parameters, or increase max_iter, tol, or check for degenerate data.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/mixture/_base.py:269: ConvergenceWarning: Best performing initialization did not converge. Try different init parameters, or increase max_iter, tol, or check for degenerate data.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/mixture/_base.py:269: ConvergenceWarning: Best performing initialization did not converge. Try different init parameters, or increase max_iter, tol, or check for degenerate data.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/mixture/_base.py:269: ConvergenceWarning: Best performing initialization did not converge. Try different init parameters, or increase max_iter, tol, or check for degenerate data.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/mixture/_base.py:269: ConvergenceWarning: Best performing initialization did not converge. Try different init parameters, or increase max_iter, tol, or check for degenerate data.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/mixture/_base.py:269: ConvergenceWarning: Best performing initialization did not converge. Try different init parameters, or increase max_iter, tol, or check for degenerate data.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/mixture/_base.py:269: ConvergenceWarning: Best performing initialization did not converge. Try different init parameters, or increase max_iter, tol, or check for degenerate data.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/mixture/_base.py:269: ConvergenceWarning: Best performing initialization did not converge. Try different init parameters, or increase max_iter, tol, or check for degenerate data.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/mixture/_base.py:269: ConvergenceWarning: Best performing initialization did not converge. Try different init parameters, or increase max_iter, tol, or check for degenerate data.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/mixture/_base.py:269: ConvergenceWarning: Best performing initialization did not converge. Try different init parameters, or increase max_iter, tol, or check for degenerate data.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/mixture/_base.py:269: ConvergenceWarning: Best performing initialization did not converge. Try different init parameters, or increase max_iter, tol, or check for degenerate data.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/mixture/_base.py:269: ConvergenceWarning: Best performing initialization did not converge. Try different init parameters, or increase max_iter, tol, or check for degenerate data.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/mixture/_base.py:269: ConvergenceWarning: Best performing initialization did not converge. Try different init parameters, or increase max_iter, tol, or check for degenerate data.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/mixture/_base.py:269: ConvergenceWarning: Best performing initialization did not converge. Try different init parameters, or increase max_iter, tol, or check for degenerate data.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/mixture/_base.py:269: ConvergenceWarning: Best performing initialization did not converge. Try different init parameters, or increase max_iter, tol, or check for degenerate data.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/mixture/_base.py:269: ConvergenceWarning: Best performing initialization did not converge. Try different init parameters, or increase max_iter, tol, or check for degenerate data.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/mixture/_base.py:269: ConvergenceWarning: Best performing initialization did not converge. Try different init parameters, or increase max_iter, tol, or check for degenerate data.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/mixture/_base.py:269: ConvergenceWarning: Best performing initialization did not converge. Try different init parameters, or increase max_iter, tol, or check for degenerate data.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/mixture/_base.py:269: ConvergenceWarning: Best performing initialization did not converge. Try different init parameters, or increase max_iter, tol, or check for degenerate data.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/mixture/_base.py:269: ConvergenceWarning: Best performing initialization did not converge. Try different init parameters, or increase max_iter, tol, or check for degenerate data.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/mixture/_base.py:269: ConvergenceWarning: Best performing initialization did not converge. Try different init parameters, or increase max_iter, tol, or check for degenerate data.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/mixture/_base.py:269: ConvergenceWarning: Best performing initialization did not converge. Try different init parameters, or increase max_iter, tol, or check for degenerate data.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/mixture/_base.py:269: ConvergenceWarning: Best performing initialization did not converge. Try different init parameters, or increase max_iter, tol, or check for degenerate data.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/mixture/_base.py:269: ConvergenceWarning: Best performing initialization did not converge. Try different init parameters, or increase max_iter, tol, or check for degenerate data.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/mixture/_base.py:269: ConvergenceWarning: Best performing initialization did not converge. Try different init parameters, or increase max_iter, tol, or check for degenerate data.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/mixture/_base.py:269: ConvergenceWarning: Best performing initialization did not converge. Try different init parameters, or increase max_iter, tol, or check for degenerate data.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/mixture/_base.py:269: ConvergenceWarning: Best performing initialization did not converge. Try different init parameters, or increase max_iter, tol, or check for degenerate data.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/mixture/_base.py:269: ConvergenceWarning: Best performing initialization did not converge. Try different init parameters, or increase max_iter, tol, or check for degenerate data.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/mixture/_base.py:269: ConvergenceWarning: Best performing initialization did not converge. Try different init parameters, or increase max_iter, tol, or check for degenerate data.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/mixture/_base.py:269: ConvergenceWarning: Best performing initialization did not converge. Try different init parameters, or increase max_iter, tol, or check for degenerate data.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/mixture/_base.py:269: ConvergenceWarning: Best performing initialization did not converge. Try different init parameters, or increase max_iter, tol, or check for degenerate data.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/mixture/_base.py:269: ConvergenceWarning: Best performing initialization did not converge. Try different init parameters, or increase max_iter, tol, or check for degenerate data.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/mixture/_base.py:269: ConvergenceWarning: Best performing initialization did not converge. Try different init parameters, or increase max_iter, tol, or check for degenerate data.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/mixture/_base.py:269: ConvergenceWarning: Best performing initialization did not converge. Try different init parameters, or increase max_iter, tol, or check for degenerate data.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/mixture/_base.py:269: ConvergenceWarning: Best performing initialization did not converge. Try different init parameters, or increase max_iter, tol, or check for degenerate data.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/mixture/_base.py:269: ConvergenceWarning: Best performing initialization did not converge. Try different init parameters, or increase max_iter, tol, or check for degenerate data.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/mixture/_base.py:269: ConvergenceWarning: Best performing initialization did not converge. Try different init parameters, or increase max_iter, tol, or check for degenerate data.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/mixture/_base.py:269: ConvergenceWarning: Best performing initialization did not converge. Try different init parameters, or increase max_iter, tol, or check for degenerate data.
#   warnings.warn(

# %%
plot_color_distribution(colors_by_year_bgm, classifier='GMM', how='not_sorted')

# %% [markdown]
# Отсортировано по яркости:

# %%
plot_color_distribution(colors_by_year_bgm, how='sorted', classifier='GMM')

# %%
rows = []
for year, colors in colors_by_year_bgm.items():
    color_list = list(colors.items())[:7]  # Оставляем только 7 цветов
    row = [year]
    for i, ((r, g, b), count) in enumerate(color_list):
        row.extend([r, g, b, count])  # Добавляем R, G, B и Count
    rows.append(row)
    
columns = ['year']
for i in range(1, 8):  # 7 цветов
    columns.extend([f'R{i}', f'G{i}', f'B{i}', f'Count{i}'])

# Создаем DataFrame
df = pd.DataFrame(rows, columns=columns)
df.head()
# Out:
#    year   R1   G1   B1  Count1   R2   G2   B2  Count2   R3  ...  B5  Count5  \
# 0  1938  187  193  181    4209  134  131  127    3502   34  ...  55    1773
# 1  1895   58   60   58    5745  212  121   72    5558   48  ...  21    4262
# 2  1902   19   27   35    6699   34   34   37    5286  179  ...  45    4358
# 3  1893  116   98   84    5873   36   15   14    5363    9  ...  35    4438
# 4  1888   65   61   53    3415  113   96   66    3336  134  ...  34    2058
#
#     R6   G6   B6  Count6   R7   G7   B7  Count7
# 0  227  202  107    1413   84  119  115    1327
# 1   77   97  131    4215   67   61   54    3840
# 2  211  174  147    4336  215  194  187    4202
# 3  168  154  178    4128  165  113   77    4076
# 4  178  144   87    1979  143   83   37     767
#
# [5 rows x 29 columns]

# %%
df_BGM = pd.merge(df_BGM, df, on='year', how='inner')
df_BGM.head()
# Out:
#    year  (126, 124, 113)  (51, 50, 49)  (125, 78, 53)  (199, 164, 114)  \
# 0  1882              471         11074            229             1465
# 1  1883              814           321           1403             1988
# 2  1885              577          6982            126              103
# 3  1886              307          5684            612              469
# 4  1888              333          2897           1588             1141
#
#    (201, 195, 184)  (21, 22, 24)  (55, 73, 93)   R1   G1  ...   B5  Count5  \
# 0              303         11192          1388   41   56  ...   22    2946
# 1              492           135            17  178  147  ...  198    1148
# 2              561          2532           481   66   72  ...  176    1061
# 3              154          4721           477   44   50  ...  128    2013
# 4               20          1710            20   65   61  ...   34    2058
#
#     R6   G6   B6  Count6   R7  G7  B7  Count7
# 0  195  161  125    2053   93  81  74    1882
# 1  195  148  122     576   56  43  46     521
# 2  137  122   99     912   84  59  43     350
# 3  146  161  147     532  121  77  57     299
# 4  178  144   87    1979  143  83  37     767
#
# [5 rows x 36 columns]

# %%
df_counts['year'] = df_counts['year'].astype(int)
df_BGM = pd.merge(df_BGM, df_counts, on='year', how='inner')

# %%
df_BGM.head()
# Out:
#    year  (126, 124, 113)  (51, 50, 49)  (125, 78, 53)  (199, 164, 114)  \
# 0  1882              471         11074            229             1465
# 1  1883              814           321           1403             1988
# 2  1885              577          6982            126              103
# 3  1886              307          5684            612              469
# 4  1888              333          2897           1588             1141
#
#    (201, 195, 184)  (21, 22, 24)  (55, 73, 93)   R1   G1  ...  Count5   R6  \
# 0              303         11192          1388   41   56  ...    2946  195
# 1              492           135            17  178  147  ...    1148  195
# 2              561          2532           481   66   72  ...    1061  137
# 3              154          4721           477   44   50  ...    2013  146
# 4               20          1710            20   65   61  ...    2058  178
#
#     G6   B6  Count6   R7  G7  B7  Count7  count
# 0  161  125    2053   93  81  74    1882      2
# 1  148  122     576   56  43  46     521      1
# 2  122   99     912   84  59  43     350      1
# 3  161  147     532  121  77  57     299      1
# 4  144   87    1979  143  83  37     767      1
#
# [5 rows x 37 columns]

# %%
df_BGM.to_csv('data_BGM.csv', index=False)
